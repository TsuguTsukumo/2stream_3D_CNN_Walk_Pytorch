# %% [markdown]
# # 推論フェーズ

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import cv2
import numpy as np
import yaml
import os
import sys
import pandas as pd
from IPython.display import display
from typing import Any, Callable, Dict, Optional, Type, Tuple

print(torch.cuda.is_available())
# Out:
# True

# %%
# --- パス設定 ---
# プロジェクトの基点となるパスを定義
project_base_path = '/workspace/project'

# このパスがPythonの検索パスリスト (sys.path) になければ追加
if project_base_path not in sys.path:
    sys.path.append(project_base_path)
    print(f"'{project_base_path}' を sys.path に追加しました。")

# --- 自作モジュールのインポート ---
try:
    # データローダーのインポート
    from project.dataloader.data_loader_multi import MultiData
    
    # モデル定義のインポート
    from project.models.make_model import single, early_fusion, late_fusion, slow_fusion

    print("\n✅ 必要な全てのモジュールが正常にインポートされました。")

except ImportError as e:
    print(f"\n❌ エラー: インポートに失敗しました: {e}")
    print("\n【トラブルシューティング】")
    print("1. `project_base_path` のパスが正しいか確認してください。")
    print("2. プロジェクト内のディレクトリに `__init__.py` ファイルが存在するか確認してください。")
    # ここで処理を停止させる
    sys.exit()
# Out:
# ✅ 必要な全てのモジュールが正常にインポートされました。

# %%
# ==============================================================================
# ## 2. 設定：ConfigとHParamsの準備
# ==============================================================================
print("\nステップ2: 設定ファイル (config.yaml) を読み込みます...")

# 学習済みモデルが含まれるディレクトリのルートパス
model_root = '/workspace/project/logs/resnet/early_fusion/2025-02-03/05-15-18'

# config.yaml のパス
config_path = os.path.join(model_root, '.hydra/config.yaml')

def load_config(config_path):
    """YAMLファイルを読み込む関数"""
    try:
        with open(config_path, 'r') as f:
            config = yaml.safe_load(f)
        print(f"設定ファイル '{config_path}' を正常に読み込みました。")
        return config
    except FileNotFoundError:
        print(f"❌ エラー: 設定ファイル '{config_path}' が見つかりません。")
        sys.exit()

# --- HParamsクラスの定義（修正版） ---
class HParams:
    """config.yamlの階層構造を模倣するクラス"""
    def __init__(self, data_config, model_config, train_config):
        self.data = type('DataConfig', (object,), data_config)()
        self.model = type('ModelConfig', (object,), model_config)()
        self.train = type('TrainConfig', (object,), train_config)()

# --- 設定の読み込みとHParamsのインスタンス化（修正版） ---
config_data = load_config(config_path)
try:
    hparams = HParams(
        config_data['data'], 
        config_data['model'], 
        config_data['train']
    )
    print("✅ HParamsオブジェクトを正常に作成しました。")
except KeyError as e:
    print(f"❌ エラー: config.yaml に必要なキー {e} が見つかりません。")
    sys.exit()
# Out:
# ステップ2: 設定ファイル (config.yaml) を読み込みます...
# 設定ファイル '/workspace/project/logs/resnet/early_fusion/2025-02-03/05-15-18/.hydra/config.yaml' を正常に読み込みました。
# ✅ HParamsオブジェクトを正常に作成しました。

# %%
# ==============================================================================
# ## 3. モデルの準備：インスタンス化と学習済み重みのロード
# ==============================================================================
print("\nステップ3: モデルを準備します...")

# --- 設定値の取得 ---
fusion_type = hparams.train.experiment
device_ids = config_data['device']['device'] # configから直接取得
model_path = os.path.join(model_root, 'fold1/version_0/checkpoints/3-0.68-0.5855.ckpt')

# --- デバイスの設定 ---
if torch.cuda.is_available():
    device = torch.device(f"cuda:{device_ids}")
    print(f"GPU {device_ids} を使用します。")
else:
    device = torch.device("cpu")
    print("GPUが利用できないため、CPUを使用します。")

# --- モデルのインスタンス化 ---
if fusion_type == 'single':
    model = single(hparams).to(device)
elif fusion_type == 'early_fusion':
    model = early_fusion(hparams).to(device)
elif fusion_type == 'late_fusion':
    model = late_fusion(hparams).to(device)
elif fusion_type == 'slow_fusion':
    model = slow_fusion(hparams).to(device)
else:
    raise ValueError(f"不明なフュージョンタイプ: {fusion_type}")
print(f"'{fusion_type}' モデルをインスタンス化し、デバイス '{device}' に配置しました。")

# --- 学習済み重みのロード（最終修正版） ---
try:
    checkpoint = torch.load(model_path, map_location=device, weights_only=False)
    
    if 'state_dict' in checkpoint:
        original_state_dict = checkpoint['state_dict']
        new_state_dict = {}
        # キーの先頭にある "model." プレフィックスを削除
        for k, v in original_state_dict.items():
            if k.startswith("model."):
                new_key = k[len("model."):]
            else:
                new_key = k
            new_state_dict[new_key] = v
        
        model.load_state_dict(new_state_dict)
    else:
        model.load_state_dict(checkpoint)
        
    model.eval() # モデルを評価モードに設定
    print("✅ 学習済み重みをモデルに正常にロードしました。")

except Exception as e:
    import traceback
    print(f"\n❌ エラー: モデルの重みロード中にエラーが発生しました: {e}")
    print(traceback.format_exc())
    sys.exit()
# Out:
# ステップ3: モデルを準備します...
# GPU 1 を使用します。
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# 'early_fusion' モデルをインスタンス化し、デバイス 'cuda:1' に配置しました。
# ✅ 学習済み重みをモデルに正常にロードしました。

# %%
# ==============================================================================
# ## 4. 推論の実行
# ==============================================================================
print("\nステップ4: 推論を実行します...")

# --- 4.1. 推論対象の設定 ---
# ここで推論したいデータの場所とfoldを指定してください
AP_DATA_ROOT = '/workspace/data/analysis/ex_20250116_ap_organaized_split'
LAT_DATA_ROOT = '/workspace/data/analysis/ex_20250116_lat_organaized_split'
TARGET_FOLD = 'fold1'  # 'fold1', 'fold2' などに変更してテストできます
INFERENCE_BATCH_SIZE = 4
# -----------------------------

# --- 4.2. データローダーの準備 ---
# hparamsオブジェクトの設定を、推論用に上書き
hparams.data.ap_data_path = AP_DATA_ROOT
hparams.data.lat_data_path = LAT_DATA_ROOT
hparams.train.current_fold = TARGET_FOLD
hparams.data.batch_size = INFERENCE_BATCH_SIZE
hparams.data.num_workers = 0 

# DataModuleをインスタンス化
datamodule = MultiData(hparams)

# 'test'ステージのデータセットを準備するようDataModuleに指示
print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
datamodule.setup(stage='test') 

# testデータローダーを取得
test_loader = datamodule.test_dataloader()
print("データローダーの準備が完了しました。")

# ### 4.3. 推論ループ (最終確定版 v2：バッチサイズ=1対応) ###

results = {}
# 勾配計算を無効にする
with torch.no_grad():
    # データローダーからバッチを一つずつ取り出してループ
    for i, batch in enumerate(test_loader):
        print(f"\n--- [バッチ {i+1}] 推論中 ---")
        
        # batchは辞書が一つだけ入ったタプルなので、まず[0]で辞書を取り出す
        batch_dict = batch[0]
        
        # 次に、辞書からキーを使って各データを取得
        inputs_front = batch_dict["ap"]["video"].to(device)
        inputs_side = batch_dict["lat"]["video"].to(device)
        video_names = batch_dict["ap"]["video_name"]
        
        # モデルで推論
        outputs = model(inputs_front, inputs_side)
        
        # ★★★★★ 修正ポイント ★★★★★
        # .squeeze() を削除して、バッチサイズが1の場合でもエラーにならないようにします。
        
        # Sigmoidを適用して「クラス1である確率」を計算
        prob_for_class_1 = torch.sigmoid(outputs) # .squeeze() を削除！
        
        # 確率が0.5の閾値でクラスに分類 (0か1か)
        predicted_indices = (prob_for_class_1 > 0.5).long()
        
        # ★★★★★ 修正ここまで ★★★★★
        
        # バッチ内の各データの結果を保存・表示
        for idx in range(len(video_names)):
            video_name = os.path.basename(video_names[idx])
            
            # テンソルの形状が(B, 1)なので、[idx]でアクセスすると要素1つのテンソルが返る
            # .item()でPythonの数値として取り出す
            pred_class = predicted_indices[idx].item()
            prob1 = prob_for_class_1[idx].item()
            
            # 予測したクラスに対する確信度を計算
            confidence = prob1 if pred_class == 1 else 1 - prob1

            results[video_name] = {
                'prediction': pred_class,
                'confidence': f"{confidence:.4f}",
                'prob_for_class_1': f"{prob1:.4f}"
            }
            print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")

# --- 4.4. 結果の集計と表示 ---
print("\n\n==================== 全ての推論結果 ====================")
if not results:
    print("推論が実行された動画はありませんでした。")
else:
    results_df = pd.DataFrame.from_dict(results, orient='index')
    results_df.index.name = 'Video Filename'
    results_df = results_df.reset_index()
    display(results_df)
# Out:
# ステップ4: 推論を実行します...
# 'fold1' の検証(val)データを読み込んでいます...
# データローダーの準備が完了しました。
#
# --- [バッチ 1] 推論中 ---
#   - ASD_20171211_10_1-6.mp4: Logit: -0.0782 -> P(class 1)=0.4804 -> 予測クラス: 0 (確信度: 51.96%)
#   - ASD_20171211_10_2-6.mp4: Logit: -0.2865 -> P(class 1)=0.4288 -> 予測クラス: 0 (確信度: 57.12%)
#   - ASD_20171211_10_3-6.mp4: Logit: -0.1337 -> P(class 1)=0.4666 -> 予測クラス: 0 (確信度: 53.34%)
#   - ASD_20171211_10_4-6.mp4: Logit: 0.0273 -> P(class 1)=0.5068 -> 予測クラス: 1 (確信度: 50.68%)
#
# --- [バッチ 2] 推論中 ---
#   - ASD_20171211_10_5-6.mp4: Logit: -0.2262 -> P(class 1)=0.4437 -> 予測クラス: 0 (確信度: 55.63%)
#   - ASD_20171211_10_6-6.mp4: Logit: -0.1527 -> P(class 1)=0.4619 -> 予測クラス: 0 (確信度: 53.81%)
#   - ASD_20171211_11_1-1.mp4: Logit: -0.1565 -> P(class 1)=0.4609 -> 予測クラス: 0 (確信度: 53.91%)
#   - ASD_20171211_12_1-8.mp4: Logit: -0.1986 -> P(class 1)=0.4505 -> 予測クラス: 0 (確信度: 54.95%)
#
# --- [バッチ 3] 推論中 ---
#   - ASD_20171211_12_2-8.mp4: Logit: -0.1417 -> P(class 1)=0.4646 -> 予測クラス: 0 (確信度: 53.54%)
#   - ASD_20171211_12_3-8.mp4: Logit: 0.1075 -> P(class 1)=0.5269 -> 予測クラス: 1 (確信度: 52.69%)
#   - ASD_20171211_12_4-8.mp4: Logit: -0.0834 -> P(class 1)=0.4792 -> 予測クラス: 0 (確信度: 52.08%)
#   - ASD_20171211_12_5-8.mp4: Logit: 0.0722 -> P(class 1)=0.5180 -> 予測クラス: 1 (確信度: 51.80%)
#
# --- [バッチ 4] 推論中 ---
#   - ASD_20171211_12_6-8.mp4: Logit: -0.1301 -> P(class 1)=0.4675 -> 予測クラス: 0 (確信度: 53.25%)
#   - ASD_20171211_12_7-8.mp4: Logit: -0.1195 -> P(class 1)=0.4702 -> 予測クラス: 0 (確信度: 52.98%)
#   - ASD_20171211_12_8-8.mp4: Logit: -0.3059 -> P(class 1)=0.4241 -> 予測クラス: 0 (確信度: 57.59%)
#   - ASD_20171211_13_1-6.mp4: Logit: -0.0727 -> P(class 1)=0.4818 -> 予測クラス: 0 (確信度: 51.82%)
#
# --- [バッチ 5] 推論中 ---
#   - ASD_20171211_13_2-6.mp4: Logit: -0.0130 -> P(class 1)=0.4967 -> 予測クラス: 0 (確信度: 50.33%)
#   - ASD_20171211_13_3-6.mp4: Logit: -0.2645 -> P(class 1)=0.4343 -> 予測クラス: 0 (確信度: 56.57%)
#   - ASD_20171211_13_4-6.mp4: Logit: -0.2188 -> P(class 1)=0.4455 -> 予測クラス: 0 (確信度: 55.45%)
#   - ASD_20171211_13_5-6.mp4: Logit: -0.1185 -> P(class 1)=0.4704 -> 予測クラス: 0 (確信度: 52.96%)
#
# --- [バッチ 6] 推論中 ---
#   - ASD_20171211_13_6-6.mp4: Logit: -0.3354 -> P(class 1)=0.4169 -> 予測クラス: 0 (確信度: 58.31%)
#   - ASD_20171211_14_1-7.mp4: Logit: 0.0162 -> P(class 1)=0.5040 -> 予測クラス: 1 (確信度: 50.40%)
#   - ASD_20171211_14_2-7.mp4: Logit: -0.0737 -> P(class 1)=0.4816 -> 予測クラス: 0 (確信度: 51.84%)
#   - ASD_20171211_14_3-7.mp4: Logit: -0.0976 -> P(class 1)=0.4756 -> 予測クラス: 0 (確信度: 52.44%)
#
# --- [バッチ 7] 推論中 ---
#   - ASD_20171211_14_4-7.mp4: Logit: -0.1720 -> P(class 1)=0.4571 -> 予測クラス: 0 (確信度: 54.29%)
#   - ASD_20171211_14_5-7.mp4: Logit: -0.2193 -> P(class 1)=0.4454 -> 予測クラス: 0 (確信度: 55.46%)
#   - ASD_20171211_14_6-7.mp4: Logit: -0.2599 -> P(class 1)=0.4354 -> 予測クラス: 0 (確信度: 56.46%)
#   - ASD_20171211_14_7-7.mp4: Logit: 0.0140 -> P(class 1)=0.5035 -> 予測クラス: 1 (確信度: 50.35%)
#
# --- [バッチ 8] 推論中 ---
#   - ASD_20171211_15_1-9.mp4: Logit: -0.1638 -> P(class 1)=0.4591 -> 予測クラス: 0 (確信度: 54.09%)
#   - ASD_20171211_15_2-9.mp4: Logit: -0.2744 -> P(class 1)=0.4318 -> 予測クラス: 0 (確信度: 56.82%)
#   - ASD_20171211_15_3-9.mp4: Logit: 0.0877 -> P(class 1)=0.5219 -> 予測クラス: 1 (確信度: 52.19%)
#   - ASD_20171211_15_4-9.mp4: Logit: -0.1428 -> P(class 1)=0.4644 -> 予測クラス: 0 (確信度: 53.56%)
#
# --- [バッチ 9] 推論中 ---
#   - ASD_20171211_15_5-9.mp4: Logit: -0.0704 -> P(class 1)=0.4824 -> 予測クラス: 0 (確信度: 51.76%)
#   - ASD_20171211_15_6-9.mp4: Logit: -0.2328 -> P(class 1)=0.4421 -> 予測クラス: 0 (確信度: 55.79%)
#   - ASD_20171211_15_7-9.mp4: Logit: -0.1723 -> P(class 1)=0.4570 -> 予測クラス: 0 (確信度: 54.30%)
#   - ASD_20171211_15_8-9.mp4: Logit: -0.0628 -> P(class 1)=0.4843 -> 予測クラス: 0 (確信度: 51.57%)
#
# --- [バッチ 10] 推論中 ---
#   - ASD_20171211_15_9-9.mp4: Logit: -0.1535 -> P(class 1)=0.4617 -> 予測クラス: 0 (確信度: 53.83%)
#   - ASD_20171211_16_1-10.mp4: Logit: -0.1937 -> P(class 1)=0.4517 -> 予測クラス: 0 (確信度: 54.83%)
#   - ASD_20171211_16_10-10.mp4: Logit: -0.0957 -> P(class 1)=0.4761 -> 予測クラス: 0 (確信度: 52.39%)
#   - ASD_20171211_16_2-10.mp4: Logit: -0.2084 -> P(class 1)=0.4481 -> 予測クラス: 0 (確信度: 55.19%)
#
# --- [バッチ 11] 推論中 ---
#   - ASD_20171211_16_3-10.mp4: Logit: -0.1515 -> P(class 1)=0.4622 -> 予測クラス: 0 (確信度: 53.78%)
#   - ASD_20171211_16_4-10.mp4: Logit: -0.0557 -> P(class 1)=0.4861 -> 予測クラス: 0 (確信度: 51.39%)
#   - ASD_20171211_16_5-10.mp4: Logit: -0.1738 -> P(class 1)=0.4567 -> 予測クラス: 0 (確信度: 54.33%)
#   - ASD_20171211_16_6-10.mp4: Logit: -0.0049 -> P(class 1)=0.4988 -> 予測クラス: 0 (確信度: 50.12%)
#
# --- [バッチ 12] 推論中 ---
#   - ASD_20171211_16_7-10.mp4: Logit: -0.0209 -> P(class 1)=0.4948 -> 予測クラス: 0 (確信度: 50.52%)
#   - ASD_20171211_16_8-10.mp4: Logit: -0.2046 -> P(class 1)=0.4490 -> 予測クラス: 0 (確信度: 55.10%)
#   - ASD_20171211_16_9-10.mp4: Logit: -0.0579 -> P(class 1)=0.4855 -> 予測クラス: 0 (確信度: 51.45%)
#   - ASD_20171211_17_1-7.mp4: Logit: -0.0513 -> P(class 1)=0.4872 -> 予測クラス: 0 (確信度: 51.28%)
#
# --- [バッチ 13] 推論中 ---
#   - ASD_20171211_17_2-7.mp4: Logit: -0.0873 -> P(class 1)=0.4782 -> 予測クラス: 0 (確信度: 52.18%)
#   - ASD_20171211_17_3-7.mp4: Logit: -0.1907 -> P(class 1)=0.4525 -> 予測クラス: 0 (確信度: 54.75%)
#   - ASD_20171211_17_4-7.mp4: Logit: -0.1854 -> P(class 1)=0.4538 -> 予測クラス: 0 (確信度: 54.62%)
#   - ASD_20171211_17_5-7.mp4: Logit: -0.1175 -> P(class 1)=0.4707 -> 予測クラス: 0 (確信度: 52.93%)
#
# --- [バッチ 14] 推論中 ---
#   - ASD_20171211_17_6-7.mp4: Logit: -0.2035 -> P(class 1)=0.4493 -> 予測クラス: 0 (確信度: 55.07%)
#   - ASD_20171211_17_7-7.mp4: Logit: -0.0349 -> P(class 1)=0.4913 -> 予測クラス: 0 (確信度: 50.87%)
#   - ASD_20171211_18_1-9.mp4: Logit: -0.0989 -> P(class 1)=0.4753 -> 予測クラス: 0 (確信度: 52.47%)
#   - ASD_20171211_18_2-9.mp4: Logit: -0.1164 -> P(class 1)=0.4709 -> 予測クラス: 0 (確信度: 52.91%)
#
# --- [バッチ 15] 推論中 ---
#   - ASD_20171211_18_3-9.mp4: Logit: 0.2050 -> P(class 1)=0.5511 -> 予測クラス: 1 (確信度: 55.11%)
#   - ASD_20171211_18_4-9.mp4: Logit: 0.0356 -> P(class 1)=0.5089 -> 予測クラス: 1 (確信度: 50.89%)
#   - ASD_20171211_18_5-9.mp4: Logit: -0.1732 -> P(class 1)=0.4568 -> 予測クラス: 0 (確信度: 54.32%)
#   - ASD_20171211_18_6-9.mp4: Logit: -0.1423 -> P(class 1)=0.4645 -> 予測クラス: 0 (確信度: 53.55%)
#
# --- [バッチ 16] 推論中 ---
#   - ASD_20171211_18_7-9.mp4: Logit: -0.1053 -> P(class 1)=0.4737 -> 予測クラス: 0 (確信度: 52.63%)
#   - ASD_20171211_18_8-9.mp4: Logit: 0.0227 -> P(class 1)=0.5057 -> 予測クラス: 1 (確信度: 50.57%)
#   - ASD_20171211_18_9-9.mp4: Logit: -0.0675 -> P(class 1)=0.4831 -> 予測クラス: 0 (確信度: 51.69%)
#   - ASD_20171211_19_1-6.mp4: Logit: -0.0026 -> P(class 1)=0.4994 -> 予測クラス: 0 (確信度: 50.06%)
#
# --- [バッチ 17] 推論中 ---
#   - ASD_20171211_19_2-6.mp4: Logit: -0.2204 -> P(class 1)=0.4451 -> 予測クラス: 0 (確信度: 55.49%)
#   - ASD_20171211_19_3-6.mp4: Logit: -0.0891 -> P(class 1)=0.4777 -> 予測クラス: 0 (確信度: 52.23%)
#   - ASD_20171211_19_4-6.mp4: Logit: -0.1650 -> P(class 1)=0.4588 -> 予測クラス: 0 (確信度: 54.12%)
#   - ASD_20171211_19_5-6.mp4: Logit: -0.3994 -> P(class 1)=0.4015 -> 予測クラス: 0 (確信度: 59.85%)
#
# --- [バッチ 18] 推論中 ---
#   - ASD_20171211_19_6-6.mp4: Logit: -0.3783 -> P(class 1)=0.4065 -> 予測クラス: 0 (確信度: 59.35%)
#   - ASD_20171211_1_1-6.mp4: Logit: 0.1033 -> P(class 1)=0.5258 -> 予測クラス: 1 (確信度: 52.58%)
#   - ASD_20171211_1_2-6.mp4: Logit: -0.2356 -> P(class 1)=0.4414 -> 予測クラス: 0 (確信度: 55.86%)
#   - ASD_20171211_1_3-6.mp4: Logit: -0.1425 -> P(class 1)=0.4644 -> 予測クラス: 0 (確信度: 53.56%)
#
# --- [バッチ 19] 推論中 ---
#   - ASD_20171211_1_4-6.mp4: Logit: -0.1176 -> P(class 1)=0.4706 -> 予測クラス: 0 (確信度: 52.94%)
#   - ASD_20171211_1_5-6.mp4: Logit: -0.3161 -> P(class 1)=0.4216 -> 予測クラス: 0 (確信度: 57.84%)
#   - ASD_20171211_1_6-6.mp4: Logit: -0.2354 -> P(class 1)=0.4414 -> 予測クラス: 0 (確信度: 55.86%)
#   - ASD_20171211_20_1-6.mp4: Logit: 0.0572 -> P(class 1)=0.5143 -> 予測クラス: 1 (確信度: 51.43%)
#
# --- [バッチ 20] 推論中 ---
#   - ASD_20171211_20_2-6.mp4: Logit: -0.0619 -> P(class 1)=0.4845 -> 予測クラス: 0 (確信度: 51.55%)
#   - ASD_20171211_20_3-6.mp4: Logit: -0.0120 -> P(class 1)=0.4970 -> 予測クラス: 0 (確信度: 50.30%)
#   - ASD_20171211_20_4-6.mp4: Logit: -0.0681 -> P(class 1)=0.4830 -> 予測クラス: 0 (確信度: 51.70%)
#   - ASD_20171211_20_5-6.mp4: Logit: -0.2568 -> P(class 1)=0.4362 -> 予測クラス: 0 (確信度: 56.38%)
#
# --- [バッチ 21] 推論中 ---
#   - ASD_20171211_20_6-6.mp4: Logit: -0.1426 -> P(class 1)=0.4644 -> 予測クラス: 0 (確信度: 53.56%)
#   - ASD_20171211_21_1-2.mp4: Logit: -0.1359 -> P(class 1)=0.4661 -> 予測クラス: 0 (確信度: 53.39%)
#   - ASD_20171211_21_2-2.mp4: Logit: -0.0542 -> P(class 1)=0.4864 -> 予測クラス: 0 (確信度: 51.36%)
#   - ASD_20171211_22_1-10.mp4: Logit: -0.1326 -> P(class 1)=0.4669 -> 予測クラス: 0 (確信度: 53.31%)
#
# --- [バッチ 22] 推論中 ---
#   - ASD_20171211_22_10-10.mp4: Logit: -0.1313 -> P(class 1)=0.4672 -> 予測クラス: 0 (確信度: 53.28%)
#   - ASD_20171211_22_2-10.mp4: Logit: -0.2588 -> P(class 1)=0.4357 -> 予測クラス: 0 (確信度: 56.43%)
#   - ASD_20171211_22_3-10.mp4: Logit: -0.1701 -> P(class 1)=0.4576 -> 予測クラス: 0 (確信度: 54.24%)
#   - ASD_20171211_22_4-10.mp4: Logit: -0.0251 -> P(class 1)=0.4937 -> 予測クラス: 0 (確信度: 50.63%)
#
# --- [バッチ 23] 推論中 ---
#   - ASD_20171211_22_5-10.mp4: Logit: 0.0339 -> P(class 1)=0.5085 -> 予測クラス: 1 (確信度: 50.85%)
#   - ASD_20171211_22_6-10.mp4: Logit: 0.1049 -> P(class 1)=0.5262 -> 予測クラス: 1 (確信度: 52.62%)
#   - ASD_20171211_22_7-10.mp4: Logit: -0.1851 -> P(class 1)=0.4539 -> 予測クラス: 0 (確信度: 54.61%)
#   - ASD_20171211_22_8-10.mp4: Logit: -0.0688 -> P(class 1)=0.4828 -> 予測クラス: 0 (確信度: 51.72%)
#
# --- [バッチ 24] 推論中 ---
#   - ASD_20171211_22_9-10.mp4: Logit: -0.1029 -> P(class 1)=0.4743 -> 予測クラス: 0 (確信度: 52.57%)
#   - ASD_20171211_23_1-1.mp4: Logit: 0.0024 -> P(class 1)=0.5006 -> 予測クラス: 1 (確信度: 50.06%)
#   - ASD_20171211_24_1-6.mp4: Logit: 0.0675 -> P(class 1)=0.5169 -> 予測クラス: 1 (確信度: 51.69%)
#   - ASD_20171211_24_2-6.mp4: Logit: -0.3101 -> P(class 1)=0.4231 -> 予測クラス: 0 (確信度: 57.69%)
#
# --- [バッチ 25] 推論中 ---
#   - ASD_20171211_24_3-6.mp4: Logit: -0.0980 -> P(class 1)=0.4755 -> 予測クラス: 0 (確信度: 52.45%)
#   - ASD_20171211_24_4-6.mp4: Logit: -0.2259 -> P(class 1)=0.4438 -> 予測クラス: 0 (確信度: 55.62%)
#   - ASD_20171211_24_5-6.mp4: Logit: -0.1680 -> P(class 1)=0.4581 -> 予測クラス: 0 (確信度: 54.19%)
#   - ASD_20171211_24_6-6.mp4: Logit: -0.0152 -> P(class 1)=0.4962 -> 予測クラス: 0 (確信度: 50.38%)
#
# --- [バッチ 26] 推論中 ---
#   - ASD_20171211_25_1-6.mp4: Logit: -0.0472 -> P(class 1)=0.4882 -> 予測クラス: 0 (確信度: 51.18%)
#   - ASD_20171211_25_2-6.mp4: Logit: -0.0419 -> P(class 1)=0.4895 -> 予測クラス: 0 (確信度: 51.05%)
#   - ASD_20171211_25_3-6.mp4: Logit: -0.0272 -> P(class 1)=0.4932 -> 予測クラス: 0 (確信度: 50.68%)
#   - ASD_20171211_25_4-6.mp4: Logit: -0.0548 -> P(class 1)=0.4863 -> 予測クラス: 0 (確信度: 51.37%)
#
# --- [バッチ 27] 推論中 ---
#   - ASD_20171211_25_5-6.mp4: Logit: -0.1729 -> P(class 1)=0.4569 -> 予測クラス: 0 (確信度: 54.31%)
#   - ASD_20171211_25_6-6.mp4: Logit: -0.1749 -> P(class 1)=0.4564 -> 予測クラス: 0 (確信度: 54.36%)
#   - ASD_20171211_26_1-2.mp4: Logit: -0.2122 -> P(class 1)=0.4471 -> 予測クラス: 0 (確信度: 55.29%)
#   - ASD_20171211_26_2-2.mp4: Logit: -0.1224 -> P(class 1)=0.4694 -> 予測クラス: 0 (確信度: 53.06%)
#
# --- [バッチ 28] 推論中 ---
#   - ASD_20171211_27_1-9.mp4: Logit: -0.1636 -> P(class 1)=0.4592 -> 予測クラス: 0 (確信度: 54.08%)
#   - ASD_20171211_27_2-9.mp4: Logit: -0.0863 -> P(class 1)=0.4785 -> 予測クラス: 0 (確信度: 52.15%)
#   - ASD_20171211_27_3-9.mp4: Logit: 0.0402 -> P(class 1)=0.5101 -> 予測クラス: 1 (確信度: 51.01%)
#   - ASD_20171211_27_4-9.mp4: Logit: -0.1464 -> P(class 1)=0.4635 -> 予測クラス: 0 (確信度: 53.65%)
#
# --- [バッチ 29] 推論中 ---
#   - ASD_20171211_27_5-9.mp4: Logit: -0.0934 -> P(class 1)=0.4767 -> 予測クラス: 0 (確信度: 52.33%)
#   - ASD_20171211_27_6-9.mp4: Logit: -0.0989 -> P(class 1)=0.4753 -> 予測クラス: 0 (確信度: 52.47%)
#   - ASD_20171211_27_7-9.mp4: Logit: 0.0199 -> P(class 1)=0.5050 -> 予測クラス: 1 (確信度: 50.50%)
#   - ASD_20171211_27_8-9.mp4: Logit: -0.0821 -> P(class 1)=0.4795 -> 予測クラス: 0 (確信度: 52.05%)
#
# --- [バッチ 30] 推論中 ---
#   - ASD_20171211_27_9-9.mp4: Logit: -0.1817 -> P(class 1)=0.4547 -> 予測クラス: 0 (確信度: 54.53%)
#   - ASD_20171211_28_1-6.mp4: Logit: -0.0611 -> P(class 1)=0.4847 -> 予測クラス: 0 (確信度: 51.53%)
#   - ASD_20171211_28_2-6.mp4: Logit: -0.0428 -> P(class 1)=0.4893 -> 予測クラス: 0 (確信度: 51.07%)
#   - ASD_20171211_28_3-6.mp4: Logit: -0.1862 -> P(class 1)=0.4536 -> 予測クラス: 0 (確信度: 54.64%)
#
# --- [バッチ 31] 推論中 ---
#   - ASD_20171211_28_4-6.mp4: Logit: -0.1593 -> P(class 1)=0.4602 -> 予測クラス: 0 (確信度: 53.98%)
#   - ASD_20171211_28_5-6.mp4: Logit: -0.1845 -> P(class 1)=0.4540 -> 予測クラス: 0 (確信度: 54.60%)
#   - ASD_20171211_28_6-6.mp4: Logit: -0.2223 -> P(class 1)=0.4446 -> 予測クラス: 0 (確信度: 55.54%)
#   - ASD_20171211_29_1-6.mp4: Logit: -0.0049 -> P(class 1)=0.4988 -> 予測クラス: 0 (確信度: 50.12%)
#
# --- [バッチ 32] 推論中 ---
#   - ASD_20171211_29_2-6.mp4: Logit: -0.0655 -> P(class 1)=0.4836 -> 予測クラス: 0 (確信度: 51.64%)
#   - ASD_20171211_29_3-6.mp4: Logit: 0.0566 -> P(class 1)=0.5141 -> 予測クラス: 1 (確信度: 51.41%)
#   - ASD_20171211_29_4-6.mp4: Logit: -0.2007 -> P(class 1)=0.4500 -> 予測クラス: 0 (確信度: 55.00%)
#   - ASD_20171211_29_5-6.mp4: Logit: 0.1487 -> P(class 1)=0.5371 -> 予測クラス: 1 (確信度: 53.71%)
#
# --- [バッチ 33] 推論中 ---
#   - ASD_20171211_29_6-6.mp4: Logit: -0.2394 -> P(class 1)=0.4404 -> 予測クラス: 0 (確信度: 55.96%)
#   - ASD_20171211_2_1-7.mp4: Logit: -0.0342 -> P(class 1)=0.4915 -> 予測クラス: 0 (確信度: 50.85%)
#   - ASD_20171211_2_2-7.mp4: Logit: -0.2753 -> P(class 1)=0.4316 -> 予測クラス: 0 (確信度: 56.84%)
#   - ASD_20171211_2_3-7.mp4: Logit: -0.0361 -> P(class 1)=0.4910 -> 予測クラス: 0 (確信度: 50.90%)
#
# --- [バッチ 34] 推論中 ---
#   - ASD_20171211_2_4-7.mp4: Logit: -0.0654 -> P(class 1)=0.4837 -> 予測クラス: 0 (確信度: 51.63%)
#   - ASD_20171211_2_5-7.mp4: Logit: -0.2054 -> P(class 1)=0.4488 -> 予測クラス: 0 (確信度: 55.12%)
#   - ASD_20171211_2_6-7.mp4: Logit: -0.1070 -> P(class 1)=0.4733 -> 予測クラス: 0 (確信度: 52.67%)
#   - ASD_20171211_2_7-7.mp4: Logit: -0.0524 -> P(class 1)=0.4869 -> 予測クラス: 0 (確信度: 51.31%)
#
# --- [バッチ 35] 推論中 ---
#   - ASD_20171211_30_1-8.mp4: Logit: -0.1570 -> P(class 1)=0.4608 -> 予測クラス: 0 (確信度: 53.92%)
#   - ASD_20171211_30_2-8.mp4: Logit: -0.0288 -> P(class 1)=0.4928 -> 予測クラス: 0 (確信度: 50.72%)
#   - ASD_20171211_30_3-8.mp4: Logit: 0.0927 -> P(class 1)=0.5232 -> 予測クラス: 1 (確信度: 52.32%)
#   - ASD_20171211_30_4-8.mp4: Logit: -0.0177 -> P(class 1)=0.4956 -> 予測クラス: 0 (確信度: 50.44%)
#
# --- [バッチ 36] 推論中 ---
#   - ASD_20171211_30_5-8.mp4: Logit: -0.1560 -> P(class 1)=0.4611 -> 予測クラス: 0 (確信度: 53.89%)
#   - ASD_20171211_30_6-8.mp4: Logit: -0.1276 -> P(class 1)=0.4682 -> 予測クラス: 0 (確信度: 53.18%)
#   - ASD_20171211_30_7-8.mp4: Logit: -0.1095 -> P(class 1)=0.4727 -> 予測クラス: 0 (確信度: 52.73%)
#   - ASD_20171211_30_8-8.mp4: Logit: -0.0989 -> P(class 1)=0.4753 -> 予測クラス: 0 (確信度: 52.47%)
#
# --- [バッチ 37] 推論中 ---
#   - ASD_20171211_31_1-6.mp4: Logit: -0.1181 -> P(class 1)=0.4705 -> 予測クラス: 0 (確信度: 52.95%)
#   - ASD_20171211_31_2-6.mp4: Logit: -0.1822 -> P(class 1)=0.4546 -> 予測クラス: 0 (確信度: 54.54%)
#   - ASD_20171211_31_3-6.mp4: Logit: 0.1219 -> P(class 1)=0.5304 -> 予測クラス: 1 (確信度: 53.04%)
#   - ASD_20171211_31_4-6.mp4: Logit: -0.2195 -> P(class 1)=0.4454 -> 予測クラス: 0 (確信度: 55.46%)
#
# --- [バッチ 38] 推論中 ---
#   - ASD_20171211_31_5-6.mp4: Logit: -0.2084 -> P(class 1)=0.4481 -> 予測クラス: 0 (確信度: 55.19%)
#   - ASD_20171211_31_6-6.mp4: Logit: -0.1600 -> P(class 1)=0.4601 -> 予測クラス: 0 (確信度: 53.99%)
#   - ASD_20171211_32_1-8.mp4: Logit: -0.0964 -> P(class 1)=0.4759 -> 予測クラス: 0 (確信度: 52.41%)
#   - ASD_20171211_32_2-8.mp4: Logit: -0.0435 -> P(class 1)=0.4891 -> 予測クラス: 0 (確信度: 51.09%)
#
# --- [バッチ 39] 推論中 ---
#   - ASD_20171211_32_3-8.mp4: Logit: -0.0014 -> P(class 1)=0.4997 -> 予測クラス: 0 (確信度: 50.03%)
#   - ASD_20171211_32_4-8.mp4: Logit: 0.0729 -> P(class 1)=0.5182 -> 予測クラス: 1 (確信度: 51.82%)
#   - ASD_20171211_32_5-8.mp4: Logit: -0.1621 -> P(class 1)=0.4596 -> 予測クラス: 0 (確信度: 54.04%)
#   - ASD_20171211_32_6-8.mp4: Logit: -0.0941 -> P(class 1)=0.4765 -> 予測クラス: 0 (確信度: 52.35%)
#
# --- [バッチ 40] 推論中 ---
#   - ASD_20171211_32_7-8.mp4: Logit: -0.1275 -> P(class 1)=0.4682 -> 予測クラス: 0 (確信度: 53.18%)
#   - ASD_20171211_32_8-8.mp4: Logit: -0.1334 -> P(class 1)=0.4667 -> 予測クラス: 0 (確信度: 53.33%)
#   - ASD_20171211_33_1-6.mp4: Logit: 0.2506 -> P(class 1)=0.5623 -> 予測クラス: 1 (確信度: 56.23%)
#   - ASD_20171211_33_2-6.mp4: Logit: -0.0247 -> P(class 1)=0.4938 -> 予測クラス: 0 (確信度: 50.62%)
#
# --- [バッチ 41] 推論中 ---
#   - ASD_20171211_33_3-6.mp4: Logit: -0.3122 -> P(class 1)=0.4226 -> 予測クラス: 0 (確信度: 57.74%)
#   - ASD_20171211_33_4-6.mp4: Logit: -0.1429 -> P(class 1)=0.4643 -> 予測クラス: 0 (確信度: 53.57%)
#   - ASD_20171211_33_5-6.mp4: Logit: -0.2461 -> P(class 1)=0.4388 -> 予測クラス: 0 (確信度: 56.12%)
#   - ASD_20171211_33_6-6.mp4: Logit: -0.1247 -> P(class 1)=0.4689 -> 予測クラス: 0 (確信度: 53.11%)
#
# --- [バッチ 42] 推論中 ---
#   - ASD_20171211_34_1-7.mp4: Logit: 0.0751 -> P(class 1)=0.5188 -> 予測クラス: 1 (確信度: 51.88%)
#   - ASD_20171211_34_2-7.mp4: Logit: -0.0992 -> P(class 1)=0.4752 -> 予測クラス: 0 (確信度: 52.48%)
#   - ASD_20171211_34_3-7.mp4: Logit: 0.1121 -> P(class 1)=0.5280 -> 予測クラス: 1 (確信度: 52.80%)
#   - ASD_20171211_34_4-7.mp4: Logit: -0.0323 -> P(class 1)=0.4919 -> 予測クラス: 0 (確信度: 50.81%)
#
# --- [バッチ 43] 推論中 ---
#   - ASD_20171211_34_5-7.mp4: Logit: -0.1374 -> P(class 1)=0.4657 -> 予測クラス: 0 (確信度: 53.43%)
#   - ASD_20171211_34_6-7.mp4: Logit: -0.0989 -> P(class 1)=0.4753 -> 予測クラス: 0 (確信度: 52.47%)
#   - ASD_20171211_34_7-7.mp4: Logit: 0.0201 -> P(class 1)=0.5050 -> 予測クラス: 1 (確信度: 50.50%)
#   - ASD_20171211_35_1-6.mp4: Logit: -0.0494 -> P(class 1)=0.4877 -> 予測クラス: 0 (確信度: 51.23%)
#
# --- [バッチ 44] 推論中 ---
#   - ASD_20171211_35_2-6.mp4: Logit: -0.4531 -> P(class 1)=0.3886 -> 予測クラス: 0 (確信度: 61.14%)
#   - ASD_20171211_35_3-6.mp4: Logit: -0.1281 -> P(class 1)=0.4680 -> 予測クラス: 0 (確信度: 53.20%)
#   - ASD_20171211_35_4-6.mp4: Logit: -0.1613 -> P(class 1)=0.4598 -> 予測クラス: 0 (確信度: 54.02%)
#   - ASD_20171211_35_5-6.mp4: Logit: -0.2785 -> P(class 1)=0.4308 -> 予測クラス: 0 (確信度: 56.92%)
#
# --- [バッチ 45] 推論中 ---
#   - ASD_20171211_35_6-6.mp4: Logit: -0.0360 -> P(class 1)=0.4910 -> 予測クラス: 0 (確信度: 50.90%)
#   - ASD_20171211_36_1-8.mp4: Logit: -0.1140 -> P(class 1)=0.4715 -> 予測クラス: 0 (確信度: 52.85%)
#   - ASD_20171211_36_2-8.mp4: Logit: -0.1105 -> P(class 1)=0.4724 -> 予測クラス: 0 (確信度: 52.76%)
#   - ASD_20171211_36_3-8.mp4: Logit: 0.0555 -> P(class 1)=0.5139 -> 予測クラス: 1 (確信度: 51.39%)
#
# --- [バッチ 46] 推論中 ---
#   - ASD_20171211_36_4-8.mp4: Logit: -0.1503 -> P(class 1)=0.4625 -> 予測クラス: 0 (確信度: 53.75%)
#   - ASD_20171211_36_5-8.mp4: Logit: -0.1212 -> P(class 1)=0.4697 -> 予測クラス: 0 (確信度: 53.03%)
#   - ASD_20171211_36_6-8.mp4: Logit: -0.2791 -> P(class 1)=0.4307 -> 予測クラス: 0 (確信度: 56.93%)
#   - ASD_20171211_36_7-8.mp4: Logit: -0.1627 -> P(class 1)=0.4594 -> 予測クラス: 0 (確信度: 54.06%)
#
# --- [バッチ 47] 推論中 ---
#   - ASD_20171211_36_8-8.mp4: Logit: -0.0343 -> P(class 1)=0.4914 -> 予測クラス: 0 (確信度: 50.86%)
#   - ASD_20171211_37_1-8.mp4: Logit: -0.0677 -> P(class 1)=0.4831 -> 予測クラス: 0 (確信度: 51.69%)
#   - ASD_20171211_37_2-8.mp4: Logit: 0.0413 -> P(class 1)=0.5103 -> 予測クラス: 1 (確信度: 51.03%)
#   - ASD_20171211_37_3-8.mp4: Logit: 0.0652 -> P(class 1)=0.5163 -> 予測クラス: 1 (確信度: 51.63%)
#
# --- [バッチ 48] 推論中 ---
#   - ASD_20171211_37_4-8.mp4: Logit: -0.0692 -> P(class 1)=0.4827 -> 予測クラス: 0 (確信度: 51.73%)
#   - ASD_20171211_37_5-8.mp4: Logit: -0.2051 -> P(class 1)=0.4489 -> 予測クラス: 0 (確信度: 55.11%)
#   - ASD_20171211_37_6-8.mp4: Logit: -0.0372 -> P(class 1)=0.4907 -> 予測クラス: 0 (確信度: 50.93%)
#   - ASD_20171211_37_7-8.mp4: Logit: -0.2094 -> P(class 1)=0.4478 -> 予測クラス: 0 (確信度: 55.22%)
#
# --- [バッチ 49] 推論中 ---
#   - ASD_20171211_37_8-8.mp4: Logit: -0.0853 -> P(class 1)=0.4787 -> 予測クラス: 0 (確信度: 52.13%)
#   - ASD_20171211_38_1-6.mp4: Logit: -0.2520 -> P(class 1)=0.4373 -> 予測クラス: 0 (確信度: 56.27%)
#   - ASD_20171211_38_2-6.mp4: Logit: -0.3114 -> P(class 1)=0.4228 -> 予測クラス: 0 (確信度: 57.72%)
#   - ASD_20171211_38_3-6.mp4: Logit: 0.1139 -> P(class 1)=0.5285 -> 予測クラス: 1 (確信度: 52.85%)
#
# --- [バッチ 50] 推論中 ---
#   - ASD_20171211_38_4-6.mp4: Logit: -0.3420 -> P(class 1)=0.4153 -> 予測クラス: 0 (確信度: 58.47%)
#   - ASD_20171211_38_5-6.mp4: Logit: -0.1562 -> P(class 1)=0.4610 -> 予測クラス: 0 (確信度: 53.90%)
#   - ASD_20171211_38_6-6.mp4: Logit: -0.1747 -> P(class 1)=0.4564 -> 予測クラス: 0 (確信度: 54.36%)
#   - ASD_20171211_39_1-9.mp4: Logit: -0.2135 -> P(class 1)=0.4468 -> 予測クラス: 0 (確信度: 55.32%)
#
# --- [バッチ 51] 推論中 ---
#   - ASD_20171211_39_2-9.mp4: Logit: -0.0927 -> P(class 1)=0.4768 -> 予測クラス: 0 (確信度: 52.32%)
#   - ASD_20171211_39_3-9.mp4: Logit: 0.2903 -> P(class 1)=0.5721 -> 予測クラス: 1 (確信度: 57.21%)
#   - ASD_20171211_39_4-9.mp4: Logit: -0.0782 -> P(class 1)=0.4805 -> 予測クラス: 0 (確信度: 51.95%)
#   - ASD_20171211_39_5-9.mp4: Logit: -0.0013 -> P(class 1)=0.4997 -> 予測クラス: 0 (確信度: 50.03%)
#
# --- [バッチ 52] 推論中 ---
#   - ASD_20171211_39_6-9.mp4: Logit: -0.0263 -> P(class 1)=0.4934 -> 予測クラス: 0 (確信度: 50.66%)
#   - ASD_20171211_39_7-9.mp4: Logit: -0.1139 -> P(class 1)=0.4716 -> 予測クラス: 0 (確信度: 52.84%)
#   - ASD_20171211_39_8-9.mp4: Logit: 0.0694 -> P(class 1)=0.5173 -> 予測クラス: 1 (確信度: 51.73%)
#   - ASD_20171211_39_9-9.mp4: Logit: -0.1186 -> P(class 1)=0.4704 -> 予測クラス: 0 (確信度: 52.96%)
#
# --- [バッチ 53] 推論中 ---
#   - ASD_20171211_3_1-6.mp4: Logit: 0.0555 -> P(class 1)=0.5139 -> 予測クラス: 1 (確信度: 51.39%)
#   - ASD_20171211_3_2-6.mp4: Logit: -0.3863 -> P(class 1)=0.4046 -> 予測クラス: 0 (確信度: 59.54%)
#   - ASD_20171211_3_3-6.mp4: Logit: 0.0875 -> P(class 1)=0.5219 -> 予測クラス: 1 (確信度: 52.19%)
#   - ASD_20171211_3_4-6.mp4: Logit: -0.2923 -> P(class 1)=0.4274 -> 予測クラス: 0 (確信度: 57.26%)
#
# --- [バッチ 54] 推論中 ---
#   - ASD_20171211_3_5-6.mp4: Logit: -0.0929 -> P(class 1)=0.4768 -> 予測クラス: 0 (確信度: 52.32%)
#   - ASD_20171211_3_6-6.mp4: Logit: -0.2034 -> P(class 1)=0.4493 -> 予測クラス: 0 (確信度: 55.07%)
#   - ASD_20171211_40_1-6.mp4: Logit: -0.1844 -> P(class 1)=0.4540 -> 予測クラス: 0 (確信度: 54.60%)
#   - ASD_20171211_40_2-6.mp4: Logit: -0.2619 -> P(class 1)=0.4349 -> 予測クラス: 0 (確信度: 56.51%)
#
# --- [バッチ 55] 推論中 ---
#   - ASD_20171211_40_3-6.mp4: Logit: -0.0925 -> P(class 1)=0.4769 -> 予測クラス: 0 (確信度: 52.31%)
#   - ASD_20171211_40_4-6.mp4: Logit: -0.2379 -> P(class 1)=0.4408 -> 予測クラス: 0 (確信度: 55.92%)
#   - ASD_20171211_40_5-6.mp4: Logit: -0.3212 -> P(class 1)=0.4204 -> 予測クラス: 0 (確信度: 57.96%)
#   - ASD_20171211_40_6-6.mp4: Logit: -0.1251 -> P(class 1)=0.4688 -> 予測クラス: 0 (確信度: 53.12%)
#
# --- [バッチ 56] 推論中 ---
#   - ASD_20171211_41_1-1.mp4: Logit: -0.1791 -> P(class 1)=0.4553 -> 予測クラス: 0 (確信度: 54.47%)
#   - ASD_20171211_42_1-6.mp4: Logit: 0.1081 -> P(class 1)=0.5270 -> 予測クラス: 1 (確信度: 52.70%)
#   - ASD_20171211_42_2-6.mp4: Logit: -0.3430 -> P(class 1)=0.4151 -> 予測クラス: 0 (確信度: 58.49%)
#   - ASD_20171211_42_3-6.mp4: Logit: -0.2133 -> P(class 1)=0.4469 -> 予測クラス: 0 (確信度: 55.31%)
#
# --- [バッチ 57] 推論中 ---
#   - ASD_20171211_42_4-6.mp4: Logit: -0.2247 -> P(class 1)=0.4441 -> 予測クラス: 0 (確信度: 55.59%)
#   - ASD_20171211_42_5-6.mp4: Logit: -0.3088 -> P(class 1)=0.4234 -> 予測クラス: 0 (確信度: 57.66%)
#   - ASD_20171211_42_6-6.mp4: Logit: -0.3050 -> P(class 1)=0.4243 -> 予測クラス: 0 (確信度: 57.57%)
#   - ASD_20171211_43_1-7.mp4: Logit: -0.0511 -> P(class 1)=0.4872 -> 予測クラス: 0 (確信度: 51.28%)
#
# --- [バッチ 58] 推論中 ---
#   - ASD_20171211_43_2-7.mp4: Logit: -0.1248 -> P(class 1)=0.4688 -> 予測クラス: 0 (確信度: 53.12%)
#   - ASD_20171211_43_3-7.mp4: Logit: 0.0747 -> P(class 1)=0.5187 -> 予測クラス: 1 (確信度: 51.87%)
#   - ASD_20171211_43_4-7.mp4: Logit: -0.0379 -> P(class 1)=0.4905 -> 予測クラス: 0 (確信度: 50.95%)
#   - ASD_20171211_43_5-7.mp4: Logit: -0.1477 -> P(class 1)=0.4631 -> 予測クラス: 0 (確信度: 53.69%)
#
# --- [バッチ 59] 推論中 ---
#   - ASD_20171211_43_6-7.mp4: Logit: -0.0539 -> P(class 1)=0.4865 -> 予測クラス: 0 (確信度: 51.35%)
#   - ASD_20171211_43_7-7.mp4: Logit: -0.0314 -> P(class 1)=0.4922 -> 予測クラス: 0 (確信度: 50.78%)
#   - ASD_20171211_44_1-10.mp4: Logit: 0.0826 -> P(class 1)=0.5206 -> 予測クラス: 1 (確信度: 52.06%)
#   - ASD_20171211_44_10-10.mp4: Logit: -0.0808 -> P(class 1)=0.4798 -> 予測クラス: 0 (確信度: 52.02%)
#
# --- [バッチ 60] 推論中 ---
#   - ASD_20171211_44_2-10.mp4: Logit: -0.1147 -> P(class 1)=0.4714 -> 予測クラス: 0 (確信度: 52.86%)
#   - ASD_20171211_44_3-10.mp4: Logit: -0.1319 -> P(class 1)=0.4671 -> 予測クラス: 0 (確信度: 53.29%)
#   - ASD_20171211_44_4-10.mp4: Logit: -0.2096 -> P(class 1)=0.4478 -> 予測クラス: 0 (確信度: 55.22%)
#   - ASD_20171211_44_5-10.mp4: Logit: 0.0100 -> P(class 1)=0.5025 -> 予測クラス: 1 (確信度: 50.25%)
#
# --- [バッチ 61] 推論中 ---
#   - ASD_20171211_44_6-10.mp4: Logit: -0.1755 -> P(class 1)=0.4562 -> 予測クラス: 0 (確信度: 54.38%)
#   - ASD_20171211_44_7-10.mp4: Logit: -0.1612 -> P(class 1)=0.4598 -> 予測クラス: 0 (確信度: 54.02%)
#   - ASD_20171211_44_8-10.mp4: Logit: -0.1190 -> P(class 1)=0.4703 -> 予測クラス: 0 (確信度: 52.97%)
#   - ASD_20171211_44_9-10.mp4: Logit: -0.1674 -> P(class 1)=0.4583 -> 予測クラス: 0 (確信度: 54.17%)
#
# --- [バッチ 62] 推論中 ---
#   - ASD_20171211_45_1-6.mp4: Logit: 0.0821 -> P(class 1)=0.5205 -> 予測クラス: 1 (確信度: 52.05%)
#   - ASD_20171211_45_2-6.mp4: Logit: -0.0795 -> P(class 1)=0.4801 -> 予測クラス: 0 (確信度: 51.99%)
#   - ASD_20171211_45_3-6.mp4: Logit: 0.1097 -> P(class 1)=0.5274 -> 予測クラス: 1 (確信度: 52.74%)
#   - ASD_20171211_45_4-6.mp4: Logit: -0.0182 -> P(class 1)=0.4955 -> 予測クラス: 0 (確信度: 50.45%)
#
# --- [バッチ 63] 推論中 ---
#   - ASD_20171211_45_5-6.mp4: Logit: -0.1961 -> P(class 1)=0.4511 -> 予測クラス: 0 (確信度: 54.89%)
#   - ASD_20171211_45_6-6.mp4: Logit: 0.0149 -> P(class 1)=0.5037 -> 予測クラス: 1 (確信度: 50.37%)
#   - ASD_20171211_46_1-6.mp4: Logit: -0.1473 -> P(class 1)=0.4633 -> 予測クラス: 0 (確信度: 53.67%)
#   - ASD_20171211_46_2-6.mp4: Logit: -0.3836 -> P(class 1)=0.4052 -> 予測クラス: 0 (確信度: 59.48%)
#
# --- [バッチ 64] 推論中 ---
#   - ASD_20171211_46_3-6.mp4: Logit: -0.0827 -> P(class 1)=0.4793 -> 予測クラス: 0 (確信度: 52.07%)
#   - ASD_20171211_46_4-6.mp4: Logit: -0.2960 -> P(class 1)=0.4265 -> 予測クラス: 0 (確信度: 57.35%)
#   - ASD_20171211_46_5-6.mp4: Logit: -0.1707 -> P(class 1)=0.4574 -> 予測クラス: 0 (確信度: 54.26%)
#   - ASD_20171211_46_6-6.mp4: Logit: -0.2023 -> P(class 1)=0.4496 -> 予測クラス: 0 (確信度: 55.04%)
#
# --- [バッチ 65] 推論中 ---
#   - ASD_20171211_47_1-7.mp4: Logit: -0.0503 -> P(class 1)=0.4874 -> 予測クラス: 0 (確信度: 51.26%)
#   - ASD_20171211_47_2-7.mp4: Logit: -0.0301 -> P(class 1)=0.4925 -> 予測クラス: 0 (確信度: 50.75%)
#   - ASD_20171211_47_3-7.mp4: Logit: -0.0261 -> P(class 1)=0.4935 -> 予測クラス: 0 (確信度: 50.65%)
#   - ASD_20171211_47_4-7.mp4: Logit: -0.0510 -> P(class 1)=0.4873 -> 予測クラス: 0 (確信度: 51.27%)
#
# --- [バッチ 66] 推論中 ---
#   - ASD_20171211_47_5-7.mp4: Logit: -0.2044 -> P(class 1)=0.4491 -> 予測クラス: 0 (確信度: 55.09%)
#   - ASD_20171211_47_6-7.mp4: Logit: -0.0923 -> P(class 1)=0.4769 -> 予測クラス: 0 (確信度: 52.31%)
#   - ASD_20171211_47_7-7.mp4: Logit: -0.0938 -> P(class 1)=0.4766 -> 予測クラス: 0 (確信度: 52.34%)
#   - ASD_20171211_48_1-10.mp4: Logit: -0.1567 -> P(class 1)=0.4609 -> 予測クラス: 0 (確信度: 53.91%)
#
# --- [バッチ 67] 推論中 ---
#   - ASD_20171211_48_10-10.mp4: Logit: 0.0657 -> P(class 1)=0.5164 -> 予測クラス: 1 (確信度: 51.64%)
#   - ASD_20171211_48_2-10.mp4: Logit: -0.1748 -> P(class 1)=0.4564 -> 予測クラス: 0 (確信度: 54.36%)
#   - ASD_20171211_48_3-10.mp4: Logit: 0.0149 -> P(class 1)=0.5037 -> 予測クラス: 1 (確信度: 50.37%)
#   - ASD_20171211_48_4-10.mp4: Logit: -0.0720 -> P(class 1)=0.4820 -> 予測クラス: 0 (確信度: 51.80%)
#
# --- [バッチ 68] 推論中 ---
#   - ASD_20171211_48_5-10.mp4: Logit: -0.0913 -> P(class 1)=0.4772 -> 予測クラス: 0 (確信度: 52.28%)
#   - ASD_20171211_48_6-10.mp4: Logit: 0.0588 -> P(class 1)=0.5147 -> 予測クラス: 1 (確信度: 51.47%)
#   - ASD_20171211_48_7-10.mp4: Logit: -0.2083 -> P(class 1)=0.4481 -> 予測クラス: 0 (確信度: 55.19%)
#   - ASD_20171211_48_8-10.mp4: Logit: -0.0998 -> P(class 1)=0.4751 -> 予測クラス: 0 (確信度: 52.49%)
#
# --- [バッチ 69] 推論中 ---
#   - ASD_20171211_48_9-10.mp4: Logit: -0.1219 -> P(class 1)=0.4696 -> 予測クラス: 0 (確信度: 53.04%)
#   - ASD_20171211_49_1-9.mp4: Logit: -0.1455 -> P(class 1)=0.4637 -> 予測クラス: 0 (確信度: 53.63%)
#   - ASD_20171211_49_2-9.mp4: Logit: -0.1492 -> P(class 1)=0.4628 -> 予測クラス: 0 (確信度: 53.72%)
#   - ASD_20171211_49_3-9.mp4: Logit: 0.0081 -> P(class 1)=0.5020 -> 予測クラス: 1 (確信度: 50.20%)
#
# --- [バッチ 70] 推論中 ---
#   - ASD_20171211_49_4-9.mp4: Logit: -0.1894 -> P(class 1)=0.4528 -> 予測クラス: 0 (確信度: 54.72%)
#   - ASD_20171211_49_5-9.mp4: Logit: -0.0141 -> P(class 1)=0.4965 -> 予測クラス: 0 (確信度: 50.35%)
#   - ASD_20171211_49_6-9.mp4: Logit: -0.1811 -> P(class 1)=0.4549 -> 予測クラス: 0 (確信度: 54.51%)
#   - ASD_20171211_49_7-9.mp4: Logit: -0.0352 -> P(class 1)=0.4912 -> 予測クラス: 0 (確信度: 50.88%)
#
# --- [バッチ 71] 推論中 ---
#   - ASD_20171211_49_8-9.mp4: Logit: -0.1869 -> P(class 1)=0.4534 -> 予測クラス: 0 (確信度: 54.66%)
#   - ASD_20171211_49_9-9.mp4: Logit: -0.1664 -> P(class 1)=0.4585 -> 予測クラス: 0 (確信度: 54.15%)
#   - ASD_20171211_4_1-5.mp4: Logit: 0.0046 -> P(class 1)=0.5012 -> 予測クラス: 1 (確信度: 50.12%)
#   - ASD_20171211_4_2-5.mp4: Logit: -0.1705 -> P(class 1)=0.4575 -> 予測クラス: 0 (確信度: 54.25%)
#
# --- [バッチ 72] 推論中 ---
#   - ASD_20171211_4_3-5.mp4: Logit: -0.1000 -> P(class 1)=0.4750 -> 予測クラス: 0 (確信度: 52.50%)
#   - ASD_20171211_4_4-5.mp4: Logit: -0.0116 -> P(class 1)=0.4971 -> 予測クラス: 0 (確信度: 50.29%)
#   - ASD_20171211_4_5-5.mp4: Logit: -0.1392 -> P(class 1)=0.4653 -> 予測クラス: 0 (確信度: 53.47%)
#   - ASD_20171211_50_1-5.mp4: Logit: -0.0676 -> P(class 1)=0.4831 -> 予測クラス: 0 (確信度: 51.69%)
#
# --- [バッチ 73] 推論中 ---
#   - ASD_20171211_50_2-5.mp4: Logit: -0.0394 -> P(class 1)=0.4902 -> 予測クラス: 0 (確信度: 50.98%)
#   - ASD_20171211_50_3-5.mp4: Logit: -0.2237 -> P(class 1)=0.4443 -> 予測クラス: 0 (確信度: 55.57%)
#   - ASD_20171211_50_4-5.mp4: Logit: -0.1963 -> P(class 1)=0.4511 -> 予測クラス: 0 (確信度: 54.89%)
#   - ASD_20171211_50_5-5.mp4: Logit: -0.1529 -> P(class 1)=0.4619 -> 予測クラス: 0 (確信度: 53.81%)
#
# --- [バッチ 74] 推論中 ---
#   - ASD_20171211_51_1-6.mp4: Logit: -0.0696 -> P(class 1)=0.4826 -> 予測クラス: 0 (確信度: 51.74%)
#   - ASD_20171211_51_2-6.mp4: Logit: -0.2335 -> P(class 1)=0.4419 -> 予測クラス: 0 (確信度: 55.81%)
#   - ASD_20171211_51_3-6.mp4: Logit: 0.1171 -> P(class 1)=0.5292 -> 予測クラス: 1 (確信度: 52.92%)
#   - ASD_20171211_51_4-6.mp4: Logit: -0.1255 -> P(class 1)=0.4687 -> 予測クラス: 0 (確信度: 53.13%)
#
# --- [バッチ 75] 推論中 ---
#   - ASD_20171211_51_5-6.mp4: Logit: -0.1369 -> P(class 1)=0.4658 -> 予測クラス: 0 (確信度: 53.42%)
#   - ASD_20171211_51_6-6.mp4: Logit: -0.0891 -> P(class 1)=0.4777 -> 予測クラス: 0 (確信度: 52.23%)
#   - ASD_20171211_52_1-6.mp4: Logit: 0.0265 -> P(class 1)=0.5066 -> 予測クラス: 1 (確信度: 50.66%)
#   - ASD_20171211_52_2-6.mp4: Logit: -0.3197 -> P(class 1)=0.4207 -> 予測クラス: 0 (確信度: 57.93%)
#
# --- [バッチ 76] 推論中 ---
#   - ASD_20171211_52_3-6.mp4: Logit: -0.2677 -> P(class 1)=0.4335 -> 予測クラス: 0 (確信度: 56.65%)
#   - ASD_20171211_52_4-6.mp4: Logit: -0.0131 -> P(class 1)=0.4967 -> 予測クラス: 0 (確信度: 50.33%)
#   - ASD_20171211_52_5-6.mp4: Logit: -0.0995 -> P(class 1)=0.4752 -> 予測クラス: 0 (確信度: 52.48%)
#   - ASD_20171211_52_6-6.mp4: Logit: -0.1536 -> P(class 1)=0.4617 -> 予測クラス: 0 (確信度: 53.83%)
#
# --- [バッチ 77] 推論中 ---
#   - ASD_20171211_53_1-8.mp4: Logit: -0.1998 -> P(class 1)=0.4502 -> 予測クラス: 0 (確信度: 54.98%)
#   - ASD_20171211_53_2-8.mp4: Logit: 0.0264 -> P(class 1)=0.5066 -> 予測クラス: 1 (確信度: 50.66%)
#   - ASD_20171211_53_3-8.mp4: Logit: 0.0203 -> P(class 1)=0.5051 -> 予測クラス: 1 (確信度: 50.51%)
#   - ASD_20171211_53_4-8.mp4: Logit: -0.0914 -> P(class 1)=0.4772 -> 予測クラス: 0 (確信度: 52.28%)
#
# --- [バッチ 78] 推論中 ---
#   - ASD_20171211_53_5-8.mp4: Logit: -0.0976 -> P(class 1)=0.4756 -> 予測クラス: 0 (確信度: 52.44%)
#   - ASD_20171211_53_6-8.mp4: Logit: -0.1515 -> P(class 1)=0.4622 -> 予測クラス: 0 (確信度: 53.78%)
#   - ASD_20171211_53_7-8.mp4: Logit: -0.0019 -> P(class 1)=0.4995 -> 予測クラス: 0 (確信度: 50.05%)
#   - ASD_20171211_53_8-8.mp4: Logit: -0.0572 -> P(class 1)=0.4857 -> 予測クラス: 0 (確信度: 51.43%)
#
# --- [バッチ 79] 推論中 ---
#   - ASD_20171211_54_1-9.mp4: Logit: -0.1240 -> P(class 1)=0.4690 -> 予測クラス: 0 (確信度: 53.10%)
#   - ASD_20171211_54_2-9.mp4: Logit: -0.2041 -> P(class 1)=0.4491 -> 予測クラス: 0 (確信度: 55.09%)
#   - ASD_20171211_54_3-9.mp4: Logit: -0.1575 -> P(class 1)=0.4607 -> 予測クラス: 0 (確信度: 53.93%)
#   - ASD_20171211_54_4-9.mp4: Logit: -0.0642 -> P(class 1)=0.4840 -> 予測クラス: 0 (確信度: 51.60%)
#
# --- [バッチ 80] 推論中 ---
#   - ASD_20171211_54_5-9.mp4: Logit: -0.0298 -> P(class 1)=0.4926 -> 予測クラス: 0 (確信度: 50.74%)
#   - ASD_20171211_54_6-9.mp4: Logit: -0.1420 -> P(class 1)=0.4645 -> 予測クラス: 0 (確信度: 53.55%)
#   - ASD_20171211_54_7-9.mp4: Logit: -0.0974 -> P(class 1)=0.4757 -> 予測クラス: 0 (確信度: 52.43%)
#   - ASD_20171211_54_8-9.mp4: Logit: -0.2403 -> P(class 1)=0.4402 -> 予測クラス: 0 (確信度: 55.98%)
#
# --- [バッチ 81] 推論中 ---
#   - ASD_20171211_54_9-9.mp4: Logit: -0.1547 -> P(class 1)=0.4614 -> 予測クラス: 0 (確信度: 53.86%)
#   - ASD_20171211_55_1-5.mp4: Logit: -0.0196 -> P(class 1)=0.4951 -> 予測クラス: 0 (確信度: 50.49%)
#   - ASD_20171211_55_2-5.mp4: Logit: -0.0756 -> P(class 1)=0.4811 -> 予測クラス: 0 (確信度: 51.89%)
#   - ASD_20171211_55_3-5.mp4: Logit: -0.0770 -> P(class 1)=0.4808 -> 予測クラス: 0 (確信度: 51.92%)
#
# --- [バッチ 82] 推論中 ---
#   - ASD_20171211_55_4-5.mp4: Logit: -0.2331 -> P(class 1)=0.4420 -> 予測クラス: 0 (確信度: 55.80%)
#   - ASD_20171211_55_5-5.mp4: Logit: -0.2905 -> P(class 1)=0.4279 -> 予測クラス: 0 (確信度: 57.21%)
#   - ASD_20171211_56_1-9.mp4: Logit: -0.3176 -> P(class 1)=0.4213 -> 予測クラス: 0 (確信度: 57.87%)
#   - ASD_20171211_56_2-9.mp4: Logit: -0.0695 -> P(class 1)=0.4826 -> 予測クラス: 0 (確信度: 51.74%)
#
# --- [バッチ 83] 推論中 ---
#   - ASD_20171211_56_3-9.mp4: Logit: -0.0073 -> P(class 1)=0.4982 -> 予測クラス: 0 (確信度: 50.18%)
#   - ASD_20171211_56_4-9.mp4: Logit: -0.1538 -> P(class 1)=0.4616 -> 予測クラス: 0 (確信度: 53.84%)
#   - ASD_20171211_56_5-9.mp4: Logit: -0.1197 -> P(class 1)=0.4701 -> 予測クラス: 0 (確信度: 52.99%)
#   - ASD_20171211_56_6-9.mp4: Logit: -0.1203 -> P(class 1)=0.4700 -> 予測クラス: 0 (確信度: 53.00%)
#
# --- [バッチ 84] 推論中 ---
#   - ASD_20171211_56_7-9.mp4: Logit: -0.1834 -> P(class 1)=0.4543 -> 予測クラス: 0 (確信度: 54.57%)
#   - ASD_20171211_56_8-9.mp4: Logit: -0.0697 -> P(class 1)=0.4826 -> 予測クラス: 0 (確信度: 51.74%)
#   - ASD_20171211_56_9-9.mp4: Logit: -0.2058 -> P(class 1)=0.4487 -> 予測クラス: 0 (確信度: 55.13%)
#   - ASD_20171211_5_1-3.mp4: Logit: -0.3670 -> P(class 1)=0.4093 -> 予測クラス: 0 (確信度: 59.07%)
#
# --- [バッチ 85] 推論中 ---
#   - ASD_20171211_5_2-3.mp4: Logit: -0.0933 -> P(class 1)=0.4767 -> 予測クラス: 0 (確信度: 52.33%)
#   - ASD_20171211_5_3-3.mp4: Logit: -0.0101 -> P(class 1)=0.4975 -> 予測クラス: 0 (確信度: 50.25%)
#   - ASD_20171211_6_1-5.mp4: Logit: -0.0802 -> P(class 1)=0.4800 -> 予測クラス: 0 (確信度: 52.00%)
#   - ASD_20171211_6_2-5.mp4: Logit: -0.0976 -> P(class 1)=0.4756 -> 予測クラス: 0 (確信度: 52.44%)
#
# --- [バッチ 86] 推論中 ---
#   - ASD_20171211_6_3-5.mp4: Logit: 0.0224 -> P(class 1)=0.5056 -> 予測クラス: 1 (確信度: 50.56%)
#   - ASD_20171211_6_4-5.mp4: Logit: -0.0502 -> P(class 1)=0.4875 -> 予測クラス: 0 (確信度: 51.25%)
#   - ASD_20171211_6_5-5.mp4: Logit: -0.1582 -> P(class 1)=0.4605 -> 予測クラス: 0 (確信度: 53.95%)
#   - ASD_20171211_7_1-10.mp4: Logit: -0.2898 -> P(class 1)=0.4280 -> 予測クラス: 0 (確信度: 57.20%)
#
# --- [バッチ 87] 推論中 ---
#   - ASD_20171211_7_10-10.mp4: Logit: -0.0484 -> P(class 1)=0.4879 -> 予測クラス: 0 (確信度: 51.21%)
#   - ASD_20171211_7_2-10.mp4: Logit: -0.1427 -> P(class 1)=0.4644 -> 予測クラス: 0 (確信度: 53.56%)
#   - ASD_20171211_7_3-10.mp4: Logit: 0.0054 -> P(class 1)=0.5013 -> 予測クラス: 1 (確信度: 50.13%)
#   - ASD_20171211_7_4-10.mp4: Logit: -0.1366 -> P(class 1)=0.4659 -> 予測クラス: 0 (確信度: 53.41%)
#
# --- [バッチ 88] 推論中 ---
#   - ASD_20171211_7_5-10.mp4: Logit: -0.1146 -> P(class 1)=0.4714 -> 予測クラス: 0 (確信度: 52.86%)
#   - ASD_20171211_7_6-10.mp4: Logit: -0.1234 -> P(class 1)=0.4692 -> 予測クラス: 0 (確信度: 53.08%)
#   - ASD_20171211_7_7-10.mp4: Logit: -0.1498 -> P(class 1)=0.4626 -> 予測クラス: 0 (確信度: 53.74%)
#   - ASD_20171211_7_8-10.mp4: Logit: -0.0907 -> P(class 1)=0.4773 -> 予測クラス: 0 (確信度: 52.27%)
#
# --- [バッチ 89] 推論中 ---
#   - ASD_20171211_7_9-10.mp4: Logit: -0.0405 -> P(class 1)=0.4899 -> 予測クラス: 0 (確信度: 51.01%)
#   - ASD_20171211_8_1-6.mp4: Logit: 0.0608 -> P(class 1)=0.5152 -> 予測クラス: 1 (確信度: 51.52%)
#   - ASD_20171211_8_2-6.mp4: Logit: -0.0638 -> P(class 1)=0.4840 -> 予測クラス: 0 (確信度: 51.60%)
#   - ASD_20171211_8_3-6.mp4: Logit: 0.0007 -> P(class 1)=0.5002 -> 予測クラス: 1 (確信度: 50.02%)
#
# --- [バッチ 90] 推論中 ---
#   - ASD_20171211_8_4-6.mp4: Logit: -0.0293 -> P(class 1)=0.4927 -> 予測クラス: 0 (確信度: 50.73%)
#   - ASD_20171211_8_5-6.mp4: Logit: -0.1575 -> P(class 1)=0.4607 -> 予測クラス: 0 (確信度: 53.93%)
#   - ASD_20171211_8_6-6.mp4: Logit: -0.2227 -> P(class 1)=0.4446 -> 予測クラス: 0 (確信度: 55.54%)
#   - ASD_20171211_9_1-6.mp4: Logit: -0.0514 -> P(class 1)=0.4872 -> 予測クラス: 0 (確信度: 51.28%)
#
# --- [バッチ 91] 推論中 ---
#   - ASD_20171211_9_2-6.mp4: Logit: -0.2017 -> P(class 1)=0.4497 -> 予測クラス: 0 (確信度: 55.03%)
#   - ASD_20171211_9_3-6.mp4: Logit: -0.0182 -> P(class 1)=0.4955 -> 予測クラス: 0 (確信度: 50.45%)
#   - ASD_20171211_9_4-6.mp4: Logit: -0.1138 -> P(class 1)=0.4716 -> 予測クラス: 0 (確信度: 52.84%)
#   - ASD_20171211_9_5-6.mp4: Logit: -0.1181 -> P(class 1)=0.4705 -> 予測クラス: 0 (確信度: 52.95%)
#
# --- [バッチ 92] 推論中 ---
#   - ASD_20171211_9_6-6.mp4: Logit: -0.1165 -> P(class 1)=0.4709 -> 予測クラス: 0 (確信度: 52.91%)
#   - ASD_20181204_10_1-8.mp4: Logit: 0.1007 -> P(class 1)=0.5252 -> 予測クラス: 1 (確信度: 52.52%)
#   - ASD_20181204_10_2-8.mp4: Logit: -0.0631 -> P(class 1)=0.4842 -> 予測クラス: 0 (確信度: 51.58%)
#   - ASD_20181204_10_3-8.mp4: Logit: -0.3732 -> P(class 1)=0.4078 -> 予測クラス: 0 (確信度: 59.22%)
#
# --- [バッチ 93] 推論中 ---
#   - ASD_20181204_10_4-8.mp4: Logit: -0.5124 -> P(class 1)=0.3746 -> 予測クラス: 0 (確信度: 62.54%)
#   - ASD_20181204_10_5-8.mp4: Logit: -0.1105 -> P(class 1)=0.4724 -> 予測クラス: 0 (確信度: 52.76%)
#   - ASD_20181204_10_6-8.mp4: Logit: -0.1257 -> P(class 1)=0.4686 -> 予測クラス: 0 (確信度: 53.14%)
#   - ASD_20181204_10_7-8.mp4: Logit: -0.0970 -> P(class 1)=0.4758 -> 予測クラス: 0 (確信度: 52.42%)
#
# --- [バッチ 94] 推論中 ---
#   - ASD_20181204_10_8-8.mp4: Logit: -0.1126 -> P(class 1)=0.4719 -> 予測クラス: 0 (確信度: 52.81%)
#   - ASD_20181204_11_1-5.mp4: Logit: -0.2003 -> P(class 1)=0.4501 -> 予測クラス: 0 (確信度: 54.99%)
#   - ASD_20181204_11_2-5.mp4: Logit: -0.3112 -> P(class 1)=0.4228 -> 予測クラス: 0 (確信度: 57.72%)
#   - ASD_20181204_11_3-5.mp4: Logit: -0.1570 -> P(class 1)=0.4608 -> 予測クラス: 0 (確信度: 53.92%)
#
# --- [バッチ 95] 推論中 ---
#   - ASD_20181204_11_4-5.mp4: Logit: -0.2338 -> P(class 1)=0.4418 -> 予測クラス: 0 (確信度: 55.82%)
#   - ASD_20181204_11_5-5.mp4: Logit: -0.3313 -> P(class 1)=0.4179 -> 予測クラス: 0 (確信度: 58.21%)
#   - ASD_20181204_12_1-5.mp4: Logit: -0.3929 -> P(class 1)=0.4030 -> 予測クラス: 0 (確信度: 59.70%)
#   - ASD_20181204_12_2-5.mp4: Logit: -0.2590 -> P(class 1)=0.4356 -> 予測クラス: 0 (確信度: 56.44%)
#
# --- [バッチ 96] 推論中 ---
#   - ASD_20181204_12_3-5.mp4: Logit: -0.1875 -> P(class 1)=0.4533 -> 予測クラス: 0 (確信度: 54.67%)
#   - ASD_20181204_12_4-5.mp4: Logit: 0.1155 -> P(class 1)=0.5288 -> 予測クラス: 1 (確信度: 52.88%)
#   - ASD_20181204_12_5-5.mp4: Logit: -0.2839 -> P(class 1)=0.4295 -> 予測クラス: 0 (確信度: 57.05%)
#   - ASD_20181204_13_1-8.mp4: Logit: 0.1329 -> P(class 1)=0.5332 -> 予測クラス: 1 (確信度: 53.32%)
#
# --- [バッチ 97] 推論中 ---
#   - ASD_20181204_13_2-8.mp4: Logit: -0.2966 -> P(class 1)=0.4264 -> 予測クラス: 0 (確信度: 57.36%)
#   - ASD_20181204_13_3-8.mp4: Logit: -0.4019 -> P(class 1)=0.4009 -> 予測クラス: 0 (確信度: 59.91%)
#   - ASD_20181204_13_4-8.mp4: Logit: -0.4618 -> P(class 1)=0.3866 -> 予測クラス: 0 (確信度: 61.34%)
#   - ASD_20181204_13_5-8.mp4: Logit: -0.4559 -> P(class 1)=0.3879 -> 予測クラス: 0 (確信度: 61.21%)
#
# --- [バッチ 98] 推論中 ---
#   - ASD_20181204_13_6-8.mp4: Logit: -0.1001 -> P(class 1)=0.4750 -> 予測クラス: 0 (確信度: 52.50%)
#   - ASD_20181204_13_7-8.mp4: Logit: 0.1468 -> P(class 1)=0.5366 -> 予測クラス: 1 (確信度: 53.66%)
#   - ASD_20181204_13_8-8.mp4: Logit: -0.0095 -> P(class 1)=0.4976 -> 予測クラス: 0 (確信度: 50.24%)
#   - ASD_20181204_14_1-7.mp4: Logit: -0.0731 -> P(class 1)=0.4817 -> 予測クラス: 0 (確信度: 51.83%)
#
# --- [バッチ 99] 推論中 ---
#   - ASD_20181204_14_2-7.mp4: Logit: -0.1302 -> P(class 1)=0.4675 -> 予測クラス: 0 (確信度: 53.25%)
#   - ASD_20181204_14_3-7.mp4: Logit: -0.3558 -> P(class 1)=0.4120 -> 予測クラス: 0 (確信度: 58.80%)
#   - ASD_20181204_14_4-7.mp4: Logit: -0.8280 -> P(class 1)=0.3041 -> 予測クラス: 0 (確信度: 69.59%)
#   - ASD_20181204_14_5-7.mp4: Logit: -0.1458 -> P(class 1)=0.4636 -> 予測クラス: 0 (確信度: 53.64%)
#
# --- [バッチ 100] 推論中 ---
#   - ASD_20181204_14_6-7.mp4: Logit: -0.2019 -> P(class 1)=0.4497 -> 予測クラス: 0 (確信度: 55.03%)
#   - ASD_20181204_14_7-7.mp4: Logit: -0.0669 -> P(class 1)=0.4833 -> 予測クラス: 0 (確信度: 51.67%)
#   - ASD_20181204_1_1-6.mp4: Logit: 0.0257 -> P(class 1)=0.5064 -> 予測クラス: 1 (確信度: 50.64%)
#   - ASD_20181204_1_2-6.mp4: Logit: -0.3213 -> P(class 1)=0.4204 -> 予測クラス: 0 (確信度: 57.96%)
#
# --- [バッチ 101] 推論中 ---
#   - ASD_20181204_1_3-6.mp4: Logit: -0.1373 -> P(class 1)=0.4657 -> 予測クラス: 0 (確信度: 53.43%)
#   - ASD_20181204_1_4-6.mp4: Logit: -0.5619 -> P(class 1)=0.3631 -> 予測クラス: 0 (確信度: 63.69%)
#   - ASD_20181204_1_5-6.mp4: Logit: -0.7875 -> P(class 1)=0.3127 -> 予測クラス: 0 (確信度: 68.73%)
#   - ASD_20181204_1_6-6.mp4: Logit: -0.4826 -> P(class 1)=0.3816 -> 予測クラス: 0 (確信度: 61.84%)
#
# --- [バッチ 102] 推論中 ---
#   - ASD_20181204_2_1-6.mp4: Logit: -0.5022 -> P(class 1)=0.3770 -> 予測クラス: 0 (確信度: 62.30%)
#   - ASD_20181204_2_2-6.mp4: Logit: -0.3251 -> P(class 1)=0.4194 -> 予測クラス: 0 (確信度: 58.06%)
#   - ASD_20181204_2_3-6.mp4: Logit: -0.3322 -> P(class 1)=0.4177 -> 予測クラス: 0 (確信度: 58.23%)
#   - ASD_20181204_2_4-6.mp4: Logit: 0.0062 -> P(class 1)=0.5016 -> 予測クラス: 1 (確信度: 50.16%)
#
# --- [バッチ 103] 推論中 ---
#   - ASD_20181204_2_5-6.mp4: Logit: -0.0999 -> P(class 1)=0.4750 -> 予測クラス: 0 (確信度: 52.50%)
#   - ASD_20181204_2_6-6.mp4: Logit: -0.1097 -> P(class 1)=0.4726 -> 予測クラス: 0 (確信度: 52.74%)
#   - ASD_20181204_3_1-1.mp4: Logit: -0.2946 -> P(class 1)=0.4269 -> 予測クラス: 0 (確信度: 57.31%)
#   - ASD_20181204_4_1-7.mp4: Logit: 0.1790 -> P(class 1)=0.5446 -> 予測クラス: 1 (確信度: 54.46%)
#
# --- [バッチ 104] 推論中 ---
#   - ASD_20181204_4_2-7.mp4: Logit: -0.2430 -> P(class 1)=0.4395 -> 予測クラス: 0 (確信度: 56.05%)
#   - ASD_20181204_4_3-7.mp4: Logit: -0.4382 -> P(class 1)=0.3922 -> 予測クラス: 0 (確信度: 60.78%)
#   - ASD_20181204_4_4-7.mp4: Logit: -0.3165 -> P(class 1)=0.4215 -> 予測クラス: 0 (確信度: 57.85%)
#   - ASD_20181204_4_5-7.mp4: Logit: -0.4830 -> P(class 1)=0.3816 -> 予測クラス: 0 (確信度: 61.84%)
#
# --- [バッチ 105] 推論中 ---
#   - ASD_20181204_4_6-7.mp4: Logit: -0.2406 -> P(class 1)=0.4401 -> 予測クラス: 0 (確信度: 55.99%)
#   - ASD_20181204_4_7-7.mp4: Logit: -0.2632 -> P(class 1)=0.4346 -> 予測クラス: 0 (確信度: 56.54%)
#   - ASD_20181204_5_1-8.mp4: Logit: -0.0001 -> P(class 1)=0.5000 -> 予測クラス: 0 (確信度: 50.00%)
#   - ASD_20181204_5_2-8.mp4: Logit: -0.2161 -> P(class 1)=0.4462 -> 予測クラス: 0 (確信度: 55.38%)
#
# --- [バッチ 106] 推論中 ---
#   - ASD_20181204_5_3-8.mp4: Logit: -0.4554 -> P(class 1)=0.3881 -> 予測クラス: 0 (確信度: 61.19%)
#   - ASD_20181204_5_4-8.mp4: Logit: -0.7651 -> P(class 1)=0.3175 -> 予測クラス: 0 (確信度: 68.25%)
#   - ASD_20181204_5_5-8.mp4: Logit: -0.3765 -> P(class 1)=0.4070 -> 予測クラス: 0 (確信度: 59.30%)
#   - ASD_20181204_5_6-8.mp4: Logit: 0.0122 -> P(class 1)=0.5031 -> 予測クラス: 1 (確信度: 50.31%)
#
# --- [バッチ 107] 推論中 ---
#   - ASD_20181204_5_7-8.mp4: Logit: -0.0399 -> P(class 1)=0.4900 -> 予測クラス: 0 (確信度: 51.00%)
#   - ASD_20181204_5_8-8.mp4: Logit: -0.1382 -> P(class 1)=0.4655 -> 予測クラス: 0 (確信度: 53.45%)
#   - ASD_20181204_6_1-3.mp4: Logit: 0.0725 -> P(class 1)=0.5181 -> 予測クラス: 1 (確信度: 51.81%)
#   - ASD_20181204_6_2-3.mp4: Logit: -0.3960 -> P(class 1)=0.4023 -> 予測クラス: 0 (確信度: 59.77%)
#
# --- [バッチ 108] 推論中 ---
#   - ASD_20181204_6_3-3.mp4: Logit: -0.1422 -> P(class 1)=0.4645 -> 予測クラス: 0 (確信度: 53.55%)
#   - ASD_20181204_7_1-8.mp4: Logit: -0.2493 -> P(class 1)=0.4380 -> 予測クラス: 0 (確信度: 56.20%)
#   - ASD_20181204_7_2-8.mp4: Logit: -0.2871 -> P(class 1)=0.4287 -> 予測クラス: 0 (確信度: 57.13%)
#   - ASD_20181204_7_3-8.mp4: Logit: -0.3162 -> P(class 1)=0.4216 -> 予測クラス: 0 (確信度: 57.84%)
#
# --- [バッチ 109] 推論中 ---
#   - ASD_20181204_7_4-8.mp4: Logit: -0.1940 -> P(class 1)=0.4516 -> 予測クラス: 0 (確信度: 54.84%)
#   - ASD_20181204_7_5-8.mp4: Logit: -0.3747 -> P(class 1)=0.4074 -> 予測クラス: 0 (確信度: 59.26%)
#   - ASD_20181204_7_6-8.mp4: Logit: -0.3365 -> P(class 1)=0.4166 -> 予測クラス: 0 (確信度: 58.34%)
#   - ASD_20181204_7_7-8.mp4: Logit: -0.2378 -> P(class 1)=0.4408 -> 予測クラス: 0 (確信度: 55.92%)
#
# --- [バッチ 110] 推論中 ---
#   - ASD_20181204_7_8-8.mp4: Logit: 0.0698 -> P(class 1)=0.5174 -> 予測クラス: 1 (確信度: 51.74%)
#   - ASD_20181204_8_1-6.mp4: Logit: -0.3882 -> P(class 1)=0.4042 -> 予測クラス: 0 (確信度: 59.58%)
#   - ASD_20181204_8_2-6.mp4: Logit: -0.3255 -> P(class 1)=0.4193 -> 予測クラス: 0 (確信度: 58.07%)
#   - ASD_20181204_8_3-6.mp4: Logit: -0.2745 -> P(class 1)=0.4318 -> 予測クラス: 0 (確信度: 56.82%)
#
# --- [バッチ 111] 推論中 ---
#   - ASD_20181204_8_4-6.mp4: Logit: -0.1564 -> P(class 1)=0.4610 -> 予測クラス: 0 (確信度: 53.90%)
#   - ASD_20181204_8_5-6.mp4: Logit: -0.1753 -> P(class 1)=0.4563 -> 予測クラス: 0 (確信度: 54.37%)
#   - ASD_20181204_8_6-6.mp4: Logit: -0.2547 -> P(class 1)=0.4367 -> 予測クラス: 0 (確信度: 56.33%)
#   - ASD_20181204_9_1-7.mp4: Logit: -0.4734 -> P(class 1)=0.3838 -> 予測クラス: 0 (確信度: 61.62%)
#
# --- [バッチ 112] 推論中 ---
#   - ASD_20181204_9_2-7.mp4: Logit: -0.3147 -> P(class 1)=0.4220 -> 予測クラス: 0 (確信度: 57.80%)
#   - ASD_20181204_9_3-7.mp4: Logit: -0.2144 -> P(class 1)=0.4466 -> 予測クラス: 0 (確信度: 55.34%)
#   - ASD_20181204_9_4-7.mp4: Logit: -0.1691 -> P(class 1)=0.4578 -> 予測クラス: 0 (確信度: 54.22%)
#   - ASD_20181204_9_5-7.mp4: Logit: -0.1445 -> P(class 1)=0.4639 -> 予測クラス: 0 (確信度: 53.61%)
#
# --- [バッチ 113] 推論中 ---
#   - ASD_20181204_9_6-7.mp4: Logit: -0.2577 -> P(class 1)=0.4359 -> 予測クラス: 0 (確信度: 56.41%)
#   - ASD_20181204_9_7-7.mp4: Logit: -0.3016 -> P(class 1)=0.4252 -> 予測クラス: 0 (確信度: 57.48%)
#   - ASD_20190507_1_10_1-5.mp4: Logit: 0.3020 -> P(class 1)=0.5749 -> 予測クラス: 1 (確信度: 57.49%)
#   - ASD_20190507_1_10_2-5.mp4: Logit: 0.6475 -> P(class 1)=0.6564 -> 予測クラス: 1 (確信度: 65.64%)
#
# --- [バッチ 114] 推論中 ---
#   - ASD_20190507_1_10_3-5.mp4: Logit: 0.8820 -> P(class 1)=0.7072 -> 予測クラス: 1 (確信度: 70.72%)
#   - ASD_20190507_1_10_4-5.mp4: Logit: 0.1052 -> P(class 1)=0.5263 -> 予測クラス: 1 (確信度: 52.63%)
#   - ASD_20190507_1_10_5-5.mp4: Logit: -0.1461 -> P(class 1)=0.4635 -> 予測クラス: 0 (確信度: 53.65%)
#   - ASD_20190507_1_11_1-5.mp4: Logit: 0.0965 -> P(class 1)=0.5241 -> 予測クラス: 1 (確信度: 52.41%)
#
# --- [バッチ 115] 推論中 ---
#   - ASD_20190507_1_11_2-5.mp4: Logit: 0.0106 -> P(class 1)=0.5027 -> 予測クラス: 1 (確信度: 50.27%)
#   - ASD_20190507_1_11_3-5.mp4: Logit: -0.0225 -> P(class 1)=0.4944 -> 予測クラス: 0 (確信度: 50.56%)
#   - ASD_20190507_1_11_4-5.mp4: Logit: 0.2970 -> P(class 1)=0.5737 -> 予測クラス: 1 (確信度: 57.37%)
#   - ASD_20190507_1_11_5-5.mp4: Logit: -0.3339 -> P(class 1)=0.4173 -> 予測クラス: 0 (確信度: 58.27%)
#
# --- [バッチ 116] 推論中 ---
#   - ASD_20190507_1_12_1-4.mp4: Logit: -0.0257 -> P(class 1)=0.4936 -> 予測クラス: 0 (確信度: 50.64%)
#   - ASD_20190507_1_12_2-4.mp4: Logit: 0.0673 -> P(class 1)=0.5168 -> 予測クラス: 1 (確信度: 51.68%)
#   - ASD_20190507_1_12_3-4.mp4: Logit: 0.1438 -> P(class 1)=0.5359 -> 予測クラス: 1 (確信度: 53.59%)
#   - ASD_20190507_1_12_4-4.mp4: Logit: 0.3303 -> P(class 1)=0.5818 -> 予測クラス: 1 (確信度: 58.18%)
#
# --- [バッチ 117] 推論中 ---
#   - ASD_20190507_1_13_1-4.mp4: Logit: 0.0543 -> P(class 1)=0.5136 -> 予測クラス: 1 (確信度: 51.36%)
#   - ASD_20190507_1_13_2-4.mp4: Logit: 0.3540 -> P(class 1)=0.5876 -> 予測クラス: 1 (確信度: 58.76%)
#   - ASD_20190507_1_13_3-4.mp4: Logit: 0.4398 -> P(class 1)=0.6082 -> 予測クラス: 1 (確信度: 60.82%)
#   - ASD_20190507_1_13_4-4.mp4: Logit: 0.5045 -> P(class 1)=0.6235 -> 予測クラス: 1 (確信度: 62.35%)
#
# --- [バッチ 118] 推論中 ---
#   - ASD_20190507_1_14_1-6.mp4: Logit: 0.2915 -> P(class 1)=0.5724 -> 予測クラス: 1 (確信度: 57.24%)
#   - ASD_20190507_1_14_2-6.mp4: Logit: 0.4698 -> P(class 1)=0.6153 -> 予測クラス: 1 (確信度: 61.53%)
#   - ASD_20190507_1_14_3-6.mp4: Logit: 0.7417 -> P(class 1)=0.6774 -> 予測クラス: 1 (確信度: 67.74%)
#   - ASD_20190507_1_14_4-6.mp4: Logit: 0.4739 -> P(class 1)=0.6163 -> 予測クラス: 1 (確信度: 61.63%)
#
# --- [バッチ 119] 推論中 ---
#   - ASD_20190507_1_14_5-6.mp4: Logit: 0.1621 -> P(class 1)=0.5404 -> 予測クラス: 1 (確信度: 54.04%)
#   - ASD_20190507_1_14_6-6.mp4: Logit: -0.0700 -> P(class 1)=0.4825 -> 予測クラス: 0 (確信度: 51.75%)
#   - ASD_20190507_1_15_1-5.mp4: Logit: -0.0113 -> P(class 1)=0.4972 -> 予測クラス: 0 (確信度: 50.28%)
#   - ASD_20190507_1_15_2-5.mp4: Logit: 0.0333 -> P(class 1)=0.5083 -> 予測クラス: 1 (確信度: 50.83%)
#
# --- [バッチ 120] 推論中 ---
#   - ASD_20190507_1_15_3-5.mp4: Logit: 0.3075 -> P(class 1)=0.5763 -> 予測クラス: 1 (確信度: 57.63%)
#   - ASD_20190507_1_15_4-5.mp4: Logit: -0.1602 -> P(class 1)=0.4600 -> 予測クラス: 0 (確信度: 54.00%)
#   - ASD_20190507_1_15_5-5.mp4: Logit: -0.0586 -> P(class 1)=0.4853 -> 予測クラス: 0 (確信度: 51.47%)
#   - ASD_20190507_1_16_1-3.mp4: Logit: 0.1499 -> P(class 1)=0.5374 -> 予測クラス: 1 (確信度: 53.74%)
#
# --- [バッチ 121] 推論中 ---
#   - ASD_20190507_1_16_2-3.mp4: Logit: 0.7122 -> P(class 1)=0.6709 -> 予測クラス: 1 (確信度: 67.09%)
#   - ASD_20190507_1_16_3-3.mp4: Logit: 0.0204 -> P(class 1)=0.5051 -> 予測クラス: 1 (確信度: 50.51%)
#   - ASD_20190507_1_17_1-5.mp4: Logit: 0.5102 -> P(class 1)=0.6249 -> 予測クラス: 1 (確信度: 62.49%)
#   - ASD_20190507_1_17_2-5.mp4: Logit: -0.0652 -> P(class 1)=0.4837 -> 予測クラス: 0 (確信度: 51.63%)
#
# --- [バッチ 122] 推論中 ---
#   - ASD_20190507_1_17_3-5.mp4: Logit: 0.1378 -> P(class 1)=0.5344 -> 予測クラス: 1 (確信度: 53.44%)
#   - ASD_20190507_1_17_4-5.mp4: Logit: 0.1295 -> P(class 1)=0.5323 -> 予測クラス: 1 (確信度: 53.23%)
#   - ASD_20190507_1_17_5-5.mp4: Logit: -0.2195 -> P(class 1)=0.4453 -> 予測クラス: 0 (確信度: 55.47%)
#   - ASD_20190507_1_18_1-4.mp4: Logit: -0.0101 -> P(class 1)=0.4975 -> 予測クラス: 0 (確信度: 50.25%)
#
# --- [バッチ 123] 推論中 ---
#   - ASD_20190507_1_18_2-4.mp4: Logit: -0.0339 -> P(class 1)=0.4915 -> 予測クラス: 0 (確信度: 50.85%)
#   - ASD_20190507_1_18_3-4.mp4: Logit: 0.1692 -> P(class 1)=0.5422 -> 予測クラス: 1 (確信度: 54.22%)
#   - ASD_20190507_1_18_4-4.mp4: Logit: 0.2398 -> P(class 1)=0.5597 -> 予測クラス: 1 (確信度: 55.97%)
#   - ASD_20190507_1_19_1-6.mp4: Logit: 0.6123 -> P(class 1)=0.6485 -> 予測クラス: 1 (確信度: 64.85%)
#
# --- [バッチ 124] 推論中 ---
#   - ASD_20190507_1_19_2-6.mp4: Logit: 0.6580 -> P(class 1)=0.6588 -> 予測クラス: 1 (確信度: 65.88%)
#   - ASD_20190507_1_19_3-6.mp4: Logit: 0.7425 -> P(class 1)=0.6775 -> 予測クラス: 1 (確信度: 67.75%)
#   - ASD_20190507_1_19_4-6.mp4: Logit: 0.1617 -> P(class 1)=0.5403 -> 予測クラス: 1 (確信度: 54.03%)
#   - ASD_20190507_1_19_5-6.mp4: Logit: 0.0268 -> P(class 1)=0.5067 -> 予測クラス: 1 (確信度: 50.67%)
#
# --- [バッチ 125] 推論中 ---
# ...
#   - LCS_20210608_26_3-4.mp4: Logit: 0.1154 -> P(class 1)=0.5288 -> 予測クラス: 1 (確信度: 52.88%)
#
# --- [バッチ 655] 推論中 ---
#   - LCS_20210608_26_4-4.mp4: Logit: 0.4218 -> P(class 1)=0.6039 -> 予測クラス: 1 (確信度: 60.39%)
#   - LCS_20210608_27_1-2.mp4: Logit: 0.1904 -> P(class 1)=0.5475 -> 予測クラス: 1 (確信度: 54.75%)
#   - LCS_20210608_27_2-2.mp4: Logit: 0.2303 -> P(class 1)=0.5573 -> 予測クラス: 1 (確信度: 55.73%)
#   - LCS_20210608_28_1-1.mp4: Logit: 0.1030 -> P(class 1)=0.5257 -> 予測クラス: 1 (確信度: 52.57%)
#
# --- [バッチ 656] 推論中 ---
#   - LCS_20210608_29_1-4.mp4: Logit: -0.1889 -> P(class 1)=0.4529 -> 予測クラス: 0 (確信度: 54.71%)
#   - LCS_20210608_29_2-4.mp4: Logit: -0.0359 -> P(class 1)=0.4910 -> 予測クラス: 0 (確信度: 50.90%)
#   - LCS_20210608_29_3-4.mp4: Logit: -0.2180 -> P(class 1)=0.4457 -> 予測クラス: 0 (確信度: 55.43%)
#   - LCS_20210608_29_4-4.mp4: Logit: 0.1271 -> P(class 1)=0.5317 -> 予測クラス: 1 (確信度: 53.17%)
#
# --- [バッチ 657] 推論中 ---
#   - LCS_20210608_2_1-4.mp4: Logit: -0.0386 -> P(class 1)=0.4903 -> 予測クラス: 0 (確信度: 50.97%)
#   - LCS_20210608_2_2-4.mp4: Logit: -0.1533 -> P(class 1)=0.4617 -> 予測クラス: 0 (確信度: 53.83%)
#   - LCS_20210608_2_3-4.mp4: Logit: -0.0647 -> P(class 1)=0.4838 -> 予測クラス: 0 (確信度: 51.62%)
#   - LCS_20210608_2_4-4.mp4: Logit: 0.1950 -> P(class 1)=0.5486 -> 予測クラス: 1 (確信度: 54.86%)
#
# --- [バッチ 658] 推論中 ---
#   - LCS_20210608_30_1-2.mp4: Logit: -0.1266 -> P(class 1)=0.4684 -> 予測クラス: 0 (確信度: 53.16%)
#   - LCS_20210608_30_2-2.mp4: Logit: -0.0029 -> P(class 1)=0.4993 -> 予測クラス: 0 (確信度: 50.07%)
#   - LCS_20210608_31_1-1.mp4: Logit: 0.4081 -> P(class 1)=0.6006 -> 予測クラス: 1 (確信度: 60.06%)
#   - LCS_20210608_32_1-6.mp4: Logit: 0.5394 -> P(class 1)=0.6317 -> 予測クラス: 1 (確信度: 63.17%)
#
# --- [バッチ 659] 推論中 ---
#   - LCS_20210608_32_2-6.mp4: Logit: 0.1909 -> P(class 1)=0.5476 -> 予測クラス: 1 (確信度: 54.76%)
#   - LCS_20210608_32_3-6.mp4: Logit: 0.2566 -> P(class 1)=0.5638 -> 予測クラス: 1 (確信度: 56.38%)
#   - LCS_20210608_32_4-6.mp4: Logit: 0.0755 -> P(class 1)=0.5189 -> 予測クラス: 1 (確信度: 51.89%)
#   - LCS_20210608_32_5-6.mp4: Logit: 0.0925 -> P(class 1)=0.5231 -> 予測クラス: 1 (確信度: 52.31%)
#
# --- [バッチ 660] 推論中 ---
#   - LCS_20210608_32_6-6.mp4: Logit: 0.1629 -> P(class 1)=0.5406 -> 予測クラス: 1 (確信度: 54.06%)
#   - LCS_20210608_33_1-2.mp4: Logit: 0.1671 -> P(class 1)=0.5417 -> 予測クラス: 1 (確信度: 54.17%)
#   - LCS_20210608_33_2-2.mp4: Logit: -0.0852 -> P(class 1)=0.4787 -> 予測クラス: 0 (確信度: 52.13%)
#   - LCS_20210608_34_1-5.mp4: Logit: -0.3390 -> P(class 1)=0.4160 -> 予測クラス: 0 (確信度: 58.40%)
#
# --- [バッチ 661] 推論中 ---
#   - LCS_20210608_34_2-5.mp4: Logit: -0.0076 -> P(class 1)=0.4981 -> 予測クラス: 0 (確信度: 50.19%)
#   - LCS_20210608_34_3-5.mp4: Logit: -0.0370 -> P(class 1)=0.4908 -> 予測クラス: 0 (確信度: 50.92%)
#   - LCS_20210608_34_4-5.mp4: Logit: -0.0120 -> P(class 1)=0.4970 -> 予測クラス: 0 (確信度: 50.30%)
#   - LCS_20210608_34_5-5.mp4: Logit: 0.2295 -> P(class 1)=0.5571 -> 予測クラス: 1 (確信度: 55.71%)
#
# --- [バッチ 662] 推論中 ---
#   - LCS_20210608_35_1-6.mp4: Logit: 0.2090 -> P(class 1)=0.5521 -> 予測クラス: 1 (確信度: 55.21%)
#   - LCS_20210608_35_2-6.mp4: Logit: 0.3012 -> P(class 1)=0.5747 -> 予測クラス: 1 (確信度: 57.47%)
#   - LCS_20210608_35_3-6.mp4: Logit: 0.4147 -> P(class 1)=0.6022 -> 予測クラス: 1 (確信度: 60.22%)
#   - LCS_20210608_35_4-6.mp4: Logit: 0.0075 -> P(class 1)=0.5019 -> 予測クラス: 1 (確信度: 50.19%)
#
# --- [バッチ 663] 推論中 ---
#   - LCS_20210608_35_5-6.mp4: Logit: 0.2925 -> P(class 1)=0.5726 -> 予測クラス: 1 (確信度: 57.26%)
#   - LCS_20210608_35_6-6.mp4: Logit: 0.2842 -> P(class 1)=0.5706 -> 予測クラス: 1 (確信度: 57.06%)
#   - LCS_20210608_36_1-5.mp4: Logit: 0.5170 -> P(class 1)=0.6264 -> 予測クラス: 1 (確信度: 62.64%)
#   - LCS_20210608_36_2-5.mp4: Logit: 0.1303 -> P(class 1)=0.5325 -> 予測クラス: 1 (確信度: 53.25%)
#
# --- [バッチ 664] 推論中 ---
#   - LCS_20210608_36_3-5.mp4: Logit: 0.3931 -> P(class 1)=0.5970 -> 予測クラス: 1 (確信度: 59.70%)
#   - LCS_20210608_36_4-5.mp4: Logit: 0.1018 -> P(class 1)=0.5254 -> 予測クラス: 1 (確信度: 52.54%)
#   - LCS_20210608_36_5-5.mp4: Logit: 0.0267 -> P(class 1)=0.5067 -> 予測クラス: 1 (確信度: 50.67%)
#   - LCS_20210608_37_1-5.mp4: Logit: -0.2888 -> P(class 1)=0.4283 -> 予測クラス: 0 (確信度: 57.17%)
#
# --- [バッチ 665] 推論中 ---
#   - LCS_20210608_37_2-5.mp4: Logit: 0.0398 -> P(class 1)=0.5099 -> 予測クラス: 1 (確信度: 50.99%)
#   - LCS_20210608_37_3-5.mp4: Logit: 0.2235 -> P(class 1)=0.5556 -> 予測クラス: 1 (確信度: 55.56%)
#   - LCS_20210608_37_4-5.mp4: Logit: 0.0138 -> P(class 1)=0.5034 -> 予測クラス: 1 (確信度: 50.34%)
#   - LCS_20210608_37_5-5.mp4: Logit: 0.0847 -> P(class 1)=0.5211 -> 予測クラス: 1 (確信度: 52.11%)
#
# --- [バッチ 666] 推論中 ---
#   - LCS_20210608_38_1-4.mp4: Logit: -0.2295 -> P(class 1)=0.4429 -> 予測クラス: 0 (確信度: 55.71%)
#   - LCS_20210608_38_2-4.mp4: Logit: 0.0098 -> P(class 1)=0.5024 -> 予測クラス: 1 (確信度: 50.24%)
#   - LCS_20210608_38_3-4.mp4: Logit: 0.1681 -> P(class 1)=0.5419 -> 予測クラス: 1 (確信度: 54.19%)
#   - LCS_20210608_38_4-4.mp4: Logit: 0.3755 -> P(class 1)=0.5928 -> 予測クラス: 1 (確信度: 59.28%)
#
# --- [バッチ 667] 推論中 ---
#   - LCS_20210608_39_1-2.mp4: Logit: 0.4653 -> P(class 1)=0.6143 -> 予測クラス: 1 (確信度: 61.43%)
#   - LCS_20210608_39_2-2.mp4: Logit: -0.0409 -> P(class 1)=0.4898 -> 予測クラス: 0 (確信度: 51.02%)
#   - LCS_20210608_3_1-4.mp4: Logit: -0.1693 -> P(class 1)=0.4578 -> 予測クラス: 0 (確信度: 54.22%)
#   - LCS_20210608_3_2-4.mp4: Logit: -0.0022 -> P(class 1)=0.4995 -> 予測クラス: 0 (確信度: 50.05%)
#
# --- [バッチ 668] 推論中 ---
#   - LCS_20210608_3_3-4.mp4: Logit: 0.0660 -> P(class 1)=0.5165 -> 予測クラス: 1 (確信度: 51.65%)
#   - LCS_20210608_3_4-4.mp4: Logit: 0.4651 -> P(class 1)=0.6142 -> 予測クラス: 1 (確信度: 61.42%)
#   - LCS_20210608_40_1-2.mp4: Logit: 0.2291 -> P(class 1)=0.5570 -> 予測クラス: 1 (確信度: 55.70%)
#   - LCS_20210608_40_2-2.mp4: Logit: 0.2357 -> P(class 1)=0.5587 -> 予測クラス: 1 (確信度: 55.87%)
#
# --- [バッチ 669] 推論中 ---
#   - LCS_20210608_41_1-3.mp4: Logit: 0.0054 -> P(class 1)=0.5014 -> 予測クラス: 1 (確信度: 50.14%)
#   - LCS_20210608_41_2-3.mp4: Logit: 0.3179 -> P(class 1)=0.5788 -> 予測クラス: 1 (確信度: 57.88%)
#   - LCS_20210608_41_3-3.mp4: Logit: -0.0129 -> P(class 1)=0.4968 -> 予測クラス: 0 (確信度: 50.32%)
#   - LCS_20210608_42_1-4.mp4: Logit: -0.0225 -> P(class 1)=0.4944 -> 予測クラス: 0 (確信度: 50.56%)
#
# --- [バッチ 670] 推論中 ---
#   - LCS_20210608_42_2-4.mp4: Logit: -0.0268 -> P(class 1)=0.4933 -> 予測クラス: 0 (確信度: 50.67%)
#   - LCS_20210608_42_3-4.mp4: Logit: -0.0088 -> P(class 1)=0.4978 -> 予測クラス: 0 (確信度: 50.22%)
#   - LCS_20210608_42_4-4.mp4: Logit: 0.6881 -> P(class 1)=0.6655 -> 予測クラス: 1 (確信度: 66.55%)
#   - LCS_20210608_43_1-2.mp4: Logit: 0.3535 -> P(class 1)=0.5875 -> 予測クラス: 1 (確信度: 58.75%)
#
# --- [バッチ 671] 推論中 ---
#   - LCS_20210608_43_2-2.mp4: Logit: 0.4394 -> P(class 1)=0.6081 -> 予測クラス: 1 (確信度: 60.81%)
#   - LCS_20210608_44_1-4.mp4: Logit: -0.2970 -> P(class 1)=0.4263 -> 予測クラス: 0 (確信度: 57.37%)
#   - LCS_20210608_44_2-4.mp4: Logit: 0.0387 -> P(class 1)=0.5097 -> 予測クラス: 1 (確信度: 50.97%)
#   - LCS_20210608_44_3-4.mp4: Logit: -0.0597 -> P(class 1)=0.4851 -> 予測クラス: 0 (確信度: 51.49%)
#
# --- [バッチ 672] 推論中 ---
#   - LCS_20210608_44_4-4.mp4: Logit: 0.5570 -> P(class 1)=0.6358 -> 予測クラス: 1 (確信度: 63.58%)
#   - LCS_20210608_45_1-4.mp4: Logit: -0.0918 -> P(class 1)=0.4771 -> 予測クラス: 0 (確信度: 52.29%)
#   - LCS_20210608_45_2-4.mp4: Logit: -0.0947 -> P(class 1)=0.4763 -> 予測クラス: 0 (確信度: 52.37%)
#   - LCS_20210608_45_3-4.mp4: Logit: -0.0735 -> P(class 1)=0.4816 -> 予測クラス: 0 (確信度: 51.84%)
#
# --- [バッチ 673] 推論中 ---
#   - LCS_20210608_45_4-4.mp4: Logit: 0.2158 -> P(class 1)=0.5537 -> 予測クラス: 1 (確信度: 55.37%)
#   - LCS_20210608_46_1-1.mp4: Logit: 0.1150 -> P(class 1)=0.5287 -> 予測クラス: 1 (確信度: 52.87%)
#   - LCS_20210608_47_1-1.mp4: Logit: 0.1646 -> P(class 1)=0.5410 -> 予測クラス: 1 (確信度: 54.10%)
#   - LCS_20210608_48_1-4.mp4: Logit: 0.2592 -> P(class 1)=0.5644 -> 予測クラス: 1 (確信度: 56.44%)
#
# --- [バッチ 674] 推論中 ---
#   - LCS_20210608_48_2-4.mp4: Logit: 0.4704 -> P(class 1)=0.6155 -> 予測クラス: 1 (確信度: 61.55%)
#   - LCS_20210608_48_3-4.mp4: Logit: 0.0067 -> P(class 1)=0.5017 -> 予測クラス: 1 (確信度: 50.17%)
#   - LCS_20210608_48_4-4.mp4: Logit: 0.1700 -> P(class 1)=0.5424 -> 予測クラス: 1 (確信度: 54.24%)
#   - LCS_20210608_49_1-4.mp4: Logit: -0.0228 -> P(class 1)=0.4943 -> 予測クラス: 0 (確信度: 50.57%)
#
# --- [バッチ 675] 推論中 ---
#   - LCS_20210608_49_2-4.mp4: Logit: -0.0252 -> P(class 1)=0.4937 -> 予測クラス: 0 (確信度: 50.63%)
#   - LCS_20210608_49_3-4.mp4: Logit: 0.3439 -> P(class 1)=0.5851 -> 予測クラス: 1 (確信度: 58.51%)
#   - LCS_20210608_49_4-4.mp4: Logit: 0.5688 -> P(class 1)=0.6385 -> 予測クラス: 1 (確信度: 63.85%)
#   - LCS_20210608_4_1-2.mp4: Logit: 0.0496 -> P(class 1)=0.5124 -> 予測クラス: 1 (確信度: 51.24%)
#
# --- [バッチ 676] 推論中 ---
#   - LCS_20210608_4_2-2.mp4: Logit: 0.3566 -> P(class 1)=0.5882 -> 予測クラス: 1 (確信度: 58.82%)
#   - LCS_20210608_5_1-7.mp4: Logit: 0.3758 -> P(class 1)=0.5929 -> 予測クラス: 1 (確信度: 59.29%)
#   - LCS_20210608_5_2-7.mp4: Logit: 0.3061 -> P(class 1)=0.5759 -> 予測クラス: 1 (確信度: 57.59%)
#   - LCS_20210608_5_3-7.mp4: Logit: 0.0310 -> P(class 1)=0.5078 -> 予測クラス: 1 (確信度: 50.78%)
#
# --- [バッチ 677] 推論中 ---
#   - LCS_20210608_5_4-7.mp4: Logit: -0.0159 -> P(class 1)=0.4960 -> 予測クラス: 0 (確信度: 50.40%)
#   - LCS_20210608_5_5-7.mp4: Logit: 0.2934 -> P(class 1)=0.5728 -> 予測クラス: 1 (確信度: 57.28%)
#   - LCS_20210608_5_6-7.mp4: Logit: 0.0326 -> P(class 1)=0.5082 -> 予測クラス: 1 (確信度: 50.82%)
#   - LCS_20210608_5_7-7.mp4: Logit: 0.0179 -> P(class 1)=0.5045 -> 予測クラス: 1 (確信度: 50.45%)
#
# --- [バッチ 678] 推論中 ---
#   - LCS_20210608_6_1-4.mp4: Logit: -0.2318 -> P(class 1)=0.4423 -> 予測クラス: 0 (確信度: 55.77%)
#   - LCS_20210608_6_2-4.mp4: Logit: 0.0371 -> P(class 1)=0.5093 -> 予測クラス: 1 (確信度: 50.93%)
#   - LCS_20210608_6_3-4.mp4: Logit: -0.1455 -> P(class 1)=0.4637 -> 予測クラス: 0 (確信度: 53.63%)
#   - LCS_20210608_6_4-4.mp4: Logit: -0.0086 -> P(class 1)=0.4978 -> 予測クラス: 0 (確信度: 50.22%)
#
# --- [バッチ 679] 推論中 ---
#   - LCS_20210608_7_1-5.mp4: Logit: -0.3785 -> P(class 1)=0.4065 -> 予測クラス: 0 (確信度: 59.35%)
#   - LCS_20210608_7_2-5.mp4: Logit: -0.0576 -> P(class 1)=0.4856 -> 予測クラス: 0 (確信度: 51.44%)
#   - LCS_20210608_7_3-5.mp4: Logit: 0.0710 -> P(class 1)=0.5177 -> 予測クラス: 1 (確信度: 51.77%)
#   - LCS_20210608_7_4-5.mp4: Logit: 0.3053 -> P(class 1)=0.5757 -> 予測クラス: 1 (確信度: 57.57%)
#
# --- [バッチ 680] 推論中 ---
#   - LCS_20210608_7_5-5.mp4: Logit: -0.0997 -> P(class 1)=0.4751 -> 予測クラス: 0 (確信度: 52.49%)
#   - LCS_20210608_8_1-6.mp4: Logit: 0.4229 -> P(class 1)=0.6042 -> 予測クラス: 1 (確信度: 60.42%)
#   - LCS_20210608_8_2-6.mp4: Logit: 0.2460 -> P(class 1)=0.5612 -> 予測クラス: 1 (確信度: 56.12%)
#   - LCS_20210608_8_3-6.mp4: Logit: 0.1990 -> P(class 1)=0.5496 -> 予測クラス: 1 (確信度: 54.96%)
#
# --- [バッチ 681] 推論中 ---
#   - LCS_20210608_8_4-6.mp4: Logit: 0.0707 -> P(class 1)=0.5177 -> 予測クラス: 1 (確信度: 51.77%)
#   - LCS_20210608_8_5-6.mp4: Logit: 0.2295 -> P(class 1)=0.5571 -> 予測クラス: 1 (確信度: 55.71%)
#   - LCS_20210608_8_6-6.mp4: Logit: -0.0482 -> P(class 1)=0.4880 -> 予測クラス: 0 (確信度: 51.20%)
#   - LCS_20210608_9_1-2.mp4: Logit: -0.0134 -> P(class 1)=0.4967 -> 予測クラス: 0 (確信度: 50.33%)
#
# --- [バッチ 682] 推論中 ---
#   - LCS_20210608_9_2-2.mp4: Logit: 0.4661 -> P(class 1)=0.6145 -> 予測クラス: 1 (確信度: 61.45%)
#   - LCS_20210706_1_1-5.mp4: Logit: -0.2030 -> P(class 1)=0.4494 -> 予測クラス: 0 (確信度: 55.06%)
#   - LCS_20210706_1_2-5.mp4: Logit: -0.4858 -> P(class 1)=0.3809 -> 予測クラス: 0 (確信度: 61.91%)
#   - LCS_20210706_1_3-5.mp4: Logit: -0.4450 -> P(class 1)=0.3906 -> 予測クラス: 0 (確信度: 60.94%)
#
# --- [バッチ 683] 推論中 ---
#   - LCS_20210706_1_4-5.mp4: Logit: -0.6094 -> P(class 1)=0.3522 -> 予測クラス: 0 (確信度: 64.78%)
#   - LCS_20210706_1_5-5.mp4: Logit: -0.3415 -> P(class 1)=0.4154 -> 予測クラス: 0 (確信度: 58.46%)
#   - LCS_20210706_2_1-7.mp4: Logit: 0.1270 -> P(class 1)=0.5317 -> 予測クラス: 1 (確信度: 53.17%)
#   - LCS_20210706_2_2-7.mp4: Logit: 0.0508 -> P(class 1)=0.5127 -> 予測クラス: 1 (確信度: 51.27%)
#
# --- [バッチ 684] 推論中 ---
#   - LCS_20210706_2_3-7.mp4: Logit: -0.2639 -> P(class 1)=0.4344 -> 予測クラス: 0 (確信度: 56.56%)
#   - LCS_20210706_2_4-7.mp4: Logit: -0.3948 -> P(class 1)=0.4026 -> 予測クラス: 0 (確信度: 59.74%)
#   - LCS_20210706_2_5-7.mp4: Logit: -0.2679 -> P(class 1)=0.4334 -> 予測クラス: 0 (確信度: 56.66%)
#   - LCS_20210706_2_6-7.mp4: Logit: -0.2183 -> P(class 1)=0.4456 -> 予測クラス: 0 (確信度: 55.44%)
#
# --- [バッチ 685] 推論中 ---
#   - LCS_20210706_2_7-7.mp4: Logit: -0.0776 -> P(class 1)=0.4806 -> 予測クラス: 0 (確信度: 51.94%)
#   - LCS_20210706_3_1-4.mp4: Logit: -0.1230 -> P(class 1)=0.4693 -> 予測クラス: 0 (確信度: 53.07%)
#   - LCS_20210706_3_2-4.mp4: Logit: -0.4547 -> P(class 1)=0.3882 -> 予測クラス: 0 (確信度: 61.18%)
#   - LCS_20210706_3_3-4.mp4: Logit: -0.4819 -> P(class 1)=0.3818 -> 予測クラス: 0 (確信度: 61.82%)
#
# --- [バッチ 686] 推論中 ---
#   - LCS_20210706_3_4-4.mp4: Logit: -0.2986 -> P(class 1)=0.4259 -> 予測クラス: 0 (確信度: 57.41%)
#   - LCS_20210706_4_1-4.mp4: Logit: -0.2869 -> P(class 1)=0.4288 -> 予測クラス: 0 (確信度: 57.12%)
#   - LCS_20210706_4_2-4.mp4: Logit: -0.3740 -> P(class 1)=0.4076 -> 予測クラス: 0 (確信度: 59.24%)
#   - LCS_20210706_4_3-4.mp4: Logit: -0.5342 -> P(class 1)=0.3695 -> 予測クラス: 0 (確信度: 63.05%)
#
# --- [バッチ 687] 推論中 ---
#   - LCS_20210706_4_4-4.mp4: Logit: -0.3801 -> P(class 1)=0.4061 -> 予測クラス: 0 (確信度: 59.39%)
#   - LCS_20210706_5_1-7.mp4: Logit: 0.0297 -> P(class 1)=0.5074 -> 予測クラス: 1 (確信度: 50.74%)
#   - LCS_20210706_5_2-7.mp4: Logit: 0.1238 -> P(class 1)=0.5309 -> 予測クラス: 1 (確信度: 53.09%)
#   - LCS_20210706_5_3-7.mp4: Logit: -0.4018 -> P(class 1)=0.4009 -> 予測クラス: 0 (確信度: 59.91%)
#
# --- [バッチ 688] 推論中 ---
#   - LCS_20210706_5_4-7.mp4: Logit: -0.1781 -> P(class 1)=0.4556 -> 予測クラス: 0 (確信度: 54.44%)
#   - LCS_20210706_5_5-7.mp4: Logit: -0.0575 -> P(class 1)=0.4856 -> 予測クラス: 0 (確信度: 51.44%)
#   - LCS_20210706_5_6-7.mp4: Logit: -0.1768 -> P(class 1)=0.4559 -> 予測クラス: 0 (確信度: 54.41%)
#   - LCS_20210706_5_7-7.mp4: Logit: 0.0948 -> P(class 1)=0.5237 -> 予測クラス: 1 (確信度: 52.37%)
#
# --- [バッチ 689] 推論中 ---
#   - LCS_20210706_6_1-7.mp4: Logit: -0.1768 -> P(class 1)=0.4559 -> 予測クラス: 0 (確信度: 54.41%)
#   - LCS_20210706_6_2-7.mp4: Logit: -0.3089 -> P(class 1)=0.4234 -> 予測クラス: 0 (確信度: 57.66%)
#   - LCS_20210706_6_3-7.mp4: Logit: -0.4512 -> P(class 1)=0.3891 -> 予測クラス: 0 (確信度: 61.09%)
#   - LCS_20210706_6_4-7.mp4: Logit: 0.0278 -> P(class 1)=0.5069 -> 予測クラス: 1 (確信度: 50.69%)
#
# --- [バッチ 690] 推論中 ---
#   - LCS_20210706_6_5-7.mp4: Logit: -0.1354 -> P(class 1)=0.4662 -> 予測クラス: 0 (確信度: 53.38%)
#   - LCS_20210706_6_6-7.mp4: Logit: -0.0258 -> P(class 1)=0.4935 -> 予測クラス: 0 (確信度: 50.65%)
#   - LCS_20210706_6_7-7.mp4: Logit: -0.0150 -> P(class 1)=0.4963 -> 予測クラス: 0 (確信度: 50.37%)
#   - LCS_20210706_7_1-6.mp4: Logit: -0.2130 -> P(class 1)=0.4469 -> 予測クラス: 0 (確信度: 55.31%)
#
# --- [バッチ 691] 推論中 ---
#   - LCS_20210706_7_2-6.mp4: Logit: -0.4205 -> P(class 1)=0.3964 -> 予測クラス: 0 (確信度: 60.36%)
#   - LCS_20210706_7_3-6.mp4: Logit: -0.6285 -> P(class 1)=0.3478 -> 予測クラス: 0 (確信度: 65.22%)
#   - LCS_20210706_7_4-6.mp4: Logit: -0.5909 -> P(class 1)=0.3564 -> 予測クラス: 0 (確信度: 64.36%)
#   - LCS_20210706_7_5-6.mp4: Logit: -0.4660 -> P(class 1)=0.3856 -> 予測クラス: 0 (確信度: 61.44%)
#
# --- [バッチ 692] 推論中 ---
#   - LCS_20210706_7_6-6.mp4: Logit: -0.3718 -> P(class 1)=0.4081 -> 予測クラス: 0 (確信度: 59.19%)
#   - LCS_20210706_8_1-7.mp4: Logit: 0.0359 -> P(class 1)=0.5090 -> 予測クラス: 1 (確信度: 50.90%)
#   - LCS_20210706_8_2-7.mp4: Logit: -0.2517 -> P(class 1)=0.4374 -> 予測クラス: 0 (確信度: 56.26%)
#   - LCS_20210706_8_3-7.mp4: Logit: -0.1827 -> P(class 1)=0.4544 -> 予測クラス: 0 (確信度: 54.56%)
#
# --- [バッチ 693] 推論中 ---
#   - LCS_20210706_8_4-7.mp4: Logit: -0.3138 -> P(class 1)=0.4222 -> 予測クラス: 0 (確信度: 57.78%)
#   - LCS_20210706_8_5-7.mp4: Logit: -0.1605 -> P(class 1)=0.4599 -> 予測クラス: 0 (確信度: 54.01%)
#   - LCS_20210706_8_6-7.mp4: Logit: -0.1978 -> P(class 1)=0.4507 -> 予測クラス: 0 (確信度: 54.93%)
#   - LCS_20210706_8_7-7.mp4: Logit: -0.1761 -> P(class 1)=0.4561 -> 予測クラス: 0 (確信度: 54.39%)
#
#
# ==================== 全ての推論結果 ====================
#                Video Filename  prediction confidence prob_for_class_1
# 0     ASD_20171211_10_1-6.mp4           0     0.5196           0.4804
# 1     ASD_20171211_10_2-6.mp4           0     0.5712           0.4288
# 2     ASD_20171211_10_3-6.mp4           0     0.5334           0.4666
# 3     ASD_20171211_10_4-6.mp4           1     0.5068           0.5068
# 4     ASD_20171211_10_5-6.mp4           0     0.5563           0.4437
# ...                       ...         ...        ...              ...
# 2767   LCS_20210706_8_3-7.mp4           0     0.5456           0.4544
# 2768   LCS_20210706_8_4-7.mp4           0     0.5778           0.4222
# 2769   LCS_20210706_8_5-7.mp4           0     0.5401           0.4599
# 2770   LCS_20210706_8_6-7.mp4           0     0.5493           0.4507
# 2771   LCS_20210706_8_7-7.mp4           0     0.5439           0.4561
#
# [2772 rows x 4 columns]

# %%
import json

# --- 1. 保存先のディレクトリとファイル名を定義 ---
# あなたが指定したパスをここに設定します
output_directory = '/workspace/data/analysis_logs/ex_20250116_organaized_split/early_fusion'
output_directory = os.path.join(output_directory, TARGET_FOLD)
output_filename = 'inference_results.json'
output_filepath = os.path.join(output_directory, output_filename)

print(f"結果を次のパスに保存します: {output_filepath}")

try:
    # results辞書が空でないことを確認
    if not results:
        print("結果が空のため、JSONファイルは作成されませんでした。")
    else:
        # --- 2. 保存先ディレクトリが存在しない場合に、自動で作成 ---
        # exist_ok=True を指定すると、ディレクトリが既に存在していてもエラーになりません
        os.makedirs(output_directory, exist_ok=True)
        print(f"ディレクトリ '{output_directory}' を確認・作成しました。")

        # --- 3. ファイルを書き込む ---
        with open(output_filepath, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=4)
        
        print(f"\n✅ 推論結果が '{output_filepath}' に正常に保存されました。")

except NameError:
    print("エラー: `results` 辞書が見つかりません。先に推論処理のセルを実行してください。")
except Exception as e:
    print(f"ファイルの保存中に予期せぬエラーが発生しました: {e}")
# Out:
# 結果を次のパスに保存します: /workspace/data/analysis_logs/ex_20250116_organaized_split/early_fusion/fold1/inference_results.json
# ディレクトリ '/workspace/data/analysis_logs/ex_20250116_organaized_split/early_fusion/fold1' を確認・作成しました。
#
# ✅ 推論結果が '/workspace/data/analysis_logs/ex_20250116_organaized_split/early_fusion/fold1/inference_results.json' に正常に保存されました。

# %% [markdown]
# # 描画フェーズ

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob # ファイル検索のためのライブラリ

# ==============================================================================
# ## 1. 複数foldのJSONファイルを読み込み、単一のデータフレームに統合
# ==============================================================================
print("ステップ1: 複数foldのJSONファイルを読み込んで統合します...")

# JSONファイルが格納されている親ディレクトリを指定
JSON_ROOT_DIRECTORY = '/workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion'

# 指定したディレクトリ以下の全ての inference_results.json を探す
json_file_paths = glob.glob(os.path.join(JSON_ROOT_DIRECTORY, 'fold*', 'inference_results.json'))

if not json_file_paths:
    print(f"エラー: '{JSON_ROOT_DIRECTORY}' 内に 'foldX/inference_results.json' のパターンに一致するファイルが見つかりませんでした。")
    raise SystemExit()

print(f"{len(json_file_paths)} 個のJSONファイルが見つかりました:")
for path in json_file_paths:
    print(f"  - {path}")

# 各JSONファイルをDataFrameとして読み込み、一つのリストにまとめる
all_dfs = []
for file_path in json_file_paths:
    fold_name = os.path.basename(os.path.dirname(file_path))
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df_fold = pd.DataFrame.from_dict(data, orient='index')
    df_fold = df_fold.reset_index().rename(columns={'index': 'filename'})
    df_fold['fold'] = fold_name 
    all_dfs.append(df_fold)

# 全てのfoldのDataFrameを縦に結合
df_all = pd.concat(all_dfs, ignore_index=True)
df_all['prediction'] = df_all['prediction'].astype(int)
df_all['confidence'] = df_all['confidence'].astype(float)
print("\n✅ 全てのJSONデータを統合しました。")


# ==============================================================================
# ## 2. 統合データフレームの処理
# ==============================================================================
print("\nステップ2: データフレームを処理し、分析用の列を追加します...")

def extract_position(filename):
    try:
        base_name = os.path.splitext(filename)[0]
        position_str = base_name.split('_')[-1]
        if '-' in position_str and all(part.isdigit() for part in position_str.split('-')):
            return position_str
        return None
    except:
        return None

def get_ground_truth(filename):
    # ASD -> 0, ASD_not -> 1
    if filename.startswith('ASD'):
        return 0
    else:
        return 1

df_all['position'] = df_all['filename'].apply(extract_position)
df_all['ground_truth'] = df_all['filename'].apply(get_ground_truth)
df_all.dropna(subset=['position'], inplace=True)
df_all['is_correct'] = (df_all['prediction'] == df_all['ground_truth']).astype(int)
print("✅ 位置情報、正解ラベル、正誤判定の列を追加しました。")


# ==============================================================================
# ## 3.【詳細分析】位置ごとの集計
# ==============================================================================
print("\nステップ3: 詳細な位置ごとの集計を行います...")
position_analysis = df_all.groupby('position').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
position_analysis['accuracy_rate'] = position_analysis['correct_count'] / position_analysis['total_count']
position_analysis['mistake_count'] = position_analysis['total_count'] - position_analysis['correct_count']

def position_to_midpoint(position_str):
    try:
        numerator, denominator = map(int, position_str.split('-'))
        return (2 * numerator - 1) / (2 * denominator)
    except (ValueError, ZeroDivisionError):
        return float('inf')

position_analysis['sort_value'] = position_analysis['position'].apply(position_to_midpoint)
position_analysis = position_analysis.sort_values(by='sort_value').reset_index(drop=True)
print("✅ 詳細分析の集計が完了しました。")


# ==============================================================================
# ## 4.【詳細分析】結果の可視化
# ==============================================================================
print("\nステップ4: 詳細分析の結果を可視化します...")

# --- グラフA: 絶対数（積み上げ棒グラフ） ---
plot_data_detail = position_analysis.set_index('position')[['correct_count', 'mistake_count']]
plot_data_detail.plot(kind='bar', stacked=True, figsize=(14, 7), color=['#2ca02c', '#d62728'])
plt.title('Number of Correct/Incorrect Predictions by Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Number of Videos', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(['Correct', 'Incorrect'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_0.png'))
plt.show()


# --- グラフB: 正解率 ---
plt.figure(figsize=(14, 7))
ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
for p in ax_detail.patches:
    ax_detail.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Model Accuracy Rate by Course Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_1.png'))
plt.show()


# ==============================================================================
# ## 5.【概要分析】コースを4等分した区間ごとの集計
# ==============================================================================
print("\nステップ5: コースを4分割した概要分析の集計を行います...")

def get_quadrant(midpoint_value):
    if 0 <= midpoint_value < 0.25: return "1st Quadrant (0-25%)"
    elif 0.25 <= midpoint_value < 0.5: return "2nd Quadrant (25-50%)"
    elif 0.5 <= midpoint_value < 0.75: return "3rd Quadrant (50-75%)"
    elif 0.75 <= midpoint_value <= 1.0: return "4th Quadrant (75-100%)"
    else: return "N/A"

df_all['sort_value'] = df_all['position'].apply(position_to_midpoint)
df_all['quadrant'] = df_all['sort_value'].apply(get_quadrant)

quadrant_analysis = df_all.groupby('quadrant').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
quadrant_analysis['accuracy_rate'] = quadrant_analysis['correct_count'] / quadrant_analysis['total_count']
print("✅ 概要分析の集計が完了しました。")


# ==============================================================================
# ## 6.【概要分析】結果の可視化
# ==============================================================================
print("\nステップ6: 概要分析の結果を可視化します...")

# --- display()で集計結果のテーブルを表示 ---
print("\n--- Accuracy Analysis by Course Quadrant ---")
display(quadrant_analysis)

# --- グラフA: 絶対数 ---
plt.figure(figsize=(10, 6))
ax_abs_q = sns.barplot(x='quadrant', y='correct_count', data=quadrant_analysis, color='steelblue', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_abs_q.patches:
    ax_abs_q.annotate(f"{p.get_height():.0f}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Number of Correct Predictions per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_2.png'))
plt.show()

# --- グラフB: 正解率 ---
plt.figure(figsize=(10, 6))
ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_rate_q.patches:
    ax_rate_q.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Accuracy Rate per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_3.png'))
plt.show()
# Out:
# ステップ1: 複数foldのJSONファイルを読み込んで統合します...
# 5 個のJSONファイルが見つかりました:
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion/fold3/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion/fold2/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion/fold0/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion/fold1/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/late_fusion/fold4/inference_results.json
#
# ✅ 全てのJSONデータを統合しました。
#
# ステップ2: データフレームを処理し、分析用の列を追加します...
# ✅ 位置情報、正解ラベル、正誤判定の列を追加しました。
#
# ステップ3: 詳細な位置ごとの集計を行います...
# ✅ 詳細分析の集計が完了しました。
#
# ステップ4: 詳細分析の結果を可視化します...
# /tmp/ipykernel_1156/2234840010.py:118: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
# ステップ5: コースを4分割した概要分析の集計を行います...
# ✅ 概要分析の集計が完了しました。
#
# ステップ6: 概要分析の結果を可視化します...
#
# --- Accuracy Analysis by Course Quadrant ---
#                  quadrant  correct_count  total_count  accuracy_rate
# 0    1st Quadrant (0-25%)           1668         2358       0.707379
# 1   2nd Quadrant (25-50%)           1769         2404       0.735857
# 2   3rd Quadrant (50-75%)           2095         2873       0.729203
# 3  4th Quadrant (75-100%)           2067         2909       0.710553
# /tmp/ipykernel_1156/2234840010.py:179: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])

# %%
# ==============================================================================
# ## 7.【症例別分析＋総合】症例ごとの正解率の集計と可視化
# ==============================================================================
print("ステップ7: 症例別の分析（総合結果付き）を開始します...")

# --- 1. ファイル名から「症例タイプ」を抽出 ---
def extract_case_type(filename):
    try:
        return filename.split('_')[0]
    except:
        return None

# 'case_type' 列を新しく作成
df_all['case_type'] = df_all['filename'].apply(extract_case_type)
print("  - 症例タイプ列を追加しました。")


# --- 2. 症例タイプごとに正解率と絶対数を集計 ---
# 'case_type' 列でグループ化し、正解数と全体の数を計算
case_analysis = df_all.groupby('case_type').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()

# 正解率を計算
case_analysis['accuracy_rate'] = case_analysis['correct_count'] / case_analysis['total_count']
print("  - 症例タイプごとの集計が完了しました。")


# --- 3. 「総合(Total)」の行を計算して追加 ---
# 全体の合計を計算
total_correct = case_analysis['correct_count'].sum()
total_total = case_analysis['total_count'].sum()
total_accuracy = total_correct / total_total if total_total > 0 else 0

# 'Total'の行を新しいDataFrameとして作成
total_df = pd.DataFrame([{
    'case_type': 'Total',
    'correct_count': total_correct,
    'total_count': total_total,
    'accuracy_rate': total_accuracy
}])

# 元のDataFrameと結合して、'Total'行を含む新しいDataFrameを作成
case_analysis_with_total = pd.concat([total_df, case_analysis], ignore_index=True)

# グラフの表示順を定義 ('Total'を先頭に、残りはアルファベット順)
plot_order = ['Total'] + sorted(case_analysis['case_type'].unique())
print("  - 総合結果の追加と表示順の定義が完了しました。")


# --- 4. 可視化 (2パターン、総合結果付き) ---

# display()で集計結果のテーブルを表示
print("\n--- Accuracy Analysis by Case Type (with Total) ---")
display(case_analysis_with_total)


# ### パターンA: 正解の「絶対数」を可視化 ###
plt.figure(figsize=(10, 6))
ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
for p in ax_abs_case.patches:
    ax_abs_case.annotate(f"{p.get_height():.0f}", 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Number of Correct Predictions per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_4.png'))
plt.show()


# ### パターンB: 「正解率」を可視化 ###
plt.figure(figsize=(10, 6))
ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')
for p in ax_rate_case.patches:
    ax_rate_case.annotate(f"{p.get_height():.2%}", 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Accuracy Rate per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_5.png'))
plt.show()
# Out:
# ステップ7: 症例別の分析（総合結果付き）を開始します...
#   - 症例タイプ列を追加しました。
#   - 症例タイプごとの集計が完了しました。
#   - 総合結果の追加と表示順の定義が完了しました。
#
# --- Accuracy Analysis by Case Type (with Total) ---
#   case_type  correct_count  total_count  accuracy_rate
# 0     Total           7599        10544       0.720694
# 1       ASD           4359         5343       0.815834
# 2       DHS           2192         2793       0.784819
# 3     HipOA             65          816       0.079657
# 4       LCS            983         1592       0.617462
# /tmp/ipykernel_1156/4160753937.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
# /tmp/ipykernel_1156/4160753937.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')
