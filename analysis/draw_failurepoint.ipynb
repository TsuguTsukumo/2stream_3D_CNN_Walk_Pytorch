# %% [markdown]
# # 推論フェーズ

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import cv2
import numpy as np
import yaml
import os
import sys
import pandas as pd
from IPython.display import display
from typing import Any, Callable, Dict, Optional, Type, Tuple

print(torch.cuda.is_available())
# Out:
# True

# %%
# --- パス設定 ---
# プロジェクトの基点となるパスを定義
project_base_path = '/workspace/project'

# このパスがPythonの検索パスリスト (sys.path) になければ追加
if project_base_path not in sys.path:
    sys.path.append(project_base_path)
    print(f"'{project_base_path}' を sys.path に追加しました。")

# --- 自作モジュールのインポート ---
try:
    # データローダーのインポート
    from project.dataloader.data_loader_multi import MultiData
    from project.dataloader.data_loader import WalkDataModule
    
    # モデル定義のインポート
    from project.models.make_model import single, early_fusion, late_fusion, slow_fusion

    print("\n✅ 必要な全てのモジュールが正常にインポートされました。")

except ImportError as e:
    print(f"\n❌ エラー: インポートに失敗しました: {e}")
    print("\n【トラブルシューティング】")
    print("1. `project_base_path` のパスが正しいか確認してください。")
    print("2. プロジェクト内のディレクトリに `__init__.py` ファイルが存在するか確認してください。")
    # ここで処理を停止させる
    sys.exit()
# Out:
# '/workspace/project' を sys.path に追加しました。
#
# ✅ 必要な全てのモジュールが正常にインポートされました。

# %%
# ==============================================================================
# ## 2. 設定：ConfigとHParamsの準備
# ==============================================================================
print("\nステップ2: 設定ファイル (config.yaml) を読み込みます...")

# 学習済みモデルが含まれるディレクトリのルートパス
model_root = '/workspace/project/logs/resnet/slow_fusion/2025-02-03/05-15-18'

# config.yaml のパス
config_path = os.path.join(model_root, '.hydra/config.yaml')

def load_config(config_path):
    """YAMLファイルを読み込む関数"""
    try:
        with open(config_path, 'r') as f:
            config = yaml.safe_load(f)
        print(f"設定ファイル '{config_path}' を正常に読み込みました。")
        return config
    except FileNotFoundError:
        print(f"❌ エラー: 設定ファイル '{config_path}' が見つかりません。")
        sys.exit()

# --- HParamsクラスの定義（修正版） ---
class HParams:
    """config.yamlの階層構造を模倣するクラス"""
    def __init__(self, data_config, model_config, train_config):
        self.data = type('DataConfig', (object,), data_config)()
        self.model = type('ModelConfig', (object,), model_config)()
        self.train = type('TrainConfig', (object,), train_config)()

# --- 設定の読み込みとHParamsのインスタンス化（修正版） ---
config_data = load_config(config_path)
try:
    hparams = HParams(
        config_data['data'], 
        config_data['model'], 
        config_data['train']
    )
    print("✅ HParamsオブジェクトを正常に作成しました。")
except KeyError as e:
    print(f"❌ エラー: config.yaml に必要なキー {e} が見つかりません。")
    sys.exit()
# Out:
# ステップ2: 設定ファイル (config.yaml) を読み込みます...
# 設定ファイル '/workspace/project/logs/resnet/slow_fusion/2025-02-03/05-15-18/.hydra/config.yaml' を正常に読み込みました。
# ✅ HParamsオブジェクトを正常に作成しました。

# %%
# ==============================================================================
# ## 3. モデルの準備：インスタンス化と学習済み重みのロード
# ==============================================================================
print("\nステップ3: モデルを準備します...")

# --- 設定値の取得 ---
fusion_type = hparams.train.experiment
device_ids = 1
model_path = os.path.join(model_root, 'fold4/version_0/checkpoints/2-0.61-0.6986.ckpt')

# --- デバイスの設定 ---
if torch.cuda.is_available():
    # 指定されたGPU IDが利用可能かチェック
    if device_ids >= torch.cuda.device_count():
        print(f"\n❌ エラー: 指定されたGPU ID {device_ids} は利用できません。利用可能なGPUは {torch.cuda.device_count()}台です。")
        sys.exit()
    
    device = torch.device(f"cuda:{device_ids}")
    print(f"GPU {device_ids} を使用します。")
else:
    device = torch.device("cpu")
    print("GPUが利用できないため、CPUを使用します。")

# --- モデルのインスタンス化 ---
if fusion_type == 'single':
    model = single(hparams).to(device)
elif fusion_type == 'early_fusion':
    model = early_fusion(hparams).to(device)
elif fusion_type == 'late_fusion':
    model = late_fusion(hparams).to(device)
elif fusion_type == 'slow_fusion':
    model = slow_fusion(hparams).to(device)
else:
    raise ValueError(f"不明なフュージョンタイプ: {fusion_type}")
print(f"'{fusion_type}' モデルをインスタンス化し、デバイス '{device}' に配置しました。")

# --- 学習済み重みのロード（最終修正版） ---
try:
    checkpoint = torch.load(model_path, map_location=device, weights_only=False)
    
    if 'state_dict' in checkpoint:
        original_state_dict = checkpoint['state_dict']
        new_state_dict = {}
        # キーの先頭にある "model." プレフィックスを削除
        for k, v in original_state_dict.items():
            if k.startswith("model."):
                new_key = k[len("model."):]
            else:
                new_key = k
            new_state_dict[new_key] = v
        
        model.load_state_dict(new_state_dict)
    else:
        model.load_state_dict(checkpoint)
        
    model.eval() # モデルを評価モードに設定
    print("✅ 学習済み重みをモデルに正常にロードしました。")

except Exception as e:
    import traceback
    print(f"\n❌ エラー: モデルの重みロード中にエラーが発生しました: {e}")
    print(traceback.format_exc())
    sys.exit()
# Out:
# ステップ3: モデルを準備します...
# GPU 1 を使用します。
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# Using cache found in /root/.cache/torch/hub/facebookresearch_pytorchvideo_main
# 'slow_fusion' モデルをインスタンス化し、デバイス 'cuda:1' に配置しました。
# ✅ 学習済み重みをモデルに正常にロードしました。

# %%
# ==============================================================================
# ## 4. 推論の実行（single / multi-stream 両対応・修正版）
# ==============================================================================
print("\nステップ4: 推論を実行します...")

# --- 4.1. 推論対象の設定 ---
AP_DATA_ROOT = '/workspace/data/out_dir_ver2_classified_front'
LAT_DATA_ROOT = '/workspace/data/out_dir_ver2_classified_side'
TARGET_FOLD = 'fold4'
INFERENCE_BATCH_SIZE = 4
# -----------------------------

results = {}

# ### ケース1: 2つの動画を入力するフュージョンモデルの場合 ###
if fusion_type in ['late_fusion', 'early_fusion', 'slow_fusion']:
    print(f"'{fusion_type}' モデル（2入力）の推論パイプラインを開始します。")
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    
    datamodule = MultiData(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test') 
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            print(f"\n--- [バッチ {i+1}] 推論中 ---")
            batch_dict = batch[0]
            inputs_front, inputs_side = batch_dict["ap"]["video"].to(device), batch_dict["lat"]["video"].to(device)
            video_names = batch_dict["ap"]["video_name"]
            if batch_dict['ap']['video_name'] != batch_dict['lat']['video_name']:
                print('error')
            outputs = model(inputs_front, inputs_side)
            prob_for_class_1 = torch.sigmoid(outputs)
            predicted_indices = (prob_for_class_1 > 0.5).long()
            
            for idx in range(len(video_names)):
                video_name = os.path.basename(video_names[idx])
                pred_class, prob1 = predicted_indices[idx].item(), prob_for_class_1[idx].item()
                confidence = prob1 if pred_class == 1 else 1 - prob1
                results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")

# ### ケース2: 1つの動画を入力する 'single' モデルの場合（修正版） ###
elif fusion_type == 'single':
    print(f"'single' モデル（1入力）の推論パイプラインを開始します。")
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    
    datamodule = WalkDataModule(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test') 
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            print(f"\n--- [バッチ {i+1}] 推論中 ---")
            # batch_dict = batch[0]
            input_video = batch["video"].to(device)
            video_names = batch["video_name"]
            input_video= input_video.permute(0, 2, 1, 3, 4).contiguous()
            outputs = model(input_video)
            prob_for_class_1 = torch.sigmoid(outputs)
            predicted_indices = (prob_for_class_1 > 0.5).long()
            
            for idx in range(len(video_names)):
                video_name = os.path.basename(video_names[idx])
                pred_class, prob1 = predicted_indices[idx].item(), prob_for_class_1[idx].item()
                confidence = prob1 if pred_class == 1 else 1 - prob1
                results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")
    
    

else:
    print(f"エラー: fusion_type '{fusion_type}' はこのスクリプトでサポートされていません。")

# --- 4.4. 結果の集計と表示 ---
print("\n\n==================== 全ての推論結果 ====================")
if not results:
    print("推論が実行された動画はありませんでした。")
else:
    results_df = pd.DataFrame.from_dict(results, orient='index')
    results_df.index.name = 'Video Filename'
    results_df = results_df.reset_index()
    display(results_df)
# Out:
# ステップ4: 推論を実行します...
# 'slow_fusion' モデル（2入力）の推論パイプラインを開始します。
# 'fold4' の検証(val)データを読み込んでいます...
# データローダーの準備が完了しました。
#
# --- [バッチ 1] 推論中 ---
#   - ASD_Left_20180123_1648_1-11.mp4: Logit: -0.0151 -> P(class 1)=0.4962 -> 予測クラス: 0 (確信度: 50.38%)
#   - ASD_Left_20180123_1648_10-11.mp4: Logit: -0.0761 -> P(class 1)=0.4810 -> 予測クラス: 0 (確信度: 51.90%)
#   - ASD_Left_20180123_1648_11-11.mp4: Logit: -0.3759 -> P(class 1)=0.4071 -> 予測クラス: 0 (確信度: 59.29%)
#   - ASD_Left_20180123_1648_2-11.mp4: Logit: -0.1205 -> P(class 1)=0.4699 -> 予測クラス: 0 (確信度: 53.01%)
#
# --- [バッチ 2] 推論中 ---
#   - ASD_Left_20180123_1648_3-11.mp4: Logit: -0.1381 -> P(class 1)=0.4655 -> 予測クラス: 0 (確信度: 53.45%)
#   - ASD_Left_20180123_1648_4-11.mp4: Logit: -0.0790 -> P(class 1)=0.4803 -> 予測クラス: 0 (確信度: 51.97%)
#   - ASD_Left_20180123_1648_5-11.mp4: Logit: -0.1229 -> P(class 1)=0.4693 -> 予測クラス: 0 (確信度: 53.07%)
#   - ASD_Left_20180123_1648_6-11.mp4: Logit: -0.1071 -> P(class 1)=0.4733 -> 予測クラス: 0 (確信度: 52.67%)
#
# --- [バッチ 3] 推論中 ---
#   - ASD_Left_20180123_1648_7-11.mp4: Logit: -0.4134 -> P(class 1)=0.3981 -> 予測クラス: 0 (確信度: 60.19%)
#   - ASD_Left_20180123_1648_8-11.mp4: Logit: -0.3255 -> P(class 1)=0.4193 -> 予測クラス: 0 (確信度: 58.07%)
#   - ASD_Left_20180123_1648_9-11.mp4: Logit: -0.1697 -> P(class 1)=0.4577 -> 予測クラス: 0 (確信度: 54.23%)
#   - ASD_Left_20180123_1650_1-10.mp4: Logit: -0.0220 -> P(class 1)=0.4945 -> 予測クラス: 0 (確信度: 50.55%)
#
# --- [バッチ 4] 推論中 ---
#   - ASD_Left_20180123_1650_10-10.mp4: Logit: -0.0426 -> P(class 1)=0.4893 -> 予測クラス: 0 (確信度: 51.07%)
#   - ASD_Left_20180123_1650_2-10.mp4: Logit: -0.0254 -> P(class 1)=0.4937 -> 予測クラス: 0 (確信度: 50.63%)
#   - ASD_Left_20180123_1650_3-10.mp4: Logit: -0.1141 -> P(class 1)=0.4715 -> 予測クラス: 0 (確信度: 52.85%)
#   - ASD_Left_20180123_1650_4-10.mp4: Logit: -0.1725 -> P(class 1)=0.4570 -> 予測クラス: 0 (確信度: 54.30%)
#
# --- [バッチ 5] 推論中 ---
#   - ASD_Left_20180123_1650_5-10.mp4: Logit: -0.2204 -> P(class 1)=0.4451 -> 予測クラス: 0 (確信度: 55.49%)
#   - ASD_Left_20180123_1650_6-10.mp4: Logit: -0.2013 -> P(class 1)=0.4498 -> 予測クラス: 0 (確信度: 55.02%)
#   - ASD_Left_20180123_1650_7-10.mp4: Logit: -0.0410 -> P(class 1)=0.4898 -> 予測クラス: 0 (確信度: 51.02%)
#   - ASD_Left_20180123_1650_8-10.mp4: Logit: -0.2044 -> P(class 1)=0.4491 -> 予測クラス: 0 (確信度: 55.09%)
#
# --- [バッチ 6] 推論中 ---
#   - ASD_Left_20180123_1650_9-10.mp4: Logit: -0.0956 -> P(class 1)=0.4761 -> 予測クラス: 0 (確信度: 52.39%)
#   - ASD_Left_20180123_1652_1-10.mp4: Logit: -0.1587 -> P(class 1)=0.4604 -> 予測クラス: 0 (確信度: 53.96%)
#   - ASD_Left_20180123_1652_10-10.mp4: Logit: -0.0425 -> P(class 1)=0.4894 -> 予測クラス: 0 (確信度: 51.06%)
#   - ASD_Left_20180123_1652_2-10.mp4: Logit: -0.0651 -> P(class 1)=0.4837 -> 予測クラス: 0 (確信度: 51.63%)
#
# --- [バッチ 7] 推論中 ---
#   - ASD_Left_20180123_1652_3-10.mp4: Logit: 0.0315 -> P(class 1)=0.5079 -> 予測クラス: 1 (確信度: 50.79%)
#   - ASD_Left_20180123_1652_4-10.mp4: Logit: -0.0422 -> P(class 1)=0.4895 -> 予測クラス: 0 (確信度: 51.05%)
#   - ASD_Left_20180123_1652_5-10.mp4: Logit: -0.1076 -> P(class 1)=0.4731 -> 予測クラス: 0 (確信度: 52.69%)
#   - ASD_Left_20180123_1652_6-10.mp4: Logit: -0.3026 -> P(class 1)=0.4249 -> 予測クラス: 0 (確信度: 57.51%)
#
# --- [バッチ 8] 推論中 ---
#   - ASD_Left_20180123_1652_7-10.mp4: Logit: -0.2050 -> P(class 1)=0.4489 -> 予測クラス: 0 (確信度: 55.11%)
#   - ASD_Left_20180123_1652_8-10.mp4: Logit: -0.0100 -> P(class 1)=0.4975 -> 予測クラス: 0 (確信度: 50.25%)
#   - ASD_Left_20180123_1652_9-10.mp4: Logit: -0.0116 -> P(class 1)=0.4971 -> 予測クラス: 0 (確信度: 50.29%)
#   - ASD_Left_20180123_1654_1-11.mp4: Logit: -0.0383 -> P(class 1)=0.4904 -> 予測クラス: 0 (確信度: 50.96%)
#
# --- [バッチ 9] 推論中 ---
#   - ASD_Left_20180123_1654_10-11.mp4: Logit: -0.1488 -> P(class 1)=0.4629 -> 予測クラス: 0 (確信度: 53.71%)
#   - ASD_Left_20180123_1654_11-11.mp4: Logit: -0.0972 -> P(class 1)=0.4757 -> 予測クラス: 0 (確信度: 52.43%)
#   - ASD_Left_20180123_1654_2-11.mp4: Logit: 0.1389 -> P(class 1)=0.5347 -> 予測クラス: 1 (確信度: 53.47%)
#   - ASD_Left_20180123_1654_3-11.mp4: Logit: 0.0157 -> P(class 1)=0.5039 -> 予測クラス: 1 (確信度: 50.39%)
#
# --- [バッチ 10] 推論中 ---
#   - ASD_Left_20180123_1654_4-11.mp4: Logit: 0.0159 -> P(class 1)=0.5040 -> 予測クラス: 1 (確信度: 50.40%)
#   - ASD_Left_20180123_1654_5-11.mp4: Logit: -0.1321 -> P(class 1)=0.4670 -> 予測クラス: 0 (確信度: 53.30%)
#   - ASD_Left_20180123_1654_6-11.mp4: Logit: -0.1060 -> P(class 1)=0.4735 -> 予測クラス: 0 (確信度: 52.65%)
#   - ASD_Left_20180123_1654_7-11.mp4: Logit: -0.1021 -> P(class 1)=0.4745 -> 予測クラス: 0 (確信度: 52.55%)
#
# --- [バッチ 11] 推論中 ---
#   - ASD_Left_20180123_1654_8-11.mp4: Logit: -0.2411 -> P(class 1)=0.4400 -> 予測クラス: 0 (確信度: 56.00%)
#   - ASD_Left_20180123_1654_9-11.mp4: Logit: -0.1187 -> P(class 1)=0.4704 -> 予測クラス: 0 (確信度: 52.96%)
#   - ASD_Left_20180123_1656_1-10.mp4: Logit: 0.0370 -> P(class 1)=0.5092 -> 予測クラス: 1 (確信度: 50.92%)
#   - ASD_Left_20180123_1656_10-10.mp4: Logit: -0.1261 -> P(class 1)=0.4685 -> 予測クラス: 0 (確信度: 53.15%)
#
# --- [バッチ 12] 推論中 ---
#   - ASD_Left_20180123_1656_2-10.mp4: Logit: -0.0085 -> P(class 1)=0.4979 -> 予測クラス: 0 (確信度: 50.21%)
#   - ASD_Left_20180123_1656_3-10.mp4: Logit: 0.0123 -> P(class 1)=0.5031 -> 予測クラス: 1 (確信度: 50.31%)
#   - ASD_Left_20180123_1656_4-10.mp4: Logit: -0.0776 -> P(class 1)=0.4806 -> 予測クラス: 0 (確信度: 51.94%)
#   - ASD_Left_20180123_1656_5-10.mp4: Logit: -0.2149 -> P(class 1)=0.4465 -> 予測クラス: 0 (確信度: 55.35%)
#
# --- [バッチ 13] 推論中 ---
#   - ASD_Left_20180123_1656_6-10.mp4: Logit: -0.1637 -> P(class 1)=0.4592 -> 予測クラス: 0 (確信度: 54.08%)
#   - ASD_Left_20180123_1656_7-10.mp4: Logit: -0.2313 -> P(class 1)=0.4424 -> 予測クラス: 0 (確信度: 55.76%)
#   - ASD_Left_20180123_1656_8-10.mp4: Logit: -0.1359 -> P(class 1)=0.4661 -> 予測クラス: 0 (確信度: 53.39%)
#   - ASD_Left_20180123_1656_9-10.mp4: Logit: -0.1541 -> P(class 1)=0.4615 -> 予測クラス: 0 (確信度: 53.85%)
#
# --- [バッチ 14] 推論中 ---
#   - ASD_Left_20180123_1658_1-9.mp4: Logit: -0.1450 -> P(class 1)=0.4638 -> 予測クラス: 0 (確信度: 53.62%)
#   - ASD_Left_20180123_1658_2-9.mp4: Logit: 0.0232 -> P(class 1)=0.5058 -> 予測クラス: 1 (確信度: 50.58%)
#   - ASD_Left_20180123_1658_3-9.mp4: Logit: -0.0170 -> P(class 1)=0.4958 -> 予測クラス: 0 (確信度: 50.42%)
#   - ASD_Left_20180123_1658_4-9.mp4: Logit: -0.0166 -> P(class 1)=0.4958 -> 予測クラス: 0 (確信度: 50.42%)
#
# --- [バッチ 15] 推論中 ---
#   - ASD_Left_20180123_1658_5-9.mp4: Logit: -0.1172 -> P(class 1)=0.4707 -> 予測クラス: 0 (確信度: 52.93%)
#   - ASD_Left_20180123_1658_6-9.mp4: Logit: -0.4164 -> P(class 1)=0.3974 -> 予測クラス: 0 (確信度: 60.26%)
#   - ASD_Left_20180123_1658_7-9.mp4: Logit: -0.0877 -> P(class 1)=0.4781 -> 予測クラス: 0 (確信度: 52.19%)
#   - ASD_Left_20180123_1658_8-9.mp4: Logit: -0.0967 -> P(class 1)=0.4758 -> 予測クラス: 0 (確信度: 52.42%)
#
# --- [バッチ 16] 推論中 ---
#   - ASD_Left_20180123_1658_9-9.mp4: Logit: 0.0230 -> P(class 1)=0.5057 -> 予測クラス: 1 (確信度: 50.57%)
#   - ASD_Left_20180123_1660_1-10.mp4: Logit: -0.0929 -> P(class 1)=0.4768 -> 予測クラス: 0 (確信度: 52.32%)
#   - ASD_Left_20180123_1660_10-10.mp4: Logit: -0.2838 -> P(class 1)=0.4295 -> 予測クラス: 0 (確信度: 57.05%)
#   - ASD_Left_20180123_1660_2-10.mp4: Logit: -0.0859 -> P(class 1)=0.4785 -> 予測クラス: 0 (確信度: 52.15%)
#
# --- [バッチ 17] 推論中 ---
#   - ASD_Left_20180123_1660_3-10.mp4: Logit: 0.0371 -> P(class 1)=0.5093 -> 予測クラス: 1 (確信度: 50.93%)
#   - ASD_Left_20180123_1660_4-10.mp4: Logit: -0.0563 -> P(class 1)=0.4859 -> 予測クラス: 0 (確信度: 51.41%)
#   - ASD_Left_20180123_1660_5-10.mp4: Logit: -0.0481 -> P(class 1)=0.4880 -> 予測クラス: 0 (確信度: 51.20%)
#   - ASD_Left_20180123_1660_6-10.mp4: Logit: -0.1298 -> P(class 1)=0.4676 -> 予測クラス: 0 (確信度: 53.24%)
#
# --- [バッチ 18] 推論中 ---
#   - ASD_Left_20180123_1660_7-10.mp4: Logit: -0.2622 -> P(class 1)=0.4348 -> 予測クラス: 0 (確信度: 56.52%)
#   - ASD_Left_20180123_1660_8-10.mp4: Logit: -0.2634 -> P(class 1)=0.4345 -> 予測クラス: 0 (確信度: 56.55%)
#   - ASD_Left_20180123_1660_9-10.mp4: Logit: 0.0154 -> P(class 1)=0.5038 -> 予測クラス: 1 (確信度: 50.38%)
#   - ASD_Left_20180123_1662_1-10.mp4: Logit: 0.0691 -> P(class 1)=0.5173 -> 予測クラス: 1 (確信度: 51.73%)
#
# --- [バッチ 19] 推論中 ---
#   - ASD_Left_20180123_1662_10-10.mp4: Logit: -0.1607 -> P(class 1)=0.4599 -> 予測クラス: 0 (確信度: 54.01%)
#   - ASD_Left_20180123_1662_2-10.mp4: Logit: -0.1067 -> P(class 1)=0.4734 -> 予測クラス: 0 (確信度: 52.66%)
#   - ASD_Left_20180123_1662_3-10.mp4: Logit: 0.0038 -> P(class 1)=0.5009 -> 予測クラス: 1 (確信度: 50.09%)
#   - ASD_Left_20180123_1662_4-10.mp4: Logit: -0.0610 -> P(class 1)=0.4848 -> 予測クラス: 0 (確信度: 51.52%)
#
# --- [バッチ 20] 推論中 ---
#   - ASD_Left_20180123_1662_5-10.mp4: Logit: -0.0141 -> P(class 1)=0.4965 -> 予測クラス: 0 (確信度: 50.35%)
#   - ASD_Left_20180123_1662_6-10.mp4: Logit: -0.1299 -> P(class 1)=0.4676 -> 予測クラス: 0 (確信度: 53.24%)
#   - ASD_Left_20180123_1662_7-10.mp4: Logit: -0.1297 -> P(class 1)=0.4676 -> 予測クラス: 0 (確信度: 53.24%)
#   - ASD_Left_20180123_1662_8-10.mp4: Logit: -0.2656 -> P(class 1)=0.4340 -> 予測クラス: 0 (確信度: 56.60%)
#
# --- [バッチ 21] 推論中 ---
#   - ASD_Left_20180123_1662_9-10.mp4: Logit: -0.0496 -> P(class 1)=0.4876 -> 予測クラス: 0 (確信度: 51.24%)
#   - ASD_Left_20180123_1664_1-3.mp4: Logit: -0.0520 -> P(class 1)=0.4870 -> 予測クラス: 0 (確信度: 51.30%)
#   - ASD_Left_20180123_1664_2-3.mp4: Logit: -0.0138 -> P(class 1)=0.4966 -> 予測クラス: 0 (確信度: 50.34%)
#   - ASD_Left_20180123_1664_3-3.mp4: Logit: -0.0592 -> P(class 1)=0.4852 -> 予測クラス: 0 (確信度: 51.48%)
#
# --- [バッチ 22] 推論中 ---
#   - ASD_Left_20180123_1665_1-10.mp4: Logit: -0.3380 -> P(class 1)=0.4163 -> 予測クラス: 0 (確信度: 58.37%)
#   - ASD_Left_20180123_1665_10-10.mp4: Logit: -0.2392 -> P(class 1)=0.4405 -> 予測クラス: 0 (確信度: 55.95%)
#   - ASD_Left_20180123_1665_2-10.mp4: Logit: -0.4817 -> P(class 1)=0.3819 -> 予測クラス: 0 (確信度: 61.81%)
#   - ASD_Left_20180123_1665_3-10.mp4: Logit: -0.5106 -> P(class 1)=0.3751 -> 予測クラス: 0 (確信度: 62.49%)
#
# --- [バッチ 23] 推論中 ---
#   - ASD_Left_20180123_1665_4-10.mp4: Logit: -0.3993 -> P(class 1)=0.4015 -> 予測クラス: 0 (確信度: 59.85%)
#   - ASD_Left_20180123_1665_5-10.mp4: Logit: -0.5493 -> P(class 1)=0.3660 -> 予測クラス: 0 (確信度: 63.40%)
#   - ASD_Left_20180123_1665_6-10.mp4: Logit: -0.4387 -> P(class 1)=0.3920 -> 予測クラス: 0 (確信度: 60.80%)
#   - ASD_Left_20180123_1665_7-10.mp4: Logit: -0.5645 -> P(class 1)=0.3625 -> 予測クラス: 0 (確信度: 63.75%)
#
# --- [バッチ 24] 推論中 ---
#   - ASD_Left_20180123_1665_8-10.mp4: Logit: -0.4267 -> P(class 1)=0.3949 -> 予測クラス: 0 (確信度: 60.51%)
#   - ASD_Left_20180123_1665_9-10.mp4: Logit: -0.2923 -> P(class 1)=0.4274 -> 予測クラス: 0 (確信度: 57.26%)
#   - ASD_Left_20180312_1667_1-2.mp4: Logit: -0.1689 -> P(class 1)=0.4579 -> 予測クラス: 0 (確信度: 54.21%)
#   - ASD_Left_20180312_1667_2-2.mp4: Logit: -0.4907 -> P(class 1)=0.3797 -> 予測クラス: 0 (確信度: 62.03%)
#
# --- [バッチ 25] 推論中 ---
#   - ASD_Left_20180312_1668_1-6.mp4: Logit: -0.1303 -> P(class 1)=0.4675 -> 予測クラス: 0 (確信度: 53.25%)
#   - ASD_Left_20180312_1668_2-6.mp4: Logit: -0.0363 -> P(class 1)=0.4909 -> 予測クラス: 0 (確信度: 50.91%)
#   - ASD_Left_20180312_1668_3-6.mp4: Logit: -0.3321 -> P(class 1)=0.4177 -> 予測クラス: 0 (確信度: 58.23%)
#   - ASD_Left_20180312_1668_4-6.mp4: Logit: -0.0468 -> P(class 1)=0.4883 -> 予測クラス: 0 (確信度: 51.17%)
#
# --- [バッチ 26] 推論中 ---
#   - ASD_Left_20180312_1668_5-6.mp4: Logit: -0.4160 -> P(class 1)=0.3975 -> 予測クラス: 0 (確信度: 60.25%)
#   - ASD_Left_20180312_1668_6-6.mp4: Logit: -0.0299 -> P(class 1)=0.4925 -> 予測クラス: 0 (確信度: 50.75%)
#   - ASD_Left_20180312_1670_1-10.mp4: Logit: -0.1628 -> P(class 1)=0.4594 -> 予測クラス: 0 (確信度: 54.06%)
#   - ASD_Left_20180312_1670_10-10.mp4: Logit: 0.1955 -> P(class 1)=0.5487 -> 予測クラス: 1 (確信度: 54.87%)
#
# --- [バッチ 27] 推論中 ---
#   - ASD_Left_20180312_1670_2-10.mp4: Logit: -0.0459 -> P(class 1)=0.4885 -> 予測クラス: 0 (確信度: 51.15%)
#   - ASD_Left_20180312_1670_3-10.mp4: Logit: -0.1566 -> P(class 1)=0.4609 -> 予測クラス: 0 (確信度: 53.91%)
#   - ASD_Left_20180312_1670_4-10.mp4: Logit: -0.5284 -> P(class 1)=0.3709 -> 予測クラス: 0 (確信度: 62.91%)
#   - ASD_Left_20180312_1670_5-10.mp4: Logit: 0.1010 -> P(class 1)=0.5252 -> 予測クラス: 1 (確信度: 52.52%)
#
# --- [バッチ 28] 推論中 ---
#   - ASD_Left_20180312_1670_6-10.mp4: Logit: -0.2030 -> P(class 1)=0.4494 -> 予測クラス: 0 (確信度: 55.06%)
#   - ASD_Left_20180312_1670_7-10.mp4: Logit: 0.0161 -> P(class 1)=0.5040 -> 予測クラス: 1 (確信度: 50.40%)
#   - ASD_Left_20180312_1670_8-10.mp4: Logit: 0.4141 -> P(class 1)=0.6021 -> 予測クラス: 1 (確信度: 60.21%)
#   - ASD_Left_20180312_1670_9-10.mp4: Logit: 0.4122 -> P(class 1)=0.6016 -> 予測クラス: 1 (確信度: 60.16%)
#
# --- [バッチ 29] 推論中 ---
#   - ASD_Left_20180521_1_1507_1-9.mp4: Logit: -1.2079 -> P(class 1)=0.2301 -> 予測クラス: 0 (確信度: 76.99%)
#   - ASD_Left_20180521_1_1507_2-9.mp4: Logit: -1.2481 -> P(class 1)=0.2230 -> 予測クラス: 0 (確信度: 77.70%)
#   - ASD_Left_20180521_1_1507_3-9.mp4: Logit: -1.5742 -> P(class 1)=0.1716 -> 予測クラス: 0 (確信度: 82.84%)
#   - ASD_Left_20180521_1_1507_4-9.mp4: Logit: -1.4629 -> P(class 1)=0.1880 -> 予測クラス: 0 (確信度: 81.20%)
#
# --- [バッチ 30] 推論中 ---
#   - ASD_Left_20180521_1_1507_5-9.mp4: Logit: -1.4971 -> P(class 1)=0.1829 -> 予測クラス: 0 (確信度: 81.71%)
#   - ASD_Left_20180521_1_1507_6-9.mp4: Logit: -1.0022 -> P(class 1)=0.2685 -> 予測クラス: 0 (確信度: 73.15%)
#   - ASD_Left_20180521_1_1507_7-9.mp4: Logit: -1.3493 -> P(class 1)=0.2060 -> 予測クラス: 0 (確信度: 79.40%)
#   - ASD_Left_20180521_1_1507_8-9.mp4: Logit: -1.0603 -> P(class 1)=0.2572 -> 予測クラス: 0 (確信度: 74.28%)
#
# --- [バッチ 31] 推論中 ---
#   - ASD_Left_20180521_1_1507_9-9.mp4: Logit: -1.4321 -> P(class 1)=0.1928 -> 予測クラス: 0 (確信度: 80.72%)
#   - ASD_Left_20180521_1_1509_1-9.mp4: Logit: -1.1339 -> P(class 1)=0.2435 -> 予測クラス: 0 (確信度: 75.65%)
#   - ASD_Left_20180521_1_1509_2-9.mp4: Logit: -1.1510 -> P(class 1)=0.2403 -> 予測クラス: 0 (確信度: 75.97%)
#   - ASD_Left_20180521_1_1509_3-9.mp4: Logit: -1.5158 -> P(class 1)=0.1801 -> 予測クラス: 0 (確信度: 81.99%)
#
# --- [バッチ 32] 推論中 ---
#   - ASD_Left_20180521_1_1509_4-9.mp4: Logit: -1.2687 -> P(class 1)=0.2195 -> 予測クラス: 0 (確信度: 78.05%)
#   - ASD_Left_20180521_1_1509_5-9.mp4: Logit: -1.5605 -> P(class 1)=0.1736 -> 予測クラス: 0 (確信度: 82.64%)
#   - ASD_Left_20180521_1_1509_6-9.mp4: Logit: -1.0876 -> P(class 1)=0.2521 -> 予測クラス: 0 (確信度: 74.79%)
#   - ASD_Left_20180521_1_1509_7-9.mp4: Logit: -1.3687 -> P(class 1)=0.2028 -> 予測クラス: 0 (確信度: 79.72%)
#
# --- [バッチ 33] 推論中 ---
#   - ASD_Left_20180521_1_1509_8-9.mp4: Logit: -0.9728 -> P(class 1)=0.2743 -> 予測クラス: 0 (確信度: 72.57%)
#   - ASD_Left_20180521_1_1509_9-9.mp4: Logit: -1.4385 -> P(class 1)=0.1918 -> 予測クラス: 0 (確信度: 80.82%)
#   - ASD_Left_20180521_1_1511_1-9.mp4: Logit: -1.1775 -> P(class 1)=0.2355 -> 予測クラス: 0 (確信度: 76.45%)
#   - ASD_Left_20180521_1_1511_2-9.mp4: Logit: -1.3639 -> P(class 1)=0.2036 -> 予測クラス: 0 (確信度: 79.64%)
#
# --- [バッチ 34] 推論中 ---
#   - ASD_Left_20180521_1_1511_3-9.mp4: Logit: -1.3914 -> P(class 1)=0.1992 -> 予測クラス: 0 (確信度: 80.08%)
#   - ASD_Left_20180521_1_1511_4-9.mp4: Logit: -1.2593 -> P(class 1)=0.2211 -> 予測クラス: 0 (確信度: 77.89%)
#   - ASD_Left_20180521_1_1511_5-9.mp4: Logit: -1.3991 -> P(class 1)=0.1980 -> 予測クラス: 0 (確信度: 80.20%)
#   - ASD_Left_20180521_1_1511_6-9.mp4: Logit: -1.3629 -> P(class 1)=0.2038 -> 予測クラス: 0 (確信度: 79.62%)
#
# --- [バッチ 35] 推論中 ---
#   - ASD_Left_20180521_1_1511_7-9.mp4: Logit: -0.9600 -> P(class 1)=0.2769 -> 予測クラス: 0 (確信度: 72.31%)
#   - ASD_Left_20180521_1_1511_8-9.mp4: Logit: -1.0537 -> P(class 1)=0.2585 -> 予測クラス: 0 (確信度: 74.15%)
#   - ASD_Left_20180521_1_1511_9-9.mp4: Logit: -1.1387 -> P(class 1)=0.2426 -> 予測クラス: 0 (確信度: 75.74%)
#   - ASD_Left_20180521_1_1513_1-8.mp4: Logit: -1.1532 -> P(class 1)=0.2399 -> 予測クラス: 0 (確信度: 76.01%)
#
# --- [バッチ 36] 推論中 ---
#   - ASD_Left_20180521_1_1513_2-8.mp4: Logit: -1.3597 -> P(class 1)=0.2043 -> 予測クラス: 0 (確信度: 79.57%)
#   - ASD_Left_20180521_1_1513_3-8.mp4: Logit: -1.3965 -> P(class 1)=0.1984 -> 予測クラス: 0 (確信度: 80.16%)
#   - ASD_Left_20180521_1_1513_4-8.mp4: Logit: -1.4585 -> P(class 1)=0.1887 -> 予測クラス: 0 (確信度: 81.13%)
#   - ASD_Left_20180521_1_1513_5-8.mp4: Logit: -1.1715 -> P(class 1)=0.2366 -> 予測クラス: 0 (確信度: 76.34%)
#
# --- [バッチ 37] 推論中 ---
#   - ASD_Left_20180521_1_1513_6-8.mp4: Logit: -1.2969 -> P(class 1)=0.2147 -> 予測クラス: 0 (確信度: 78.53%)
#   - ASD_Left_20180521_1_1513_7-8.mp4: Logit: -1.0190 -> P(class 1)=0.2652 -> 予測クラス: 0 (確信度: 73.48%)
#   - ASD_Left_20180521_1_1513_8-8.mp4: Logit: -0.9528 -> P(class 1)=0.2783 -> 予測クラス: 0 (確信度: 72.17%)
#   - ASD_Left_20180521_1_1515_1-9.mp4: Logit: -1.3893 -> P(class 1)=0.1995 -> 予測クラス: 0 (確信度: 80.05%)
#
# --- [バッチ 38] 推論中 ---
#   - ASD_Left_20180521_1_1515_2-9.mp4: Logit: -1.1340 -> P(class 1)=0.2434 -> 予測クラス: 0 (確信度: 75.66%)
#   - ASD_Left_20180521_1_1515_3-9.mp4: Logit: -1.3501 -> P(class 1)=0.2059 -> 予測クラス: 0 (確信度: 79.41%)
#   - ASD_Left_20180521_1_1515_4-9.mp4: Logit: -1.4991 -> P(class 1)=0.1826 -> 予測クラス: 0 (確信度: 81.74%)
#   - ASD_Left_20180521_1_1515_5-9.mp4: Logit: -1.7244 -> P(class 1)=0.1513 -> 予測クラス: 0 (確信度: 84.87%)
#
# --- [バッチ 39] 推論中 ---
#   - ASD_Left_20180521_1_1515_6-9.mp4: Logit: -0.9742 -> P(class 1)=0.2740 -> 予測クラス: 0 (確信度: 72.60%)
#   - ASD_Left_20180521_1_1515_7-9.mp4: Logit: -1.1786 -> P(class 1)=0.2353 -> 予測クラス: 0 (確信度: 76.47%)
#   - ASD_Left_20180521_1_1515_8-9.mp4: Logit: -1.0583 -> P(class 1)=0.2576 -> 予測クラス: 0 (確信度: 74.24%)
#   - ASD_Left_20180521_1_1515_9-9.mp4: Logit: -1.0915 -> P(class 1)=0.2513 -> 予測クラス: 0 (確信度: 74.87%)
#
# --- [バッチ 40] 推論中 ---
#   - ASD_Left_20180521_1_1517_1-8.mp4: Logit: -1.1500 -> P(class 1)=0.2405 -> 予測クラス: 0 (確信度: 75.95%)
#   - ASD_Left_20180521_1_1517_2-8.mp4: Logit: -1.2036 -> P(class 1)=0.2308 -> 予測クラス: 0 (確信度: 76.92%)
#   - ASD_Left_20180521_1_1517_3-8.mp4: Logit: -1.6076 -> P(class 1)=0.1669 -> 予測クラス: 0 (確信度: 83.31%)
#   - ASD_Left_20180521_1_1517_4-8.mp4: Logit: -1.4009 -> P(class 1)=0.1977 -> 予測クラス: 0 (確信度: 80.23%)
#
# --- [バッチ 41] 推論中 ---
#   - ASD_Left_20180521_1_1517_5-8.mp4: Logit: -1.3990 -> P(class 1)=0.1980 -> 予測クラス: 0 (確信度: 80.20%)
#   - ASD_Left_20180521_1_1517_6-8.mp4: Logit: -0.9888 -> P(class 1)=0.2711 -> 予測クラス: 0 (確信度: 72.89%)
#   - ASD_Left_20180521_1_1517_7-8.mp4: Logit: -1.1430 -> P(class 1)=0.2418 -> 予測クラス: 0 (確信度: 75.82%)
#   - ASD_Left_20180521_1_1517_8-8.mp4: Logit: -1.0960 -> P(class 1)=0.2505 -> 予測クラス: 0 (確信度: 74.95%)
#
# --- [バッチ 42] 推論中 ---
#   - ASD_Left_20180521_1_1519_1-9.mp4: Logit: -1.0688 -> P(class 1)=0.2556 -> 予測クラス: 0 (確信度: 74.44%)
#   - ASD_Left_20180521_1_1519_2-9.mp4: Logit: -1.3578 -> P(class 1)=0.2046 -> 予測クラス: 0 (確信度: 79.54%)
#   - ASD_Left_20180521_1_1519_3-9.mp4: Logit: -1.3773 -> P(class 1)=0.2014 -> 予測クラス: 0 (確信度: 79.86%)
#   - ASD_Left_20180521_1_1519_4-9.mp4: Logit: -1.1337 -> P(class 1)=0.2435 -> 予測クラス: 0 (確信度: 75.65%)
#
# --- [バッチ 43] 推論中 ---
#   - ASD_Left_20180521_1_1519_5-9.mp4: Logit: -1.4669 -> P(class 1)=0.1874 -> 予測クラス: 0 (確信度: 81.26%)
#   - ASD_Left_20180521_1_1519_6-9.mp4: Logit: -1.4028 -> P(class 1)=0.1974 -> 予測クラス: 0 (確信度: 80.26%)
#   - ASD_Left_20180521_1_1519_7-9.mp4: Logit: -0.9104 -> P(class 1)=0.2869 -> 予測クラス: 0 (確信度: 71.31%)
#   - ASD_Left_20180521_1_1519_8-9.mp4: Logit: -1.1846 -> P(class 1)=0.2342 -> 予測クラス: 0 (確信度: 76.58%)
#
# --- [バッチ 44] 推論中 ---
#   - ASD_Left_20180521_1_1519_9-9.mp4: Logit: -1.1227 -> P(class 1)=0.2455 -> 予測クラス: 0 (確信度: 75.45%)
#   - ASD_Left_20180521_1_1521_1-9.mp4: Logit: -1.1026 -> P(class 1)=0.2492 -> 予測クラス: 0 (確信度: 75.08%)
#   - ASD_Left_20180521_1_1521_2-9.mp4: Logit: -1.3357 -> P(class 1)=0.2082 -> 予測クラス: 0 (確信度: 79.18%)
#   - ASD_Left_20180521_1_1521_3-9.mp4: Logit: -1.4351 -> P(class 1)=0.1923 -> 予測クラス: 0 (確信度: 80.77%)
#
# --- [バッチ 45] 推論中 ---
#   - ASD_Left_20180521_1_1521_4-9.mp4: Logit: -1.3302 -> P(class 1)=0.2091 -> 予測クラス: 0 (確信度: 79.09%)
#   - ASD_Left_20180521_1_1521_5-9.mp4: Logit: -1.3089 -> P(class 1)=0.2127 -> 予測クラス: 0 (確信度: 78.73%)
#   - ASD_Left_20180521_1_1521_6-9.mp4: Logit: -0.8776 -> P(class 1)=0.2937 -> 予測クラス: 0 (確信度: 70.63%)
#   - ASD_Left_20180521_1_1521_7-9.mp4: Logit: -0.6878 -> P(class 1)=0.3345 -> 予測クラス: 0 (確信度: 66.55%)
#
# --- [バッチ 46] 推論中 ---
#   - ASD_Left_20180521_1_1521_8-9.mp4: Logit: -1.0110 -> P(class 1)=0.2668 -> 予測クラス: 0 (確信度: 73.32%)
#   - ASD_Left_20180521_1_1521_9-9.mp4: Logit: -1.0545 -> P(class 1)=0.2584 -> 予測クラス: 0 (確信度: 74.16%)
#   - ASD_Left_20180521_2_1765_1-5.mp4: Logit: -1.5347 -> P(class 1)=0.1773 -> 予測クラス: 0 (確信度: 82.27%)
#   - ASD_Left_20180521_2_1765_2-5.mp4: Logit: -1.6813 -> P(class 1)=0.1569 -> 予測クラス: 0 (確信度: 84.31%)
#
# --- [バッチ 47] 推論中 ---
#   - ASD_Left_20180521_2_1765_3-5.mp4: Logit: -1.7442 -> P(class 1)=0.1488 -> 予測クラス: 0 (確信度: 85.12%)
#   - ASD_Left_20180521_2_1765_4-5.mp4: Logit: -1.8628 -> P(class 1)=0.1344 -> 予測クラス: 0 (確信度: 86.56%)
#   - ASD_Left_20180521_2_1765_5-5.mp4: Logit: -1.1550 -> P(class 1)=0.2396 -> 予測クラス: 0 (確信度: 76.04%)
#   - ASD_Left_20180521_2_1767_1-4.mp4: Logit: -1.5810 -> P(class 1)=0.1706 -> 予測クラス: 0 (確信度: 82.94%)
#
# --- [バッチ 48] 推論中 ---
#   - ASD_Left_20180521_2_1767_2-4.mp4: Logit: -1.7740 -> P(class 1)=0.1450 -> 予測クラス: 0 (確信度: 85.50%)
#   - ASD_Left_20180521_2_1767_3-4.mp4: Logit: -1.8573 -> P(class 1)=0.1350 -> 予測クラス: 0 (確信度: 86.50%)
#   - ASD_Left_20180521_2_1767_4-4.mp4: Logit: -1.6890 -> P(class 1)=0.1559 -> 予測クラス: 0 (確信度: 84.41%)
#   - ASD_Left_20180521_2_1769_1-4.mp4: Logit: -1.7239 -> P(class 1)=0.1514 -> 予測クラス: 0 (確信度: 84.86%)
#
# --- [バッチ 49] 推論中 ---
#   - ASD_Left_20180521_2_1769_2-4.mp4: Logit: -1.6022 -> P(class 1)=0.1677 -> 予測クラス: 0 (確信度: 83.23%)
#   - ASD_Left_20180521_2_1769_3-4.mp4: Logit: -1.4386 -> P(class 1)=0.1918 -> 予測クラス: 0 (確信度: 80.82%)
#   - ASD_Left_20180521_2_1769_4-4.mp4: Logit: -1.5718 -> P(class 1)=0.1720 -> 予測クラス: 0 (確信度: 82.80%)
#   - ASD_Left_20180521_2_1771_1-4.mp4: Logit: -1.4349 -> P(class 1)=0.1923 -> 予測クラス: 0 (確信度: 80.77%)
#
# --- [バッチ 50] 推論中 ---
#   - ASD_Left_20180521_2_1771_2-4.mp4: Logit: -1.6642 -> P(class 1)=0.1592 -> 予測クラス: 0 (確信度: 84.08%)
#   - ASD_Left_20180521_2_1771_3-4.mp4: Logit: -1.7235 -> P(class 1)=0.1514 -> 予測クラス: 0 (確信度: 84.86%)
#   - ASD_Left_20180521_2_1771_4-4.mp4: Logit: -1.6955 -> P(class 1)=0.1551 -> 予測クラス: 0 (確信度: 84.49%)
#   - ASD_Left_20180521_2_1773_1-5.mp4: Logit: -1.4568 -> P(class 1)=0.1890 -> 予測クラス: 0 (確信度: 81.10%)
#
# --- [バッチ 51] 推論中 ---
#   - ASD_Left_20180521_2_1773_2-5.mp4: Logit: -1.4485 -> P(class 1)=0.1902 -> 予測クラス: 0 (確信度: 80.98%)
#   - ASD_Left_20180521_2_1773_3-5.mp4: Logit: -1.5724 -> P(class 1)=0.1719 -> 予測クラス: 0 (確信度: 82.81%)
#   - ASD_Left_20180521_2_1773_4-5.mp4: Logit: -1.6888 -> P(class 1)=0.1559 -> 予測クラス: 0 (確信度: 84.41%)
#   - ASD_Left_20180521_2_1773_5-5.mp4: Logit: -0.9488 -> P(class 1)=0.2791 -> 予測クラス: 0 (確信度: 72.09%)
#
# --- [バッチ 52] 推論中 ---
#   - ASD_Left_20180521_2_1775_1-5.mp4: Logit: -1.7155 -> P(class 1)=0.1525 -> 予測クラス: 0 (確信度: 84.75%)
#   - ASD_Left_20180521_2_1775_2-5.mp4: Logit: -1.4535 -> P(class 1)=0.1895 -> 予測クラス: 0 (確信度: 81.05%)
#   - ASD_Left_20180521_2_1775_3-5.mp4: Logit: -1.4407 -> P(class 1)=0.1914 -> 予測クラス: 0 (確信度: 80.86%)
#   - ASD_Left_20180521_2_1775_4-5.mp4: Logit: -1.6579 -> P(class 1)=0.1600 -> 予測クラス: 0 (確信度: 84.00%)
#
# --- [バッチ 53] 推論中 ---
#   - ASD_Left_20180521_2_1775_5-5.mp4: Logit: -1.0312 -> P(class 1)=0.2628 -> 予測クラス: 0 (確信度: 73.72%)
#   - ASD_Left_20180521_2_1777_1-4.mp4: Logit: -1.5490 -> P(class 1)=0.1752 -> 予測クラス: 0 (確信度: 82.48%)
#   - ASD_Left_20180521_2_1777_2-4.mp4: Logit: -1.5904 -> P(class 1)=0.1693 -> 予測クラス: 0 (確信度: 83.07%)
#   - ASD_Left_20180521_2_1777_3-4.mp4: Logit: -1.8994 -> P(class 1)=0.1302 -> 予測クラス: 0 (確信度: 86.98%)
#
# --- [バッチ 54] 推論中 ---
#   - ASD_Left_20180521_2_1777_4-4.mp4: Logit: -1.7732 -> P(class 1)=0.1451 -> 予測クラス: 0 (確信度: 85.49%)
#   - ASD_Left_20180521_2_1779_1-4.mp4: Logit: -1.5941 -> P(class 1)=0.1688 -> 予測クラス: 0 (確信度: 83.12%)
#   - ASD_Left_20180521_2_1779_2-4.mp4: Logit: -1.5747 -> P(class 1)=0.1716 -> 予測クラス: 0 (確信度: 82.84%)
#   - ASD_Left_20180521_2_1779_3-4.mp4: Logit: -1.5807 -> P(class 1)=0.1707 -> 予測クラス: 0 (確信度: 82.93%)
#
# --- [バッチ 55] 推論中 ---
#   - ASD_Left_20180521_2_1779_4-4.mp4: Logit: -1.6638 -> P(class 1)=0.1593 -> 予測クラス: 0 (確信度: 84.07%)
#   - ASD_Left_20180521_2_1781_1-4.mp4: Logit: -1.7081 -> P(class 1)=0.1534 -> 予測クラス: 0 (確信度: 84.66%)
#   - ASD_Left_20180521_2_1781_2-4.mp4: Logit: -1.2695 -> P(class 1)=0.2193 -> 予測クラス: 0 (確信度: 78.07%)
#   - ASD_Left_20180521_2_1781_3-4.mp4: Logit: -1.8733 -> P(class 1)=0.1332 -> 予測クラス: 0 (確信度: 86.68%)
#
# --- [バッチ 56] 推論中 ---
#   - ASD_Left_20180521_2_1781_4-4.mp4: Logit: -1.5252 -> P(class 1)=0.1787 -> 予測クラス: 0 (確信度: 82.13%)
#   - ASD_Left_20180521_2_1783_1-4.mp4: Logit: -1.4870 -> P(class 1)=0.1844 -> 予測クラス: 0 (確信度: 81.56%)
#   - ASD_Left_20180521_2_1783_2-4.mp4: Logit: -1.4280 -> P(class 1)=0.1934 -> 予測クラス: 0 (確信度: 80.66%)
#   - ASD_Left_20180521_2_1783_3-4.mp4: Logit: -1.9097 -> P(class 1)=0.1290 -> 予測クラス: 0 (確信度: 87.10%)
#
# --- [バッチ 57] 推論中 ---
#   - ASD_Left_20180521_2_1783_4-4.mp4: Logit: -1.7328 -> P(class 1)=0.1502 -> 予測クラス: 0 (確信度: 84.98%)
#   - ASD_Left_20180521_2_1785_1-5.mp4: Logit: -1.6567 -> P(class 1)=0.1602 -> 予測クラス: 0 (確信度: 83.98%)
#   - ASD_Left_20180521_2_1785_2-5.mp4: Logit: -1.5897 -> P(class 1)=0.1694 -> 予測クラス: 0 (確信度: 83.06%)
#   - ASD_Left_20180521_2_1785_3-5.mp4: Logit: -1.6299 -> P(class 1)=0.1638 -> 予測クラス: 0 (確信度: 83.62%)
#
# --- [バッチ 58] 推論中 ---
#   - ASD_Left_20180521_2_1785_4-5.mp4: Logit: -2.0178 -> P(class 1)=0.1173 -> 予測クラス: 0 (確信度: 88.27%)
#   - ASD_Left_20180521_2_1785_5-5.mp4: Logit: -0.8403 -> P(class 1)=0.3015 -> 予測クラス: 0 (確信度: 69.85%)
#   - ASD_Left_20180521_2_1787_1-5.mp4: Logit: -1.5016 -> P(class 1)=0.1822 -> 予測クラス: 0 (確信度: 81.78%)
#   - ASD_Left_20180521_2_1787_2-5.mp4: Logit: -1.5485 -> P(class 1)=0.1753 -> 予測クラス: 0 (確信度: 82.47%)
#
# --- [バッチ 59] 推論中 ---
#   - ASD_Left_20180521_2_1787_3-5.mp4: Logit: -1.4332 -> P(class 1)=0.1926 -> 予測クラス: 0 (確信度: 80.74%)
#   - ASD_Left_20180521_2_1787_4-5.mp4: Logit: -1.7560 -> P(class 1)=0.1473 -> 予測クラス: 0 (確信度: 85.27%)
#   - ASD_Left_20180521_2_1787_5-5.mp4: Logit: -1.0790 -> P(class 1)=0.2537 -> 予測クラス: 0 (確信度: 74.63%)
#   - ASD_Left_20180521_2_1789_1-4.mp4: Logit: -1.8187 -> P(class 1)=0.1396 -> 予測クラス: 0 (確信度: 86.04%)
#
# --- [バッチ 60] 推論中 ---
#   - ASD_Left_20180521_2_1789_2-4.mp4: Logit: -1.5154 -> P(class 1)=0.1801 -> 予測クラス: 0 (確信度: 81.99%)
#   - ASD_Left_20180521_2_1789_3-4.mp4: Logit: -1.3170 -> P(class 1)=0.2113 -> 予測クラス: 0 (確信度: 78.87%)
#   - ASD_Left_20180521_2_1789_4-4.mp4: Logit: -1.5508 -> P(class 1)=0.1750 -> 予測クラス: 0 (確信度: 82.50%)
#   - ASD_Left_20180521_2_1791_1-4.mp4: Logit: -1.4371 -> P(class 1)=0.1920 -> 予測クラス: 0 (確信度: 80.80%)
#
# --- [バッチ 61] 推論中 ---
#   - ASD_Left_20180521_2_1791_2-4.mp4: Logit: -1.6115 -> P(class 1)=0.1664 -> 予測クラス: 0 (確信度: 83.36%)
#   - ASD_Left_20180521_2_1791_3-4.mp4: Logit: -1.5930 -> P(class 1)=0.1690 -> 予測クラス: 0 (確信度: 83.10%)
#   - ASD_Left_20180521_2_1791_4-4.mp4: Logit: -1.4335 -> P(class 1)=0.1926 -> 予測クラス: 0 (確信度: 80.74%)
#   - ASD_Left_20180521_2_1793_1-5.mp4: Logit: -1.6098 -> P(class 1)=0.1666 -> 予測クラス: 0 (確信度: 83.34%)
#
# --- [バッチ 62] 推論中 ---
#   - ASD_Left_20180521_2_1793_2-5.mp4: Logit: -1.6246 -> P(class 1)=0.1646 -> 予測クラス: 0 (確信度: 83.54%)
#   - ASD_Left_20180521_2_1793_3-5.mp4: Logit: -1.5450 -> P(class 1)=0.1758 -> 予測クラス: 0 (確信度: 82.42%)
#   - ASD_Left_20180521_2_1793_4-5.mp4: Logit: -1.8296 -> P(class 1)=0.1383 -> 予測クラス: 0 (確信度: 86.17%)
#   - ASD_Left_20180521_2_1793_5-5.mp4: Logit: -1.1394 -> P(class 1)=0.2424 -> 予測クラス: 0 (確信度: 75.76%)
#
# --- [バッチ 63] 推論中 ---
#   - ASD_Left_20180521_2_1795_1-5.mp4: Logit: -1.5183 -> P(class 1)=0.1797 -> 予測クラス: 0 (確信度: 82.03%)
#   - ASD_Left_20180521_2_1795_2-5.mp4: Logit: -1.7848 -> P(class 1)=0.1437 -> 予測クラス: 0 (確信度: 85.63%)
#   - ASD_Left_20180521_2_1795_3-5.mp4: Logit: -1.5504 -> P(class 1)=0.1750 -> 予測クラス: 0 (確信度: 82.50%)
#   - ASD_Left_20180521_2_1795_4-5.mp4: Logit: -1.6829 -> P(class 1)=0.1567 -> 予測クラス: 0 (確信度: 84.33%)
#
# --- [バッチ 64] 推論中 ---
#   - ASD_Left_20180521_2_1795_5-5.mp4: Logit: -0.9695 -> P(class 1)=0.2750 -> 予測クラス: 0 (確信度: 72.50%)
#   - ASD_Left_20180521_2_1797_1-5.mp4: Logit: -1.6520 -> P(class 1)=0.1608 -> 予測クラス: 0 (確信度: 83.92%)
#   - ASD_Left_20180521_2_1797_2-5.mp4: Logit: -1.5879 -> P(class 1)=0.1697 -> 予測クラス: 0 (確信度: 83.03%)
#   - ASD_Left_20180521_2_1797_3-5.mp4: Logit: -1.7421 -> P(class 1)=0.1491 -> 予測クラス: 0 (確信度: 85.09%)
#
# --- [バッチ 65] 推論中 ---
#   - ASD_Left_20180521_2_1797_4-5.mp4: Logit: -1.8322 -> P(class 1)=0.1380 -> 予測クラス: 0 (確信度: 86.20%)
#   - ASD_Left_20180521_2_1797_5-5.mp4: Logit: -1.2150 -> P(class 1)=0.2288 -> 予測クラス: 0 (確信度: 77.12%)
#   - ASD_Left_20180521_2_1799_1-5.mp4: Logit: -1.6705 -> P(class 1)=0.1584 -> 予測クラス: 0 (確信度: 84.16%)
#   - ASD_Left_20180521_2_1799_2-5.mp4: Logit: -1.6438 -> P(class 1)=0.1620 -> 予測クラス: 0 (確信度: 83.80%)
#
# --- [バッチ 66] 推論中 ---
#   - ASD_Left_20180521_2_1799_3-5.mp4: Logit: -1.5462 -> P(class 1)=0.1756 -> 予測クラス: 0 (確信度: 82.44%)
#   - ASD_Left_20180521_2_1799_4-5.mp4: Logit: -1.7579 -> P(class 1)=0.1471 -> 予測クラス: 0 (確信度: 85.29%)
#   - ASD_Left_20180521_2_1799_5-5.mp4: Logit: -0.7375 -> P(class 1)=0.3236 -> 予測クラス: 0 (確信度: 67.64%)
#   - ASD_Left_20180521_2_1801_1-4.mp4: Logit: -1.1860 -> P(class 1)=0.2340 -> 予測クラス: 0 (確信度: 76.60%)
#
# --- [バッチ 67] 推論中 ---
#   - ASD_Left_20180521_2_1801_2-4.mp4: Logit: -1.4134 -> P(class 1)=0.1957 -> 予測クラス: 0 (確信度: 80.43%)
#   - ASD_Left_20180521_2_1801_3-4.mp4: Logit: -1.6964 -> P(class 1)=0.1549 -> 予測クラス: 0 (確信度: 84.51%)
#   - ASD_Left_20180521_2_1801_4-4.mp4: Logit: -1.6249 -> P(class 1)=0.1645 -> 予測クラス: 0 (確信度: 83.55%)
#   - ASD_Left_20180521_2_1803_1-5.mp4: Logit: -1.5922 -> P(class 1)=0.1691 -> 予測クラス: 0 (確信度: 83.09%)
#
# --- [バッチ 68] 推論中 ---
#   - ASD_Left_20180521_2_1803_2-5.mp4: Logit: -1.5408 -> P(class 1)=0.1764 -> 予測クラス: 0 (確信度: 82.36%)
#   - ASD_Left_20180521_2_1803_3-5.mp4: Logit: -1.3790 -> P(class 1)=0.2012 -> 予測クラス: 0 (確信度: 79.88%)
#   - ASD_Left_20180521_2_1803_4-5.mp4: Logit: -1.4380 -> P(class 1)=0.1919 -> 予測クラス: 0 (確信度: 80.81%)
#   - ASD_Left_20180521_2_1803_5-5.mp4: Logit: -0.9174 -> P(class 1)=0.2855 -> 予測クラス: 0 (確信度: 71.45%)
#
# --- [バッチ 69] 推論中 ---
#   - ASD_Left_20180521_2_1805_1-5.mp4: Logit: -1.3998 -> P(class 1)=0.1978 -> 予測クラス: 0 (確信度: 80.22%)
#   - ASD_Left_20180521_2_1805_2-5.mp4: Logit: -1.4001 -> P(class 1)=0.1978 -> 予測クラス: 0 (確信度: 80.22%)
#   - ASD_Left_20180521_2_1805_3-5.mp4: Logit: -1.4708 -> P(class 1)=0.1868 -> 予測クラス: 0 (確信度: 81.32%)
#   - ASD_Left_20180521_2_1805_4-5.mp4: Logit: -1.6116 -> P(class 1)=0.1664 -> 予測クラス: 0 (確信度: 83.36%)
#
# --- [バッチ 70] 推論中 ---
#   - ASD_Left_20180521_2_1805_5-5.mp4: Logit: -1.0866 -> P(class 1)=0.2523 -> 予測クラス: 0 (確信度: 74.77%)
#   - ASD_Left_20180521_2_1807_1-4.mp4: Logit: -1.6603 -> P(class 1)=0.1597 -> 予測クラス: 0 (確信度: 84.03%)
#   - ASD_Left_20180521_2_1807_2-4.mp4: Logit: -1.5752 -> P(class 1)=0.1715 -> 予測クラス: 0 (確信度: 82.85%)
#   - ASD_Left_20180521_2_1807_3-4.mp4: Logit: -1.6405 -> P(class 1)=0.1624 -> 予測クラス: 0 (確信度: 83.76%)
#
# --- [バッチ 71] 推論中 ---
#   - ASD_Left_20180521_2_1807_4-4.mp4: Logit: -1.8644 -> P(class 1)=0.1342 -> 予測クラス: 0 (確信度: 86.58%)
#   - ASD_Left_20180521_2_1809_1-5.mp4: Logit: -1.2115 -> P(class 1)=0.2294 -> 予測クラス: 0 (確信度: 77.06%)
#   - ASD_Left_20180521_2_1809_2-5.mp4: Logit: -1.3253 -> P(class 1)=0.2099 -> 予測クラス: 0 (確信度: 79.01%)
#   - ASD_Left_20180521_2_1809_3-5.mp4: Logit: -1.5248 -> P(class 1)=0.1788 -> 予測クラス: 0 (確信度: 82.12%)
#
# --- [バッチ 72] 推論中 ---
#   - ASD_Left_20180521_2_1809_4-5.mp4: Logit: -1.6080 -> P(class 1)=0.1669 -> 予測クラス: 0 (確信度: 83.31%)
#   - ASD_Left_20180521_2_1809_5-5.mp4: Logit: -1.1845 -> P(class 1)=0.2343 -> 予測クラス: 0 (確信度: 76.57%)
#   - ASD_Left_20180521_2_1811_1-4.mp4: Logit: -1.5630 -> P(class 1)=0.1732 -> 予測クラス: 0 (確信度: 82.68%)
#   - ASD_Left_20180521_2_1811_2-4.mp4: Logit: -1.7316 -> P(class 1)=0.1504 -> 予測クラス: 0 (確信度: 84.96%)
#
# --- [バッチ 73] 推論中 ---
#   - ASD_Left_20180521_2_1811_3-4.mp4: Logit: -1.7901 -> P(class 1)=0.1431 -> 予測クラス: 0 (確信度: 85.69%)
#   - ASD_Left_20180521_2_1811_4-4.mp4: Logit: -1.4911 -> P(class 1)=0.1838 -> 予測クラス: 0 (確信度: 81.62%)
#   - ASD_Left_20180521_2_1813_1-4.mp4: Logit: -1.3202 -> P(class 1)=0.2108 -> 予測クラス: 0 (確信度: 78.92%)
#   - ASD_Left_20180521_2_1813_2-4.mp4: Logit: -1.3985 -> P(class 1)=0.1981 -> 予測クラス: 0 (確信度: 80.19%)
#
# --- [バッチ 74] 推論中 ---
#   - ASD_Left_20180521_2_1813_3-4.mp4: Logit: -1.7741 -> P(class 1)=0.1450 -> 予測クラス: 0 (確信度: 85.50%)
#   - ASD_Left_20180521_2_1813_4-4.mp4: Logit: -1.5862 -> P(class 1)=0.1699 -> 予測クラス: 0 (確信度: 83.01%)
#   - ASD_Left_20180521_2_1815_1-5.mp4: Logit: -1.5871 -> P(class 1)=0.1698 -> 予測クラス: 0 (確信度: 83.02%)
#   - ASD_Left_20180521_2_1815_2-5.mp4: Logit: -1.3945 -> P(class 1)=0.1987 -> 予測クラス: 0 (確信度: 80.13%)
#
# --- [バッチ 75] 推論中 ---
#   - ASD_Left_20180521_2_1815_3-5.mp4: Logit: -1.4410 -> P(class 1)=0.1914 -> 予測クラス: 0 (確信度: 80.86%)
#   - ASD_Left_20180521_2_1815_4-5.mp4: Logit: -1.7864 -> P(class 1)=0.1435 -> 予測クラス: 0 (確信度: 85.65%)
#   - ASD_Left_20180521_2_1815_5-5.mp4: Logit: -0.9208 -> P(class 1)=0.2848 -> 予測クラス: 0 (確信度: 71.52%)
#   - ASD_Left_20180521_2_1817_1-4.mp4: Logit: -1.5707 -> P(class 1)=0.1721 -> 予測クラス: 0 (確信度: 82.79%)
#
# --- [バッチ 76] 推論中 ---
#   - ASD_Left_20180521_2_1817_2-4.mp4: Logit: -1.5331 -> P(class 1)=0.1775 -> 予測クラス: 0 (確信度: 82.25%)
#   - ASD_Left_20180521_2_1817_3-4.mp4: Logit: -1.7546 -> P(class 1)=0.1475 -> 予測クラス: 0 (確信度: 85.25%)
#   - ASD_Left_20180521_2_1817_4-4.mp4: Logit: -1.3155 -> P(class 1)=0.2116 -> 予測クラス: 0 (確信度: 78.84%)
#   - ASD_Left_20180521_2_1819_1-5.mp4: Logit: -1.1790 -> P(class 1)=0.2352 -> 予測クラス: 0 (確信度: 76.48%)
#
# --- [バッチ 77] 推論中 ---
#   - ASD_Left_20180521_2_1819_2-5.mp4: Logit: -1.5083 -> P(class 1)=0.1812 -> 予測クラス: 0 (確信度: 81.88%)
#   - ASD_Left_20180521_2_1819_3-5.mp4: Logit: -1.5978 -> P(class 1)=0.1683 -> 予測クラス: 0 (確信度: 83.17%)
#   - ASD_Left_20180521_2_1819_4-5.mp4: Logit: -1.6048 -> P(class 1)=0.1673 -> 予測クラス: 0 (確信度: 83.27%)
#   - ASD_Left_20180521_2_1819_5-5.mp4: Logit: -1.1561 -> P(class 1)=0.2394 -> 予測クラス: 0 (確信度: 76.06%)
#
# --- [バッチ 78] 推論中 ---
#   - ASD_Left_20180521_2_1821_1-5.mp4: Logit: -1.4260 -> P(class 1)=0.1937 -> 予測クラス: 0 (確信度: 80.63%)
#   - ASD_Left_20180521_2_1821_2-5.mp4: Logit: -1.3874 -> P(class 1)=0.1998 -> 予測クラス: 0 (確信度: 80.02%)
#   - ASD_Left_20180521_2_1821_3-5.mp4: Logit: -1.5003 -> P(class 1)=0.1824 -> 予測クラス: 0 (確信度: 81.76%)
#   - ASD_Left_20180521_2_1821_4-5.mp4: Logit: -1.6797 -> P(class 1)=0.1571 -> 予測クラス: 0 (確信度: 84.29%)
#
# --- [バッチ 79] 推論中 ---
#   - ASD_Left_20180521_2_1821_5-5.mp4: Logit: -1.1024 -> P(class 1)=0.2493 -> 予測クラス: 0 (確信度: 75.07%)
#   - ASD_Left_20180521_2_1823_1-5.mp4: Logit: -1.5146 -> P(class 1)=0.1803 -> 予測クラス: 0 (確信度: 81.97%)
#   - ASD_Left_20180521_2_1823_2-5.mp4: Logit: -1.7049 -> P(class 1)=0.1538 -> 予測クラス: 0 (確信度: 84.62%)
#   - ASD_Left_20180521_2_1823_3-5.mp4: Logit: -1.2931 -> P(class 1)=0.2153 -> 予測クラス: 0 (確信度: 78.47%)
#
# --- [バッチ 80] 推論中 ---
#   - ASD_Left_20180521_2_1823_4-5.mp4: Logit: -1.6458 -> P(class 1)=0.1617 -> 予測クラス: 0 (確信度: 83.83%)
#   - ASD_Left_20180521_2_1823_5-5.mp4: Logit: -0.6646 -> P(class 1)=0.3397 -> 予測クラス: 0 (確信度: 66.03%)
#   - ASD_Left_20180521_2_1825_1-5.mp4: Logit: -1.4413 -> P(class 1)=0.1913 -> 予測クラス: 0 (確信度: 80.87%)
#   - ASD_Left_20180521_2_1825_2-5.mp4: Logit: -1.4353 -> P(class 1)=0.1923 -> 予測クラス: 0 (確信度: 80.77%)
#
# --- [バッチ 81] 推論中 ---
#   - ASD_Left_20180521_2_1825_3-5.mp4: Logit: -1.4715 -> P(class 1)=0.1867 -> 予測クラス: 0 (確信度: 81.33%)
#   - ASD_Left_20180521_2_1825_4-5.mp4: Logit: -1.6541 -> P(class 1)=0.1606 -> 予測クラス: 0 (確信度: 83.94%)
#   - ASD_Left_20180521_2_1825_5-5.mp4: Logit: -1.2548 -> P(class 1)=0.2219 -> 予測クラス: 0 (確信度: 77.81%)
#   - ASD_Left_20180521_2_1827_1-5.mp4: Logit: -1.3742 -> P(class 1)=0.2019 -> 予測クラス: 0 (確信度: 79.81%)
#
# --- [バッチ 82] 推論中 ---
#   - ASD_Left_20180521_2_1827_2-5.mp4: Logit: -1.5029 -> P(class 1)=0.1820 -> 予測クラス: 0 (確信度: 81.80%)
#   - ASD_Left_20180521_2_1827_3-5.mp4: Logit: -1.4424 -> P(class 1)=0.1912 -> 予測クラス: 0 (確信度: 80.88%)
#   - ASD_Left_20180521_2_1827_4-5.mp4: Logit: -1.7923 -> P(class 1)=0.1428 -> 予測クラス: 0 (確信度: 85.72%)
#   - ASD_Left_20180521_2_1827_5-5.mp4: Logit: -1.0602 -> P(class 1)=0.2573 -> 予測クラス: 0 (確信度: 74.27%)
#
# --- [バッチ 83] 推論中 ---
#   - ASD_Left_20180521_2_1829_1-4.mp4: Logit: -1.4115 -> P(class 1)=0.1960 -> 予測クラス: 0 (確信度: 80.40%)
#   - ASD_Left_20180521_2_1829_2-4.mp4: Logit: -1.5137 -> P(class 1)=0.1804 -> 予測クラス: 0 (確信度: 81.96%)
#   - ASD_Left_20180521_2_1829_3-4.mp4: Logit: -1.6929 -> P(class 1)=0.1554 -> 予測クラス: 0 (確信度: 84.46%)
#   - ASD_Left_20180521_2_1829_4-4.mp4: Logit: -1.5956 -> P(class 1)=0.1686 -> 予測クラス: 0 (確信度: 83.14%)
#
# --- [バッチ 84] 推論中 ---
#   - ASD_Left_20180521_2_1831_1-4.mp4: Logit: -1.5556 -> P(class 1)=0.1743 -> 予測クラス: 0 (確信度: 82.57%)
#   - ASD_Left_20180521_2_1831_2-4.mp4: Logit: -1.4969 -> P(class 1)=0.1829 -> 予測クラス: 0 (確信度: 81.71%)
#   - ASD_Left_20180521_2_1831_3-4.mp4: Logit: -1.7569 -> P(class 1)=0.1472 -> 予測クラス: 0 (確信度: 85.28%)
#   - ASD_Left_20180521_2_1831_4-4.mp4: Logit: -1.3495 -> P(class 1)=0.2059 -> 予測クラス: 0 (確信度: 79.41%)
#
# --- [バッチ 85] 推論中 ---
#   - ASD_Left_20180521_2_1833_1-5.mp4: Logit: -1.6146 -> P(class 1)=0.1660 -> 予測クラス: 0 (確信度: 83.40%)
#   - ASD_Left_20180521_2_1833_2-5.mp4: Logit: -1.7036 -> P(class 1)=0.1540 -> 予測クラス: 0 (確信度: 84.60%)
#   - ASD_Left_20180521_2_1833_3-5.mp4: Logit: -1.4645 -> P(class 1)=0.1878 -> 予測クラス: 0 (確信度: 81.22%)
#   - ASD_Left_20180521_2_1833_4-5.mp4: Logit: -1.7106 -> P(class 1)=0.1531 -> 予測クラス: 0 (確信度: 84.69%)
#
# --- [バッチ 86] 推論中 ---
#   - ASD_Left_20180521_2_1833_5-5.mp4: Logit: -0.8820 -> P(class 1)=0.2928 -> 予測クラス: 0 (確信度: 70.72%)
#   - ASD_Left_20180521_2_1835_1-5.mp4: Logit: -1.4763 -> P(class 1)=0.1860 -> 予測クラス: 0 (確信度: 81.40%)
#   - ASD_Left_20180521_2_1835_2-5.mp4: Logit: -1.6210 -> P(class 1)=0.1651 -> 予測クラス: 0 (確信度: 83.49%)
#   - ASD_Left_20180521_2_1835_3-5.mp4: Logit: -1.5529 -> P(class 1)=0.1747 -> 予測クラス: 0 (確信度: 82.53%)
#
# --- [バッチ 87] 推論中 ---
#   - ASD_Left_20180521_2_1835_4-5.mp4: Logit: -1.7935 -> P(class 1)=0.1426 -> 予測クラス: 0 (確信度: 85.74%)
#   - ASD_Left_20180521_2_1835_5-5.mp4: Logit: -1.0418 -> P(class 1)=0.2608 -> 予測クラス: 0 (確信度: 73.92%)
#   - ASD_Left_20180521_2_1837_1-5.mp4: Logit: -1.6376 -> P(class 1)=0.1628 -> 予測クラス: 0 (確信度: 83.72%)
#   - ASD_Left_20180521_2_1837_2-5.mp4: Logit: -1.6941 -> P(class 1)=0.1552 -> 予測クラス: 0 (確信度: 84.48%)
#
# --- [バッチ 88] 推論中 ---
#   - ASD_Left_20180521_2_1837_3-5.mp4: Logit: -1.6300 -> P(class 1)=0.1638 -> 予測クラス: 0 (確信度: 83.62%)
#   - ASD_Left_20180521_2_1837_4-5.mp4: Logit: -1.6303 -> P(class 1)=0.1638 -> 予測クラス: 0 (確信度: 83.62%)
#   - ASD_Left_20180521_2_1837_5-5.mp4: Logit: -0.8252 -> P(class 1)=0.3047 -> 予測クラス: 0 (確信度: 69.53%)
#   - ASD_Left_20181204_1879_1-10.mp4: Logit: -0.0190 -> P(class 1)=0.4953 -> 予測クラス: 0 (確信度: 50.47%)
#
# --- [バッチ 89] 推論中 ---
#   - ASD_Left_20181204_1879_10-10.mp4: Logit: -0.7231 -> P(class 1)=0.3267 -> 予測クラス: 0 (確信度: 67.33%)
#   - ASD_Left_20181204_1879_2-10.mp4: Logit: -0.0881 -> P(class 1)=0.4780 -> 予測クラス: 0 (確信度: 52.20%)
#   - ASD_Left_20181204_1879_3-10.mp4: Logit: -0.5050 -> P(class 1)=0.3764 -> 予測クラス: 0 (確信度: 62.36%)
#   - ASD_Left_20181204_1879_4-10.mp4: Logit: -0.3549 -> P(class 1)=0.4122 -> 予測クラス: 0 (確信度: 58.78%)
#
# --- [バッチ 90] 推論中 ---
#   - ASD_Left_20181204_1879_5-10.mp4: Logit: -0.7152 -> P(class 1)=0.3285 -> 予測クラス: 0 (確信度: 67.15%)
#   - ASD_Left_20181204_1879_6-10.mp4: Logit: -0.3064 -> P(class 1)=0.4240 -> 予測クラス: 0 (確信度: 57.60%)
#   - ASD_Left_20181204_1879_7-10.mp4: Logit: -0.4870 -> P(class 1)=0.3806 -> 予測クラス: 0 (確信度: 61.94%)
#   - ASD_Left_20181204_1879_8-10.mp4: Logit: -0.3077 -> P(class 1)=0.4237 -> 予測クラス: 0 (確信度: 57.63%)
#
# --- [バッチ 91] 推論中 ---
#   - ASD_Left_20181204_1879_9-10.mp4: Logit: -0.8299 -> P(class 1)=0.3037 -> 予測クラス: 0 (確信度: 69.63%)
#   - ASD_Left_20181204_1881_1-9.mp4: Logit: 0.1621 -> P(class 1)=0.5404 -> 予測クラス: 1 (確信度: 54.04%)
#   - ASD_Left_20181204_1881_2-9.mp4: Logit: 0.1355 -> P(class 1)=0.5338 -> 予測クラス: 1 (確信度: 53.38%)
#   - ASD_Left_20181204_1881_3-9.mp4: Logit: -0.2797 -> P(class 1)=0.4305 -> 予測クラス: 0 (確信度: 56.95%)
#
# --- [バッチ 92] 推論中 ---
#   - ASD_Left_20181204_1881_4-9.mp4: Logit: -0.5007 -> P(class 1)=0.3774 -> 予測クラス: 0 (確信度: 62.26%)
#   - ASD_Left_20181204_1881_5-9.mp4: Logit: -0.6423 -> P(class 1)=0.3447 -> 予測クラス: 0 (確信度: 65.53%)
#   - ASD_Left_20181204_1881_6-9.mp4: Logit: -0.4277 -> P(class 1)=0.3947 -> 予測クラス: 0 (確信度: 60.53%)
#   - ASD_Left_20181204_1881_7-9.mp4: Logit: -0.3054 -> P(class 1)=0.4242 -> 予測クラス: 0 (確信度: 57.58%)
#
# --- [バッチ 93] 推論中 ---
#   - ASD_Left_20181204_1881_8-9.mp4: Logit: -0.7686 -> P(class 1)=0.3168 -> 予測クラス: 0 (確信度: 68.32%)
#   - ASD_Left_20181204_1881_9-9.mp4: Logit: -0.6161 -> P(class 1)=0.3507 -> 予測クラス: 0 (確信度: 64.93%)
#   - ASD_Left_20181204_1883_1-10.mp4: Logit: 0.1938 -> P(class 1)=0.5483 -> 予測クラス: 1 (確信度: 54.83%)
#   - ASD_Left_20181204_1883_10-10.mp4: Logit: -0.7278 -> P(class 1)=0.3257 -> 予測クラス: 0 (確信度: 67.43%)
#
# --- [バッチ 94] 推論中 ---
#   - ASD_Left_20181204_1883_2-10.mp4: Logit: 0.0345 -> P(class 1)=0.5086 -> 予測クラス: 1 (確信度: 50.86%)
#   - ASD_Left_20181204_1883_3-10.mp4: Logit: -0.1447 -> P(class 1)=0.4639 -> 予測クラス: 0 (確信度: 53.61%)
#   - ASD_Left_20181204_1883_4-10.mp4: Logit: -0.8924 -> P(class 1)=0.2906 -> 予測クラス: 0 (確信度: 70.94%)
#   - ASD_Left_20181204_1883_5-10.mp4: Logit: -0.7510 -> P(class 1)=0.3206 -> 予測クラス: 0 (確信度: 67.94%)
#
# --- [バッチ 95] 推論中 ---
#   - ASD_Left_20181204_1883_6-10.mp4: Logit: -0.2895 -> P(class 1)=0.4281 -> 予測クラス: 0 (確信度: 57.19%)
#   - ASD_Left_20181204_1883_7-10.mp4: Logit: -0.7480 -> P(class 1)=0.3213 -> 予測クラス: 0 (確信度: 67.87%)
#   - ASD_Left_20181204_1883_8-10.mp4: Logit: -0.9183 -> P(class 1)=0.2853 -> 予測クラス: 0 (確信度: 71.47%)
#   - ASD_Left_20181204_1883_9-10.mp4: Logit: -0.6398 -> P(class 1)=0.3453 -> 予測クラス: 0 (確信度: 65.47%)
#
# --- [バッチ 96] 推論中 ---
#   - ASD_Left_20181204_1885_1-10.mp4: Logit: -0.0714 -> P(class 1)=0.4821 -> 予測クラス: 0 (確信度: 51.79%)
#   - ASD_Left_20181204_1885_10-10.mp4: Logit: -0.6475 -> P(class 1)=0.3435 -> 予測クラス: 0 (確信度: 65.65%)
#   - ASD_Left_20181204_1885_2-10.mp4: Logit: 0.0135 -> P(class 1)=0.5034 -> 予測クラス: 1 (確信度: 50.34%)
#   - ASD_Left_20181204_1885_3-10.mp4: Logit: -0.4378 -> P(class 1)=0.3923 -> 予測クラス: 0 (確信度: 60.77%)
#
# --- [バッチ 97] 推論中 ---
#   - ASD_Left_20181204_1885_4-10.mp4: Logit: -0.7663 -> P(class 1)=0.3173 -> 予測クラス: 0 (確信度: 68.27%)
#   - ASD_Left_20181204_1885_5-10.mp4: Logit: -0.5955 -> P(class 1)=0.3554 -> 予測クラス: 0 (確信度: 64.46%)
#   - ASD_Left_20181204_1885_6-10.mp4: Logit: -0.2780 -> P(class 1)=0.4310 -> 予測クラス: 0 (確信度: 56.90%)
#   - ASD_Left_20181204_1885_7-10.mp4: Logit: -0.4445 -> P(class 1)=0.3907 -> 予測クラス: 0 (確信度: 60.93%)
#
# --- [バッチ 98] 推論中 ---
#   - ASD_Left_20181204_1885_8-10.mp4: Logit: -0.3737 -> P(class 1)=0.4077 -> 予測クラス: 0 (確信度: 59.23%)
#   - ASD_Left_20181204_1885_9-10.mp4: Logit: -0.9286 -> P(class 1)=0.2832 -> 予測クラス: 0 (確信度: 71.68%)
#   - ASD_Left_20181204_1887_1-10.mp4: Logit: 0.0247 -> P(class 1)=0.5062 -> 予測クラス: 1 (確信度: 50.62%)
#   - ASD_Left_20181204_1887_10-10.mp4: Logit: -0.9405 -> P(class 1)=0.2808 -> 予測クラス: 0 (確信度: 71.92%)
#
# --- [バッチ 99] 推論中 ---
#   - ASD_Left_20181204_1887_2-10.mp4: Logit: 0.0542 -> P(class 1)=0.5136 -> 予測クラス: 1 (確信度: 51.36%)
#   - ASD_Left_20181204_1887_3-10.mp4: Logit: -0.4269 -> P(class 1)=0.3949 -> 予測クラス: 0 (確信度: 60.51%)
#   - ASD_Left_20181204_1887_4-10.mp4: Logit: -0.8689 -> P(class 1)=0.2955 -> 予測クラス: 0 (確信度: 70.45%)
#   - ASD_Left_20181204_1887_5-10.mp4: Logit: -0.6442 -> P(class 1)=0.3443 -> 予測クラス: 0 (確信度: 65.57%)
#
# --- [バッチ 100] 推論中 ---
#   - ASD_Left_20181204_1887_6-10.mp4: Logit: -0.3092 -> P(class 1)=0.4233 -> 予測クラス: 0 (確信度: 57.67%)
#   - ASD_Left_20181204_1887_7-10.mp4: Logit: -0.0158 -> P(class 1)=0.4961 -> 予測クラス: 0 (確信度: 50.39%)
#   - ASD_Left_20181204_1887_8-10.mp4: Logit: -0.2795 -> P(class 1)=0.4306 -> 予測クラス: 0 (確信度: 56.94%)
#   - ASD_Left_20181204_1887_9-10.mp4: Logit: -0.5219 -> P(class 1)=0.3724 -> 予測クラス: 0 (確信度: 62.76%)
#
# --- [バッチ 101] 推論中 ---
#   - ASD_Left_20181204_1889_1-10.mp4: Logit: 0.0618 -> P(class 1)=0.5154 -> 予測クラス: 1 (確信度: 51.54%)
#   - ASD_Left_20181204_1889_10-10.mp4: Logit: -0.5717 -> P(class 1)=0.3608 -> 予測クラス: 0 (確信度: 63.92%)
#   - ASD_Left_20181204_1889_2-10.mp4: Logit: 0.0590 -> P(class 1)=0.5147 -> 予測クラス: 1 (確信度: 51.47%)
#   - ASD_Left_20181204_1889_3-10.mp4: Logit: -0.4056 -> P(class 1)=0.4000 -> 予測クラス: 0 (確信度: 60.00%)
#
# --- [バッチ 102] 推論中 ---
#   - ASD_Left_20181204_1889_4-10.mp4: Logit: -0.7115 -> P(class 1)=0.3293 -> 予測クラス: 0 (確信度: 67.07%)
#   - ASD_Left_20181204_1889_5-10.mp4: Logit: -0.7493 -> P(class 1)=0.3210 -> 予測クラス: 0 (確信度: 67.90%)
#   - ASD_Left_20181204_1889_6-10.mp4: Logit: -0.2782 -> P(class 1)=0.4309 -> 予測クラス: 0 (確信度: 56.91%)
#   - ASD_Left_20181204_1889_7-10.mp4: Logit: -0.7803 -> P(class 1)=0.3143 -> 予測クラス: 0 (確信度: 68.57%)
#
# --- [バッチ 103] 推論中 ---
#   - ASD_Left_20181204_1889_8-10.mp4: Logit: -0.7224 -> P(class 1)=0.3269 -> 予測クラス: 0 (確信度: 67.31%)
#   - ASD_Left_20181204_1889_9-10.mp4: Logit: -0.8069 -> P(class 1)=0.3086 -> 予測クラス: 0 (確信度: 69.14%)
#   - ASD_Left_20200120_1406_1-6.mp4: Logit: 0.3113 -> P(class 1)=0.5772 -> 予測クラス: 1 (確信度: 57.72%)
#   - ASD_Left_20200120_1406_2-6.mp4: Logit: 0.0772 -> P(class 1)=0.5193 -> 予測クラス: 1 (確信度: 51.93%)
#
# --- [バッチ 104] 推論中 ---
#   - ASD_Left_20200120_1406_3-6.mp4: Logit: 0.0878 -> P(class 1)=0.5219 -> 予測クラス: 1 (確信度: 52.19%)
#   - ASD_Left_20200120_1406_4-6.mp4: Logit: 0.1805 -> P(class 1)=0.5450 -> 予測クラス: 1 (確信度: 54.50%)
#   - ASD_Left_20200120_1406_5-6.mp4: Logit: 0.2857 -> P(class 1)=0.5710 -> 予測クラス: 1 (確信度: 57.10%)
#   - ASD_Left_20200120_1406_6-6.mp4: Logit: 0.4016 -> P(class 1)=0.5991 -> 予測クラス: 1 (確信度: 59.91%)
#
# --- [バッチ 105] 推論中 ---
#   - ASD_Left_20200120_1408_1-6.mp4: Logit: -0.0281 -> P(class 1)=0.4930 -> 予測クラス: 0 (確信度: 50.70%)
#   - ASD_Left_20200120_1408_2-6.mp4: Logit: -0.0171 -> P(class 1)=0.4957 -> 予測クラス: 0 (確信度: 50.43%)
#   - ASD_Left_20200120_1408_3-6.mp4: Logit: -0.0184 -> P(class 1)=0.4954 -> 予測クラス: 0 (確信度: 50.46%)
#   - ASD_Left_20200120_1408_4-6.mp4: Logit: 0.0920 -> P(class 1)=0.5230 -> 予測クラス: 1 (確信度: 52.30%)
#
# --- [バッチ 106] 推論中 ---
#   - ASD_Left_20200120_1408_5-6.mp4: Logit: 0.4212 -> P(class 1)=0.6038 -> 予測クラス: 1 (確信度: 60.38%)
#   - ASD_Left_20200120_1408_6-6.mp4: Logit: 0.6516 -> P(class 1)=0.6574 -> 予測クラス: 1 (確信度: 65.74%)
#   - ASD_Left_20210803_1409_1-10.mp4: Logit: -1.2198 -> P(class 1)=0.2280 -> 予測クラス: 0 (確信度: 77.20%)
#   - ASD_Left_20210803_1409_10-10.mp4: Logit: -0.8492 -> P(class 1)=0.2996 -> 予測クラス: 0 (確信度: 70.04%)
#
# --- [バッチ 107] 推論中 ---
#   - ASD_Left_20210803_1409_2-10.mp4: Logit: -1.2125 -> P(class 1)=0.2293 -> 予測クラス: 0 (確信度: 77.07%)
#   - ASD_Left_20210803_1409_3-10.mp4: Logit: -1.3970 -> P(class 1)=0.1983 -> 予測クラス: 0 (確信度: 80.17%)
#   - ASD_Left_20210803_1409_4-10.mp4: Logit: -1.4155 -> P(class 1)=0.1954 -> 予測クラス: 0 (確信度: 80.46%)
#   - ASD_Left_20210803_1409_5-10.mp4: Logit: -1.1875 -> P(class 1)=0.2337 -> 予測クラス: 0 (確信度: 76.63%)
#
# --- [バッチ 108] 推論中 ---
#   - ASD_Left_20210803_1409_6-10.mp4: Logit: -1.1499 -> P(class 1)=0.2405 -> 予測クラス: 0 (確信度: 75.95%)
#   - ASD_Left_20210803_1409_7-10.mp4: Logit: -1.1152 -> P(class 1)=0.2469 -> 予測クラス: 0 (確信度: 75.31%)
#   - ASD_Left_20210803_1409_8-10.mp4: Logit: -1.1357 -> P(class 1)=0.2431 -> 予測クラス: 0 (確信度: 75.69%)
#   - ASD_Left_20210803_1409_9-10.mp4: Logit: -1.1339 -> P(class 1)=0.2434 -> 予測クラス: 0 (確信度: 75.66%)
#
# --- [バッチ 109] 推論中 ---
#   - ASD_Left_20210803_1411_1-14.mp4: Logit: -1.1432 -> P(class 1)=0.2417 -> 予測クラス: 0 (確信度: 75.83%)
#   - ASD_Left_20210803_1411_10-14.mp4: Logit: -1.1330 -> P(class 1)=0.2436 -> 予測クラス: 0 (確信度: 75.64%)
#   - ASD_Left_20210803_1411_11-14.mp4: Logit: -1.3464 -> P(class 1)=0.2065 -> 予測クラス: 0 (確信度: 79.35%)
#   - ASD_Left_20210803_1411_12-14.mp4: Logit: -0.6930 -> P(class 1)=0.3334 -> 予測クラス: 0 (確信度: 66.66%)
#
# --- [バッチ 110] 推論中 ---
#   - ASD_Left_20210803_1411_13-14.mp4: Logit: -0.9783 -> P(class 1)=0.2732 -> 予測クラス: 0 (確信度: 72.68%)
#   - ASD_Left_20210803_1411_14-14.mp4: Logit: -0.6589 -> P(class 1)=0.3410 -> 予測クラス: 0 (確信度: 65.90%)
#   - ASD_Left_20210803_1411_2-14.mp4: Logit: -1.1056 -> P(class 1)=0.2487 -> 予測クラス: 0 (確信度: 75.13%)
#   - ASD_Left_20210803_1411_3-14.mp4: Logit: -1.2911 -> P(class 1)=0.2157 -> 予測クラス: 0 (確信度: 78.43%)
#
# --- [バッチ 111] 推論中 ---
#   - ASD_Left_20210803_1411_4-14.mp4: Logit: -1.3257 -> P(class 1)=0.2099 -> 予測クラス: 0 (確信度: 79.01%)
#   - ASD_Left_20210803_1411_5-14.mp4: Logit: -1.1032 -> P(class 1)=0.2491 -> 予測クラス: 0 (確信度: 75.09%)
#   - ASD_Left_20210803_1411_6-14.mp4: Logit: -1.1907 -> P(class 1)=0.2331 -> 予測クラス: 0 (確信度: 76.69%)
#   - ASD_Left_20210803_1411_7-14.mp4: Logit: -1.3159 -> P(class 1)=0.2115 -> 予測クラス: 0 (確信度: 78.85%)
#
# --- [バッチ 112] 推論中 ---
#   - ASD_Left_20210803_1411_8-14.mp4: Logit: -1.1043 -> P(class 1)=0.2489 -> 予測クラス: 0 (確信度: 75.11%)
#   - ASD_Left_20210803_1411_9-14.mp4: Logit: -1.0419 -> P(class 1)=0.2608 -> 予測クラス: 0 (確信度: 73.92%)
#   - ASD_Right_20180123_1647_1-8.mp4: Logit: -0.6305 -> P(class 1)=0.3474 -> 予測クラス: 0 (確信度: 65.26%)
#   - ASD_Right_20180123_1647_2-8.mp4: Logit: -0.5654 -> P(class 1)=0.3623 -> 予測クラス: 0 (確信度: 63.77%)
#
# --- [バッチ 113] 推論中 ---
#   - ASD_Right_20180123_1647_3-8.mp4: Logit: -0.2632 -> P(class 1)=0.4346 -> 予測クラス: 0 (確信度: 56.54%)
#   - ASD_Right_20180123_1647_4-8.mp4: Logit: -0.0787 -> P(class 1)=0.4803 -> 予測クラス: 0 (確信度: 51.97%)
#   - ASD_Right_20180123_1647_5-8.mp4: Logit: -0.5436 -> P(class 1)=0.3674 -> 予測クラス: 0 (確信度: 63.26%)
#   - ASD_Right_20180123_1647_6-8.mp4: Logit: -0.4766 -> P(class 1)=0.3831 -> 予測クラス: 0 (確信度: 61.69%)
#
# --- [バッチ 114] 推論中 ---
#   - ASD_Right_20180123_1647_7-8.mp4: Logit: -0.0834 -> P(class 1)=0.4792 -> 予測クラス: 0 (確信度: 52.08%)
#   - ASD_Right_20180123_1647_8-8.mp4: Logit: -0.1673 -> P(class 1)=0.4583 -> 予測クラス: 0 (確信度: 54.17%)
#   - ASD_Right_20180123_1649_1-7.mp4: Logit: -0.6467 -> P(class 1)=0.3437 -> 予測クラス: 0 (確信度: 65.63%)
#   - ASD_Right_20180123_1649_2-7.mp4: Logit: -0.3841 -> P(class 1)=0.4051 -> 予測クラス: 0 (確信度: 59.49%)
#
# --- [バッチ 115] 推論中 ---
# ...
#   - LCS_Right_20180326_689_1-3.mp4: Logit: -0.2586 -> P(class 1)=0.4357 -> 予測クラス: 0 (確信度: 56.43%)
#   - LCS_Right_20180326_689_2-3.mp4: Logit: 0.0478 -> P(class 1)=0.5120 -> 予測クラス: 1 (確信度: 51.20%)
#
# --- [バッチ 406] 推論中 ---
#   - LCS_Right_20180326_689_3-3.mp4: Logit: 0.0815 -> P(class 1)=0.5204 -> 予測クラス: 1 (確信度: 52.04%)
#   - LCS_Right_20180326_691_1-3.mp4: Logit: -0.1332 -> P(class 1)=0.4667 -> 予測クラス: 0 (確信度: 53.33%)
#   - LCS_Right_20180326_691_2-3.mp4: Logit: 0.3504 -> P(class 1)=0.5867 -> 予測クラス: 1 (確信度: 58.67%)
#   - LCS_Right_20180326_691_3-3.mp4: Logit: 0.0164 -> P(class 1)=0.5041 -> 予測クラス: 1 (確信度: 50.41%)
#
# --- [バッチ 407] 推論中 ---
#   - LCS_Right_20180326_693_1-3.mp4: Logit: -0.2838 -> P(class 1)=0.4295 -> 予測クラス: 0 (確信度: 57.05%)
#   - LCS_Right_20180326_693_2-3.mp4: Logit: 0.1228 -> P(class 1)=0.5307 -> 予測クラス: 1 (確信度: 53.07%)
#   - LCS_Right_20180326_693_3-3.mp4: Logit: 0.1529 -> P(class 1)=0.5381 -> 予測クラス: 1 (確信度: 53.81%)
#   - LCS_Right_20180326_695_1-3.mp4: Logit: -0.0399 -> P(class 1)=0.4900 -> 予測クラス: 0 (確信度: 51.00%)
#
# --- [バッチ 408] 推論中 ---
#   - LCS_Right_20180326_695_2-3.mp4: Logit: 0.1799 -> P(class 1)=0.5449 -> 予測クラス: 1 (確信度: 54.49%)
#   - LCS_Right_20180326_695_3-3.mp4: Logit: -0.0087 -> P(class 1)=0.4978 -> 予測クラス: 0 (確信度: 50.22%)
#   - LCS_Right_20180326_697_1-3.mp4: Logit: -0.2383 -> P(class 1)=0.4407 -> 予測クラス: 0 (確信度: 55.93%)
#   - LCS_Right_20180326_697_2-3.mp4: Logit: 0.2140 -> P(class 1)=0.5533 -> 予測クラス: 1 (確信度: 55.33%)
#
# --- [バッチ 409] 推論中 ---
#   - LCS_Right_20180326_697_3-3.mp4: Logit: -0.0136 -> P(class 1)=0.4966 -> 予測クラス: 0 (確信度: 50.34%)
#   - LCS_Right_20180326_699_1-3.mp4: Logit: -0.0264 -> P(class 1)=0.4934 -> 予測クラス: 0 (確信度: 50.66%)
#   - LCS_Right_20180326_699_2-3.mp4: Logit: 0.0855 -> P(class 1)=0.5214 -> 予測クラス: 1 (確信度: 52.14%)
#   - LCS_Right_20180326_699_3-3.mp4: Logit: 0.0496 -> P(class 1)=0.5124 -> 予測クラス: 1 (確信度: 51.24%)
#
# --- [バッチ 410] 推論中 ---
#   - LCS_Right_20180326_701_1-3.mp4: Logit: -0.3551 -> P(class 1)=0.4122 -> 予測クラス: 0 (確信度: 58.78%)
#   - LCS_Right_20180326_701_2-3.mp4: Logit: 0.3716 -> P(class 1)=0.5918 -> 予測クラス: 1 (確信度: 59.18%)
#   - LCS_Right_20180326_701_3-3.mp4: Logit: 0.0710 -> P(class 1)=0.5177 -> 予測クラス: 1 (確信度: 51.77%)
#   - LCS_Right_20180326_703_1-3.mp4: Logit: -0.0488 -> P(class 1)=0.4878 -> 予測クラス: 0 (確信度: 51.22%)
#
# --- [バッチ 411] 推論中 ---
#   - LCS_Right_20180326_703_2-3.mp4: Logit: 0.4852 -> P(class 1)=0.6190 -> 予測クラス: 1 (確信度: 61.90%)
#   - LCS_Right_20180326_703_3-3.mp4: Logit: -0.1055 -> P(class 1)=0.4736 -> 予測クラス: 0 (確信度: 52.64%)
#   - LCS_Right_20180326_705_1-3.mp4: Logit: -0.3616 -> P(class 1)=0.4106 -> 予測クラス: 0 (確信度: 58.94%)
#   - LCS_Right_20180326_705_2-3.mp4: Logit: 0.4694 -> P(class 1)=0.6152 -> 予測クラス: 1 (確信度: 61.52%)
#
# --- [バッチ 412] 推論中 ---
#   - LCS_Right_20180326_705_3-3.mp4: Logit: 0.0248 -> P(class 1)=0.5062 -> 予測クラス: 1 (確信度: 50.62%)
#   - LCS_Right_20180326_707_1-3.mp4: Logit: 0.0809 -> P(class 1)=0.5202 -> 予測クラス: 1 (確信度: 52.02%)
#   - LCS_Right_20180326_707_2-3.mp4: Logit: 0.1307 -> P(class 1)=0.5326 -> 予測クラス: 1 (確信度: 53.26%)
#   - LCS_Right_20180326_707_3-3.mp4: Logit: 0.0242 -> P(class 1)=0.5060 -> 予測クラス: 1 (確信度: 50.60%)
#
# --- [バッチ 413] 推論中 ---
#   - LCS_Right_20180326_709_1-3.mp4: Logit: -0.1631 -> P(class 1)=0.4593 -> 予測クラス: 0 (確信度: 54.07%)
#   - LCS_Right_20180326_709_2-3.mp4: Logit: 0.3057 -> P(class 1)=0.5758 -> 予測クラス: 1 (確信度: 57.58%)
#   - LCS_Right_20180326_709_3-3.mp4: Logit: 0.1482 -> P(class 1)=0.5370 -> 予測クラス: 1 (確信度: 53.70%)
#   - LCS_Right_20180326_711_1-3.mp4: Logit: -0.1803 -> P(class 1)=0.4550 -> 予測クラス: 0 (確信度: 54.50%)
#
# --- [バッチ 414] 推論中 ---
#   - LCS_Right_20180326_711_2-3.mp4: Logit: 0.2793 -> P(class 1)=0.5694 -> 予測クラス: 1 (確信度: 56.94%)
#   - LCS_Right_20180326_711_3-3.mp4: Logit: -0.0066 -> P(class 1)=0.4983 -> 予測クラス: 0 (確信度: 50.17%)
#   - LCS_Right_20180326_713_1-3.mp4: Logit: -0.0880 -> P(class 1)=0.4780 -> 予測クラス: 0 (確信度: 52.20%)
#   - LCS_Right_20180326_713_2-3.mp4: Logit: 0.9400 -> P(class 1)=0.7191 -> 予測クラス: 1 (確信度: 71.91%)
#
# --- [バッチ 415] 推論中 ---
#   - LCS_Right_20180326_713_3-3.mp4: Logit: 0.0644 -> P(class 1)=0.5161 -> 予測クラス: 1 (確信度: 51.61%)
#   - LCS_Right_20180326_715_1-3.mp4: Logit: 0.0912 -> P(class 1)=0.5228 -> 予測クラス: 1 (確信度: 52.28%)
#   - LCS_Right_20180326_715_2-3.mp4: Logit: 0.1899 -> P(class 1)=0.5473 -> 予測クラス: 1 (確信度: 54.73%)
#   - LCS_Right_20180326_715_3-3.mp4: Logit: 0.1215 -> P(class 1)=0.5303 -> 予測クラス: 1 (確信度: 53.03%)
#
# --- [バッチ 416] 推論中 ---
#   - LCS_Right_20180326_717_1-3.mp4: Logit: -0.2835 -> P(class 1)=0.4296 -> 予測クラス: 0 (確信度: 57.04%)
#   - LCS_Right_20180326_717_2-3.mp4: Logit: 0.1803 -> P(class 1)=0.5450 -> 予測クラス: 1 (確信度: 54.50%)
#   - LCS_Right_20180326_717_3-3.mp4: Logit: 0.0185 -> P(class 1)=0.5046 -> 予測クラス: 1 (確信度: 50.46%)
#   - LCS_Right_20180326_719_1-3.mp4: Logit: -0.1130 -> P(class 1)=0.4718 -> 予測クラス: 0 (確信度: 52.82%)
#
# --- [バッチ 417] 推論中 ---
#   - LCS_Right_20180326_719_2-3.mp4: Logit: 0.0807 -> P(class 1)=0.5202 -> 予測クラス: 1 (確信度: 52.02%)
#   - LCS_Right_20180326_719_3-3.mp4: Logit: -0.1541 -> P(class 1)=0.4615 -> 予測クラス: 0 (確信度: 53.85%)
#   - LCS_Right_20180326_721_1-3.mp4: Logit: 0.0239 -> P(class 1)=0.5060 -> 予測クラス: 1 (確信度: 50.60%)
#   - LCS_Right_20180326_721_2-3.mp4: Logit: 0.4101 -> P(class 1)=0.6011 -> 予測クラス: 1 (確信度: 60.11%)
#
# --- [バッチ 418] 推論中 ---
#   - LCS_Right_20180326_721_3-3.mp4: Logit: 0.2154 -> P(class 1)=0.5536 -> 予測クラス: 1 (確信度: 55.36%)
#   - LCS_Right_20180326_723_1-3.mp4: Logit: -0.2452 -> P(class 1)=0.4390 -> 予測クラス: 0 (確信度: 56.10%)
#   - LCS_Right_20180326_723_2-3.mp4: Logit: 0.2640 -> P(class 1)=0.5656 -> 予測クラス: 1 (確信度: 56.56%)
#   - LCS_Right_20180326_723_3-3.mp4: Logit: 0.0080 -> P(class 1)=0.5020 -> 予測クラス: 1 (確信度: 50.20%)
#
# --- [バッチ 419] 推論中 ---
#   - LCS_Right_20180326_725_1-3.mp4: Logit: -0.1829 -> P(class 1)=0.4544 -> 予測クラス: 0 (確信度: 54.56%)
#   - LCS_Right_20180326_725_2-3.mp4: Logit: 0.0775 -> P(class 1)=0.5194 -> 予測クラス: 1 (確信度: 51.94%)
#   - LCS_Right_20180326_725_3-3.mp4: Logit: -0.1704 -> P(class 1)=0.4575 -> 予測クラス: 0 (確信度: 54.25%)
#   - LCS_Right_20180326_727_1-3.mp4: Logit: -0.3188 -> P(class 1)=0.4210 -> 予測クラス: 0 (確信度: 57.90%)
#
# --- [バッチ 420] 推論中 ---
#   - LCS_Right_20180326_727_2-3.mp4: Logit: 0.3750 -> P(class 1)=0.5927 -> 予測クラス: 1 (確信度: 59.27%)
#   - LCS_Right_20180326_727_3-3.mp4: Logit: 0.2516 -> P(class 1)=0.5626 -> 予測クラス: 1 (確信度: 56.26%)
#   - LCS_Right_20180326_729_1-3.mp4: Logit: -0.0854 -> P(class 1)=0.4787 -> 予測クラス: 0 (確信度: 52.13%)
#   - LCS_Right_20180326_729_2-3.mp4: Logit: 0.4744 -> P(class 1)=0.6164 -> 予測クラス: 1 (確信度: 61.64%)
#
# --- [バッチ 421] 推論中 ---
#   - LCS_Right_20180326_729_3-3.mp4: Logit: 0.0141 -> P(class 1)=0.5035 -> 予測クラス: 1 (確信度: 50.35%)
#   - LCS_Right_20180326_731_1-3.mp4: Logit: -0.2164 -> P(class 1)=0.4461 -> 予測クラス: 0 (確信度: 55.39%)
#   - LCS_Right_20180326_731_2-3.mp4: Logit: -0.0730 -> P(class 1)=0.4817 -> 予測クラス: 0 (確信度: 51.83%)
#   - LCS_Right_20180326_731_3-3.mp4: Logit: -0.0325 -> P(class 1)=0.4919 -> 予測クラス: 0 (確信度: 50.81%)
#
# --- [バッチ 422] 推論中 ---
#   - LCS_Right_20180326_733_1-3.mp4: Logit: 0.1851 -> P(class 1)=0.5461 -> 予測クラス: 1 (確信度: 54.61%)
#   - LCS_Right_20180326_733_2-3.mp4: Logit: 0.4417 -> P(class 1)=0.6087 -> 予測クラス: 1 (確信度: 60.87%)
#   - LCS_Right_20180326_733_3-3.mp4: Logit: 0.0722 -> P(class 1)=0.5180 -> 予測クラス: 1 (確信度: 51.80%)
#   - LCS_Right_20180326_735_1-3.mp4: Logit: 0.0800 -> P(class 1)=0.5200 -> 予測クラス: 1 (確信度: 52.00%)
#
# --- [バッチ 423] 推論中 ---
#   - LCS_Right_20180326_735_2-3.mp4: Logit: 0.3179 -> P(class 1)=0.5788 -> 予測クラス: 1 (確信度: 57.88%)
#   - LCS_Right_20180326_735_3-3.mp4: Logit: -0.0209 -> P(class 1)=0.4948 -> 予測クラス: 0 (確信度: 50.52%)
#   - LCS_Right_20180326_737_1-3.mp4: Logit: -0.0801 -> P(class 1)=0.4800 -> 予測クラス: 0 (確信度: 52.00%)
#   - LCS_Right_20180326_737_2-3.mp4: Logit: 0.7417 -> P(class 1)=0.6774 -> 予測クラス: 1 (確信度: 67.74%)
#
# --- [バッチ 424] 推論中 ---
#   - LCS_Right_20180326_737_3-3.mp4: Logit: 0.1656 -> P(class 1)=0.5413 -> 予測クラス: 1 (確信度: 54.13%)
#   - LCS_Right_20211012_739_1-3.mp4: Logit: -1.0049 -> P(class 1)=0.2680 -> 予測クラス: 0 (確信度: 73.20%)
#   - LCS_Right_20211012_739_2-3.mp4: Logit: -1.1236 -> P(class 1)=0.2453 -> 予測クラス: 0 (確信度: 75.47%)
#   - LCS_Right_20211012_739_3-3.mp4: Logit: -1.1457 -> P(class 1)=0.2413 -> 予測クラス: 0 (確信度: 75.87%)
#
# --- [バッチ 425] 推論中 ---
#   - LCS_Right_20211012_741_1-3.mp4: Logit: -1.0142 -> P(class 1)=0.2662 -> 予測クラス: 0 (確信度: 73.38%)
#   - LCS_Right_20211012_741_2-3.mp4: Logit: -1.2148 -> P(class 1)=0.2289 -> 予測クラス: 0 (確信度: 77.11%)
#   - LCS_Right_20211012_741_3-3.mp4: Logit: -1.4194 -> P(class 1)=0.1947 -> 予測クラス: 0 (確信度: 80.53%)
#   - LCS_Right_20211012_743_1-4.mp4: Logit: -0.8507 -> P(class 1)=0.2993 -> 予測クラス: 0 (確信度: 70.07%)
#
# --- [バッチ 426] 推論中 ---
#   - LCS_Right_20211012_743_2-4.mp4: Logit: -0.7869 -> P(class 1)=0.3128 -> 予測クラス: 0 (確信度: 68.72%)
#   - LCS_Right_20211012_743_3-4.mp4: Logit: -1.0169 -> P(class 1)=0.2656 -> 予測クラス: 0 (確信度: 73.44%)
#   - LCS_Right_20211012_743_4-4.mp4: Logit: -1.0602 -> P(class 1)=0.2573 -> 予測クラス: 0 (確信度: 74.27%)
#   - LCS_Right_20211012_745_1-3.mp4: Logit: -0.9157 -> P(class 1)=0.2858 -> 予測クラス: 0 (確信度: 71.42%)
#
# --- [バッチ 427] 推論中 ---
#   - LCS_Right_20211012_745_2-3.mp4: Logit: -1.0930 -> P(class 1)=0.2510 -> 予測クラス: 0 (確信度: 74.90%)
#   - LCS_Right_20211012_745_3-3.mp4: Logit: -1.3265 -> P(class 1)=0.2097 -> 予測クラス: 0 (確信度: 79.03%)
#   - LCS_Right_20211012_747_1-3.mp4: Logit: -0.9746 -> P(class 1)=0.2740 -> 予測クラス: 0 (確信度: 72.60%)
#   - LCS_Right_20211012_747_2-3.mp4: Logit: -1.1295 -> P(class 1)=0.2443 -> 予測クラス: 0 (確信度: 75.57%)
#
# --- [バッチ 428] 推論中 ---
#   - LCS_Right_20211012_747_3-3.mp4: Logit: -1.3214 -> P(class 1)=0.2106 -> 予測クラス: 0 (確信度: 78.94%)
#   - LCS_Right_20211012_749_1-3.mp4: Logit: -0.7934 -> P(class 1)=0.3114 -> 予測クラス: 0 (確信度: 68.86%)
#   - LCS_Right_20211012_749_2-3.mp4: Logit: -1.3069 -> P(class 1)=0.2130 -> 予測クラス: 0 (確信度: 78.70%)
#   - LCS_Right_20211012_749_3-3.mp4: Logit: -1.2260 -> P(class 1)=0.2269 -> 予測クラス: 0 (確信度: 77.31%)
#
# --- [バッチ 429] 推論中 ---
#   - LCS_Right_20211012_751_1-4.mp4: Logit: -1.0067 -> P(class 1)=0.2676 -> 予測クラス: 0 (確信度: 73.24%)
#   - LCS_Right_20211012_751_2-4.mp4: Logit: -0.9069 -> P(class 1)=0.2876 -> 予測クラス: 0 (確信度: 71.24%)
#   - LCS_Right_20211012_751_3-4.mp4: Logit: -1.0051 -> P(class 1)=0.2679 -> 予測クラス: 0 (確信度: 73.21%)
#   - LCS_Right_20211012_751_4-4.mp4: Logit: -0.6670 -> P(class 1)=0.3392 -> 予測クラス: 0 (確信度: 66.08%)
#
# --- [バッチ 430] 推論中 ---
#   - LCS_Right_20211012_753_1-3.mp4: Logit: -1.1981 -> P(class 1)=0.2318 -> 予測クラス: 0 (確信度: 76.82%)
#   - LCS_Right_20211012_753_2-3.mp4: Logit: -0.9664 -> P(class 1)=0.2756 -> 予測クラス: 0 (確信度: 72.44%)
#   - LCS_Right_20211012_753_3-3.mp4: Logit: -0.9447 -> P(class 1)=0.2800 -> 予測クラス: 0 (確信度: 72.00%)
#   - LCS_Right_20211012_755_1-3.mp4: Logit: -1.2006 -> P(class 1)=0.2314 -> 予測クラス: 0 (確信度: 76.86%)
#
# --- [バッチ 431] 推論中 ---
#   - LCS_Right_20211012_755_2-3.mp4: Logit: -1.1463 -> P(class 1)=0.2412 -> 予測クラス: 0 (確信度: 75.88%)
#   - LCS_Right_20211012_755_3-3.mp4: Logit: -1.2401 -> P(class 1)=0.2244 -> 予測クラス: 0 (確信度: 77.56%)
#   - LCS_Right_20211012_757_1-3.mp4: Logit: -0.9244 -> P(class 1)=0.2841 -> 予測クラス: 0 (確信度: 71.59%)
#   - LCS_Right_20211012_757_2-3.mp4: Logit: -0.7996 -> P(class 1)=0.3101 -> 予測クラス: 0 (確信度: 68.99%)
#
# --- [バッチ 432] 推論中 ---
#   - LCS_Right_20211012_757_3-3.mp4: Logit: -1.0263 -> P(class 1)=0.2638 -> 予測クラス: 0 (確信度: 73.62%)
#   - LCS_Right_20211012_759_1-3.mp4: Logit: -1.1250 -> P(class 1)=0.2451 -> 予測クラス: 0 (確信度: 75.49%)
#   - LCS_Right_20211012_759_2-3.mp4: Logit: -1.0775 -> P(class 1)=0.2540 -> 予測クラス: 0 (確信度: 74.60%)
#   - LCS_Right_20211012_759_3-3.mp4: Logit: -1.0011 -> P(class 1)=0.2687 -> 予測クラス: 0 (確信度: 73.13%)
#
# --- [バッチ 433] 推論中 ---
#   - LCS_Right_20211012_761_1-4.mp4: Logit: -0.8294 -> P(class 1)=0.3038 -> 予測クラス: 0 (確信度: 69.62%)
#   - LCS_Right_20211012_761_2-4.mp4: Logit: -0.7682 -> P(class 1)=0.3169 -> 予測クラス: 0 (確信度: 68.31%)
#   - LCS_Right_20211012_761_3-4.mp4: Logit: -0.8911 -> P(class 1)=0.2909 -> 予測クラス: 0 (確信度: 70.91%)
#   - LCS_Right_20211012_761_4-4.mp4: Logit: -0.7334 -> P(class 1)=0.3244 -> 予測クラス: 0 (確信度: 67.56%)
#
# --- [バッチ 434] 推論中 ---
#   - LCS_Right_20211012_763_1-3.mp4: Logit: -0.8101 -> P(class 1)=0.3079 -> 予測クラス: 0 (確信度: 69.21%)
#   - LCS_Right_20211012_763_2-3.mp4: Logit: -0.8737 -> P(class 1)=0.2945 -> 予測クラス: 0 (確信度: 70.55%)
#   - LCS_Right_20211012_763_3-3.mp4: Logit: -0.8381 -> P(class 1)=0.3019 -> 予測クラス: 0 (確信度: 69.81%)
#   - LCS_Right_20211012_765_1-3.mp4: Logit: -0.7321 -> P(class 1)=0.3247 -> 予測クラス: 0 (確信度: 67.53%)
#
# --- [バッチ 435] 推論中 ---
#   - LCS_Right_20211012_765_2-3.mp4: Logit: -0.8498 -> P(class 1)=0.2995 -> 予測クラス: 0 (確信度: 70.05%)
#   - LCS_Right_20211012_765_3-3.mp4: Logit: -1.1181 -> P(class 1)=0.2464 -> 予測クラス: 0 (確信度: 75.36%)
#   - LCS_Right_20211012_767_1-3.mp4: Logit: -1.1028 -> P(class 1)=0.2492 -> 予測クラス: 0 (確信度: 75.08%)
#   - LCS_Right_20211012_767_2-3.mp4: Logit: -1.0671 -> P(class 1)=0.2560 -> 予測クラス: 0 (確信度: 74.40%)
#
# --- [バッチ 436] 推論中 ---
#   - LCS_Right_20211012_767_3-3.mp4: Logit: -1.1556 -> P(class 1)=0.2395 -> 予測クラス: 0 (確信度: 76.05%)
#   - LCS_Right_20211012_769_1-3.mp4: Logit: -0.8528 -> P(class 1)=0.2988 -> 予測クラス: 0 (確信度: 70.12%)
#   - LCS_Right_20211012_769_2-3.mp4: Logit: -1.2008 -> P(class 1)=0.2313 -> 予測クラス: 0 (確信度: 76.87%)
#   - LCS_Right_20211012_769_3-3.mp4: Logit: -1.2248 -> P(class 1)=0.2271 -> 予測クラス: 0 (確信度: 77.29%)
#
# --- [バッチ 437] 推論中 ---
#   - LCS_Right_20211012_771_1-3.mp4: Logit: -0.9750 -> P(class 1)=0.2739 -> 予測クラス: 0 (確信度: 72.61%)
#   - LCS_Right_20211012_771_2-3.mp4: Logit: -0.8382 -> P(class 1)=0.3019 -> 予測クラス: 0 (確信度: 69.81%)
#   - LCS_Right_20211012_771_3-3.mp4: Logit: -1.1138 -> P(class 1)=0.2472 -> 予測クラス: 0 (確信度: 75.28%)
#   - LCS_Right_20211012_773_1-3.mp4: Logit: -0.8091 -> P(class 1)=0.3081 -> 予測クラス: 0 (確信度: 69.19%)
#
# --- [バッチ 438] 推論中 ---
#   - LCS_Right_20211012_773_2-3.mp4: Logit: -0.6112 -> P(class 1)=0.3518 -> 予測クラス: 0 (確信度: 64.82%)
#   - LCS_Right_20211012_773_3-3.mp4: Logit: -1.0858 -> P(class 1)=0.2524 -> 予測クラス: 0 (確信度: 74.76%)
#   - LCS_Right_20211012_775_1-3.mp4: Logit: -0.9229 -> P(class 1)=0.2844 -> 予測クラス: 0 (確信度: 71.56%)
#   - LCS_Right_20211012_775_2-3.mp4: Logit: -1.0704 -> P(class 1)=0.2553 -> 予測クラス: 0 (確信度: 74.47%)
#
# --- [バッチ 439] 推論中 ---
#   - LCS_Right_20211012_775_3-3.mp4: Logit: -1.1886 -> P(class 1)=0.2335 -> 予測クラス: 0 (確信度: 76.65%)
#   - LCS_Right_20211012_777_1-3.mp4: Logit: -1.0298 -> P(class 1)=0.2631 -> 予測クラス: 0 (確信度: 73.69%)
#   - LCS_Right_20211012_777_2-3.mp4: Logit: -1.0555 -> P(class 1)=0.2582 -> 予測クラス: 0 (確信度: 74.18%)
#   - LCS_Right_20211012_777_3-3.mp4: Logit: -1.0120 -> P(class 1)=0.2666 -> 予測クラス: 0 (確信度: 73.34%)
#
# --- [バッチ 440] 推論中 ---
#   - LCS_Right_20211012_779_1-3.mp4: Logit: -0.9057 -> P(class 1)=0.2879 -> 予測クラス: 0 (確信度: 71.21%)
#   - LCS_Right_20211012_779_2-3.mp4: Logit: -0.7166 -> P(class 1)=0.3281 -> 予測クラス: 0 (確信度: 67.19%)
#   - LCS_Right_20211012_779_3-3.mp4: Logit: -1.0492 -> P(class 1)=0.2594 -> 予測クラス: 0 (確信度: 74.06%)
#   - LCS_Right_20211012_781_1-3.mp4: Logit: -0.8761 -> P(class 1)=0.2940 -> 予測クラス: 0 (確信度: 70.60%)
#
# --- [バッチ 441] 推論中 ---
#   - LCS_Right_20211012_781_2-3.mp4: Logit: -1.0701 -> P(class 1)=0.2554 -> 予測クラス: 0 (確信度: 74.46%)
#   - LCS_Right_20211012_781_3-3.mp4: Logit: -1.2490 -> P(class 1)=0.2229 -> 予測クラス: 0 (確信度: 77.71%)
#
#
# ==================== 全ての推論結果 ====================
#                         Video Filename  prediction confidence prob_for_class_1
# 0      ASD_Left_20180123_1648_1-11.mp4           0     0.5038           0.4962
# 1     ASD_Left_20180123_1648_10-11.mp4           0     0.5190           0.4810
# 2     ASD_Left_20180123_1648_11-11.mp4           0     0.5929           0.4071
# 3      ASD_Left_20180123_1648_2-11.mp4           0     0.5301           0.4699
# 4      ASD_Left_20180123_1648_3-11.mp4           0     0.5345           0.4655
# ...                                ...         ...        ...              ...
# 1757    LCS_Right_20211012_779_2-3.mp4           0     0.6719           0.3281
# 1758    LCS_Right_20211012_779_3-3.mp4           0     0.7406           0.2594
# 1759    LCS_Right_20211012_781_1-3.mp4           0     0.7060           0.2940
# 1760    LCS_Right_20211012_781_2-3.mp4           0     0.7446           0.2554
# 1761    LCS_Right_20211012_781_3-3.mp4           0     0.7771           0.2229
#
# [1762 rows x 4 columns]

# %%
import json

# --- 1. 保存先のディレクトリとファイル名を定義 ---
# あなたが指定したパスをここに設定します
output_directory = '/workspace/data/analysis_logs/fails_points/slow'
output_directory = os.path.join(output_directory, TARGET_FOLD)
output_filename = 'inference_results.json'
output_filepath = os.path.join(output_directory, output_filename)

print(f"結果を次のパスに保存します: {output_filepath}")

try:
    # results辞書が空でないことを確認
    if not results:
        print("結果が空のため、JSONファイルは作成されませんでした。")
    else:
        # --- 2. 保存先ディレクトリが存在しない場合に、自動で作成 ---
        # exist_ok=True を指定すると、ディレクトリが既に存在していてもエラーになりません
        os.makedirs(output_directory, exist_ok=True)
        print(f"ディレクトリ '{output_directory}' を確認・作成しました。")

        # --- 3. ファイルを書き込む ---
        with open(output_filepath, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=4)
        
        print(f"\n✅ 推論結果が '{output_filepath}' に正常に保存されました。")

except NameError:
    print("エラー: `results` 辞書が見つかりません。先に推論処理のセルを実行してください。")
except Exception as e:
    print(f"ファイルの保存中に予期せぬエラーが発生しました: {e}")

# %% [markdown]
# # 描画フェーズ

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob # ファイル検索のためのライブラリ

# ==============================================================================
# ## 1. 複数foldのJSONファイルを読み込み、単一のデータフレームに統合
# ==============================================================================
print("ステップ1: 複数foldのJSONファイルを読み込んで統合します...")

# JSONファイルが格納されている親ディレクトリを指定
JSON_ROOT_DIRECTORY = '/workspace/data/analysis_logs/fails_points/late'

# 指定したディレクトリ以下の全ての inference_results.json を探す
json_file_paths = glob.glob(os.path.join(JSON_ROOT_DIRECTORY, 'fold*', 'inference_results.json'))

if not json_file_paths:
    print(f"エラー: '{JSON_ROOT_DIRECTORY}' 内に 'foldX/inference_results.json' のパターンに一致するファイルが見つかりませんでした。")
    raise SystemExit()

print(f"{len(json_file_paths)} 個のJSONファイルが見つかりました:")
for path in json_file_paths:
    print(f"  - {path}")

# 各JSONファイルをDataFrameとして読み込み、一つのリストにまとめる
all_dfs = []
for file_path in json_file_paths:
    fold_name = os.path.basename(os.path.dirname(file_path))
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df_fold = pd.DataFrame.from_dict(data, orient='index')
    df_fold = df_fold.reset_index().rename(columns={'index': 'filename'})
    df_fold['fold'] = fold_name 
    all_dfs.append(df_fold)

# 全てのfoldのDataFrameを縦に結合
df_all = pd.concat(all_dfs, ignore_index=True)
df_all['prediction'] = df_all['prediction'].astype(int)
df_all['confidence'] = df_all['confidence'].astype(float)
print("\n✅ 全てのJSONデータを統合しました。")


# ==============================================================================
# ## 2. 統合データフレームの処理
# ==============================================================================
print("\nステップ2: データフレームを処理し、分析用の列を追加します...")

def extract_position(filename):
    try:
        base_name = os.path.splitext(filename)[0]
        position_str = base_name.split('_')[-1]
        if '-' in position_str and all(part.isdigit() for part in position_str.split('-')):
            return position_str
        return None
    except:
        return None

def get_ground_truth(filename):
    # ASD -> 0, ASD_not -> 1
    if filename.startswith('ASD'):
        return 0
    else:
        return 1

df_all['position'] = df_all['filename'].apply(extract_position)
df_all['ground_truth'] = df_all['filename'].apply(get_ground_truth)
df_all.dropna(subset=['position'], inplace=True)
df_all['is_correct'] = (df_all['prediction'] == df_all['ground_truth']).astype(int)
print("✅ 位置情報、正解ラベル、正誤判定の列を追加しました。")


# ==============================================================================
# ## 3.【詳細分析】位置ごとの集計
# ==============================================================================
print("\nステップ3: 詳細な位置ごとの集計を行います...")
position_analysis = df_all.groupby('position').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
position_analysis['accuracy_rate'] = position_analysis['correct_count'] / position_analysis['total_count']
position_analysis['mistake_count'] = position_analysis['total_count'] - position_analysis['correct_count']

def position_to_midpoint(position_str):
    try:
        numerator, denominator = map(int, position_str.split('-'))
        return (2 * numerator - 1) / (2 * denominator)
    except (ValueError, ZeroDivisionError):
        return float('inf')

position_analysis['sort_value'] = position_analysis['position'].apply(position_to_midpoint)
position_analysis = position_analysis.sort_values(by='sort_value').reset_index(drop=True)
print("✅ 詳細分析の集計が完了しました。")


# ==============================================================================
# ## 4.【詳細分析】結果の可視化
# ==============================================================================
print("\nステップ4: 詳細分析の結果を可視化します...")

# --- グラフA: 絶対数（積み上げ棒グラフ） ---
plot_data_detail = position_analysis.set_index('position')[['correct_count', 'mistake_count']]
plot_data_detail.plot(kind='bar', stacked=True, figsize=(14, 7), color=['#2ca02c', '#d62728'])
plt.title('Number of Correct/Incorrect Predictions by Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Number of Videos', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(['Correct', 'Incorrect'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_0.png'))
plt.show()


# --- グラフB: 正解率 ---
plt.figure(figsize=(14, 7))
ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
for p in ax_detail.patches:
    ax_detail.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Model Accuracy Rate by Course Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_1.png'))
plt.show()


# ==============================================================================
# ## 5.【概要分析】コースを4等分した区間ごとの集計
# ==============================================================================
print("\nステップ5: コースを4分割した概要分析の集計を行います...")

def get_quadrant(midpoint_value):
    if 0 <= midpoint_value < 0.25: return "1st Quadrant (0-25%)"
    elif 0.25 <= midpoint_value < 0.5: return "2nd Quadrant (25-50%)"
    elif 0.5 <= midpoint_value < 0.75: return "3rd Quadrant (50-75%)"
    elif 0.75 <= midpoint_value <= 1.0: return "4th Quadrant (75-100%)"
    else: return "N/A"

df_all['sort_value'] = df_all['position'].apply(position_to_midpoint)
df_all['quadrant'] = df_all['sort_value'].apply(get_quadrant)

quadrant_analysis = df_all.groupby('quadrant').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
quadrant_analysis['accuracy_rate'] = quadrant_analysis['correct_count'] / quadrant_analysis['total_count']
print("✅ 概要分析の集計が完了しました。")


# ==============================================================================
# ## 6.【概要分析】結果の可視化
# ==============================================================================
print("\nステップ6: 概要分析の結果を可視化します...")

# --- display()で集計結果のテーブルを表示 ---
print("\n--- Accuracy Analysis by Course Quadrant ---")
display(quadrant_analysis)

# --- グラフA: 絶対数 ---
plt.figure(figsize=(10, 6))
ax_abs_q = sns.barplot(x='quadrant', y='correct_count', data=quadrant_analysis, color='steelblue', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_abs_q.patches:
    ax_abs_q.annotate(f"{p.get_height():.0f}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Number of Correct Predictions per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_2.png'))
plt.show()

# --- グラフB: 正解率 ---
plt.figure(figsize=(10, 6))
ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_rate_q.patches:
    ax_rate_q.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Accuracy Rate per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_3.png'))
plt.show()
# Out:
# ステップ1: 複数foldのJSONファイルを読み込んで統合します...
# 5 個のJSONファイルが見つかりました:
#   - /workspace/data/analysis_logs/fails_points/slow/fold3/inference_results.json
#   - /workspace/data/analysis_logs/fails_points/slow/fold2/inference_results.json
#   - /workspace/data/analysis_logs/fails_points/slow/fold0/inference_results.json
#   - /workspace/data/analysis_logs/fails_points/slow/fold1/inference_results.json
#   - /workspace/data/analysis_logs/fails_points/slow/fold4/inference_results.json
#
# ✅ 全てのJSONデータを統合しました。
#
# ステップ2: データフレームを処理し、分析用の列を追加します...
# ✅ 位置情報、正解ラベル、正誤判定の列を追加しました。
#
# ステップ3: 詳細な位置ごとの集計を行います...
# ✅ 詳細分析の集計が完了しました。
#
# ステップ4: 詳細分析の結果を可視化します...
# /tmp/ipykernel_408634/3816796263.py:118: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
# ステップ5: コースを4分割した概要分析の集計を行います...
# ✅ 概要分析の集計が完了しました。
#
# ステップ6: 概要分析の結果を可視化します...
#
# --- Accuracy Analysis by Course Quadrant ---
#                  quadrant  correct_count  total_count  accuracy_rate
# 0    1st Quadrant (0-25%)           1829         2524       0.724643
# 1   2nd Quadrant (25-50%)           1951         2591       0.752991
# 2   3rd Quadrant (50-75%)           2170         2984       0.727212
# 3  4th Quadrant (75-100%)           2182         3115       0.700482
# /tmp/ipykernel_408634/3816796263.py:179: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])

# %%
# ==============================================================================
# ## 7.【症例別分析＋総合】症例ごとの正解率の集計と可視化
# ==============================================================================
print("ステップ7: 症例別の分析（総合結果付き）を開始します...")

# --- 1. ファイル名から「症例タイプ」を抽出 ---
def extract_case_type(filename):
    try:
        return filename.split('_')[0]
    except:
        return None

# 'case_type' 列を新しく作成
df_all['case_type'] = df_all['filename'].apply(extract_case_type)
print("  - 症例タイプ列を追加しました。")


# --- 2. 症例タイプごとに正解率と絶対数を集計 ---
# 'case_type' 列でグループ化し、正解数と全体の数を計算
case_analysis = df_all.groupby('case_type').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()

# 正解率を計算
case_analysis['accuracy_rate'] = case_analysis['correct_count'] / case_analysis['total_count']
print("  - 症例タイプごとの集計が完了しました。")


# --- 3. 「総合(Total)」の行を計算して追加 ---
# 全体の合計を計算
total_correct = case_analysis['correct_count'].sum()
total_total = case_analysis['total_count'].sum()
total_accuracy = total_correct / total_total if total_total > 0 else 0

# 'Total'の行を新しいDataFrameとして作成
total_df = pd.DataFrame([{
    'case_type': 'Total',
    'correct_count': total_correct,
    'total_count': total_total,
    'accuracy_rate': total_accuracy
}])

# 元のDataFrameと結合して、'Total'行を含む新しいDataFrameを作成
case_analysis_with_total = pd.concat([total_df, case_analysis], ignore_index=True)

# グラフの表示順を定義 ('Total'を先頭に、残りはアルファベット順)
plot_order = ['Total'] + sorted(case_analysis['case_type'].unique())
print("  - 総合結果の追加と表示順の定義が完了しました。")


# --- 4. 可視化 (2パターン、総合結果付き) ---

# display()で集計結果のテーブルを表示
print("\n--- Accuracy Analysis by Case Type (with Total) ---")
display(case_analysis_with_total)


# ### パターンA: 正解の「絶対数」を可視化 ###
plt.figure(figsize=(10, 6))
ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
for p in ax_abs_case.patches:
    ax_abs_case.annotate(f"{p.get_height():.0f}", 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Number of Correct Predictions per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_4.png'))
plt.show()


# ### パターンB: 「正解率」を可視化 ###
plt.figure(figsize=(10, 6))
ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')
for p in ax_rate_case.patches:
    ax_rate_case.annotate(f"{p.get_height():.2%}", 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Accuracy Rate per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_5.png'))
plt.show()
# Out:
# ステップ7: 症例別の分析（総合結果付き）を開始します...
#   - 症例タイプ列を追加しました。
#   - 症例タイプごとの集計が完了しました。
#   - 総合結果の追加と表示順の定義が完了しました。
#
# --- Accuracy Analysis by Case Type (with Total) ---
#   case_type  correct_count  total_count  accuracy_rate
# 0     Total           8132        11214       0.725165
# 1       ASD           5923         6392       0.926627
# 2       DHS           1525         2371       0.643189
# 3     HipOA             25          834       0.029976
# 4       LCS            659         1617       0.407545
# /tmp/ipykernel_408634/4160753937.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
# /tmp/ipykernel_408634/4160753937.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')

# %%
# =============================================================================
# セル 1: ライブラリのインポートと設定
# =============================================================================
import os
import json
import pandas as pd
import re

# pandasの表示オプションを設定して、表が途中で省略されないようにする
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)

# =============================================================================
# セル 3: データの読み込みと基本分析
# =============================================================================
print("--- データの読み込みと基本分析を開始します ---")
inp_dir = JSON_ROOT_DIRECTORY
all_results = []

for i in range(5):
    fold_name = f'fold{i}'
    json_path = os.path.join(inp_dir, fold_name, 'inference_results.json')

    if os.path.exists(json_path):
        print(f"{json_path} を読み込んでいます...")
        with open(json_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        for filename, results in data.items():
            parts = filename.split('_')
            ground_truth = parts[0]
            direction = parts[1]
            
            prediction_val = results['prediction']
            prediction_label = 'ASD' if prediction_val == 0 else 'ASD以外の疾患'

            is_correct = (ground_truth == 'ASD' and prediction_label == 'ASD') or \
                         (ground_truth != 'ASD' and prediction_label == 'ASD以外の疾患')

            all_results.append({
                'fold': i,
                'filename': filename,
                'direction': direction,
                'ground_truth': ground_truth,
                'prediction_label': prediction_label,
                'confidence': float(results['confidence']),
                'is_correct': is_correct
            })

results_df = pd.DataFrame(all_results)
print("データの読み込みと基本分析が完了しました。\n")


# =============================================================================
# セル 4: Zone分類と最終集計（Right/Left全体比較を追加）
# =============================================================================

def get_zone(row):
    """ファイル名と方向からZoneを判定する関数"""
    filename = row['filename']
    direction = row['direction']

    name_without_ext = os.path.splitext(filename)[0]
    match = re.search(r'(\d+)[-_](\d+)$', name_without_ext)
    if not match: return 'zone_unknown'

    a = int(match.group(1))
    b = int(match.group(2))

    if b == 0 or (a - 1) < 0: return 'zone_unknown'

    avg = ((a / b) + ((a - 1) / b)) / 2
    
    if direction == 'Left':
        if (0 <= avg <= 0.25) or (0.75 <= avg <= 1): return 'zone-1'
        elif 0.25 < avg < 0.75: return 'zone-2'
    elif direction == 'Right':
        if (0 <= avg <= 0.125) or (0.875 <= avg <= 1): return 'zone-0'
        elif (0.125 < avg <= 0.3125) or (0.6875 <= avg < 0.875): return 'zone-1'
        elif 0.3125 < avg < 0.6875: return 'zone-2'
            
    return 'zone_unknown'

if not results_df.empty:
    print("--- Zoneの分類と集計を開始します ---")
    
    # 信頼スコアと正解値(1 or 0)の差を計算
    results_df['confidence_diff'] = np.where(
        results_df['is_correct'],
        1.0 - results_df['confidence'],
        results_df['confidence']
    )
    
    # Zone列を追加
    results_df['zone'] = results_df.apply(get_zone, axis=1)
    
    print("--- 分析結果 ---")

    # 1.【詳細サマリー】方向(Right/Left)とZoneごとの集計
    summary_detailed = results_df.groupby(['direction', 'zone']).agg(
        total_count=('is_correct', 'count'),
        correct_count=('is_correct', 'sum'),
        avg_confidence_diff=('confidence_diff', 'mean')
    ).reset_index()
    summary_detailed['accuracy'] = (summary_detailed['correct_count'] / summary_detailed['total_count'])
    
    # 表示用にフォーマット
    summary_detailed_display = summary_detailed.copy()
    summary_detailed_display['accuracy'] = summary_detailed_display['accuracy'].apply(lambda x: f"{x:.2%}")
    summary_detailed_display['avg_confidence_diff'] = summary_detailed_display['avg_confidence_diff'].apply(lambda x: f"{x:.4f}")
    
    print("\n[1. 方向(Right/Left)とZoneごとの詳細サマリー]")
    display(summary_detailed_display)

    # #################################################
    # ### ここが追加点です ###
    # #################################################
    # 2.【全体サマリー】方向(Right/Left)ごとの集計
    summary_direction = results_df.groupby('direction').agg(
        total_count=('is_correct', 'count'),
        correct_count=('is_correct', 'sum'),
        avg_confidence_diff=('confidence_diff', 'mean')
    ).reset_index()
    summary_direction['accuracy'] = (summary_direction['correct_count'] / summary_direction['total_count'])

    # 表示用にフォーマット
    summary_direction_display = summary_direction.copy()
    summary_direction_display['accuracy'] = summary_direction_display['accuracy'].apply(lambda x: f"{x:.2%}")
    summary_direction_display['avg_confidence_diff'] = summary_direction_display['avg_confidence_diff'].apply(lambda x: f"{x:.4f}")

    print("\n[2. 方向(Right/Left)ごとの全体サマリー]")
    display(summary_direction_display)
    
    # 3. 全データの詳細を表示
    print("\n[3. 全データ詳細]")
    display(results_df)
    
    # 6. CSVファイルとして保存
    save_csv_dir = '/workspace/data/analysis_logs/fails_points'
    fusion_method=os.path.basename(JSON_ROOT_DIRECTORY)
    output_csv_name = 'prediction_analysis_with_zone.csv'
    save_csv_path = os.path.join(save_csv_dir, fusion_method, output_csv_name)
    results_df.to_csv(save_csv_path, index=False, encoding='utf-8-sig')
    print(f"\n全データ詳細を '{save_csv_path}' に保存しました。")

else:
    print("データが見つからなかったため、分析を実行できませんでした。")
# Out:
# --- データの読み込みと基本分析を開始します ---
# /workspace/data/analysis_logs/fails_points/slow/fold0/inference_results.json を読み込んでいます...
# /workspace/data/analysis_logs/fails_points/slow/fold1/inference_results.json を読み込んでいます...
# /workspace/data/analysis_logs/fails_points/slow/fold2/inference_results.json を読み込んでいます...
# /workspace/data/analysis_logs/fails_points/slow/fold3/inference_results.json を読み込んでいます...
# /workspace/data/analysis_logs/fails_points/slow/fold4/inference_results.json を読み込んでいます...
# データの読み込みと基本分析が完了しました。
#
# --- Zoneの分類と集計を開始します ---
# --- 分析結果 ---
#
# [1. 方向(Right/Left)とZoneごとの詳細サマリー]
#   direction    zone  total_count  correct_count avg_confidence_diff accuracy
# 0      Left  zone-1         3556           2727              0.3431   76.69%
# 1      Left  zone-2         2962           2226              0.3626   75.15%
# 2     Right  zone-0         1490           1066              0.3731   71.54%
# 3     Right  zone-1         1428            829              0.4754   58.05%
# 4     Right  zone-2         1778           1284              0.3816   72.22%
# [2. 方向(Right/Left)ごとの全体サマリー]
#   direction  total_count  correct_count avg_confidence_diff accuracy
# 0      Left         6518           4953              0.3519   75.99%
# 1     Right         4696           3179              0.4074   67.70%
# [3. 全データ詳細]
#        fold                          filename direction ground_truth  \
# 0         0  ASD_Left_20180521_1_1507_1-9.mp4      Left          ASD
# 1         0  ASD_Left_20180521_1_1507_2-9.mp4      Left          ASD
# 2         0  ASD_Left_20180521_1_1507_3-9.mp4      Left          ASD
# 3         0  ASD_Left_20180521_1_1507_4-9.mp4      Left          ASD
# 4         0  ASD_Left_20180521_1_1507_5-9.mp4      Left          ASD
# ...     ...                               ...       ...          ...
# 11209     4    LCS_Right_20211012_779_2-3.mp4     Right          LCS
# 11210     4    LCS_Right_20211012_779_3-3.mp4     Right          LCS
# 11211     4    LCS_Right_20211012_781_1-3.mp4     Right          LCS
# 11212     4    LCS_Right_20211012_781_2-3.mp4     Right          LCS
# 11213     4    LCS_Right_20211012_781_3-3.mp4     Right          LCS
#
#       prediction_label  confidence  is_correct  confidence_diff    zone
# 0                  ASD      0.8669        True           0.1331  zone-1
# 1                  ASD      0.8473        True           0.1527  zone-1
# 2                  ASD      0.8613        True           0.1387  zone-2
# 3                  ASD      0.8427        True           0.1573  zone-2
# 4                  ASD      0.8389        True           0.1611  zone-2
# ...                ...         ...         ...              ...     ...
# 11209              ASD      0.6719       False           0.6719  zone-2
# 11210              ASD      0.7406       False           0.7406  zone-1
# 11211              ASD      0.7060       False           0.7060  zone-1
# 11212              ASD      0.7446       False           0.7446  zone-2
# 11213              ASD      0.7771       False           0.7771  zone-1
#
# [11214 rows x 9 columns]
# 全データ詳細を '/workspace/data/analysis_logs/fails_points/slow/prediction_analysis_with_zone.csv' に保存しました。
