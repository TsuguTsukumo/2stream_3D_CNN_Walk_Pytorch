# %% [markdown]
# # 推論フェーズ

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import cv2
import numpy as np
import yaml
import os
import sys
import pandas as pd
from IPython.display import display
from typing import Any, Callable, Dict, Optional, Type, Tuple

print(torch.cuda.is_available())
# Out:
# True

# %%
# --- パス設定 ---
# プロジェクトの基点となるパスを定義
project_base_path = '/workspace/project'

# このパスがPythonの検索パスリスト (sys.path) になければ追加
if project_base_path not in sys.path:
    sys.path.append(project_base_path)
    print(f"'{project_base_path}' を sys.path に追加しました。")

# --- 自作モジュールのインポート ---
try:
    # データローダーのインポート
    from project.dataloader.data_loader_multi import MultiData
    from project.dataloader.data_loader import WalkDataModule
    
    # モデル定義のインポート
    from project.models.make_model import single, early_fusion, late_fusion, slow_fusion

    print("\n✅ 必要な全てのモジュールが正常にインポートされました。")

except ImportError as e:
    print(f"\n❌ エラー: インポートに失敗しました: {e}")
    print("\n【トラブルシューティング】")
    print("1. `project_base_path` のパスが正しいか確認してください。")
    print("2. プロジェクト内のディレクトリに `__init__.py` ファイルが存在するか確認してください。")
    # ここで処理を停止させる
    sys.exit()
# Out:
# ✅ 必要な全てのモジュールが正常にインポートされました。

# %%
# ==============================================================================
# ## 2. 設定：ConfigとHParamsの準備
# ==============================================================================
print("\nステップ2: 設定ファイル (config.yaml) を読み込みます...")

# 学習済みモデルが含まれるディレクトリのルートパス
model_root = '/workspace/logs/resnet/single/2025-06-23/11-27-11'

# config.yaml のパス
config_path = os.path.join(model_root, '.hydra/config.yaml')

def load_config(config_path):
    """YAMLファイルを読み込む関数"""
    try:
        with open(config_path, 'r') as f:
            config = yaml.safe_load(f)
        print(f"設定ファイル '{config_path}' を正常に読み込みました。")
        return config
    except FileNotFoundError:
        print(f"❌ エラー: 設定ファイル '{config_path}' が見つかりません。")
        sys.exit()

# --- HParamsクラスの定義（修正版） ---
class HParams:
    """config.yamlの階層構造を模倣するクラス"""
    def __init__(self, data_config, model_config, train_config):
        self.data = type('DataConfig', (object,), data_config)()
        self.model = type('ModelConfig', (object,), model_config)()
        self.train = type('TrainConfig', (object,), train_config)()

# --- 設定の読み込みとHParamsのインスタンス化（修正版） ---
config_data = load_config(config_path)
try:
    hparams = HParams(
        config_data['data'], 
        config_data['model'], 
        config_data['train']
    )
    print("✅ HParamsオブジェクトを正常に作成しました。")
except KeyError as e:
    print(f"❌ エラー: config.yaml に必要なキー {e} が見つかりません。")
    sys.exit()
# Out:
# ステップ2: 設定ファイル (config.yaml) を読み込みます...
# 設定ファイル '/workspace/logs/resnet/single/2025-06-23/11-27-11/.hydra/config.yaml' を正常に読み込みました。
# ✅ HParamsオブジェクトを正常に作成しました。

# %%
# ==============================================================================
# ## 3. モデルの準備：インスタンス化と学習済み重みのロード
# ==============================================================================
print("\nステップ3: モデルを準備します...")

# --- 設定値の取得 ---
fusion_type = hparams.train.experiment
device_ids = 1
model_path = os.path.join(model_root, 'fold3/version_0/checkpoints/1-1.32-0.5332.ckpt')

# --- デバイスの設定 ---
if torch.cuda.is_available():
    # 指定されたGPU IDが利用可能かチェック
    if device_ids >= torch.cuda.device_count():
        print(f"\n❌ エラー: 指定されたGPU ID {device_ids} は利用できません。利用可能なGPUは {torch.cuda.device_count()}台です。")
        sys.exit()
    
    device = torch.device(f"cuda:{device_ids}")
    print(f"GPU {device_ids} を使用します。")
else:
    device = torch.device("cpu")
    print("GPUが利用できないため、CPUを使用します。")

# --- モデルのインスタンス化 ---
if fusion_type == 'single':
    model = single(hparams).to(device)
elif fusion_type == 'early_fusion':
    model = early_fusion(hparams).to(device)
elif fusion_type == 'late_fusion':
    model = late_fusion(hparams).to(device)
elif fusion_type == 'slow_fusion':
    model = slow_fusion(hparams).to(device)
else:
    raise ValueError(f"不明なフュージョンタイプ: {fusion_type}")
print(f"'{fusion_type}' モデルをインスタンス化し、デバイス '{device}' に配置しました。")

# --- 学習済み重みのロード（最終修正版） ---
try:
    checkpoint = torch.load(model_path, map_location=device, weights_only=False)
    
    if 'state_dict' in checkpoint:
        original_state_dict = checkpoint['state_dict']
        new_state_dict = {}
        # キーの先頭にある "model." プレフィックスを削除
        for k, v in original_state_dict.items():
            if k.startswith("model."):
                new_key = k[len("model."):]
            else:
                new_key = k
            new_state_dict[new_key] = v
        
        model.load_state_dict(new_state_dict)
    else:
        model.load_state_dict(checkpoint)
        
    model.eval() # モデルを評価モードに設定
    print("✅ 学習済み重みをモデルに正常にロードしました。")

except Exception as e:
    import traceback
    print(f"\n❌ エラー: モデルの重みロード中にエラーが発生しました: {e}")
    print(traceback.format_exc())
    sys.exit()
# Out:
# ステップ3: モデルを準備します...
# GPU 1 を使用します。
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 'single' モデルをインスタンス化し、デバイス 'cuda:1' に配置しました。
# ✅ 学習済み重みをモデルに正常にロードしました。

# %%
# ==============================================================================
# ## 4. 推論の実行（single / multi-stream 両対応・修正版）
# ==============================================================================
print("\nステップ4: 推論を実行します...")

# --- 4.1. 推論対象の設定 ---
AP_DATA_ROOT = '/workspace/data/analysis/ex_20250116_lat_organaized_split'
LAT_DATA_ROOT = '/workspace/data/analysis/ex_20250116_lat_organaized_split'
TARGET_FOLD = 'fold3'
INFERENCE_BATCH_SIZE = 4
# -----------------------------

results = {}

# ### ケース1: 2つの動画を入力するフュージョンモデルの場合 ###
if fusion_type in ['late_fusion', 'early_fusion', 'slow_fusion']:
    print(f"'{fusion_type}' モデル（2入力）の推論パイプラインを開始します。")
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    
    datamodule = MultiData(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test') 
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            print(f"\n--- [バッチ {i+1}] 推論中 ---")
            batch_dict = batch[0]
            inputs_front, inputs_side = batch_dict["ap"]["video"].to(device), batch_dict["lat"]["video"].to(device)
            video_names = batch_dict["ap"]["video_name"]
            outputs = model(inputs_front, inputs_side)
            prob_for_class_1 = torch.sigmoid(outputs)
            predicted_indices = (prob_for_class_1 > 0.5).long()
            
            for idx in range(len(video_names)):
                video_name = os.path.basename(video_names[idx])
                pred_class, prob1 = predicted_indices[idx].item(), prob_for_class_1[idx].item()
                confidence = prob1 if pred_class == 1 else 1 - prob1
                results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")

# ### ケース2: 1つの動画を入力する 'single' モデルの場合（修正版） ###
elif fusion_type == 'single':
    print(f"'single' モデル（1入力）の推論パイプラインを開始します。")
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    
    datamodule = WalkDataModule(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test') 
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            print(f"\n--- [バッチ {i+1}] 推論中 ---")
            # batch_dict = batch[0]
            input_video = batch["video"].to(device)
            video_names = batch["video_name"]
            input_video= input_video.permute(0, 2, 1, 3, 4).contiguous()
            outputs = model(input_video)
            prob_for_class_1 = torch.sigmoid(outputs)
            predicted_indices = (prob_for_class_1 > 0.5).long()
            
            for idx in range(len(video_names)):
                video_name = os.path.basename(video_names[idx])
                pred_class, prob1 = predicted_indices[idx].item(), prob_for_class_1[idx].item()
                confidence = prob1 if pred_class == 1 else 1 - prob1
                results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")
    
    

else:
    print(f"エラー: fusion_type '{fusion_type}' はこのスクリプトでサポートされていません。")

# --- 4.4. 結果の集計と表示 ---
print("\n\n==================== 全ての推論結果 ====================")
if not results:
    print("推論が実行された動画はありませんでした。")
else:
    results_df = pd.DataFrame.from_dict(results, orient='index')
    results_df.index.name = 'Video Filename'
    results_df = results_df.reset_index()
    display(results_df)
# Out:
# ステップ4: 推論を実行します...
# 'single' モデル（1入力）の推論パイプラインを開始します。
# 'fold3' の検証(val)データを読み込んでいます...
# データローダーの準備が完了しました。
#
# --- [バッチ 1] 推論中 ---
#   - ASD_20200127_50_1-7.mp4: Logit: -0.4104 -> P(class 1)=0.3988 -> 予測クラス: 0 (確信度: 60.12%)
#   - ASD_20190917_34_1-4.mp4: Logit: -1.0891 -> P(class 1)=0.2518 -> 予測クラス: 0 (確信度: 74.82%)
#   - HipOA_20180806_2_33_1-5.mp4: Logit: -1.4821 -> P(class 1)=0.1851 -> 予測クラス: 0 (確信度: 81.49%)
#   - ASD_20190819_15_2-3.mp4: Logit: -2.4473 -> P(class 1)=0.0796 -> 予測クラス: 0 (確信度: 92.04%)
#
# --- [バッチ 2] 推論中 ---
#   - LCS_20211012_34_2-3.mp4: Logit: -2.8537 -> P(class 1)=0.0545 -> 予測クラス: 0 (確信度: 94.55%)
#   - ASD_20190917_55_2-4.mp4: Logit: -1.9103 -> P(class 1)=0.1290 -> 予測クラス: 0 (確信度: 87.10%)
#   - ASD_20190819_6_2-4.mp4: Logit: 0.8091 -> P(class 1)=0.6919 -> 予測クラス: 1 (確信度: 69.19%)
#   - DHS_20160927_39_1-4.mp4: Logit: -0.7622 -> P(class 1)=0.3182 -> 予測クラス: 0 (確信度: 68.18%)
#
# --- [バッチ 3] 推論中 ---
#   - DHS_20200528_33_6-8.mp4: Logit: 2.5800 -> P(class 1)=0.9296 -> 予測クラス: 1 (確信度: 92.96%)
#   - ASD_20200127_45_5-7.mp4: Logit: 2.6707 -> P(class 1)=0.9353 -> 予測クラス: 1 (確信度: 93.53%)
#   - ASD_20190917_41_2-3.mp4: Logit: -0.7207 -> P(class 1)=0.3272 -> 予測クラス: 0 (確信度: 67.28%)
#   - DHS_20160927_49_1-5.mp4: Logit: -0.5177 -> P(class 1)=0.3734 -> 予測クラス: 0 (確信度: 62.66%)
#
# --- [バッチ 4] 推論中 ---
#   - DHS_20200528_26_5-8.mp4: Logit: 1.2516 -> P(class 1)=0.7776 -> 予測クラス: 1 (確信度: 77.76%)
#   - ASD_20190819_16_1-1.mp4: Logit: 0.3134 -> P(class 1)=0.5777 -> 予測クラス: 1 (確信度: 57.77%)
#   - ASD_20190819_21_3-3.mp4: Logit: 0.5923 -> P(class 1)=0.6439 -> 予測クラス: 1 (確信度: 64.39%)
#   - LCS_20211012_30_4-5.mp4: Logit: 2.0177 -> P(class 1)=0.8826 -> 予測クラス: 1 (確信度: 88.26%)
#
# --- [バッチ 5] 推論中 ---
#   - ASD_20190917_25_1-2.mp4: Logit: 1.1622 -> P(class 1)=0.7617 -> 予測クラス: 1 (確信度: 76.17%)
#   - ASD_20200127_52_3-7.mp4: Logit: 2.5251 -> P(class 1)=0.9259 -> 予測クラス: 1 (確信度: 92.59%)
#   - DHS_20200528_34_7-7.mp4: Logit: 3.5229 -> P(class 1)=0.9713 -> 予測クラス: 1 (確信度: 97.13%)
#   - ASD_20210323_7_5-7.mp4: Logit: 4.7847 -> P(class 1)=0.9917 -> 予測クラス: 1 (確信度: 99.17%)
#
# --- [バッチ 6] 推論中 ---
#   - LCS_20211012_15_5-5.mp4: Logit: -5.7258 -> P(class 1)=0.0033 -> 予測クラス: 0 (確信度: 99.67%)
#   - DHS_20200528_39_3-6.mp4: Logit: -1.9293 -> P(class 1)=0.1268 -> 予測クラス: 0 (確信度: 87.32%)
#   - ASD_20210323_4_6-7.mp4: Logit: -3.5618 -> P(class 1)=0.0276 -> 予測クラス: 0 (確信度: 97.24%)
#   - HipOA_20180806_2_46_4-5.mp4: Logit: -6.6419 -> P(class 1)=0.0013 -> 予測クラス: 0 (確信度: 99.87%)
#
# --- [バッチ 7] 推論中 ---
#   - LCS_20210706_5_2-7.mp4: Logit: -0.9055 -> P(class 1)=0.2879 -> 予測クラス: 0 (確信度: 71.21%)
#   - ASD_20200127_6_10-10.mp4: Logit: -0.4448 -> P(class 1)=0.3906 -> 予測クラス: 0 (確信度: 60.94%)
#   - LCS_20211012_5_5-5.mp4: Logit: -1.0953 -> P(class 1)=0.2506 -> 予測クラス: 0 (確信度: 74.94%)
#   - HipOA_20180806_2_39_3-4.mp4: Logit: -1.5548 -> P(class 1)=0.1744 -> 予測クラス: 0 (確信度: 82.56%)
#
# --- [バッチ 8] 推論中 ---
#   - LCS_20211012_22_1-3.mp4: Logit: 1.7770 -> P(class 1)=0.8553 -> 予測クラス: 1 (確信度: 85.53%)
#   - ASD_20200127_32_5-6.mp4: Logit: 1.8172 -> P(class 1)=0.8602 -> 予測クラス: 1 (確信度: 86.02%)
#   - DHS_20160927_12_1-3.mp4: Logit: 0.0447 -> P(class 1)=0.5112 -> 予測クラス: 1 (確信度: 51.12%)
#   - LCS_20211012_41_1-3.mp4: Logit: 0.1496 -> P(class 1)=0.5373 -> 予測クラス: 1 (確信度: 53.73%)
#
# --- [バッチ 9] 推論中 ---
#   - HipOA_20180806_2_6_5-5.mp4: Logit: -2.7403 -> P(class 1)=0.0606 -> 予測クラス: 0 (確信度: 93.94%)
#   - DHS_20200528_22_3-9.mp4: Logit: -2.7533 -> P(class 1)=0.0599 -> 予測クラス: 0 (確信度: 94.01%)
#   - ASD_20190917_24_2-4.mp4: Logit: -1.7568 -> P(class 1)=0.1472 -> 予測クラス: 0 (確信度: 85.28%)
#   - HipOA_20180806_2_26_6-6.mp4: Logit: -3.8263 -> P(class 1)=0.0213 -> 予測クラス: 0 (確信度: 97.87%)
#
# --- [バッチ 10] 推論中 ---
#   - DHS_20160927_50_3-5.mp4: Logit: 5.3999 -> P(class 1)=0.9955 -> 予測クラス: 1 (確信度: 99.55%)
#   - ASD_20200127_7_7-8.mp4: Logit: 3.2996 -> P(class 1)=0.9644 -> 予測クラス: 1 (確信度: 96.44%)
#   - DHS_20200528_15_2-6.mp4: Logit: 4.0301 -> P(class 1)=0.9825 -> 予測クラス: 1 (確信度: 98.25%)
#   - ASD_20190917_49_2-5.mp4: Logit: 3.9861 -> P(class 1)=0.9818 -> 予測クラス: 1 (確信度: 98.18%)
#
# --- [バッチ 11] 推論中 ---
#   - LCS_20211012_16_4-4.mp4: Logit: -4.0035 -> P(class 1)=0.0179 -> 予測クラス: 0 (確信度: 98.21%)
#   - ASD_20190819_8_2-3.mp4: Logit: -6.4983 -> P(class 1)=0.0015 -> 予測クラス: 0 (確信度: 99.85%)
#   - LCS_20211012_19_2-3.mp4: Logit: -5.2973 -> P(class 1)=0.0050 -> 予測クラス: 0 (確信度: 99.50%)
#   - DHS_20200528_41_5-8.mp4: Logit: -4.9725 -> P(class 1)=0.0069 -> 予測クラス: 0 (確信度: 99.31%)
#
# --- [バッチ 12] 推論中 ---
#   - ASD_20190917_2_3-4.mp4: Logit: 4.0381 -> P(class 1)=0.9827 -> 予測クラス: 1 (確信度: 98.27%)
#   - HipOA_20180806_2_38_3-4.mp4: Logit: 3.1426 -> P(class 1)=0.9586 -> 予測クラス: 1 (確信度: 95.86%)
#   - LCS_20211012_9_5-5.mp4: Logit: 1.3699 -> P(class 1)=0.7974 -> 予測クラス: 1 (確信度: 79.74%)
#   - ASD_20200127_37_10-11.mp4: Logit: 2.1480 -> P(class 1)=0.8955 -> 予測クラス: 1 (確信度: 89.55%)
#
# --- [バッチ 13] 推論中 ---
#   - ASD_20200127_26_3-4.mp4: Logit: 0.3558 -> P(class 1)=0.5880 -> 予測クラス: 1 (確信度: 58.80%)
#   - HipOA_20180806_2_37_2-3.mp4: Logit: 0.0615 -> P(class 1)=0.5154 -> 予測クラス: 1 (確信度: 51.54%)
#   - ASD_20190917_37_2-4.mp4: Logit: -1.1790 -> P(class 1)=0.2352 -> 予測クラス: 0 (確信度: 76.48%)
#   - ASD_20190917_20_2-3.mp4: Logit: -1.5556 -> P(class 1)=0.1743 -> 予測クラス: 0 (確信度: 82.57%)
#
# --- [バッチ 14] 推論中 ---
#   - HipOA_20180806_2_16_2-6.mp4: Logit: -3.9548 -> P(class 1)=0.0188 -> 予測クラス: 0 (確信度: 98.12%)
#   - ASD_20190917_54_1-3.mp4: Logit: -1.8748 -> P(class 1)=0.1330 -> 予測クラス: 0 (確信度: 86.70%)
#   - ASD_20190917_59_1-4.mp4: Logit: -1.7927 -> P(class 1)=0.1427 -> 予測クラス: 0 (確信度: 85.73%)
#   - ASD_20190917_29_1-3.mp4: Logit: -2.1655 -> P(class 1)=0.1029 -> 予測クラス: 0 (確信度: 89.71%)
#
# --- [バッチ 15] 推論中 ---
#   - DHS_20160927_18_2-3.mp4: Logit: 1.0162 -> P(class 1)=0.7342 -> 予測クラス: 1 (確信度: 73.42%)
#   - ASD_20190819_21_1-3.mp4: Logit: -2.5049 -> P(class 1)=0.0755 -> 予測クラス: 0 (確信度: 92.45%)
#   - ASD_20210323_8_2-2.mp4: Logit: -1.2686 -> P(class 1)=0.2195 -> 予測クラス: 0 (確信度: 78.05%)
#   - ASD_20190917_18_3-4.mp4: Logit: 1.5549 -> P(class 1)=0.8256 -> 予測クラス: 1 (確信度: 82.56%)
#
# --- [バッチ 16] 推論中 ---
#   - ASD_20190819_2_3-3.mp4: Logit: 2.6428 -> P(class 1)=0.9336 -> 予測クラス: 1 (確信度: 93.36%)
#   - ASD_20190819_24_1-2.mp4: Logit: 5.4236 -> P(class 1)=0.9956 -> 予測クラス: 1 (確信度: 99.56%)
#   - ASD_20200127_50_3-7.mp4: Logit: 4.3795 -> P(class 1)=0.9876 -> 予測クラス: 1 (確信度: 98.76%)
#   - ASD_20190917_38_1-2.mp4: Logit: 0.2585 -> P(class 1)=0.5643 -> 予測クラス: 1 (確信度: 56.43%)
#
# --- [バッチ 17] 推論中 ---
#   - ASD_20210323_4_7-7.mp4: Logit: 1.3367 -> P(class 1)=0.7919 -> 予測クラス: 1 (確信度: 79.19%)
#   - LCS_20210706_7_1-6.mp4: Logit: 1.9493 -> P(class 1)=0.8754 -> 予測クラス: 1 (確信度: 87.54%)
#   - DHS_20200528_21_6-6.mp4: Logit: 1.6242 -> P(class 1)=0.8354 -> 予測クラス: 1 (確信度: 83.54%)
#   - DHS_20160927_29_1-3.mp4: Logit: 0.3472 -> P(class 1)=0.5859 -> 予測クラス: 1 (確信度: 58.59%)
#
# --- [バッチ 18] 推論中 ---
#   - LCS_20210706_1_4-5.mp4: Logit: -2.2567 -> P(class 1)=0.0948 -> 予測クラス: 0 (確信度: 90.52%)
#   - HipOA_20180806_2_30_2-3.mp4: Logit: -3.3933 -> P(class 1)=0.0325 -> 予測クラス: 0 (確信度: 96.75%)
#   - ASD_20190917_19_1-4.mp4: Logit: -2.2607 -> P(class 1)=0.0944 -> 予測クラス: 0 (確信度: 90.56%)
#   - LCS_20211012_10_2-5.mp4: Logit: -1.3591 -> P(class 1)=0.2044 -> 予測クラス: 0 (確信度: 79.56%)
#
# --- [バッチ 19] 推論中 ---
#   - DHS_20200528_27_1-6.mp4: Logit: -4.1901 -> P(class 1)=0.0149 -> 予測クラス: 0 (確信度: 98.51%)
#   - DHS_20160927_42_2-3.mp4: Logit: -3.5155 -> P(class 1)=0.0289 -> 予測クラス: 0 (確信度: 97.11%)
#   - ASD_20200127_6_7-10.mp4: Logit: -4.5106 -> P(class 1)=0.0109 -> 予測クラス: 0 (確信度: 98.91%)
#   - LCS_20211012_10_4-5.mp4: Logit: -5.1787 -> P(class 1)=0.0056 -> 予測クラス: 0 (確信度: 99.44%)
#
# --- [バッチ 20] 推論中 ---
#   - ASD_20200127_61_6-7.mp4: Logit: 0.5556 -> P(class 1)=0.6354 -> 予測クラス: 1 (確信度: 63.54%)
#   - HipOA_20180806_2_32_1-4.mp4: Logit: -0.8287 -> P(class 1)=0.3039 -> 予測クラス: 0 (確信度: 69.61%)
#   - DHS_20200528_15_6-6.mp4: Logit: 0.8480 -> P(class 1)=0.7001 -> 予測クラス: 1 (確信度: 70.01%)
#   - ASD_20200127_57_1-8.mp4: Logit: 1.0851 -> P(class 1)=0.7475 -> 予測クラス: 1 (確信度: 74.75%)
#
# --- [バッチ 21] 推論中 ---
#   - ASD_20200127_35_6-7.mp4: Logit: -0.7174 -> P(class 1)=0.3280 -> 予測クラス: 0 (確信度: 67.20%)
#   - ASD_20190917_33_3-4.mp4: Logit: -1.6239 -> P(class 1)=0.1647 -> 予測クラス: 0 (確信度: 83.53%)
#   - ASD_20180625_1_5_5-6.mp4: Logit: -2.8102 -> P(class 1)=0.0568 -> 予測クラス: 0 (確信度: 94.32%)
#   - DHS_20200528_36_1-6.mp4: Logit: -4.6503 -> P(class 1)=0.0095 -> 予測クラス: 0 (確信度: 99.05%)
#
# --- [バッチ 22] 推論中 ---
#   - ASD_20200127_30_6-7.mp4: Logit: -1.7557 -> P(class 1)=0.1473 -> 予測クラス: 0 (確信度: 85.27%)
#   - DHS_20200528_34_3-7.mp4: Logit: -1.3355 -> P(class 1)=0.2083 -> 予測クラス: 0 (確信度: 79.17%)
#   - ASD_20200127_44_7-10.mp4: Logit: -1.8848 -> P(class 1)=0.1318 -> 予測クラス: 0 (確信度: 86.82%)
#   - ASD_20200127_40_2-10.mp4: Logit: 0.6282 -> P(class 1)=0.6521 -> 予測クラス: 1 (確信度: 65.21%)
#
# --- [バッチ 23] 推論中 ---
#   - ASD_20190917_65_2-4.mp4: Logit: -0.8936 -> P(class 1)=0.2904 -> 予測クラス: 0 (確信度: 70.96%)
#   - ASD_20190917_68_1-4.mp4: Logit: -0.1182 -> P(class 1)=0.4705 -> 予測クラス: 0 (確信度: 52.95%)
#   - ASD_20200127_40_5-10.mp4: Logit: 1.0847 -> P(class 1)=0.7474 -> 予測クラス: 1 (確信度: 74.74%)
#   - ASD_20190917_2_1-4.mp4: Logit: 2.4471 -> P(class 1)=0.9203 -> 予測クラス: 1 (確信度: 92.03%)
#
# --- [バッチ 24] 推論中 ---
#   - ASD_20200127_68_1-3.mp4: Logit: -3.5553 -> P(class 1)=0.0278 -> 予測クラス: 0 (確信度: 97.22%)
#   - DHS_20200528_41_6-8.mp4: Logit: -2.9956 -> P(class 1)=0.0476 -> 予測クラス: 0 (確信度: 95.24%)
#   - ASD_20200127_11_1-5.mp4: Logit: -0.8392 -> P(class 1)=0.3017 -> 予測クラス: 0 (確信度: 69.83%)
#   - ASD_20200127_54_7-7.mp4: Logit: -3.0795 -> P(class 1)=0.0440 -> 予測クラス: 0 (確信度: 95.60%)
#
# --- [バッチ 25] 推論中 ---
#   - ASD_20200127_8_3-8.mp4: Logit: 1.2601 -> P(class 1)=0.7790 -> 予測クラス: 1 (確信度: 77.90%)
#   - DHS_20200528_37_6-6.mp4: Logit: -0.8755 -> P(class 1)=0.2941 -> 予測クラス: 0 (確信度: 70.59%)
#   - ASD_20190819_9_1-4.mp4: Logit: -2.3985 -> P(class 1)=0.0833 -> 予測クラス: 0 (確信度: 91.67%)
#   - HipOA_20180806_2_3_3-4.mp4: Logit: -2.8896 -> P(class 1)=0.0527 -> 予測クラス: 0 (確信度: 94.73%)
#
# --- [バッチ 26] 推論中 ---
#   - ASD_20200127_6_8-10.mp4: Logit: -3.6664 -> P(class 1)=0.0249 -> 予測クラス: 0 (確信度: 97.51%)
#   - ASD_20210803_3_4-10.mp4: Logit: -3.2033 -> P(class 1)=0.0390 -> 予測クラス: 0 (確信度: 96.10%)
#   - DHS_20160927_55_1-4.mp4: Logit: -1.5227 -> P(class 1)=0.1791 -> 予測クラス: 0 (確信度: 82.09%)
#   - HipOA_20180806_2_22_1-3.mp4: Logit: -1.2321 -> P(class 1)=0.2258 -> 予測クラス: 0 (確信度: 77.42%)
#
# --- [バッチ 27] 推論中 ---
#   - HipOA_20180806_2_17_4-6.mp4: Logit: -4.1957 -> P(class 1)=0.0148 -> 予測クラス: 0 (確信度: 98.52%)
#   - LCS_20211012_17_2-3.mp4: Logit: -4.2417 -> P(class 1)=0.0142 -> 予測クラス: 0 (確信度: 98.58%)
#   - DHS_20200528_23_3-5.mp4: Logit: -4.5882 -> P(class 1)=0.0101 -> 予測クラス: 0 (確信度: 98.99%)
#   - ASD_20190819_15_1-3.mp4: Logit: -4.0145 -> P(class 1)=0.0177 -> 予測クラス: 0 (確信度: 98.23%)
#
# --- [バッチ 28] 推論中 ---
#   - ASD_20190819_11_3-5.mp4: Logit: 1.2858 -> P(class 1)=0.7834 -> 予測クラス: 1 (確信度: 78.34%)
#   - ASD_20200127_6_5-10.mp4: Logit: 1.8239 -> P(class 1)=0.8610 -> 予測クラス: 1 (確信度: 86.10%)
#   - LCS_20211012_1_1-3.mp4: Logit: 1.0469 -> P(class 1)=0.7402 -> 予測クラス: 1 (確信度: 74.02%)
#   - ASD_20200127_12_5-6.mp4: Logit: -0.0663 -> P(class 1)=0.4834 -> 予測クラス: 0 (確信度: 51.66%)
#
# --- [バッチ 29] 推論中 ---
#   - HipOA_20180806_2_16_3-6.mp4: Logit: -4.3519 -> P(class 1)=0.0127 -> 予測クラス: 0 (確信度: 98.73%)
#   - ASD_20200127_21_5-6.mp4: Logit: -4.6881 -> P(class 1)=0.0091 -> 予測クラス: 0 (確信度: 99.09%)
#   - ASD_20190917_8_2-5.mp4: Logit: -5.9609 -> P(class 1)=0.0026 -> 予測クラス: 0 (確信度: 99.74%)
#   - HipOA_20180806_2_4_1-4.mp4: Logit: -2.3749 -> P(class 1)=0.0851 -> 予測クラス: 0 (確信度: 91.49%)
#
# --- [バッチ 30] 推論中 ---
#   - DHS_20160927_13_1-3.mp4: Logit: 2.7030 -> P(class 1)=0.9372 -> 予測クラス: 1 (確信度: 93.72%)
#   - LCS_20211012_3_3-3.mp4: Logit: -1.3258 -> P(class 1)=0.2099 -> 予測クラス: 0 (確信度: 79.01%)
#   - ASD_20190917_28_1-3.mp4: Logit: -0.6889 -> P(class 1)=0.3343 -> 予測クラス: 0 (確信度: 66.57%)
#   - DHS_20200528_17_2-6.mp4: Logit: 0.3927 -> P(class 1)=0.5969 -> 予測クラス: 1 (確信度: 59.69%)
#
# --- [バッチ 31] 推論中 ---
#   - DHS_20160927_35_2-4.mp4: Logit: 4.2000 -> P(class 1)=0.9852 -> 予測クラス: 1 (確信度: 98.52%)
#   - LCS_20211012_4_1-4.mp4: Logit: 4.0791 -> P(class 1)=0.9834 -> 予測クラス: 1 (確信度: 98.34%)
#   - DHS_20200528_23_1-5.mp4: Logit: 3.2429 -> P(class 1)=0.9624 -> 予測クラス: 1 (確信度: 96.24%)
#   - ASD_20210323_7_6-7.mp4: Logit: 2.0510 -> P(class 1)=0.8861 -> 予測クラス: 1 (確信度: 88.61%)
#
# --- [バッチ 32] 推論中 ---
#   - ASD_20200127_63_1-6.mp4: Logit: -1.1431 -> P(class 1)=0.2418 -> 予測クラス: 0 (確信度: 75.82%)
#   - HipOA_20180806_2_17_5-6.mp4: Logit: -4.3654 -> P(class 1)=0.0125 -> 予測クラス: 0 (確信度: 98.75%)
#   - HipOA_20180806_2_19_2-3.mp4: Logit: -3.8474 -> P(class 1)=0.0209 -> 予測クラス: 0 (確信度: 97.91%)
#   - DHS_20160927_33_3-3.mp4: Logit: -3.2088 -> P(class 1)=0.0388 -> 予測クラス: 0 (確信度: 96.12%)
#
# --- [バッチ 33] 推論中 ---
#   - DHS_20200528_3_1-1.mp4: Logit: 3.5105 -> P(class 1)=0.9710 -> 予測クラス: 1 (確信度: 97.10%)
#   - ASD_20200127_63_3-6.mp4: Logit: 1.1744 -> P(class 1)=0.7639 -> 予測クラス: 1 (確信度: 76.39%)
#   - HipOA_20180806_2_13_1-4.mp4: Logit: 0.8801 -> P(class 1)=0.7068 -> 予測クラス: 1 (確信度: 70.68%)
#   - DHS_20160927_12_2-3.mp4: Logit: 5.0447 -> P(class 1)=0.9936 -> 予測クラス: 1 (確信度: 99.36%)
#
# --- [バッチ 34] 推論中 ---
#   - ASD_20200127_30_4-7.mp4: Logit: -4.8343 -> P(class 1)=0.0079 -> 予測クラス: 0 (確信度: 99.21%)
#   - ASD_20200127_10_1-9.mp4: Logit: -4.1191 -> P(class 1)=0.0160 -> 予測クラス: 0 (確信度: 98.40%)
#   - LCS_20210706_7_5-6.mp4: Logit: -2.6390 -> P(class 1)=0.0667 -> 予測クラス: 0 (確信度: 93.33%)
#   - ASD_20200127_43_1-7.mp4: Logit: -2.2143 -> P(class 1)=0.0985 -> 予測クラス: 0 (確信度: 90.15%)
#
# --- [バッチ 35] 推論中 ---
#   - HipOA_20180806_2_43_5-5.mp4: Logit: -3.6722 -> P(class 1)=0.0248 -> 予測クラス: 0 (確信度: 97.52%)
#   - DHS_20160927_27_2-3.mp4: Logit: -5.8447 -> P(class 1)=0.0029 -> 予測クラス: 0 (確信度: 99.71%)
#   - DHS_20160927_31_1-5.mp4: Logit: -3.6776 -> P(class 1)=0.0247 -> 予測クラス: 0 (確信度: 97.53%)
#   - DHS_20200528_24_7-7.mp4: Logit: -5.0669 -> P(class 1)=0.0063 -> 予測クラス: 0 (確信度: 99.37%)
#
# --- [バッチ 36] 推論中 ---
#   - ASD_20200127_20_1-6.mp4: Logit: -1.6806 -> P(class 1)=0.1570 -> 予測クラス: 0 (確信度: 84.30%)
#   - ASD_20180625_1_3_3-4.mp4: Logit: -1.0952 -> P(class 1)=0.2506 -> 予測クラス: 0 (確信度: 74.94%)
#   - ASD_20190917_78_5-5.mp4: Logit: -1.1248 -> P(class 1)=0.2451 -> 予測クラス: 0 (確信度: 75.49%)
#   - LCS_20211012_25_3-5.mp4: Logit: -2.2928 -> P(class 1)=0.0917 -> 予測クラス: 0 (確信度: 90.83%)
#
# --- [バッチ 37] 推論中 ---
#   - ASD_20200127_12_1-6.mp4: Logit: -1.5069 -> P(class 1)=0.1814 -> 予測クラス: 0 (確信度: 81.86%)
#   - ASD_20190819_24_2-2.mp4: Logit: 0.2524 -> P(class 1)=0.5628 -> 予測クラス: 1 (確信度: 56.28%)
#   - ASD_20190917_24_3-4.mp4: Logit: -1.3342 -> P(class 1)=0.2085 -> 予測クラス: 0 (確信度: 79.15%)
#   - ASD_20200127_1_5-5.mp4: Logit: 4.2574 -> P(class 1)=0.9860 -> 予測クラス: 1 (確信度: 98.60%)
#
# --- [バッチ 38] 推論中 ---
#   - ASD_20200127_39_1-7.mp4: Logit: 1.4262 -> P(class 1)=0.8063 -> 予測クラス: 1 (確信度: 80.63%)
#   - DHS_20200528_39_1-6.mp4: Logit: -2.1085 -> P(class 1)=0.1083 -> 予測クラス: 0 (確信度: 89.17%)
#   - ASD_20200127_30_1-7.mp4: Logit: -2.7854 -> P(class 1)=0.0581 -> 予測クラス: 0 (確信度: 94.19%)
#   - DHS_20160927_43_5-5.mp4: Logit: -2.7791 -> P(class 1)=0.0585 -> 予測クラス: 0 (確信度: 94.15%)
#
# --- [バッチ 39] 推論中 ---
#   - DHS_20200528_42_1-6.mp4: Logit: -4.7262 -> P(class 1)=0.0088 -> 予測クラス: 0 (確信度: 99.12%)
#   - DHS_20200528_6_6-8.mp4: Logit: -5.7057 -> P(class 1)=0.0033 -> 予測クラス: 0 (確信度: 99.67%)
#   - ASD_20200127_7_2-8.mp4: Logit: -4.3126 -> P(class 1)=0.0132 -> 予測クラス: 0 (確信度: 98.68%)
#   - ASD_20200127_10_5-9.mp4: Logit: -4.4333 -> P(class 1)=0.0117 -> 予測クラス: 0 (確信度: 98.83%)
#
# --- [バッチ 40] 推論中 ---
#   - ASD_20190917_69_1-3.mp4: Logit: -0.3511 -> P(class 1)=0.4131 -> 予測クラス: 0 (確信度: 58.69%)
#   - ASD_20200127_63_6-6.mp4: Logit: 1.3536 -> P(class 1)=0.7947 -> 予測クラス: 1 (確信度: 79.47%)
#   - ASD_20200127_51_8-9.mp4: Logit: 0.8255 -> P(class 1)=0.6954 -> 予測クラス: 1 (確信度: 69.54%)
#   - LCS_20211012_23_3-3.mp4: Logit: 0.8173 -> P(class 1)=0.6937 -> 予測クラス: 1 (確信度: 69.37%)
#
# --- [バッチ 41] 推論中 ---
#   - ASD_20200127_34_3-7.mp4: Logit: 0.4567 -> P(class 1)=0.6122 -> 予測クラス: 1 (確信度: 61.22%)
#   - HipOA_20180806_2_17_3-6.mp4: Logit: -0.0383 -> P(class 1)=0.4904 -> 予測クラス: 0 (確信度: 50.96%)
#   - ASD_20200127_8_7-8.mp4: Logit: 0.1337 -> P(class 1)=0.5334 -> 予測クラス: 1 (確信度: 53.34%)
#   - DHS_20200528_24_6-7.mp4: Logit: -0.6559 -> P(class 1)=0.3417 -> 予測クラス: 0 (確信度: 65.83%)
#
# --- [バッチ 42] 推論中 ---
#   - ASD_20190819_4_1-4.mp4: Logit: 2.0740 -> P(class 1)=0.8884 -> 予測クラス: 1 (確信度: 88.84%)
#   - ASD_20180625_1_10_2-6.mp4: Logit: 2.9929 -> P(class 1)=0.9523 -> 予測クラス: 1 (確信度: 95.23%)
#   - DHS_20160927_37_4-4.mp4: Logit: 3.0271 -> P(class 1)=0.9538 -> 予測クラス: 1 (確信度: 95.38%)
#   - ASD_20200127_24_4-6.mp4: Logit: -0.7886 -> P(class 1)=0.3125 -> 予測クラス: 0 (確信度: 68.75%)
#
# --- [バッチ 43] 推論中 ---
#   - HipOA_20180806_2_14_3-4.mp4: Logit: -1.7739 -> P(class 1)=0.1451 -> 予測クラス: 0 (確信度: 85.49%)
#   - ASD_20200127_60_6-9.mp4: Logit: -1.3836 -> P(class 1)=0.2004 -> 予測クラス: 0 (確信度: 79.96%)
#   - ASD_20200127_51_1-9.mp4: Logit: -0.0823 -> P(class 1)=0.4794 -> 予測クラス: 0 (確信度: 52.06%)
#   - DHS_20160927_35_3-4.mp4: Logit: -3.6751 -> P(class 1)=0.0247 -> 予測クラス: 0 (確信度: 97.53%)
#
# --- [バッチ 44] 推論中 ---
#   - LCS_20210706_2_7-7.mp4: Logit: -2.7875 -> P(class 1)=0.0580 -> 予測クラス: 0 (確信度: 94.20%)
#   - DHS_20200528_4_4-8.mp4: Logit: -3.0277 -> P(class 1)=0.0462 -> 予測クラス: 0 (確信度: 95.38%)
#   - HipOA_20180806_2_45_2-6.mp4: Logit: -2.6461 -> P(class 1)=0.0662 -> 予測クラス: 0 (確信度: 93.38%)
#   - HipOA_20180806_2_42_3-6.mp4: Logit: -2.0223 -> P(class 1)=0.1169 -> 予測クラス: 0 (確信度: 88.31%)
#
# --- [バッチ 45] 推論中 ---
#   - ASD_20190819_8_1-3.mp4: Logit: -0.4078 -> P(class 1)=0.3994 -> 予測クラス: 0 (確信度: 60.06%)
#   - ASD_20190917_6_1-3.mp4: Logit: -0.5091 -> P(class 1)=0.3754 -> 予測クラス: 0 (確信度: 62.46%)
#   - ASD_20200127_17_7-7.mp4: Logit: 0.6950 -> P(class 1)=0.6671 -> 予測クラス: 1 (確信度: 66.71%)
#   - DHS_20200528_7_8-8.mp4: Logit: -1.5729 -> P(class 1)=0.1718 -> 予測クラス: 0 (確信度: 82.82%)
#
# --- [バッチ 46] 推論中 ---
#   - HipOA_20180806_2_27_1-4.mp4: Logit: -2.7587 -> P(class 1)=0.0596 -> 予測クラス: 0 (確信度: 94.04%)
#   - ASD_20210803_2_12-14.mp4: Logit: -3.5320 -> P(class 1)=0.0284 -> 予測クラス: 0 (確信度: 97.16%)
#   - DHS_20200528_26_7-8.mp4: Logit: -2.0493 -> P(class 1)=0.1141 -> 予測クラス: 0 (確信度: 88.59%)
#   - ASD_20190917_36_4-4.mp4: Logit: -0.9582 -> P(class 1)=0.2772 -> 予測クラス: 0 (確信度: 72.28%)
#
# --- [バッチ 47] 推論中 ---
#   - ASD_20200127_3_6-6.mp4: Logit: -1.2820 -> P(class 1)=0.2172 -> 予測クラス: 0 (確信度: 78.28%)
#   - ASD_20200127_24_2-6.mp4: Logit: -0.4522 -> P(class 1)=0.3888 -> 予測クラス: 0 (確信度: 61.12%)
#   - ASD_20200127_65_7-7.mp4: Logit: -0.0839 -> P(class 1)=0.4790 -> 予測クラス: 0 (確信度: 52.10%)
#   - DHS_20160927_38_1-3.mp4: Logit: 0.0777 -> P(class 1)=0.5194 -> 予測クラス: 1 (確信度: 51.94%)
#
# --- [バッチ 48] 推論中 ---
#   - ASD_20200127_62_4-4.mp4: Logit: -1.4305 -> P(class 1)=0.1930 -> 予測クラス: 0 (確信度: 80.70%)
#   - DHS_20160927_50_4-5.mp4: Logit: -2.4002 -> P(class 1)=0.0832 -> 予測クラス: 0 (確信度: 91.68%)
#   - ASD_20200127_18_1-6.mp4: Logit: -2.2562 -> P(class 1)=0.0948 -> 予測クラス: 0 (確信度: 90.52%)
#   - ASD_20190917_21_4-4.mp4: Logit: -3.0679 -> P(class 1)=0.0445 -> 予測クラス: 0 (確信度: 95.55%)
#
# --- [バッチ 49] 推論中 ---
#   - DHS_20160927_36_1-4.mp4: Logit: -2.5372 -> P(class 1)=0.0733 -> 予測クラス: 0 (確信度: 92.67%)
#   - ASD_20190917_49_5-5.mp4: Logit: 0.0484 -> P(class 1)=0.5121 -> 予測クラス: 1 (確信度: 51.21%)
#   - ASD_20200127_39_2-7.mp4: Logit: 2.0699 -> P(class 1)=0.8879 -> 予測クラス: 1 (確信度: 88.79%)
#   - ASD_20190917_79_2-2.mp4: Logit: 1.9096 -> P(class 1)=0.8710 -> 予測クラス: 1 (確信度: 87.10%)
#
# --- [バッチ 50] 推論中 ---
#   - HipOA_20180806_2_1_3-4.mp4: Logit: -1.3892 -> P(class 1)=0.1995 -> 予測クラス: 0 (確信度: 80.05%)
#   - ASD_20180625_1_8_3-4.mp4: Logit: 0.6547 -> P(class 1)=0.6581 -> 予測クラス: 1 (確信度: 65.81%)
#   - ASD_20200127_17_1-7.mp4: Logit: -3.1930 -> P(class 1)=0.0394 -> 予測クラス: 0 (確信度: 96.06%)
#   - ASD_20190917_36_2-4.mp4: Logit: 0.5560 -> P(class 1)=0.6355 -> 予測クラス: 1 (確信度: 63.55%)
#
# --- [バッチ 51] 推論中 ---
#   - ASD_20190917_30_1-5.mp4: Logit: -0.5621 -> P(class 1)=0.3631 -> 予測クラス: 0 (確信度: 63.69%)
#   - DHS_20200528_27_2-6.mp4: Logit: -0.4027 -> P(class 1)=0.4007 -> 予測クラス: 0 (確信度: 59.93%)
#   - ASD_20180625_1_4_6-6.mp4: Logit: -2.1489 -> P(class 1)=0.1044 -> 予測クラス: 0 (確信度: 89.56%)
#   - HipOA_20180806_2_7_1-1.mp4: Logit: 0.1700 -> P(class 1)=0.5424 -> 予測クラス: 1 (確信度: 54.24%)
#
# --- [バッチ 52] 推論中 ---
#   - HipOA_20180806_2_47_1-6.mp4: Logit: -1.6644 -> P(class 1)=0.1592 -> 予測クラス: 0 (確信度: 84.08%)
#   - ASD_20200127_25_1-7.mp4: Logit: -2.1664 -> P(class 1)=0.1028 -> 予測クラス: 0 (確信度: 89.72%)
#   - LCS_20211012_31_3-4.mp4: Logit: -3.7961 -> P(class 1)=0.0220 -> 予測クラス: 0 (確信度: 97.80%)
#   - ASD_20200127_45_7-7.mp4: Logit: 0.5055 -> P(class 1)=0.6238 -> 予測クラス: 1 (確信度: 62.38%)
#
# --- [バッチ 53] 推論中 ---
#   - DHS_20160927_55_4-4.mp4: Logit: -0.4654 -> P(class 1)=0.3857 -> 予測クラス: 0 (確信度: 61.43%)
#   - DHS_20160927_52_1-4.mp4: Logit: 4.1417 -> P(class 1)=0.9844 -> 予測クラス: 1 (確信度: 98.44%)
#   - DHS_20200528_8_6-9.mp4: Logit: -0.2492 -> P(class 1)=0.4380 -> 予測クラス: 0 (確信度: 56.20%)
#   - ASD_20190917_78_2-5.mp4: Logit: -0.0886 -> P(class 1)=0.4779 -> 予測クラス: 0 (確信度: 52.21%)
#
# --- [バッチ 54] 推論中 ---
#   - ASD_20200127_37_2-11.mp4: Logit: -4.0791 -> P(class 1)=0.0166 -> 予測クラス: 0 (確信度: 98.34%)
#   - ASD_20200127_34_2-7.mp4: Logit: -1.8535 -> P(class 1)=0.1355 -> 予測クラス: 0 (確信度: 86.45%)
#   - DHS_20200528_8_1-9.mp4: Logit: -4.4791 -> P(class 1)=0.0112 -> 予測クラス: 0 (確信度: 98.88%)
#   - ASD_20200127_62_2-4.mp4: Logit: -4.3763 -> P(class 1)=0.0124 -> 予測クラス: 0 (確信度: 98.76%)
#
# --- [バッチ 55] 推論中 ---
#   - ASD_20190819_14_1-4.mp4: Logit: 1.6101 -> P(class 1)=0.8334 -> 予測クラス: 1 (確信度: 83.34%)
#   - DHS_20160927_40_5-5.mp4: Logit: 2.2643 -> P(class 1)=0.9059 -> 予測クラス: 1 (確信度: 90.59%)
#   - HipOA_20180806_2_6_2-5.mp4: Logit: -0.2008 -> P(class 1)=0.4500 -> 予測クラス: 0 (確信度: 55.00%)
#   - HipOA_20180806_2_43_4-5.mp4: Logit: 2.1543 -> P(class 1)=0.8961 -> 予測クラス: 1 (確信度: 89.61%)
#
# --- [バッチ 56] 推論中 ---
#   - ASD_20190819_11_2-5.mp4: Logit: 4.8877 -> P(class 1)=0.9925 -> 予測クラス: 1 (確信度: 99.25%)
#   - DHS_20160927_14_4-4.mp4: Logit: 3.9132 -> P(class 1)=0.9804 -> 予測クラス: 1 (確信度: 98.04%)
#   - ASD_20190917_3_1-3.mp4: Logit: 2.4912 -> P(class 1)=0.9235 -> 予測クラス: 1 (確信度: 92.35%)
#   - HipOA_20180806_2_18_2-3.mp4: Logit: 2.1268 -> P(class 1)=0.8935 -> 予測クラス: 1 (確信度: 89.35%)
#
# --- [バッチ 57] 推論中 ---
#   - DHS_20200528_33_8-8.mp4: Logit: 1.0295 -> P(class 1)=0.7368 -> 予測クラス: 1 (確信度: 73.68%)
#   - LCS_20211012_38_1-3.mp4: Logit: 0.8623 -> P(class 1)=0.7031 -> 予測クラス: 1 (確信度: 70.31%)
#   - LCS_20211012_39_1-4.mp4: Logit: 0.3694 -> P(class 1)=0.5913 -> 予測クラス: 1 (確信度: 59.13%)
#   - ASD_20210803_3_7-10.mp4: Logit: 1.7469 -> P(class 1)=0.8516 -> 予測クラス: 1 (確信度: 85.16%)
#
# --- [バッチ 58] 推論中 ---
#   - ASD_20200127_20_3-6.mp4: Logit: -3.4285 -> P(class 1)=0.0314 -> 予測クラス: 0 (確信度: 96.86%)
#   - ASD_20200127_60_8-9.mp4: Logit: -2.6906 -> P(class 1)=0.0635 -> 予測クラス: 0 (確信度: 93.65%)
#   - DHS_20160927_15_2-4.mp4: Logit: -2.8646 -> P(class 1)=0.0539 -> 予測クラス: 0 (確信度: 94.61%)
#   - ASD_20200127_13_1-4.mp4: Logit: -3.8981 -> P(class 1)=0.0199 -> 予測クラス: 0 (確信度: 98.01%)
#
# --- [バッチ 59] 推論中 ---
#   - DHS_20200528_21_3-6.mp4: Logit: 2.3986 -> P(class 1)=0.9167 -> 予測クラス: 1 (確信度: 91.67%)
#   - ASD_20190819_5_1-4.mp4: Logit: 2.7262 -> P(class 1)=0.9386 -> 予測クラス: 1 (確信度: 93.86%)
#   - DHS_20200528_7_6-8.mp4: Logit: 5.5007 -> P(class 1)=0.9959 -> 予測クラス: 1 (確信度: 99.59%)
#   - ASD_20190917_19_3-4.mp4: Logit: 5.0638 -> P(class 1)=0.9937 -> 予測クラス: 1 (確信度: 99.37%)
#
# --- [バッチ 60] 推論中 ---
#   - ASD_20180625_1_2_3-4.mp4: Logit: -1.5961 -> P(class 1)=0.1685 -> 予測クラス: 0 (確信度: 83.15%)
#   - DHS_20200528_11_2-6.mp4: Logit: -2.4674 -> P(class 1)=0.0782 -> 予測クラス: 0 (確信度: 92.18%)
#   - ASD_20190917_70_1-3.mp4: Logit: -5.0114 -> P(class 1)=0.0066 -> 予測クラス: 0 (確信度: 99.34%)
#   - ASD_20200127_10_9-9.mp4: Logit: -1.2440 -> P(class 1)=0.2237 -> 予測クラス: 0 (確信度: 77.63%)
#
# --- [バッチ 61] 推論中 ---
#   - DHS_20200528_12_5-6.mp4: Logit: -0.0437 -> P(class 1)=0.4891 -> 予測クラス: 0 (確信度: 51.09%)
#   - HipOA_20180806_2_13_3-4.mp4: Logit: 1.4430 -> P(class 1)=0.8089 -> 予測クラス: 1 (確信度: 80.89%)
#   - HipOA_20180806_2_21_3-4.mp4: Logit: 1.8004 -> P(class 1)=0.8582 -> 予測クラス: 1 (確信度: 85.82%)
#   - DHS_20160927_27_1-3.mp4: Logit: -0.7650 -> P(class 1)=0.3176 -> 予測クラス: 0 (確信度: 68.24%)
#
# --- [バッチ 62] 推論中 ---
#   - ASD_20200127_63_4-6.mp4: Logit: -0.5082 -> P(class 1)=0.3756 -> 予測クラス: 0 (確信度: 62.44%)
#   - DHS_20200528_28_5-6.mp4: Logit: -1.8282 -> P(class 1)=0.1385 -> 予測クラス: 0 (確信度: 86.15%)
#   - ASD_20190819_7_1-3.mp4: Logit: 0.6566 -> P(class 1)=0.6585 -> 予測クラス: 1 (確信度: 65.85%)
#   - DHS_20200528_37_3-6.mp4: Logit: -1.0866 -> P(class 1)=0.2523 -> 予測クラス: 0 (確信度: 74.77%)
#
# --- [バッチ 63] 推論中 ---
#   - ASD_20190917_58_1-3.mp4: Logit: 2.1638 -> P(class 1)=0.8969 -> 予測クラス: 1 (確信度: 89.69%)
#   - ASD_20190917_54_2-3.mp4: Logit: 3.3211 -> P(class 1)=0.9651 -> 予測クラス: 1 (確信度: 96.51%)
#   - DHS_20200528_20_5-6.mp4: Logit: 4.4848 -> P(class 1)=0.9888 -> 予測クラス: 1 (確信度: 98.88%)
#   - ASD_20190917_3_3-3.mp4: Logit: 4.9110 -> P(class 1)=0.9927 -> 予測クラス: 1 (確信度: 99.27%)
#
# --- [バッチ 64] 推論中 ---
#   - DHS_20160927_1_2-4.mp4: Logit: -0.8541 -> P(class 1)=0.2986 -> 予測クラス: 0 (確信度: 70.14%)
#   - ASD_20200127_37_8-11.mp4: Logit: 1.7806 -> P(class 1)=0.8558 -> 予測クラス: 1 (確信度: 85.58%)
#   - DHS_20200528_31_1-9.mp4: Logit: 4.1192 -> P(class 1)=0.9840 -> 予測クラス: 1 (確信度: 98.40%)
#   - ASD_20200127_49_5-6.mp4: Logit: 4.1259 -> P(class 1)=0.9841 -> 予測クラス: 1 (確信度: 98.41%)
#
# --- [バッチ 65] 推論中 ---
#   - LCS_20210706_8_5-7.mp4: Logit: -2.4321 -> P(class 1)=0.0808 -> 予測クラス: 0 (確信度: 91.92%)
#   - DHS_20160927_44_2-3.mp4: Logit: -2.2847 -> P(class 1)=0.0924 -> 予測クラス: 0 (確信度: 90.76%)
#   - ASD_20190917_40_4-4.mp4: Logit: -0.9980 -> P(class 1)=0.2693 -> 予測クラス: 0 (確信度: 73.07%)
#   - ASD_20200127_47_1-4.mp4: Logit: -1.7885 -> P(class 1)=0.1433 -> 予測クラス: 0 (確信度: 85.67%)
#
# --- [バッチ 66] 推論中 ---
#   - DHS_20200528_1_4-9.mp4: Logit: 1.2794 -> P(class 1)=0.7824 -> 予測クラス: 1 (確信度: 78.24%)
#   - DHS_20200528_26_1-8.mp4: Logit: 2.1073 -> P(class 1)=0.8916 -> 予測クラス: 1 (確信度: 89.16%)
#   - DHS_20160927_39_4-4.mp4: Logit: 2.4909 -> P(class 1)=0.9235 -> 予測クラス: 1 (確信度: 92.35%)
#   - ASD_20200127_23_3-10.mp4: Logit: 3.4491 -> P(class 1)=0.9692 -> 予測クラス: 1 (確信度: 96.92%)
#
# --- [バッチ 67] 推論中 ---
#   - LCS_20211012_21_2-5.mp4: Logit: -1.5939 -> P(class 1)=0.1688 -> 予測クラス: 0 (確信度: 83.12%)
#   - ASD_20190917_51_3-4.mp4: Logit: -2.7630 -> P(class 1)=0.0594 -> 予測クラス: 0 (確信度: 94.06%)
#   - HipOA_20180806_2_40_1-3.mp4: Logit: -1.2075 -> P(class 1)=0.2302 -> 予測クラス: 0 (確信度: 76.98%)
#   - DHS_20200528_38_2-2.mp4: Logit: -1.4962 -> P(class 1)=0.1830 -> 予測クラス: 0 (確信度: 81.70%)
#
# --- [バッチ 68] 推論中 ---
#   - HipOA_20180806_2_9_1-5.mp4: Logit: -0.5268 -> P(class 1)=0.3713 -> 予測クラス: 0 (確信度: 62.87%)
#   - LCS_20211012_33_5-5.mp4: Logit: -0.2706 -> P(class 1)=0.4328 -> 予測クラス: 0 (確信度: 56.72%)
#   - LCS_20211012_12_4-5.mp4: Logit: -1.4706 -> P(class 1)=0.1868 -> 予測クラス: 0 (確信度: 81.32%)
#   - DHS_20200528_24_1-7.mp4: Logit: -5.9162 -> P(class 1)=0.0027 -> 予測クラス: 0 (確信度: 99.73%)
#
# --- [バッチ 69] 推論中 ---
#   - ASD_20200127_28_3-4.mp4: Logit: -1.8075 -> P(class 1)=0.1409 -> 予測クラス: 0 (確信度: 85.91%)
#   - HipOA_20180806_2_6_4-5.mp4: Logit: -0.1174 -> P(class 1)=0.4707 -> 予測クラス: 0 (確信度: 52.93%)
#   - HipOA_20180806_2_10_1-3.mp4: Logit: -1.0115 -> P(class 1)=0.2667 -> 予測クラス: 0 (確信度: 73.33%)
#   - HipOA_20180806_2_27_2-4.mp4: Logit: -4.1939 -> P(class 1)=0.0149 -> 予測クラス: 0 (確信度: 98.51%)
#
# --- [バッチ 70] 推論中 ---
#   - DHS_20160927_54_1-3.mp4: Logit: 1.4151 -> P(class 1)=0.8046 -> 予測クラス: 1 (確信度: 80.46%)
#   - LCS_20210706_7_2-6.mp4: Logit: 2.1604 -> P(class 1)=0.8966 -> 予測クラス: 1 (確信度: 89.66%)
#   - HipOA_20180806_2_9_3-5.mp4: Logit: 0.7351 -> P(class 1)=0.6759 -> 予測クラス: 1 (確信度: 67.59%)
#   - HipOA_20180806_2_33_4-5.mp4: Logit: 0.0250 -> P(class 1)=0.5062 -> 予測クラス: 1 (確信度: 50.62%)
#
# --- [バッチ 71] 推論中 ---
#   - LCS_20211012_15_2-5.mp4: Logit: -5.5934 -> P(class 1)=0.0037 -> 予測クラス: 0 (確信度: 99.63%)
#   - LCS_20211012_44_5-5.mp4: Logit: -5.0871 -> P(class 1)=0.0061 -> 予測クラス: 0 (確信度: 99.39%)
#   - HipOA_20180806_2_36_1-4.mp4: Logit: -4.7172 -> P(class 1)=0.0089 -> 予測クラス: 0 (確信度: 99.11%)
#   - ASD_20200127_27_2-7.mp4: Logit: -4.6367 -> P(class 1)=0.0096 -> 予測クラス: 0 (確信度: 99.04%)
#
# --- [バッチ 72] 推論中 ---
#   - LCS_20211012_33_2-5.mp4: Logit: -3.7448 -> P(class 1)=0.0231 -> 予測クラス: 0 (確信度: 97.69%)
#   - ASD_20190917_35_1-5.mp4: Logit: -3.9329 -> P(class 1)=0.0192 -> 予測クラス: 0 (確信度: 98.08%)
#   - DHS_20200528_10_1-6.mp4: Logit: -6.7166 -> P(class 1)=0.0012 -> 予測クラス: 0 (確信度: 99.88%)
#   - ASD_20200127_66_5-6.mp4: Logit: -6.0500 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#
# --- [バッチ 73] 推論中 ---
#   - ASD_20190819_20_4-4.mp4: Logit: 2.4741 -> P(class 1)=0.9223 -> 予測クラス: 1 (確信度: 92.23%)
#   - ASD_20200127_55_2-8.mp4: Logit: 0.7876 -> P(class 1)=0.6873 -> 予測クラス: 1 (確信度: 68.73%)
#   - ASD_20200127_30_3-7.mp4: Logit: -0.5272 -> P(class 1)=0.3712 -> 予測クラス: 0 (確信度: 62.88%)
#   - HipOA_20180806_2_11_1-4.mp4: Logit: 1.2957 -> P(class 1)=0.7851 -> 予測クラス: 1 (確信度: 78.51%)
#
# --- [バッチ 74] 推論中 ---
#   - ASD_20180625_1_2_1-4.mp4: Logit: 1.6617 -> P(class 1)=0.8405 -> 予測クラス: 1 (確信度: 84.05%)
#   - ASD_20190819_27_3-3.mp4: Logit: 1.6285 -> P(class 1)=0.8360 -> 予測クラス: 1 (確信度: 83.60%)
#   - DHS_20160927_23_3-3.mp4: Logit: 1.9817 -> P(class 1)=0.8789 -> 予測クラス: 1 (確信度: 87.89%)
#   - ASD_20200127_65_4-7.mp4: Logit: -2.5562 -> P(class 1)=0.0720 -> 予測クラス: 0 (確信度: 92.80%)
#
# --- [バッチ 75] 推論中 ---
#   - ASD_20190819_1_3-4.mp4: Logit: -0.9383 -> P(class 1)=0.2812 -> 予測クラス: 0 (確信度: 71.88%)
#   - ASD_20200127_34_6-7.mp4: Logit: -0.2960 -> P(class 1)=0.4265 -> 予測クラス: 0 (確信度: 57.35%)
#   - DHS_20200528_17_5-6.mp4: Logit: -0.2533 -> P(class 1)=0.4370 -> 予測クラス: 0 (確信度: 56.30%)
#   - ASD_20190917_52_3-3.mp4: Logit: -1.2151 -> P(class 1)=0.2288 -> 予測クラス: 0 (確信度: 77.12%)
#
# --- [バッチ 76] 推論中 ---
#   - DHS_20200528_26_3-8.mp4: Logit: 1.0804 -> P(class 1)=0.7466 -> 予測クラス: 1 (確信度: 74.66%)
#   - DHS_20200528_6_2-8.mp4: Logit: 1.2765 -> P(class 1)=0.7818 -> 予測クラス: 1 (確信度: 78.18%)
#   - ASD_20180625_1_5_1-6.mp4: Logit: 2.6813 -> P(class 1)=0.9359 -> 予測クラス: 1 (確信度: 93.59%)
#   - ASD_20200127_9_3-6.mp4: Logit: 0.4627 -> P(class 1)=0.6137 -> 予測クラス: 1 (確信度: 61.37%)
#
# --- [バッチ 77] 推論中 ---
#   - LCS_20211012_22_2-3.mp4: Logit: 1.0953 -> P(class 1)=0.7494 -> 予測クラス: 1 (確信度: 74.94%)
#   - DHS_20200528_40_1-1.mp4: Logit: -0.3399 -> P(class 1)=0.4158 -> 予測クラス: 0 (確信度: 58.42%)
#   - ASD_20190917_20_3-3.mp4: Logit: -2.9027 -> P(class 1)=0.0520 -> 予測クラス: 0 (確信度: 94.80%)
#   - LCS_20211012_9_3-5.mp4: Logit: -4.2758 -> P(class 1)=0.0137 -> 予測クラス: 0 (確信度: 98.63%)
#
# --- [バッチ 78] 推論中 ---
#   - DHS_20160927_3_2-5.mp4: Logit: 0.8649 -> P(class 1)=0.7037 -> 予測クラス: 1 (確信度: 70.37%)
#   - HipOA_20180806_2_41_3-5.mp4: Logit: 3.4048 -> P(class 1)=0.9679 -> 予測クラス: 1 (確信度: 96.79%)
#   - DHS_20160927_40_1-5.mp4: Logit: 2.6187 -> P(class 1)=0.9321 -> 予測クラス: 1 (確信度: 93.21%)
#   - HipOA_20180806_2_29_1-4.mp4: Logit: 2.8760 -> P(class 1)=0.9466 -> 予測クラス: 1 (確信度: 94.66%)
#
# --- [バッチ 79] 推論中 ---
#   - DHS_20200528_14_3-5.mp4: Logit: 1.3708 -> P(class 1)=0.7975 -> 予測クラス: 1 (確信度: 79.75%)
#   - HipOA_20180806_2_29_4-4.mp4: Logit: 0.6439 -> P(class 1)=0.6556 -> 予測クラス: 1 (確信度: 65.56%)
#   - ASD_20210323_1_1-4.mp4: Logit: 0.5353 -> P(class 1)=0.6307 -> 予測クラス: 1 (確信度: 63.07%)
#   - DHS_20160927_40_4-5.mp4: Logit: -0.1423 -> P(class 1)=0.4645 -> 予測クラス: 0 (確信度: 53.55%)
#
# --- [バッチ 80] 推論中 ---
#   - ASD_20200127_34_1-7.mp4: Logit: 0.1776 -> P(class 1)=0.5443 -> 予測クラス: 1 (確信度: 54.43%)
#   - ASD_20200127_27_6-7.mp4: Logit: -0.8229 -> P(class 1)=0.3052 -> 予測クラス: 0 (確信度: 69.48%)
#   - HipOA_20180806_2_48_3-3.mp4: Logit: 0.1562 -> P(class 1)=0.5390 -> 予測クラス: 1 (確信度: 53.90%)
#   - DHS_20160927_21_2-4.mp4: Logit: -0.4345 -> P(class 1)=0.3931 -> 予測クラス: 0 (確信度: 60.69%)
#
# --- [バッチ 81] 推論中 ---
#   - DHS_20200528_32_3-5.mp4: Logit: 2.1553 -> P(class 1)=0.8962 -> 予測クラス: 1 (確信度: 89.62%)
#   - LCS_20211012_14_5-5.mp4: Logit: 4.5417 -> P(class 1)=0.9895 -> 予測クラス: 1 (確信度: 98.95%)
#   - DHS_20200528_16_5-6.mp4: Logit: 1.6812 -> P(class 1)=0.8431 -> 予測クラス: 1 (確信度: 84.31%)
#   - ASD_20190917_8_1-5.mp4: Logit: 3.4024 -> P(class 1)=0.9678 -> 予測クラス: 1 (確信度: 96.78%)
#
# --- [バッチ 82] 推論中 ---
#   - DHS_20160927_40_2-5.mp4: Logit: 0.4639 -> P(class 1)=0.6139 -> 予測クラス: 1 (確信度: 61.39%)
#   - ASD_20190917_35_2-5.mp4: Logit: -0.2148 -> P(class 1)=0.4465 -> 予測クラス: 0 (確信度: 55.35%)
#   - DHS_20200528_1_5-9.mp4: Logit: -0.1432 -> P(class 1)=0.4643 -> 予測クラス: 0 (確信度: 53.57%)
#   - DHS_20160927_33_2-3.mp4: Logit: 2.5088 -> P(class 1)=0.9248 -> 予測クラス: 1 (確信度: 92.48%)
#
# --- [バッチ 83] 推論中 ---
#   - ASD_20200127_60_5-9.mp4: Logit: -1.3738 -> P(class 1)=0.2020 -> 予測クラス: 0 (確信度: 79.80%)
#   - HipOA_20180806_2_42_2-6.mp4: Logit: -1.6462 -> P(class 1)=0.1616 -> 予測クラス: 0 (確信度: 83.84%)
#   - DHS_20200528_32_5-5.mp4: Logit: -2.2187 -> P(class 1)=0.0981 -> 予測クラス: 0 (確信度: 90.19%)
#   - ASD_20180625_1_6_1-6.mp4: Logit: -2.0593 -> P(class 1)=0.1131 -> 予測クラス: 0 (確信度: 88.69%)
#
# --- [バッチ 84] 推論中 ---
#   - DHS_20160927_11_3-3.mp4: Logit: 2.1793 -> P(class 1)=0.8984 -> 予測クラス: 1 (確信度: 89.84%)
#   - ASD_20190917_56_1-3.mp4: Logit: 3.0022 -> P(class 1)=0.9527 -> 予測クラス: 1 (確信度: 95.27%)
#   - LCS_20211012_29_1-3.mp4: Logit: -0.4504 -> P(class 1)=0.3893 -> 予測クラス: 0 (確信度: 61.07%)
#   - ASD_20200127_39_4-7.mp4: Logit: 2.6658 -> P(class 1)=0.9350 -> 予測クラス: 1 (確信度: 93.50%)
#
# --- [バッチ 85] 推論中 ---
#   - DHS_20160927_33_1-3.mp4: Logit: 1.7717 -> P(class 1)=0.8547 -> 予測クラス: 1 (確信度: 85.47%)
#   - ASD_20210803_2_1-14.mp4: Logit: 3.2935 -> P(class 1)=0.9642 -> 予測クラス: 1 (確信度: 96.42%)
#   - ASD_20200127_37_11-11.mp4: Logit: 0.0619 -> P(class 1)=0.5155 -> 予測クラス: 1 (確信度: 51.55%)
#   - ASD_20200127_13_2-4.mp4: Logit: 0.3886 -> P(class 1)=0.5960 -> 予測クラス: 1 (確信度: 59.60%)
#
# --- [バッチ 86] 推論中 ---
#   - DHS_20200528_34_6-7.mp4: Logit: -0.2769 -> P(class 1)=0.4312 -> 予測クラス: 0 (確信度: 56.88%)
#   - ASD_20200127_49_4-6.mp4: Logit: 0.7373 -> P(class 1)=0.6764 -> 予測クラス: 1 (確信度: 67.64%)
#   - DHS_20200528_1_9-9.mp4: Logit: -2.7777 -> P(class 1)=0.0585 -> 予測クラス: 0 (確信度: 94.15%)
#   - ASD_20200127_23_10-10.mp4: Logit: -0.2834 -> P(class 1)=0.4296 -> 予測クラス: 0 (確信度: 57.04%)
#
# --- [バッチ 87] 推論中 ---
#   - ASD_20190917_42_2-2.mp4: Logit: 2.8135 -> P(class 1)=0.9434 -> 予測クラス: 1 (確信度: 94.34%)
#   - LCS_20211012_26_3-4.mp4: Logit: 0.4797 -> P(class 1)=0.6177 -> 予測クラス: 1 (確信度: 61.77%)
#   - ASD_20190917_71_5-5.mp4: Logit: -0.1401 -> P(class 1)=0.4650 -> 予測クラス: 0 (確信度: 53.50%)
#   - ASD_20200127_50_6-7.mp4: Logit: 0.6655 -> P(class 1)=0.6605 -> 予測クラス: 1 (確信度: 66.05%)
#
# --- [バッチ 88] 推論中 ---
#   - LCS_20210706_4_3-4.mp4: Logit: 0.1008 -> P(class 1)=0.5252 -> 予測クラス: 1 (確信度: 52.52%)
#   - ASD_20200127_60_2-9.mp4: Logit: -1.2315 -> P(class 1)=0.2259 -> 予測クラス: 0 (確信度: 77.41%)
#   - HipOA_20180806_2_3_2-4.mp4: Logit: -3.2560 -> P(class 1)=0.0371 -> 予測クラス: 0 (確信度: 96.29%)
#   - ASD_20200127_6_4-10.mp4: Logit: -1.4265 -> P(class 1)=0.1936 -> 予測クラス: 0 (確信度: 80.64%)
#
# --- [バッチ 89] 推論中 ---
#   - ASD_20210323_5_2-3.mp4: Logit: -1.0590 -> P(class 1)=0.2575 -> 予測クラス: 0 (確信度: 74.25%)
#   - ASD_20200127_47_4-4.mp4: Logit: 0.5137 -> P(class 1)=0.6257 -> 予測クラス: 1 (確信度: 62.57%)
#   - DHS_20200528_15_5-6.mp4: Logit: -1.1528 -> P(class 1)=0.2400 -> 予測クラス: 0 (確信度: 76.00%)
#   - ASD_20200127_37_1-11.mp4: Logit: -4.1062 -> P(class 1)=0.0162 -> 予測クラス: 0 (確信度: 98.38%)
#
# --- [バッチ 90] 推論中 ---
#   - DHS_20200528_22_1-9.mp4: Logit: -3.1582 -> P(class 1)=0.0408 -> 予測クラス: 0 (確信度: 95.92%)
#   - DHS_20200528_4_5-8.mp4: Logit: -2.6733 -> P(class 1)=0.0646 -> 予測クラス: 0 (確信度: 93.54%)
#   - LCS_20211012_21_3-5.mp4: Logit: 0.9267 -> P(class 1)=0.7164 -> 予測クラス: 1 (確信度: 71.64%)
#   - HipOA_20180806_2_25_6-6.mp4: Logit: -0.3324 -> P(class 1)=0.4177 -> 予測クラス: 0 (確信度: 58.23%)
#
# --- [バッチ 91] 推論中 ---
#   - ASD_20190917_45_3-3.mp4: Logit: 4.1073 -> P(class 1)=0.9838 -> 予測クラス: 1 (確信度: 98.38%)
#   - DHS_20160927_54_2-3.mp4: Logit: 2.1580 -> P(class 1)=0.8964 -> 予測クラス: 1 (確信度: 89.64%)
#   - LCS_20211012_40_3-5.mp4: Logit: 2.2562 -> P(class 1)=0.9052 -> 予測クラス: 1 (確信度: 90.52%)
#   - DHS_20200528_27_3-6.mp4: Logit: 2.4450 -> P(class 1)=0.9202 -> 予測クラス: 1 (確信度: 92.02%)
#
# --- [バッチ 92] 推論中 ---
#   - DHS_20200528_29_1-6.mp4: Logit: 2.0732 -> P(class 1)=0.8883 -> 予測クラス: 1 (確信度: 88.83%)
#   - HipOA_20180806_2_41_4-5.mp4: Logit: 2.2693 -> P(class 1)=0.9063 -> 予測クラス: 1 (確信度: 90.63%)
#   - ASD_20200127_48_2-10.mp4: Logit: 2.7842 -> P(class 1)=0.9418 -> 予測クラス: 1 (確信度: 94.18%)
#   - ASD_20190917_60_2-4.mp4: Logit: 7.3191 -> P(class 1)=0.9993 -> 予測クラス: 1 (確信度: 99.93%)
#
# --- [バッチ 93] 推論中 ---
#   - ASD_20200127_44_6-10.mp4: Logit: -3.6671 -> P(class 1)=0.0249 -> 予測クラス: 0 (確信度: 97.51%)
#   - ASD_20190917_44_4-4.mp4: Logit: -2.3667 -> P(class 1)=0.0857 -> 予測クラス: 0 (確信度: 91.43%)
#   - ASD_20190917_76_1-3.mp4: Logit: -3.9358 -> P(class 1)=0.0192 -> 予測クラス: 0 (確信度: 98.08%)
#   - HipOA_20180806_2_25_5-6.mp4: Logit: -4.3972 -> P(class 1)=0.0122 -> 予測クラス: 0 (確信度: 98.78%)
#
# --- [バッチ 94] 推論中 ---
#   - DHS_20160927_44_1-3.mp4: Logit: -0.2653 -> P(class 1)=0.4341 -> 予測クラス: 0 (確信度: 56.59%)
#   - ASD_20180625_1_5_6-6.mp4: Logit: -0.6356 -> P(class 1)=0.3462 -> 予測クラス: 0 (確信度: 65.38%)
#   - ASD_20190917_52_1-3.mp4: Logit: 0.7037 -> P(class 1)=0.6690 -> 予測クラス: 1 (確信度: 66.90%)
#   - ASD_20200127_54_1-7.mp4: Logit: -1.7005 -> P(class 1)=0.1544 -> 予測クラス: 0 (確信度: 84.56%)
#
# --- [バッチ 95] 推論中 ---
#   - ASD_20200127_19_6-10.mp4: Logit: -2.1377 -> P(class 1)=0.1055 -> 予測クラス: 0 (確信度: 89.45%)
#   - LCS_20211012_32_4-5.mp4: Logit: -3.5223 -> P(class 1)=0.0287 -> 予測クラス: 0 (確信度: 97.13%)
#   - DHS_20200528_19_6-8.mp4: Logit: -3.6306 -> P(class 1)=0.0258 -> 予測クラス: 0 (確信度: 97.42%)
#   - ASD_20190917_65_3-4.mp4: Logit: -2.9667 -> P(class 1)=0.0490 -> 予測クラス: 0 (確信度: 95.10%)
#
# --- [バッチ 96] 推論中 ---
#   - ASD_20190819_19_3-3.mp4: Logit: -1.1870 -> P(class 1)=0.2338 -> 予測クラス: 0 (確信度: 76.62%)
#   - ASD_20190917_12_4-4.mp4: Logit: -3.4759 -> P(class 1)=0.0300 -> 予測クラス: 0 (確信度: 97.00%)
#   - DHS_20160927_52_2-4.mp4: Logit: 0.0534 -> P(class 1)=0.5134 -> 予測クラス: 1 (確信度: 51.34%)
#   - ASD_20200127_44_10-10.mp4: Logit: -0.7113 -> P(class 1)=0.3293 -> 予測クラス: 0 (確信度: 67.07%)
#
# --- [バッチ 97] 推論中 ---
#   - HipOA_20180806_2_37_1-3.mp4: Logit: -5.6578 -> P(class 1)=0.0035 -> 予測クラス: 0 (確信度: 99.65%)
#   - ASD_20200127_12_2-6.mp4: Logit: -5.0132 -> P(class 1)=0.0066 -> 予測クラス: 0 (確信度: 99.34%)
#   - LCS_20211012_42_4-5.mp4: Logit: -4.7449 -> P(class 1)=0.0086 -> 予測クラス: 0 (確信度: 99.14%)
#   - ASD_20190917_64_3-4.mp4: Logit: -4.0561 -> P(class 1)=0.0170 -> 予測クラス: 0 (確信度: 98.30%)
#
# --- [バッチ 98] 推論中 ---
#   - ASD_20200127_51_5-9.mp4: Logit: -1.9469 -> P(class 1)=0.1249 -> 予測クラス: 0 (確信度: 87.51%)
#   - ASD_20200127_1_3-5.mp4: Logit: -2.6849 -> P(class 1)=0.0639 -> 予測クラス: 0 (確信度: 93.61%)
#   - ASD_20190917_59_4-4.mp4: Logit: -2.7217 -> P(class 1)=0.0617 -> 予測クラス: 0 (確信度: 93.83%)
#   - LCS_20211012_16_2-4.mp4: Logit: -4.0152 -> P(class 1)=0.0177 -> 予測クラス: 0 (確信度: 98.23%)
#
# --- [バッチ 99] 推論中 ---
#   - LCS_20211012_43_1-5.mp4: Logit: 0.3234 -> P(class 1)=0.5802 -> 予測クラス: 1 (確信度: 58.02%)
#   - ASD_20190819_9_2-4.mp4: Logit: -0.7149 -> P(class 1)=0.3285 -> 予測クラス: 0 (確信度: 67.15%)
#   - DHS_20160927_1_4-4.mp4: Logit: -1.8201 -> P(class 1)=0.1394 -> 予測クラス: 0 (確信度: 86.06%)
#   - ASD_20190917_9_2-2.mp4: Logit: -4.1148 -> P(class 1)=0.0161 -> 予測クラス: 0 (確信度: 98.39%)
#
# --- [バッチ 100] 推論中 ---
#   - HipOA_20180806_2_34_1-3.mp4: Logit: -3.8469 -> P(class 1)=0.0209 -> 予測クラス: 0 (確信度: 97.91%)
#   - ASD_20190917_37_3-4.mp4: Logit: -4.3903 -> P(class 1)=0.0122 -> 予測クラス: 0 (確信度: 98.78%)
#   - ASD_20200127_7_1-8.mp4: Logit: 1.1046 -> P(class 1)=0.7511 -> 予測クラス: 1 (確信度: 75.11%)
#   - HipOA_20180806_2_23_2-6.mp4: Logit: -1.4435 -> P(class 1)=0.1910 -> 予測クラス: 0 (確信度: 80.90%)
#
# --- [バッチ 101] 推論中 ---
#   - DHS_20160927_22_1-3.mp4: Logit: -0.0619 -> P(class 1)=0.4845 -> 予測クラス: 0 (確信度: 51.55%)
#   - ASD_20210803_3_9-10.mp4: Logit: 2.2128 -> P(class 1)=0.9014 -> 予測クラス: 1 (確信度: 90.14%)
#   - LCS_20211012_35_1-3.mp4: Logit: 3.7752 -> P(class 1)=0.9776 -> 予測クラス: 1 (確信度: 97.76%)
#   - LCS_20211012_33_1-5.mp4: Logit: 2.1287 -> P(class 1)=0.8937 -> 予測クラス: 1 (確信度: 89.37%)
#
# --- [バッチ 102] 推論中 ---
#   - HipOA_20180806_2_10_2-3.mp4: Logit: -3.2595 -> P(class 1)=0.0370 -> 予測クラス: 0 (確信度: 96.30%)
#   - LCS_20211012_17_1-3.mp4: Logit: -3.8854 -> P(class 1)=0.0201 -> 予測クラス: 0 (確信度: 97.99%)
#   - ASD_20200127_5_3-10.mp4: Logit: -4.0194 -> P(class 1)=0.0176 -> 予測クラス: 0 (確信度: 98.24%)
#   - ASD_20200127_33_6-7.mp4: Logit: -2.4051 -> P(class 1)=0.0828 -> 予測クラス: 0 (確信度: 91.72%)
#
# --- [バッチ 103] 推論中 ---
#   - ASD_20200127_48_10-10.mp4: Logit: -3.1989 -> P(class 1)=0.0392 -> 予測クラス: 0 (確信度: 96.08%)
#   - ASD_20210803_1_4-7.mp4: Logit: -2.9279 -> P(class 1)=0.0508 -> 予測クラス: 0 (確信度: 94.92%)
#   - DHS_20200528_10_6-6.mp4: Logit: 0.5988 -> P(class 1)=0.6454 -> 予測クラス: 1 (確信度: 64.54%)
#   - DHS_20160927_47_2-4.mp4: Logit: -2.0221 -> P(class 1)=0.1169 -> 予測クラス: 0 (確信度: 88.31%)
#
# --- [バッチ 104] 推論中 ---
#   - LCS_20211012_35_2-3.mp4: Logit: -1.6563 -> P(class 1)=0.1603 -> 予測クラス: 0 (確信度: 83.97%)
#   - ASD_20200127_17_6-7.mp4: Logit: -2.0468 -> P(class 1)=0.1144 -> 予測クラス: 0 (確信度: 88.56%)
#   - ASD_20190917_29_2-3.mp4: Logit: -3.1781 -> P(class 1)=0.0400 -> 予測クラス: 0 (確信度: 96.00%)
#   - HipOA_20180806_2_15_2-4.mp4: Logit: 0.2092 -> P(class 1)=0.5521 -> 予測クラス: 1 (確信度: 55.21%)
#
# --- [バッチ 105] 推論中 ---
#   - ASD_20190917_63_1-4.mp4: Logit: 0.6842 -> P(class 1)=0.6647 -> 予測クラス: 1 (確信度: 66.47%)
#   - DHS_20160927_53_4-5.mp4: Logit: -1.3296 -> P(class 1)=0.2092 -> 予測クラス: 0 (確信度: 79.08%)
#   - DHS_20160927_29_2-3.mp4: Logit: -0.4434 -> P(class 1)=0.3909 -> 予測クラス: 0 (確信度: 60.91%)
#   - ASD_20200127_40_7-10.mp4: Logit: -0.9029 -> P(class 1)=0.2885 -> 予測クラス: 0 (確信度: 71.15%)
#
# --- [バッチ 106] 推論中 ---
#   - HipOA_20180806_2_1_1-4.mp4: Logit: 1.5886 -> P(class 1)=0.8304 -> 予測クラス: 1 (確信度: 83.04%)
#   - ASD_20200127_17_5-7.mp4: Logit: 0.3412 -> P(class 1)=0.5845 -> 予測クラス: 1 (確信度: 58.45%)
#   - DHS_20160927_6_1-3.mp4: Logit: 2.5755 -> P(class 1)=0.9293 -> 予測クラス: 1 (確信度: 92.93%)
#   - LCS_20211012_6_3-3.mp4: Logit: 2.4753 -> P(class 1)=0.9224 -> 予測クラス: 1 (確信度: 92.24%)
#
# --- [バッチ 107] 推論中 ---
#   - ASD_20190917_29_3-3.mp4: Logit: -2.3967 -> P(class 1)=0.0834 -> 予測クラス: 0 (確信度: 91.66%)
#   - LCS_20210706_7_4-6.mp4: Logit: -0.1743 -> P(class 1)=0.4565 -> 予測クラス: 0 (確信度: 54.35%)
#   - ASD_20190917_62_3-4.mp4: Logit: 0.1728 -> P(class 1)=0.5431 -> 予測クラス: 1 (確信度: 54.31%)
#   - DHS_20200528_17_6-6.mp4: Logit: 0.3071 -> P(class 1)=0.5762 -> 予測クラス: 1 (確信度: 57.62%)
#
# --- [バッチ 108] 推論中 ---
#   - LCS_20211012_8_4-5.mp4: Logit: -2.4135 -> P(class 1)=0.0821 -> 予測クラス: 0 (確信度: 91.79%)
#   - ASD_20210323_1_2-4.mp4: Logit: -3.4807 -> P(class 1)=0.0299 -> 予測クラス: 0 (確信度: 97.01%)
#   - DHS_20200528_22_7-9.mp4: Logit: -5.1508 -> P(class 1)=0.0058 -> 予測クラス: 0 (確信度: 99.42%)
#   - ASD_20190819_9_4-4.mp4: Logit: -4.4669 -> P(class 1)=0.0114 -> 予測クラス: 0 (確信度: 98.86%)
#
# --- [バッチ 109] 推論中 ---
#   - ASD_20190917_25_2-2.mp4: Logit: -3.0245 -> P(class 1)=0.0463 -> 予測クラス: 0 (確信度: 95.37%)
#   - ASD_20200127_35_7-7.mp4: Logit: -0.9447 -> P(class 1)=0.2800 -> 予測クラス: 0 (確信度: 72.00%)
#   - ASD_20200127_16_3-4.mp4: Logit: -0.8176 -> P(class 1)=0.3063 -> 予測クラス: 0 (確信度: 69.37%)
#   - LCS_20211012_10_1-5.mp4: Logit: -2.1383 -> P(class 1)=0.1054 -> 予測クラス: 0 (確信度: 89.46%)
#
# --- [バッチ 110] 推論中 ---
#   - DHS_20200528_13_6-6.mp4: Logit: 0.4503 -> P(class 1)=0.6107 -> 予測クラス: 1 (確信度: 61.07%)
#   - LCS_20210706_8_6-7.mp4: Logit: -3.6487 -> P(class 1)=0.0254 -> 予測クラス: 0 (確信度: 97.46%)
#   - ASD_20200127_51_9-9.mp4: Logit: -1.6383 -> P(class 1)=0.1627 -> 予測クラス: 0 (確信度: 83.73%)
#   - DHS_20200528_19_5-8.mp4: Logit: -2.8197 -> P(class 1)=0.0563 -> 予測クラス: 0 (確信度: 94.37%)
#
# --- [バッチ 111] 推論中 ---
#   - HipOA_20180806_2_20_1-4.mp4: Logit: -4.0155 -> P(class 1)=0.0177 -> 予測クラス: 0 (確信度: 98.23%)
#   - ASD_20200127_28_4-4.mp4: Logit: -4.3348 -> P(class 1)=0.0129 -> 予測クラス: 0 (確信度: 98.71%)
#   - DHS_20160927_26_4-4.mp4: Logit: -3.3955 -> P(class 1)=0.0324 -> 予測クラス: 0 (確信度: 96.76%)
#   - ASD_20200127_44_9-10.mp4: Logit: -2.6082 -> P(class 1)=0.0686 -> 予測クラス: 0 (確信度: 93.14%)
#
# --- [バッチ 112] 推論中 ---
#   - DHS_20160927_8_2-3.mp4: Logit: -0.1013 -> P(class 1)=0.4747 -> 予測クラス: 0 (確信度: 52.53%)
#   - LCS_20210706_6_7-7.mp4: Logit: 0.0177 -> P(class 1)=0.5044 -> 予測クラス: 1 (確信度: 50.44%)
#   - ASD_20210323_4_5-7.mp4: Logit: 2.6983 -> P(class 1)=0.9369 -> 予測クラス: 1 (確信度: 93.69%)
#   - DHS_20200528_22_5-9.mp4: Logit: 0.9981 -> P(class 1)=0.7307 -> 予測クラス: 1 (確信度: 73.07%)
#
# --- [バッチ 113] 推論中 ---
#   - ASD_20200127_60_9-9.mp4: Logit: -2.3588 -> P(class 1)=0.0864 -> 予測クラス: 0 (確信度: 91.36%)
#   - ASD_20190917_66_2-4.mp4: Logit: -2.6862 -> P(class 1)=0.0638 -> 予測クラス: 0 (確信度: 93.62%)
#   - DHS_20160927_13_2-3.mp4: Logit: -2.0515 -> P(class 1)=0.1139 -> 予測クラス: 0 (確信度: 88.61%)
#   - ASD_20200127_55_5-8.mp4: Logit: -0.9458 -> P(class 1)=0.2797 -> 予測クラス: 0 (確信度: 72.03%)
#
# --- [バッチ 114] 推論中 ---
#   - LCS_20210706_4_4-4.mp4: Logit: -3.4670 -> P(class 1)=0.0303 -> 予測クラス: 0 (確信度: 96.97%)
#   - HipOA_20180806_2_2_5-5.mp4: Logit: -2.9027 -> P(class 1)=0.0520 -> 予測クラス: 0 (確信度: 94.80%)
#   - DHS_20160927_52_3-4.mp4: Logit: -2.7047 -> P(class 1)=0.0627 -> 予測クラス: 0 (確信度: 93.73%)
#   - ASD_20200127_49_2-6.mp4: Logit: -2.1562 -> P(class 1)=0.1038 -> 予測クラス: 0 (確信度: 89.62%)
#
# --- [バッチ 115] 推論中 ---
#   - ASD_20210803_3_5-10.mp4: Logit: -5.6523 -> P(class 1)=0.0035 -> 予測クラス: 0 (確信度: 99.65%)
#   - DHS_20160927_1_1-4.mp4: Logit: -4.2503 -> P(class 1)=0.0141 -> 予測クラス: 0 (確信度: 98.59%)
#   - DHS_20160927_25_3-4.mp4: Logit: -4.1838 -> P(class 1)=0.0150 -> 予測クラス: 0 (確信度: 98.50%)
#   - LCS_20210706_7_3-6.mp4: Logit: -5.8749 -> P(class 1)=0.0028 -> 予測クラス: 0 (確信度: 99.72%)
#
# --- [バッチ 116] 推論中 ---
#   - HipOA_20180806_2_48_2-3.mp4: Logit: -3.6852 -> P(class 1)=0.0245 -> 予測クラス: 0 (確信度: 97.55%)
#   - ASD_20200127_36_2-6.mp4: Logit: -4.5492 -> P(class 1)=0.0105 -> 予測クラス: 0 (確信度: 98.95%)
#   - ASD_20200127_42_8-8.mp4: Logit: -4.4413 -> P(class 1)=0.0116 -> 予測クラス: 0 (確信度: 98.84%)
#   - LCS_20211012_41_3-3.mp4: Logit: -3.5734 -> P(class 1)=0.0273 -> 予測クラス: 0 (確信度: 97.27%)
#
# --- [バッチ 117] 推論中 ---
#   - ASD_20200127_58_4-7.mp4: Logit: -1.5304 -> P(class 1)=0.1779 -> 予測クラス: 0 (確信度: 82.21%)
#   - ASD_20190917_52_2-3.mp4: Logit: -1.8957 -> P(class 1)=0.1306 -> 予測クラス: 0 (確信度: 86.94%)
#   - HipOA_20180806_2_2_2-5.mp4: Logit: -1.6019 -> P(class 1)=0.1677 -> 予測クラス: 0 (確信度: 83.23%)
#   - LCS_20211012_33_4-5.mp4: Logit: -1.7674 -> P(class 1)=0.1459 -> 予測クラス: 0 (確信度: 85.41%)
#
# --- [バッチ 118] 推論中 ---
#   - DHS_20200528_36_6-6.mp4: Logit: 2.9282 -> P(class 1)=0.9492 -> 予測クラス: 1 (確信度: 94.92%)
#   - ASD_20190917_22_1-4.mp4: Logit: 0.6380 -> P(class 1)=0.6543 -> 予測クラス: 1 (確信度: 65.43%)
#   - HipOA_20180806_2_4_3-4.mp4: Logit: 0.9316 -> P(class 1)=0.7174 -> 予測クラス: 1 (確信度: 71.74%)
#   - ASD_20200127_40_10-10.mp4: Logit: -0.0990 -> P(class 1)=0.4753 -> 予測クラス: 0 (確信度: 52.47%)
#
# --- [バッチ 119] 推論中 ---
#   - ASD_20200127_50_4-7.mp4: Logit: -1.5683 -> P(class 1)=0.1725 -> 予測クラス: 0 (確信度: 82.75%)
#   - DHS_20160927_6_3-3.mp4: Logit: -1.9812 -> P(class 1)=0.1212 -> 予測クラス: 0 (確信度: 87.88%)
#   - ASD_20190917_63_4-4.mp4: Logit: -0.4865 -> P(class 1)=0.3807 -> 予測クラス: 0 (確信度: 61.93%)
#   - HipOA_20180806_2_36_3-4.mp4: Logit: -1.8655 -> P(class 1)=0.1341 -> 予測クラス: 0 (確信度: 86.59%)
#
# --- [バッチ 120] 推論中 ---
#   - ASD_20200127_57_3-8.mp4: Logit: -2.9905 -> P(class 1)=0.0479 -> 予測クラス: 0 (確信度: 95.21%)
#   - LCS_20211012_32_2-5.mp4: Logit: -3.6365 -> P(class 1)=0.0257 -> 予測クラス: 0 (確信度: 97.43%)
#   - ASD_20200127_9_5-6.mp4: Logit: 0.5777 -> P(class 1)=0.6405 -> 予測クラス: 1 (確信度: 64.05%)
#   - ASD_20200127_5_10-10.mp4: Logit: -1.0174 -> P(class 1)=0.2655 -> 予測クラス: 0 (確信度: 73.45%)
#
# --- [バッチ 121] 推論中 ---
#   - ASD_20200127_15_1-10.mp4: Logit: -1.4852 -> P(class 1)=0.1846 -> 予測クラス: 0 (確信度: 81.54%)
#   - ASD_20200127_52_7-7.mp4: Logit: 0.1168 -> P(class 1)=0.5292 -> 予測クラス: 1 (確信度: 52.92%)
#   - ASD_20180625_1_3_4-4.mp4: Logit: -2.3527 -> P(class 1)=0.0869 -> 予測クラス: 0 (確信度: 91.31%)
#   - DHS_20160927_21_4-4.mp4: Logit: -0.3213 -> P(class 1)=0.4204 -> 予測クラス: 0 (確信度: 57.96%)
#
# --- [バッチ 122] 推論中 ---
#   - ASD_20210323_8_1-2.mp4: Logit: -2.9714 -> P(class 1)=0.0487 -> 予測クラス: 0 (確信度: 95.13%)
#   - LCS_20211012_24_3-3.mp4: Logit: -3.4855 -> P(class 1)=0.0297 -> 予測クラス: 0 (確信度: 97.03%)
#   - ASD_20200127_42_5-8.mp4: Logit: -3.4992 -> P(class 1)=0.0293 -> 予測クラス: 0 (確信度: 97.07%)
#   - ASD_20180625_1_2_4-4.mp4: Logit: -2.8665 -> P(class 1)=0.0538 -> 予測クラス: 0 (確信度: 94.62%)
#
# --- [バッチ 123] 推論中 ---
#   - LCS_20211012_5_3-5.mp4: Logit: -4.2000 -> P(class 1)=0.0148 -> 予測クラス: 0 (確信度: 98.52%)
#   - LCS_20210706_5_3-7.mp4: Logit: -2.9457 -> P(class 1)=0.0499 -> 予測クラス: 0 (確信度: 95.01%)
#   - HipOA_20180806_2_27_3-4.mp4: Logit: -3.9655 -> P(class 1)=0.0186 -> 予測クラス: 0 (確信度: 98.14%)
#   - DHS_20160927_41_3-3.mp4: Logit: -3.6521 -> P(class 1)=0.0253 -> 予測クラス: 0 (確信度: 97.47%)
#
# --- [バッチ 124] 推論中 ---
#   - HipOA_20180806_2_46_2-5.mp4: Logit: -4.8903 -> P(class 1)=0.0075 -> 予測クラス: 0 (確信度: 99.25%)
#   - ASD_20190917_34_4-4.mp4: Logit: -2.9519 -> P(class 1)=0.0496 -> 予測クラス: 0 (確信度: 95.04%)
#   - ASD_20200127_9_2-6.mp4: Logit: -4.6697 -> P(class 1)=0.0093 -> 予測クラス: 0 (確信度: 99.07%)
# ...
#   - ASD_20200127_63_2-6.mp4: Logit: 3.4836 -> P(class 1)=0.9702 -> 予測クラス: 1 (確信度: 97.02%)
#   - DHS_20160927_43_4-5.mp4: Logit: 3.7265 -> P(class 1)=0.9765 -> 予測クラス: 1 (確信度: 97.65%)
#
# --- [バッチ 414] 推論中 ---
#   - LCS_20211012_22_3-3.mp4: Logit: -2.4707 -> P(class 1)=0.0779 -> 予測クラス: 0 (確信度: 92.21%)
#   - DHS_20200528_13_3-6.mp4: Logit: -3.2668 -> P(class 1)=0.0367 -> 予測クラス: 0 (確信度: 96.33%)
#   - ASD_20190819_12_3-3.mp4: Logit: 0.4215 -> P(class 1)=0.6038 -> 予測クラス: 1 (確信度: 60.38%)
#   - ASD_20190917_57_1-3.mp4: Logit: -1.9782 -> P(class 1)=0.1215 -> 予測クラス: 0 (確信度: 87.85%)
#
# --- [バッチ 415] 推論中 ---
#   - ASD_20190917_61_1-3.mp4: Logit: 3.2580 -> P(class 1)=0.9630 -> 予測クラス: 1 (確信度: 96.30%)
#   - ASD_20190917_62_2-4.mp4: Logit: 1.2863 -> P(class 1)=0.7835 -> 予測クラス: 1 (確信度: 78.35%)
#   - LCS_20211012_2_1-5.mp4: Logit: 3.6531 -> P(class 1)=0.9747 -> 予測クラス: 1 (確信度: 97.47%)
#   - ASD_20190917_53_4-4.mp4: Logit: 0.9498 -> P(class 1)=0.7211 -> 予測クラス: 1 (確信度: 72.11%)
#
# --- [バッチ 416] 推論中 ---
#   - ASD_20190917_26_1-2.mp4: Logit: 3.7529 -> P(class 1)=0.9771 -> 予測クラス: 1 (確信度: 97.71%)
#   - ASD_20200127_50_5-7.mp4: Logit: -0.2432 -> P(class 1)=0.4395 -> 予測クラス: 0 (確信度: 56.05%)
#   - ASD_20200127_31_2-7.mp4: Logit: 1.4924 -> P(class 1)=0.8164 -> 予測クラス: 1 (確信度: 81.64%)
#   - ASD_20190917_10_2-4.mp4: Logit: 2.7701 -> P(class 1)=0.9410 -> 予測クラス: 1 (確信度: 94.10%)
#
# --- [バッチ 417] 推論中 ---
#   - DHS_20200528_43_4-5.mp4: Logit: 0.9684 -> P(class 1)=0.7248 -> 予測クラス: 1 (確信度: 72.48%)
#   - ASD_20200127_55_4-8.mp4: Logit: 1.6615 -> P(class 1)=0.8404 -> 予測クラス: 1 (確信度: 84.04%)
#   - ASD_20180625_1_1_4-4.mp4: Logit: 3.1809 -> P(class 1)=0.9601 -> 予測クラス: 1 (確信度: 96.01%)
#   - DHS_20200528_30_1-6.mp4: Logit: 1.4404 -> P(class 1)=0.8085 -> 予測クラス: 1 (確信度: 80.85%)
#
# --- [バッチ 418] 推論中 ---
#   - HipOA_20180806_2_32_3-4.mp4: Logit: -3.6206 -> P(class 1)=0.0261 -> 予測クラス: 0 (確信度: 97.39%)
#   - DHS_20200528_42_6-6.mp4: Logit: -3.4421 -> P(class 1)=0.0310 -> 予測クラス: 0 (確信度: 96.90%)
#   - LCS_20210706_1_2-5.mp4: Logit: -3.0480 -> P(class 1)=0.0453 -> 予測クラス: 0 (確信度: 95.47%)
#   - DHS_20200528_6_4-8.mp4: Logit: -3.9641 -> P(class 1)=0.0186 -> 予測クラス: 0 (確信度: 98.14%)
#
# --- [バッチ 419] 推論中 ---
#   - ASD_20200127_42_4-8.mp4: Logit: -3.8253 -> P(class 1)=0.0213 -> 予測クラス: 0 (確信度: 97.87%)
#   - ASD_20200127_35_3-7.mp4: Logit: -3.1579 -> P(class 1)=0.0408 -> 予測クラス: 0 (確信度: 95.92%)
#   - DHS_20200528_24_4-7.mp4: Logit: -2.4514 -> P(class 1)=0.0793 -> 予測クラス: 0 (確信度: 92.07%)
#   - ASD_20200127_8_6-8.mp4: Logit: -1.5206 -> P(class 1)=0.1794 -> 予測クラス: 0 (確信度: 82.06%)
#
# --- [バッチ 420] 推論中 ---
#   - ASD_20190917_12_2-4.mp4: Logit: 2.0054 -> P(class 1)=0.8814 -> 予測クラス: 1 (確信度: 88.14%)
#   - ASD_20200127_31_4-7.mp4: Logit: -0.1090 -> P(class 1)=0.4728 -> 予測クラス: 0 (確信度: 52.72%)
#   - DHS_20200528_41_3-8.mp4: Logit: -0.1385 -> P(class 1)=0.4654 -> 予測クラス: 0 (確信度: 53.46%)
#   - LCS_20211012_10_5-5.mp4: Logit: 0.9404 -> P(class 1)=0.7192 -> 予測クラス: 1 (確信度: 71.92%)
#
# --- [バッチ 421] 推論中 ---
#   - HipOA_20180806_2_30_1-3.mp4: Logit: -0.0475 -> P(class 1)=0.4881 -> 予測クラス: 0 (確信度: 51.19%)
#   - ASD_20190819_7_3-3.mp4: Logit: -0.8180 -> P(class 1)=0.3062 -> 予測クラス: 0 (確信度: 69.38%)
#   - ASD_20200127_57_7-8.mp4: Logit: -3.0732 -> P(class 1)=0.0442 -> 予測クラス: 0 (確信度: 95.58%)
#   - HipOA_20180806_2_23_5-6.mp4: Logit: -1.4287 -> P(class 1)=0.1933 -> 予測クラス: 0 (確信度: 80.67%)
#
# --- [バッチ 422] 推論中 ---
#   - ASD_20200127_18_6-6.mp4: Logit: -1.4217 -> P(class 1)=0.1944 -> 予測クラス: 0 (確信度: 80.56%)
#   - DHS_20200528_6_5-8.mp4: Logit: -0.9348 -> P(class 1)=0.2820 -> 予測クラス: 0 (確信度: 71.80%)
#   - LCS_20211012_30_1-5.mp4: Logit: -2.3569 -> P(class 1)=0.0865 -> 予測クラス: 0 (確信度: 91.35%)
#   - ASD_20210323_2_1-2.mp4: Logit: -2.2591 -> P(class 1)=0.0946 -> 予測クラス: 0 (確信度: 90.54%)
#
# --- [バッチ 423] 推論中 ---
#   - ASD_20200127_3_2-6.mp4: Logit: 0.5731 -> P(class 1)=0.6395 -> 予測クラス: 1 (確信度: 63.95%)
#   - ASD_20190917_18_1-4.mp4: Logit: -1.7916 -> P(class 1)=0.1429 -> 予測クラス: 0 (確信度: 85.71%)
#   - LCS_20211012_25_1-5.mp4: Logit: -0.2061 -> P(class 1)=0.4487 -> 予測クラス: 0 (確信度: 55.13%)
#   - DHS_20200528_22_8-9.mp4: Logit: -0.2317 -> P(class 1)=0.4423 -> 予測クラス: 0 (確信度: 55.77%)
#
# --- [バッチ 424] 推論中 ---
#   - ASD_20200127_44_3-10.mp4: Logit: -3.4431 -> P(class 1)=0.0310 -> 予測クラス: 0 (確信度: 96.90%)
#   - HipOA_20180806_2_28_3-6.mp4: Logit: -0.3923 -> P(class 1)=0.4032 -> 予測クラス: 0 (確信度: 59.68%)
#   - LCS_20211012_15_3-5.mp4: Logit: -0.6495 -> P(class 1)=0.3431 -> 予測クラス: 0 (確信度: 65.69%)
#   - HipOA_20180806_2_19_3-3.mp4: Logit: -2.2926 -> P(class 1)=0.0917 -> 予測クラス: 0 (確信度: 90.83%)
#
# --- [バッチ 425] 推論中 ---
#   - ASD_20200127_19_3-10.mp4: Logit: -0.4607 -> P(class 1)=0.3868 -> 予測クラス: 0 (確信度: 61.32%)
#   - LCS_20211012_31_4-4.mp4: Logit: -0.7829 -> P(class 1)=0.3137 -> 予測クラス: 0 (確信度: 68.63%)
#   - DHS_20160927_30_3-3.mp4: Logit: -2.2068 -> P(class 1)=0.0991 -> 予測クラス: 0 (確信度: 90.09%)
#   - ASD_20200127_22_1-4.mp4: Logit: -1.5987 -> P(class 1)=0.1682 -> 予測クラス: 0 (確信度: 83.18%)
#
# --- [バッチ 426] 推論中 ---
#   - DHS_20200528_17_4-6.mp4: Logit: -2.3068 -> P(class 1)=0.0906 -> 予測クラス: 0 (確信度: 90.94%)
#   - HipOA_20180806_2_25_1-6.mp4: Logit: -0.7554 -> P(class 1)=0.3196 -> 予測クラス: 0 (確信度: 68.04%)
#   - DHS_20200528_41_8-8.mp4: Logit: 0.1146 -> P(class 1)=0.5286 -> 予測クラス: 1 (確信度: 52.86%)
#   - HipOA_20180806_2_2_4-5.mp4: Logit: -2.4901 -> P(class 1)=0.0766 -> 予測クラス: 0 (確信度: 92.34%)
#
# --- [バッチ 427] 推論中 ---
#   - ASD_20180625_1_6_5-6.mp4: Logit: 2.1530 -> P(class 1)=0.8960 -> 予測クラス: 1 (確信度: 89.60%)
#   - ASD_20190917_28_2-3.mp4: Logit: -1.3395 -> P(class 1)=0.2076 -> 予測クラス: 0 (確信度: 79.24%)
#   - ASD_20200127_34_5-7.mp4: Logit: -1.0136 -> P(class 1)=0.2663 -> 予測クラス: 0 (確信度: 73.37%)
#   - ASD_20190917_21_1-4.mp4: Logit: -1.0724 -> P(class 1)=0.2549 -> 予測クラス: 0 (確信度: 74.51%)
#
# --- [バッチ 428] 推論中 ---
#   - ASD_20200127_56_3-10.mp4: Logit: -2.2122 -> P(class 1)=0.0987 -> 予測クラス: 0 (確信度: 90.13%)
#   - HipOA_20180806_2_2_3-5.mp4: Logit: -3.3777 -> P(class 1)=0.0330 -> 予測クラス: 0 (確信度: 96.70%)
#   - DHS_20200528_39_5-6.mp4: Logit: -3.0471 -> P(class 1)=0.0453 -> 予測クラス: 0 (確信度: 95.47%)
#   - ASD_20190819_14_4-4.mp4: Logit: -2.9009 -> P(class 1)=0.0521 -> 予測クラス: 0 (確信度: 94.79%)
#
# --- [バッチ 429] 推論中 ---
#   - DHS_20160927_37_3-4.mp4: Logit: 1.3586 -> P(class 1)=0.7955 -> 予測クラス: 1 (確信度: 79.55%)
#   - HipOA_20180806_2_39_4-4.mp4: Logit: 2.3839 -> P(class 1)=0.9156 -> 予測クラス: 1 (確信度: 91.56%)
#   - ASD_20180625_1_9_2-4.mp4: Logit: 1.1251 -> P(class 1)=0.7549 -> 予測クラス: 1 (確信度: 75.49%)
#   - DHS_20200528_7_2-8.mp4: Logit: 1.5914 -> P(class 1)=0.8308 -> 予測クラス: 1 (確信度: 83.08%)
#
# --- [バッチ 430] 推論中 ---
#   - ASD_20200127_58_7-7.mp4: Logit: 0.2550 -> P(class 1)=0.5634 -> 予測クラス: 1 (確信度: 56.34%)
#   - LCS_20211012_21_4-5.mp4: Logit: -0.2459 -> P(class 1)=0.4388 -> 予測クラス: 0 (確信度: 56.12%)
#   - ASD_20190917_64_2-4.mp4: Logit: 0.4930 -> P(class 1)=0.6208 -> 予測クラス: 1 (確信度: 62.08%)
#   - DHS_20200528_24_3-7.mp4: Logit: -2.5286 -> P(class 1)=0.0739 -> 予測クラス: 0 (確信度: 92.61%)
#
# --- [バッチ 431] 推論中 ---
#   - DHS_20200528_12_3-6.mp4: Logit: -1.5997 -> P(class 1)=0.1680 -> 予測クラス: 0 (確信度: 83.20%)
#   - LCS_20211012_18_2-5.mp4: Logit: -1.6004 -> P(class 1)=0.1679 -> 予測クラス: 0 (確信度: 83.21%)
#   - LCS_20211012_39_2-4.mp4: Logit: -2.5308 -> P(class 1)=0.0737 -> 予測クラス: 0 (確信度: 92.63%)
#   - ASD_20200127_51_4-9.mp4: Logit: -2.7135 -> P(class 1)=0.0622 -> 予測クラス: 0 (確信度: 93.78%)
#
# --- [バッチ 432] 推論中 ---
#   - ASD_20190917_6_3-3.mp4: Logit: -0.4227 -> P(class 1)=0.3959 -> 予測クラス: 0 (確信度: 60.41%)
#   - LCS_20210706_7_6-6.mp4: Logit: 1.2825 -> P(class 1)=0.7829 -> 予測クラス: 1 (確信度: 78.29%)
#   - DHS_20160927_16_3-3.mp4: Logit: -1.4416 -> P(class 1)=0.1913 -> 予測クラス: 0 (確信度: 80.87%)
#   - ASD_20210803_1_7-7.mp4: Logit: -1.3552 -> P(class 1)=0.2050 -> 予測クラス: 0 (確信度: 79.50%)
#
# --- [バッチ 433] 推論中 ---
#   - ASD_20190917_64_1-4.mp4: Logit: 0.8151 -> P(class 1)=0.6932 -> 予測クラス: 1 (確信度: 69.32%)
#   - ASD_20200127_37_3-11.mp4: Logit: -0.1156 -> P(class 1)=0.4711 -> 予測クラス: 0 (確信度: 52.89%)
#   - ASD_20200127_4_2-3.mp4: Logit: 0.1403 -> P(class 1)=0.5350 -> 予測クラス: 1 (確信度: 53.50%)
#   - HipOA_20180806_2_45_5-6.mp4: Logit: -1.7380 -> P(class 1)=0.1496 -> 予測クラス: 0 (確信度: 85.04%)
#
# --- [バッチ 434] 推論中 ---
#   - ASD_20190917_78_3-5.mp4: Logit: 2.3665 -> P(class 1)=0.9142 -> 予測クラス: 1 (確信度: 91.42%)
#   - DHS_20200528_31_5-9.mp4: Logit: 1.7368 -> P(class 1)=0.8503 -> 予測クラス: 1 (確信度: 85.03%)
#   - ASD_20200127_45_1-7.mp4: Logit: 0.3113 -> P(class 1)=0.5772 -> 予測クラス: 1 (確信度: 57.72%)
#   - DHS_20160927_2_3-3.mp4: Logit: 4.5537 -> P(class 1)=0.9896 -> 予測クラス: 1 (確信度: 98.96%)
#
# --- [バッチ 435] 推論中 ---
#   - DHS_20200528_34_1-7.mp4: Logit: 3.8728 -> P(class 1)=0.9796 -> 予測クラス: 1 (確信度: 97.96%)
#   - HipOA_20180806_2_44_5-6.mp4: Logit: 5.4298 -> P(class 1)=0.9956 -> 予測クラス: 1 (確信度: 99.56%)
#   - ASD_20200127_36_3-6.mp4: Logit: 5.1321 -> P(class 1)=0.9941 -> 予測クラス: 1 (確信度: 99.41%)
#   - DHS_20200528_1_7-9.mp4: Logit: 4.3231 -> P(class 1)=0.9869 -> 予測クラス: 1 (確信度: 98.69%)
#
# --- [バッチ 436] 推論中 ---
#   - ASD_20200127_41_1-2.mp4: Logit: -0.0447 -> P(class 1)=0.4888 -> 予測クラス: 0 (確信度: 51.12%)
#   - DHS_20200528_19_2-8.mp4: Logit: -2.0032 -> P(class 1)=0.1189 -> 予測クラス: 0 (確信度: 88.11%)
#   - HipOA_20180806_2_14_2-4.mp4: Logit: 0.0070 -> P(class 1)=0.5017 -> 予測クラス: 1 (確信度: 50.17%)
#   - LCS_20211012_42_1-5.mp4: Logit: -0.3445 -> P(class 1)=0.4147 -> 予測クラス: 0 (確信度: 58.53%)
#
# --- [バッチ 437] 推論中 ---
#   - ASD_20200127_20_4-6.mp4: Logit: -1.3951 -> P(class 1)=0.1986 -> 予測クラス: 0 (確信度: 80.14%)
#   - ASD_20190917_10_1-4.mp4: Logit: -1.1569 -> P(class 1)=0.2392 -> 予測クラス: 0 (確信度: 76.08%)
#   - DHS_20200528_4_6-8.mp4: Logit: -1.3825 -> P(class 1)=0.2006 -> 予測クラス: 0 (確信度: 79.94%)
#   - DHS_20160927_37_1-4.mp4: Logit: -1.6377 -> P(class 1)=0.1628 -> 予測クラス: 0 (確信度: 83.72%)
#
# --- [バッチ 438] 推論中 ---
#   - DHS_20160927_34_1-4.mp4: Logit: 1.1194 -> P(class 1)=0.7539 -> 予測クラス: 1 (確信度: 75.39%)
#   - LCS_20210706_8_2-7.mp4: Logit: 1.7990 -> P(class 1)=0.8580 -> 予測クラス: 1 (確信度: 85.80%)
#   - ASD_20190917_57_3-3.mp4: Logit: 3.1683 -> P(class 1)=0.9596 -> 予測クラス: 1 (確信度: 95.96%)
#   - HipOA_20180806_2_26_4-6.mp4: Logit: 1.4055 -> P(class 1)=0.8031 -> 予測クラス: 1 (確信度: 80.31%)
#
# --- [バッチ 439] 推論中 ---
#   - ASD_20190917_6_2-3.mp4: Logit: 2.3230 -> P(class 1)=0.9108 -> 予測クラス: 1 (確信度: 91.08%)
#   - ASD_20190917_43_2-3.mp4: Logit: -0.5878 -> P(class 1)=0.3571 -> 予測クラス: 0 (確信度: 64.29%)
#   - ASD_20190917_7_3-3.mp4: Logit: 1.8929 -> P(class 1)=0.8691 -> 予測クラス: 1 (確信度: 86.91%)
#   - ASD_20190819_1_2-4.mp4: Logit: 0.6217 -> P(class 1)=0.6506 -> 予測クラス: 1 (確信度: 65.06%)
#
# --- [バッチ 440] 推論中 ---
#   - DHS_20200528_1_3-9.mp4: Logit: 3.0168 -> P(class 1)=0.9533 -> 予測クラス: 1 (確信度: 95.33%)
#   - ASD_20200127_26_2-4.mp4: Logit: 2.4097 -> P(class 1)=0.9176 -> 予測クラス: 1 (確信度: 91.76%)
#   - LCS_20211012_10_3-5.mp4: Logit: 4.7414 -> P(class 1)=0.9913 -> 予測クラス: 1 (確信度: 99.13%)
#   - DHS_20200528_18_3-8.mp4: Logit: 4.7538 -> P(class 1)=0.9915 -> 予測クラス: 1 (確信度: 99.15%)
#
# --- [バッチ 441] 推論中 ---
#   - ASD_20200127_43_2-7.mp4: Logit: -2.5821 -> P(class 1)=0.0703 -> 予測クラス: 0 (確信度: 92.97%)
#   - DHS_20160927_29_3-3.mp4: Logit: 0.6804 -> P(class 1)=0.6638 -> 予測クラス: 1 (確信度: 66.38%)
#   - ASD_20190819_13_1-4.mp4: Logit: -0.2138 -> P(class 1)=0.4467 -> 予測クラス: 0 (確信度: 55.33%)
#   - HipOA_20180806_2_15_4-4.mp4: Logit: 2.6062 -> P(class 1)=0.9313 -> 予測クラス: 1 (確信度: 93.13%)
#
# --- [バッチ 442] 推論中 ---
#   - ASD_20200127_33_5-7.mp4: Logit: -0.5796 -> P(class 1)=0.3590 -> 予測クラス: 0 (確信度: 64.10%)
#   - ASD_20200127_32_4-6.mp4: Logit: 0.2656 -> P(class 1)=0.5660 -> 予測クラス: 1 (確信度: 56.60%)
#   - ASD_20190917_68_3-4.mp4: Logit: -0.9459 -> P(class 1)=0.2797 -> 予測クラス: 0 (確信度: 72.03%)
#   - LCS_20211012_36_4-4.mp4: Logit: -1.7821 -> P(class 1)=0.1440 -> 予測クラス: 0 (確信度: 85.60%)
#
# --- [バッチ 443] 推論中 ---
#   - ASD_20200127_50_7-7.mp4: Logit: -0.1123 -> P(class 1)=0.4720 -> 予測クラス: 0 (確信度: 52.80%)
#   - HipOA_20180806_2_44_6-6.mp4: Logit: -0.2002 -> P(class 1)=0.4501 -> 予測クラス: 0 (確信度: 54.99%)
#   - DHS_20200528_12_4-6.mp4: Logit: 0.8465 -> P(class 1)=0.6998 -> 予測クラス: 1 (確信度: 69.98%)
#   - DHS_20200528_33_7-8.mp4: Logit: -2.4664 -> P(class 1)=0.0782 -> 予測クラス: 0 (確信度: 92.18%)
#
# --- [バッチ 444] 推論中 ---
#   - ASD_20200127_17_3-7.mp4: Logit: -1.9130 -> P(class 1)=0.1286 -> 予測クラス: 0 (確信度: 87.14%)
#   - ASD_20200127_19_1-10.mp4: Logit: -0.3862 -> P(class 1)=0.4046 -> 予測クラス: 0 (確信度: 59.54%)
#   - HipOA_20180806_2_43_3-5.mp4: Logit: -0.1566 -> P(class 1)=0.4609 -> 予測クラス: 0 (確信度: 53.91%)
#   - ASD_20190917_44_2-4.mp4: Logit: -2.0171 -> P(class 1)=0.1174 -> 予測クラス: 0 (確信度: 88.26%)
#
# --- [バッチ 445] 推論中 ---
#   - HipOA_20180806_2_30_3-3.mp4: Logit: -1.9099 -> P(class 1)=0.1290 -> 予測クラス: 0 (確信度: 87.10%)
#   - HipOA_20180806_2_25_3-6.mp4: Logit: -6.7676 -> P(class 1)=0.0011 -> 予測クラス: 0 (確信度: 99.89%)
#   - ASD_20190819_13_4-4.mp4: Logit: -5.1292 -> P(class 1)=0.0059 -> 予測クラス: 0 (確信度: 99.41%)
#   - ASD_20210323_3_1-1.mp4: Logit: -4.3561 -> P(class 1)=0.0127 -> 予測クラス: 0 (確信度: 98.73%)
#
# --- [バッチ 446] 推論中 ---
#   - ASD_20200127_39_5-7.mp4: Logit: -1.7955 -> P(class 1)=0.1424 -> 予測クラス: 0 (確信度: 85.76%)
#   - DHS_20200528_23_4-5.mp4: Logit: -0.0856 -> P(class 1)=0.4786 -> 予測クラス: 0 (確信度: 52.14%)
#   - ASD_20200127_58_6-7.mp4: Logit: -0.7565 -> P(class 1)=0.3194 -> 予測クラス: 0 (確信度: 68.06%)
#   - ASD_20190917_45_2-3.mp4: Logit: 1.3004 -> P(class 1)=0.7859 -> 予測クラス: 1 (確信度: 78.59%)
#
# --- [バッチ 447] 推論中 ---
#   - ASD_20210803_3_8-10.mp4: Logit: -4.9602 -> P(class 1)=0.0070 -> 予測クラス: 0 (確信度: 99.30%)
#   - DHS_20160927_1_3-4.mp4: Logit: -4.6524 -> P(class 1)=0.0094 -> 予測クラス: 0 (確信度: 99.06%)
#   - LCS_20211012_15_4-5.mp4: Logit: -5.1083 -> P(class 1)=0.0060 -> 予測クラス: 0 (確信度: 99.40%)
#   - DHS_20160927_51_1-3.mp4: Logit: -5.1182 -> P(class 1)=0.0060 -> 予測クラス: 0 (確信度: 99.40%)
#
# --- [バッチ 448] 推論中 ---
#   - DHS_20160927_43_3-5.mp4: Logit: 2.1755 -> P(class 1)=0.8980 -> 予測クラス: 1 (確信度: 89.80%)
#   - ASD_20200127_66_6-6.mp4: Logit: 3.1073 -> P(class 1)=0.9572 -> 予測クラス: 1 (確信度: 95.72%)
#   - ASD_20190917_64_4-4.mp4: Logit: 2.1367 -> P(class 1)=0.8944 -> 予測クラス: 1 (確信度: 89.44%)
#   - ASD_20190917_68_4-4.mp4: Logit: 3.3612 -> P(class 1)=0.9665 -> 予測クラス: 1 (確信度: 96.65%)
#
# --- [バッチ 449] 推論中 ---
#   - LCS_20211012_8_2-5.mp4: Logit: -4.2124 -> P(class 1)=0.0146 -> 予測クラス: 0 (確信度: 98.54%)
#   - LCS_20211012_27_4-5.mp4: Logit: -3.4806 -> P(class 1)=0.0299 -> 予測クラス: 0 (確信度: 97.01%)
#   - DHS_20200528_6_7-8.mp4: Logit: -2.2932 -> P(class 1)=0.0917 -> 予測クラス: 0 (確信度: 90.83%)
#   - ASD_20200127_7_4-8.mp4: Logit: -3.1540 -> P(class 1)=0.0409 -> 予測クラス: 0 (確信度: 95.91%)
#
# --- [バッチ 450] 推論中 ---
#   - ASD_20190819_6_3-4.mp4: Logit: -0.2376 -> P(class 1)=0.4409 -> 予測クラス: 0 (確信度: 55.91%)
#   - DHS_20160927_19_3-3.mp4: Logit: 0.8828 -> P(class 1)=0.7074 -> 予測クラス: 1 (確信度: 70.74%)
#   - ASD_20190917_62_1-4.mp4: Logit: 1.5243 -> P(class 1)=0.8212 -> 予測クラス: 1 (確信度: 82.12%)
#   - HipOA_20180806_2_46_3-5.mp4: Logit: 0.6940 -> P(class 1)=0.6669 -> 予測クラス: 1 (確信度: 66.69%)
#
# --- [バッチ 451] 推論中 ---
#   - ASD_20200127_9_4-6.mp4: Logit: -4.6018 -> P(class 1)=0.0099 -> 予測クラス: 0 (確信度: 99.01%)
#   - HipOA_20180806_2_49_1-3.mp4: Logit: -2.2742 -> P(class 1)=0.0933 -> 予測クラス: 0 (確信度: 90.67%)
#   - ASD_20200127_64_6-7.mp4: Logit: -1.7001 -> P(class 1)=0.1545 -> 予測クラス: 0 (確信度: 84.55%)
#   - DHS_20200528_42_5-6.mp4: Logit: -2.7226 -> P(class 1)=0.0617 -> 予測クラス: 0 (確信度: 93.83%)
#
# --- [バッチ 452] 推論中 ---
#   - ASD_20190917_35_3-5.mp4: Logit: -1.0990 -> P(class 1)=0.2499 -> 予測クラス: 0 (確信度: 75.01%)
#
#
# ==================== 全ての推論結果 ====================
#                    Video Filename  prediction confidence prob_for_class_1
# 0         ASD_20200127_50_1-7.mp4           0     0.6012           0.3988
# 1         ASD_20190917_34_1-4.mp4           0     0.7482           0.2518
# 2     HipOA_20180806_2_33_1-5.mp4           0     0.8149           0.1851
# 3         ASD_20190819_15_2-3.mp4           0     0.9204           0.0796
# 4         LCS_20211012_34_2-3.mp4           0     0.9455           0.0545
# ...                           ...         ...        ...              ...
# 1800       ASD_20200127_9_4-6.mp4           0     0.9901           0.0099
# 1801  HipOA_20180806_2_49_1-3.mp4           0     0.9067           0.0933
# 1802      ASD_20200127_64_6-7.mp4           0     0.8455           0.1545
# 1803      DHS_20200528_42_5-6.mp4           0     0.9383           0.0617
# 1804      ASD_20190917_35_3-5.mp4           0     0.7501           0.2499
#
# [1805 rows x 4 columns]

# %%
import json

# --- 1. 保存先のディレクトリとファイル名を定義 ---
# あなたが指定したパスをここに設定します
output_directory = '/workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat'
output_directory = os.path.join(output_directory, TARGET_FOLD)
output_filename = 'inference_results.json'
output_filepath = os.path.join(output_directory, output_filename)

print(f"結果を次のパスに保存します: {output_filepath}")

try:
    # results辞書が空でないことを確認
    if not results:
        print("結果が空のため、JSONファイルは作成されませんでした。")
    else:
        # --- 2. 保存先ディレクトリが存在しない場合に、自動で作成 ---
        # exist_ok=True を指定すると、ディレクトリが既に存在していてもエラーになりません
        os.makedirs(output_directory, exist_ok=True)
        print(f"ディレクトリ '{output_directory}' を確認・作成しました。")

        # --- 3. ファイルを書き込む ---
        with open(output_filepath, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=4)
        
        print(f"\n✅ 推論結果が '{output_filepath}' に正常に保存されました。")

except NameError:
    print("エラー: `results` 辞書が見つかりません。先に推論処理のセルを実行してください。")
except Exception as e:
    print(f"ファイルの保存中に予期せぬエラーが発生しました: {e}")
# Out:
# 結果を次のパスに保存します: /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold3/inference_results.json
# ディレクトリ '/workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold3' を確認・作成しました。
#
# ✅ 推論結果が '/workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold3/inference_results.json' に正常に保存されました。

# %% [markdown]
# # 描画フェーズ

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob # ファイル検索のためのライブラリ

# ==============================================================================
# ## 1. 複数foldのJSONファイルを読み込み、単一のデータフレームに統合
# ==============================================================================
print("ステップ1: 複数foldのJSONファイルを読み込んで統合します...")

# JSONファイルが格納されている親ディレクトリを指定
JSON_ROOT_DIRECTORY = '/workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat'

# 指定したディレクトリ以下の全ての inference_results.json を探す
json_file_paths = glob.glob(os.path.join(JSON_ROOT_DIRECTORY, 'fold*', 'inference_results.json'))

if not json_file_paths:
    print(f"エラー: '{JSON_ROOT_DIRECTORY}' 内に 'foldX/inference_results.json' のパターンに一致するファイルが見つかりませんでした。")
    raise SystemExit()

print(f"{len(json_file_paths)} 個のJSONファイルが見つかりました:")
for path in json_file_paths:
    print(f"  - {path}")

# 各JSONファイルをDataFrameとして読み込み、一つのリストにまとめる
all_dfs = []
for file_path in json_file_paths:
    fold_name = os.path.basename(os.path.dirname(file_path))
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    df_fold = pd.DataFrame.from_dict(data, orient='index')
    df_fold = df_fold.reset_index().rename(columns={'index': 'filename'})
    df_fold['fold'] = fold_name 
    all_dfs.append(df_fold)

# 全てのfoldのDataFrameを縦に結合
df_all = pd.concat(all_dfs, ignore_index=True)
df_all['prediction'] = df_all['prediction'].astype(int)
df_all['confidence'] = df_all['confidence'].astype(float)
print("\n✅ 全てのJSONデータを統合しました。")


# ==============================================================================
# ## 2. 統合データフレームの処理
# ==============================================================================
print("\nステップ2: データフレームを処理し、分析用の列を追加します...")

def extract_position(filename):
    try:
        base_name = os.path.splitext(filename)[0]
        position_str = base_name.split('_')[-1]
        if '-' in position_str and all(part.isdigit() for part in position_str.split('-')):
            return position_str
        return None
    except:
        return None

def get_ground_truth(filename):
    # ASD -> 0, ASD_not -> 1
    if filename.startswith('ASD'):
        return 0
    else:
        return 1

df_all['position'] = df_all['filename'].apply(extract_position)
df_all['ground_truth'] = df_all['filename'].apply(get_ground_truth)
df_all.dropna(subset=['position'], inplace=True)
df_all['is_correct'] = (df_all['prediction'] == df_all['ground_truth']).astype(int)
print("✅ 位置情報、正解ラベル、正誤判定の列を追加しました。")


# ==============================================================================
# ## 3.【詳細分析】位置ごとの集計
# ==============================================================================
print("\nステップ3: 詳細な位置ごとの集計を行います...")
position_analysis = df_all.groupby('position').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
position_analysis['accuracy_rate'] = position_analysis['correct_count'] / position_analysis['total_count']
position_analysis['mistake_count'] = position_analysis['total_count'] - position_analysis['correct_count']

def position_to_midpoint(position_str):
    try:
        numerator, denominator = map(int, position_str.split('-'))
        return (2 * numerator - 1) / (2 * denominator)
    except (ValueError, ZeroDivisionError):
        return float('inf')

position_analysis['sort_value'] = position_analysis['position'].apply(position_to_midpoint)
position_analysis = position_analysis.sort_values(by='sort_value').reset_index(drop=True)
print("✅ 詳細分析の集計が完了しました。")


# ==============================================================================
# ## 4.【詳細分析】結果の可視化
# ==============================================================================
print("\nステップ4: 詳細分析の結果を可視化します...")

# --- グラフA: 絶対数（積み上げ棒グラフ） ---
plot_data_detail = position_analysis.set_index('position')[['correct_count', 'mistake_count']]
plot_data_detail.plot(kind='bar', stacked=True, figsize=(14, 7), color=['#2ca02c', '#d62728'])
plt.title('Number of Correct/Incorrect Predictions by Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Number of Videos', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(['Correct', 'Incorrect'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_0.png'))
plt.show()


# --- グラフB: 正解率 ---
plt.figure(figsize=(14, 7))
ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
for p in ax_detail.patches:
    ax_detail.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Model Accuracy Rate by Course Position', fontsize=16)
plt.xlabel('Course Position (Segment-Total)', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_1.png'))
plt.show()


# ==============================================================================
# ## 5.【概要分析】コースを4等分した区間ごとの集計
# ==============================================================================
print("\nステップ5: コースを4分割した概要分析の集計を行います...")

def get_quadrant(midpoint_value):
    if 0 <= midpoint_value < 0.25: return "1st Quadrant (0-25%)"
    elif 0.25 <= midpoint_value < 0.5: return "2nd Quadrant (25-50%)"
    elif 0.5 <= midpoint_value < 0.75: return "3rd Quadrant (50-75%)"
    elif 0.75 <= midpoint_value <= 1.0: return "4th Quadrant (75-100%)"
    else: return "N/A"

df_all['sort_value'] = df_all['position'].apply(position_to_midpoint)
df_all['quadrant'] = df_all['sort_value'].apply(get_quadrant)

quadrant_analysis = df_all.groupby('quadrant').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()
quadrant_analysis['accuracy_rate'] = quadrant_analysis['correct_count'] / quadrant_analysis['total_count']
print("✅ 概要分析の集計が完了しました。")


# ==============================================================================
# ## 6.【概要分析】結果の可視化
# ==============================================================================
print("\nステップ6: 概要分析の結果を可視化します...")

# --- display()で集計結果のテーブルを表示 ---
print("\n--- Accuracy Analysis by Course Quadrant ---")
display(quadrant_analysis)

# --- グラフA: 絶対数 ---
plt.figure(figsize=(10, 6))
ax_abs_q = sns.barplot(x='quadrant', y='correct_count', data=quadrant_analysis, color='steelblue', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_abs_q.patches:
    ax_abs_q.annotate(f"{p.get_height():.0f}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Number of Correct Predictions per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_2.png'))
plt.show()

# --- グラフB: 正解率 ---
plt.figure(figsize=(10, 6))
ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])
for p in ax_rate_q.patches:
    ax_rate_q.annotate(f"{p.get_height():.2%}", (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 9), textcoords='offset points')
plt.title('Accuracy Rate per Course Quadrant', fontsize=16)
plt.xlabel('Course Quadrant', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_3.png'))
plt.show()
# Out:
# ステップ1: 複数foldのJSONファイルを読み込んで統合します...
# 5 個のJSONファイルが見つかりました:
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold3/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold2/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold0/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold1/inference_results.json
#   - /workspace/data/analysis_logs/ex_20250116_organaized_split/single_lat/fold4/inference_results.json
#
# ✅ 全てのJSONデータを統合しました。
#
# ステップ2: データフレームを処理し、分析用の列を追加します...
# ✅ 位置情報、正解ラベル、正誤判定の列を追加しました。
#
# ステップ3: 詳細な位置ごとの集計を行います...
# ✅ 詳細分析の集計が完了しました。
#
# ステップ4: 詳細分析の結果を可視化します...
# /tmp/ipykernel_528503/2255228165.py:118: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_detail = sns.barplot(x='position', y='accuracy_rate', data=position_analysis, palette='coolwarm')
# ステップ5: コースを4分割した概要分析の集計を行います...
# ✅ 概要分析の集計が完了しました。
#
# ステップ6: 概要分析の結果を可視化します...
#
# --- Accuracy Analysis by Course Quadrant ---
#                  quadrant  correct_count  total_count  accuracy_rate
# 0    1st Quadrant (0-25%)           1332         2358       0.564885
# 1   2nd Quadrant (25-50%)           1348         2404       0.560732
# 2   3rd Quadrant (50-75%)           1615         2873       0.562130
# 3  4th Quadrant (75-100%)           1634         2909       0.561705
# /tmp/ipykernel_528503/2255228165.py:179: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_q = sns.barplot(x='quadrant', y='accuracy_rate', data=quadrant_analysis, palette='magma', order=["1st Quadrant (0-25%)", "2nd Quadrant (25-50%)", "3rd Quadrant (50-75%)", "4th Quadrant (75-100%)"])

# %%
# ==============================================================================
# ## 7.【症例別分析＋総合】症例ごとの正解率の集計と可視化
# ==============================================================================
print("ステップ7: 症例別の分析（総合結果付き）を開始します...")

# --- 1. ファイル名から「症例タイプ」を抽出 ---
def extract_case_type(filename):
    try:
        return filename.split('_')[0]
    except:
        return None

# 'case_type' 列を新しく作成
df_all['case_type'] = df_all['filename'].apply(extract_case_type)
print("  - 症例タイプ列を追加しました。")


# --- 2. 症例タイプごとに正解率と絶対数を集計 ---
# 'case_type' 列でグループ化し、正解数と全体の数を計算
case_analysis = df_all.groupby('case_type').agg(
    correct_count=('is_correct', 'sum'),
    total_count=('filename', 'count')
).reset_index()

# 正解率を計算
case_analysis['accuracy_rate'] = case_analysis['correct_count'] / case_analysis['total_count']
print("  - 症例タイプごとの集計が完了しました。")


# --- 3. 「総合(Total)」の行を計算して追加 ---
# 全体の合計を計算
total_correct = case_analysis['correct_count'].sum()
total_total = case_analysis['total_count'].sum()
total_accuracy = total_correct / total_total if total_total > 0 else 0

# 'Total'の行を新しいDataFrameとして作成
total_df = pd.DataFrame([{
    'case_type': 'Total',
    'correct_count': total_correct,
    'total_count': total_total,
    'accuracy_rate': total_accuracy
}])

# 元のDataFrameと結合して、'Total'行を含む新しいDataFrameを作成
case_analysis_with_total = pd.concat([total_df, case_analysis], ignore_index=True)

# グラフの表示順を定義 ('Total'を先頭に、残りはアルファベット順)
plot_order = ['Total'] + sorted(case_analysis['case_type'].unique())
print("  - 総合結果の追加と表示順の定義が完了しました。")


# --- 4. 可視化 (2パターン、総合結果付き) ---

# display()で集計結果のテーブルを表示
print("\n--- Accuracy Analysis by Case Type (with Total) ---")
display(case_analysis_with_total)


# ### パターンA: 正解の「絶対数」を可視化 ###
plt.figure(figsize=(10, 6))
ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
for p in ax_abs_case.patches:
    ax_abs_case.annotate(f"{p.get_height():.0f}", 
                         (p.get_x() + p.get_width() / 2., p.get_height()), 
                         ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Number of Correct Predictions per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Number of Correct Predictions', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_4.png'))
plt.show()


# ### パターンB: 「正解率」を可視化 ###
plt.figure(figsize=(10, 6))
ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')
for p in ax_rate_case.patches:
    ax_rate_case.annotate(f"{p.get_height():.2%}", 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha = 'center', va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.title('Accuracy Rate per Case Type (with Total)', fontsize=16)
plt.xlabel('Case Type', fontsize=12)
plt.ylabel('Accuracy Rate', fontsize=12)
plt.ylim(0, 1.05)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.savefig(os.path.join(JSON_ROOT_DIRECTORY, 'output_5.png'))
plt.show()
# Out:
# ステップ7: 症例別の分析（総合結果付き）を開始します...
#   - 症例タイプ列を追加しました。
#   - 症例タイプごとの集計が完了しました。
#   - 総合結果の追加と表示順の定義が完了しました。
#
# --- Accuracy Analysis by Case Type (with Total) ---
#   case_type  correct_count  total_count  accuracy_rate
# 0     Total           5040         8739       0.576725
# 1       ASD           3395         4436       0.765329
# 2       DHS            929         2332       0.398370
# 3     HipOA            129          604       0.213576
# 4       LCS            587         1367       0.429407
# /tmp/ipykernel_528503/4160753937.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_abs_case = sns.barplot(x='case_type', y='correct_count', data=case_analysis_with_total, order=plot_order, palette='viridis')
# /tmp/ipykernel_528503/4160753937.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax_rate_case = sns.barplot(x='case_type', y='accuracy_rate', data=case_analysis_with_total, order=plot_order, palette='plasma')
