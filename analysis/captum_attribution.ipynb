# %%
import sys
import os 
print(os.getcwd())
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
current_dir = os.getcwd() 
print(f"カレントディレクトリ: {current_dir}")
project_root_path = os.path.dirname(current_dir)
print(f"プロジェクトルート: {project_root_path}")
if project_root_path not in sys.path:
    sys.path.append(project_root_path)
    
import torch
print(torch.cuda.is_available())
# Out:
# /workspace/project/analysis
# カレントディレクトリ: /workspace/project/analysis
# プロジェクトルート: /workspace/project
# True

# %%
from project.models.make_model import single, early_fusion, slow_fusion, late_fusion
from project.dataloader.data_loader import WalkDataModule
from project.dataloader.data_loader_multi import MultiData
import yaml

from pytorch_lightning import Trainer

from IPython.display import clear_output

clear_output()

import torchmetrics
import torchmetrics

# %%
from pytorch_lightning import seed_everything

seed_everything(42, workers=True)
# Out:
# Seed set to 42
# 42

# %%
model_root = '/workspace/logs/resnet/single/2025-10-06/04-29-41'
model_path = '/workspace/logs/resnet/single/2025-10-06/04-29-41/fold3/version_0/checkpoints/15-2.37-0.5889.ckpt'
config_path = os.path.join(model_root, '.hydra/config.yaml')
AP_DATA_ROOT ='/workspace/data/out_dir_ver2_classified_side'
LAT_DATA_ROOT ='/workspace/data/out_dir_ver2_classified_side'
TARGET_FOLD = 'fold3'
INFERENCE_BATCH_SIZE = 4
SAVE_CAM_VALUES = True          
CAM_OUTPUT_DIR = "/workspace/data/analysis_logs/fails_points/20251023/single_side/CAM"

# %%
def load_config(config_path):
    """YAMLファイルを読み込む関数"""
    try:
        with open(config_path, 'r') as f:
            config = yaml.safe_load(f)
        print(f"設定ファイル '{config_path}' を正常に読み込みました。")
        return config
    except FileNotFoundError:
        print(f"❌ エラー: 設定ファイル '{config_path}' が見つかりません。")
        sys.exit()

class HParams:
    """config.yamlの階層構造を模倣するクラス"""
    def __init__(self, data_config, model_config, train_config):
        self.data = type('DataConfig', (object,), data_config)()
        self.model = type('ModelConfig', (object,), model_config)()
        self.train = type('TrainConfig', (object,), train_config)()
config_data = load_config(config_path)
try:
    hparams = HParams(
        config_data['data'], 
        config_data['model'], 
        config_data['train']
    )
    print("✅ HParamsオブジェクトを正常に作成しました。")
except KeyError as e:
    print(f"❌ エラー: config.yaml に必要なキー {e} が見つかりません。")
    sys.exit()
# Out:
# 設定ファイル '/workspace/logs/resnet/single/2025-10-06/04-29-41/.hydra/config.yaml' を正常に読み込みました。
# ✅ HParamsオブジェクトを正常に作成しました。

# %%
# ==============================================================================
# ## 3. モデルの準備：インスタンス化と学習済み重みのロード
# ==============================================================================
print("\nステップ3: モデルを準備します...")

# --- 設定値の取得 ---
fusion_type = hparams.train.experiment
device_ids = 0

# --- デバイスの設定 ---
if torch.cuda.is_available():
    # 指定されたGPU IDが利用可能かチェック
    if device_ids >= torch.cuda.device_count():
        print(f"\n❌ エラー: 指定されたGPU ID {device_ids} は利用できません。利用可能なGPUは {torch.cuda.device_count()}台です。")
        sys.exit()
    
    device = torch.device(f"cuda:{device_ids}")
    print(f"GPU {device_ids} を使用します。")
else:
    device = torch.device("cpu")
    print("GPUが利用できないため、CPUを使用します。")

# --- モデルのインスタンス化 ---
if fusion_type == 'single':
    model = single(hparams).to(device)
elif fusion_type == 'early_fusion':
    model = early_fusion(hparams).to(device)
elif fusion_type == 'late_fusion':
    model = late_fusion(hparams).to(device)
elif fusion_type == 'slow_fusion':
    model = slow_fusion(hparams).to(device)
else:
    raise ValueError(f"不明なフュージョンタイプ: {fusion_type}")
print(f"'{fusion_type}' モデルをインスタンス化し、デバイス '{device}' に配置しました。")
# Out:
# ステップ3: モデルを準備します...
# GPU 0 を使用します。
# 'single' モデルをインスタンス化し、デバイス 'cuda:0' に配置しました。
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# --- 学習済み重みのロード（最終修正版） ---
try:
    checkpoint = torch.load(model_path, map_location=device, weights_only=False)
    
    if 'state_dict' in checkpoint:
        original_state_dict = checkpoint['state_dict']
        new_state_dict = {}
        # キーの先頭にある "model." プレフィックスを削除
        for k, v in original_state_dict.items():
            if k.startswith("model."):
                new_key = k[len("model."):]
            else:
                new_key = k
            new_state_dict[new_key] = v
        
        model.load_state_dict(new_state_dict)
    else:
        model.load_state_dict(checkpoint)
        
    model.eval() # モデルを評価モードに設定
    print("✅ 学習済み重みをモデルに正常にロードしました。")

except Exception as e:
    import traceback
    print(f"\n❌ エラー: モデルの重みロード中にエラーが発生しました: {e}")
    print(traceback.format_exc())
    sys.exit()
# Out:
# ✅ 学習済み重みをモデルに正常にロードしました。

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget

results = {}

# ### ケース1: 2つの動画を入力するフュージョンモデルの場合 ###
if fusion_type in ['late_fusion', 'early_fusion', 'slow_fusion']:
    print(f"'{fusion_type}' モデル（2入力）の推論パイプラインを開始します。")
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    
    datamodule = MultiData(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test') 
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            print(f"\n--- [バッチ {i+1}] 推論中 ---")
            batch_dict = batch[0]
            inputs_front, inputs_side = batch_dict["ap"]["video"].to(device), batch_dict["lat"]["video"].to(device)
            video_names = batch_dict["ap"]["video_name"]
            if batch_dict['ap']['video_name'] != batch_dict['lat']['video_name']:
                print('error')
            outputs = model(inputs_front, inputs_side)
            prob_for_class_1 = torch.sigmoid(outputs)
            predicted_indices = (prob_for_class_1 > 0.5).long()
            
            for idx in range(len(video_names)):
                video_name = os.path.basename(video_names[idx])
                pred_class, prob1 = predicted_indices[idx].item(), prob_for_class_1[idx].item()
                confidence = prob1 if pred_class == 1 else 1 - prob1
                results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")

# 'single' モデル（1入力）の推論パイプライン
elif fusion_type == 'single':
    
    # --- CAM保存設定 ---
    # ▼▼▼【設定項目】保存するCAMの対象を選択 ▼▼▼
    # 'all'                  -> 全てのビデオのCAMを保存
    # 'class_0_predictions'  -> モデルが「0」と予測したビデオのCAMのみ保存
    # 'class_1_predictions'  -> モデルが「1」と予測したビデオのCAMのみ保存
    SAVE_CAM_FOR = 'all'

    print(f"'single' モデル（1入力）の推論パイプラインを開始します。")
    # --- データ準備 (変更なし) ---
    hparams.data.ap_data_path, hparams.data.lat_data_path = AP_DATA_ROOT, LAT_DATA_ROOT
    hparams.train.current_fold = TARGET_FOLD
    hparams.data.batch_size, hparams.data.num_workers = INFERENCE_BATCH_SIZE, 0
    datamodule = WalkDataModule(hparams)
    print(f"'{TARGET_FOLD}' の検証(val)データを読み込んでいます...")
    datamodule.setup(stage='test')
    test_loader = datamodule.test_dataloader()
    print("データローダーの準備が完了しました。")

    # --- 2. Grad-CAMの準備 (変更なし) ---
    try:
        cam_model = model.resnet_model
        target_layers = [cam_model.layer4[-1]]
        cam = GradCAM(model=cam_model, target_layers=target_layers)
        print(f"Grad-CAMの準備が完了しました。")
    except Exception as e:
        print(f"エラー: Grad-CAMのターゲット層が見つかりません。詳細: {e}")
        cam = None

    # --- 3. 推論ループとGrad-CAMの実行 ---
    if test_loader is not None:
        saved_count = 0
        with torch.no_grad():
            for i, batch in enumerate(test_loader):
                print(f"\n--- [バッチ {i+1}] 推論中 ---")
                video_5d_original_shape = batch["video"].to(device)
                video_names = batch["video_name"]
                input_video_for_model = video_5d_original_shape.permute(0, 2, 1, 3, 4).contiguous()
                
                model.eval()
                outputs = model(input_video_for_model)
                prob_for_class_1 = torch.sigmoid(outputs)
                predicted_indices = (prob_for_class_1 > 0.5).long()
                
                if cam is not None:
                    # バッチ内の各ビデオに対して処理
                    for vid_idx_in_batch in range(len(video_names)):
                        prediction = predicted_indices[vid_idx_in_batch].item()
                        
                        # ▼▼▼【ここから修正】設定に基づいて保存するかどうかを判断 ▼▼▼
                        should_save = False
                        if SAVE_CAM_FOR == 'all':
                            should_save = True
                        elif SAVE_CAM_FOR == 'class_0_predictions' and prediction == 0:
                            should_save = True
                        elif SAVE_CAM_FOR == 'class_1_predictions' and prediction == 1:
                            should_save = True

                        if should_save:
                            if saved_count % 10 == 0: # ログが多すぎないように調整
                                print(f"\n--- [バッチ {i+1}] のCAMを生成・保存中... ---")
                            
                            with torch.enable_grad():
                                targets = [ClassifierOutputTarget(0)] # 常にクラス1の根拠を計算
                                B, C, T, H, W = video_5d_original_shape.shape
                                
                                # このビデオ単体でCAMを計算 (バッチ処理を避ける)
                                single_video_input = video_5d_original_shape[vid_idx_in_batch].unsqueeze(0)
                                video_permuted = single_video_input.permute(0, 2, 1, 3, 4).contiguous()
                                input_tensor_4d = video_permuted.view(1 * T, C, H, W)
                                
                                grayscale_cam = cam(input_tensor=input_tensor_4d, targets=targets)
                            
                            # --- 非ゼロCAMを平均化 ---
                            non_zero_cams = [frame for frame in grayscale_cam if np.sum(frame) > 0]
                            if non_zero_cams:
                                averaged_cam = np.mean(non_zero_cams, axis=0)
                            else:
                                averaged_cam = np.zeros_like(grayscale_cam[0])

                            # --- 保存 ---
                            fold_name = TARGET_FOLD
                            fold_output_path = os.path.join(CAM_OUTPUT_DIR, fold_name)
                            os.makedirs(fold_output_path, exist_ok=True)
                            
                            video_name_short = os.path.basename(video_names[vid_idx_in_batch])
                            base_filename, _ = os.path.splitext(video_name_short)
                            save_filename = f"cam_average_{base_filename}_pred_{prediction}.npy"
                            full_save_path = os.path.join(fold_output_path, save_filename)
                            
                            np.save(full_save_path, averaged_cam)
                            saved_count += 1
                    # ▲▲▲【修正ここまで】▲▲▲

                # --- 推論結果の出力 (変更なし) ---
                for idx in range(len(video_names)):
                    video_name = os.path.basename(video_names[idx])
                    pred_class = predicted_indices[idx].item()
                    prob1 = prob_for_class_1[idx].item()
                    confidence = prob1 if pred_class == 1 else 1 - prob1
                    results[video_name] = {'prediction': pred_class, 'confidence': f"{confidence:.4f}", 'prob_for_class_1': f"{prob1:.4f}"}
                    print(f"  - {video_name}: Logit: {outputs[idx].item():.4f} -> P(class 1)={prob1:.4f} -> 予測クラス: {pred_class} (確信度: {confidence*100:.2f}%)")
            
            if cam is not None:
                print(f"\n--- 処理完了 ---")
                print(f"条件に一致した {saved_count} 個の平均CAMを保存しました。")

else:
    print(f"エラー: fusion_type '{fusion_type}' はこのスクリプトでサポートされていません。")

# --- 4.4. 結果の集計と表示 ---
print("\n\n==================== 全ての推論結果 ====================")
if not results:
    print("推論が実行された動画はありませんでした。")
else:
    results_df = pd.DataFrame.from_dict(results, orient='index')
    results_df.index.name = 'Video Filename'
    results_df = results_df.reset_index()
    display(results_df)
# Out:
# 'single' モデル（1入力）の推論パイプラインを開始します。
# 'fold3' の検証(val)データを読み込んでいます...
# データローダーの準備が完了しました。
# Grad-CAMの準備が完了しました。
#
# --- [バッチ 1] 推論中 ---
#
# --- [バッチ 1] のCAMを生成・保存中... ---
#   - ASD_Right_20200127_1728_5-7.mp4: Logit: -0.3827 -> P(class 1)=0.4055 -> 予測クラス: 0 (確信度: 59.45%)
#   - ASD_Left_20200127_1685_4-10.mp4: Logit: 0.4775 -> P(class 1)=0.6172 -> 予測クラス: 1 (確信度: 61.72%)
#   - ASD_Left_20190917_1995_1-4.mp4: Logit: -1.5250 -> P(class 1)=0.1787 -> 予測クラス: 0 (確信度: 82.13%)
#   - ASD_Left_20180625_1_1427_2-6.mp4: Logit: 1.3374 -> P(class 1)=0.7921 -> 予測クラス: 1 (確信度: 79.21%)
#
# --- [バッチ 2] 推論中 ---
#   - HipOA_Right_20180806_2_883_3-4.mp4: Logit: -4.7851 -> P(class 1)=0.0083 -> 予測クラス: 0 (確信度: 99.17%)
#   - DHS_Left_20200528_1119_4-8.mp4: Logit: -6.9129 -> P(class 1)=0.0010 -> 予測クラス: 0 (確信度: 99.90%)
#   - DHS_Right_20160927_1098_3-3.mp4: Logit: -6.2353 -> P(class 1)=0.0020 -> 予測クラス: 0 (確信度: 99.80%)
#   - LCS_Left_20211012_780_2-5.mp4: Logit: -5.9805 -> P(class 1)=0.0025 -> 予測クラス: 0 (確信度: 99.75%)
#
# --- [バッチ 3] 推論中 ---
#
# --- [バッチ 3] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1124_4-6.mp4: Logit: -4.5475 -> P(class 1)=0.0105 -> 予測クラス: 0 (確信度: 98.95%)
#   - DHS_Right_20200528_1120_6-6.mp4: Logit: -2.2305 -> P(class 1)=0.0970 -> 予測クラス: 0 (確信度: 90.30%)
#   - ASD_Right_20190917_2018_1-2.mp4: Logit: -1.3547 -> P(class 1)=0.2051 -> 予測クラス: 0 (確信度: 79.49%)
#   - LCS_Left_20211012_764_4-5.mp4: Logit: -1.0451 -> P(class 1)=0.2602 -> 予測クラス: 0 (確信度: 73.98%)
#
# --- [バッチ 4] 推論中 ---
#   - DHS_Left_20200528_1119_8-8.mp4: Logit: 0.0415 -> P(class 1)=0.5104 -> 予測クラス: 1 (確信度: 51.04%)
#   - ASD_Left_20200127_1685_2-10.mp4: Logit: -4.2440 -> P(class 1)=0.0141 -> 予測クラス: 0 (確信度: 98.59%)
#   - DHS_Left_20160927_1093_2-4.mp4: Logit: -3.9294 -> P(class 1)=0.0193 -> 予測クラス: 0 (確信度: 98.07%)
#   - ASD_Right_20200127_1708_7-7.mp4: Logit: -3.0694 -> P(class 1)=0.0444 -> 予測クラス: 0 (確信度: 95.56%)
#
# --- [バッチ 5] 推論中 ---
#   - ASD_Right_20190917_2012_2-3.mp4: Logit: -2.3112 -> P(class 1)=0.0902 -> 予測クラス: 0 (確信度: 90.98%)
#   - ASD_Right_20200127_1700_5-6.mp4: Logit: -2.5983 -> P(class 1)=0.0692 -> 予測クラス: 0 (確信度: 93.08%)
#   - ASD_Right_20180625_1_1420_1-4.mp4: Logit: -3.5124 -> P(class 1)=0.0290 -> 予測クラス: 0 (確信度: 97.10%)
#   - ASD_Left_20190917_1999_1-4.mp4: Logit: -6.2055 -> P(class 1)=0.0020 -> 予測クラス: 0 (確信度: 99.80%)
#
# --- [バッチ 6] 推論中 ---
#
# --- [バッチ 6] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1711_2-10.mp4: Logit: -4.7131 -> P(class 1)=0.0089 -> 予測クラス: 0 (確信度: 99.11%)
#   - DHS_Right_20160927_1080_2-3.mp4: Logit: -6.1782 -> P(class 1)=0.0021 -> 予測クラス: 0 (確信度: 99.79%)
#   - HipOA_Right_20180806_2_853_1-4.mp4: Logit: -1.5572 -> P(class 1)=0.1741 -> 予測クラス: 0 (確信度: 82.59%)
#   - LCS_Left_20211012_740_3-5.mp4: Logit: -5.5374 -> P(class 1)=0.0039 -> 予測クラス: 0 (確信度: 99.61%)
#
# --- [バッチ 7] 推論中 ---
#   - DHS_Right_20200528_1132_1-6.mp4: Logit: -7.7052 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Left_20200127_1695_6-10.mp4: Logit: -6.6385 -> P(class 1)=0.0013 -> 予測クラス: 0 (確信度: 99.87%)
#   - LCS_Left_20211012_774_1-5.mp4: Logit: -7.2758 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - ASD_Right_20200127_1732_4-7.mp4: Logit: -7.2128 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#
# --- [バッチ 8] 推論中 ---
#
# --- [バッチ 8] のCAMを生成・保存中... ---
#   - LCS_Left_20211012_776_1-5.mp4: Logit: -8.9864 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20200127_1689_7-9.mp4: Logit: -6.5528 -> P(class 1)=0.0014 -> 予測クラス: 0 (確信度: 99.86%)
#   - HipOA_Right_20180806_2_873_1-4.mp4: Logit: -8.0501 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - HipOA_Left_20180806_2_852_2-5.mp4: Logit: -6.1423 -> P(class 1)=0.0021 -> 予測クラス: 0 (確信度: 99.79%)
#
# --- [バッチ 9] 推論中 ---
#   - LCS_Left_20211012_750_4-5.mp4: Logit: -7.2456 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - DHS_Right_20200528_1138_3-5.mp4: Logit: -7.8910 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#   - LCS_Right_20211012_759_3-3.mp4: Logit: -8.7429 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - LCS_Left_20211012_776_2-5.mp4: Logit: -8.1775 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#
# --- [バッチ 10] 推論中 ---
#   - DHS_Right_20200528_1133_1-5.mp4: Logit: -5.3953 -> P(class 1)=0.0045 -> 予測クラス: 0 (確信度: 99.55%)
#   - ASD_Right_20210803_1410_4-7.mp4: Logit: -5.3348 -> P(class 1)=0.0048 -> 予測クラス: 0 (確信度: 99.52%)
#   - ASD_Left_20200127_1701_3-9.mp4: Logit: -6.3319 -> P(class 1)=0.0018 -> 予測クラス: 0 (確信度: 99.82%)
#   - DHS_Left_20160927_1103_1-4.mp4: Logit: -5.8347 -> P(class 1)=0.0029 -> 予測クラス: 0 (確信度: 99.71%)
#
# --- [バッチ 11] 推論中 ---
#
# --- [バッチ 11] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1962_2-4.mp4: Logit: -3.8184 -> P(class 1)=0.0215 -> 予測クラス: 0 (確信度: 97.85%)
#   - ASD_Right_20210323_2040_6-7.mp4: Logit: -4.4565 -> P(class 1)=0.0115 -> 予測クラス: 0 (確信度: 98.85%)
#   - LCS_Left_20210706_838_1-7.mp4: Logit: -3.1298 -> P(class 1)=0.0419 -> 予測クラス: 0 (確信度: 95.81%)
#   - HipOA_Right_20180806_2_885_1-4.mp4: Logit: -3.9964 -> P(class 1)=0.0181 -> 予測クラス: 0 (確信度: 98.19%)
#
# --- [バッチ 12] 推論中 ---
#   - DHS_Right_20200528_1133_5-5.mp4: Logit: -2.1474 -> P(class 1)=0.1046 -> 予測クラス: 0 (確信度: 89.54%)
#   - ASD_Right_20200127_1710_7-7.mp4: Logit: -1.9624 -> P(class 1)=0.1232 -> 予測クラス: 0 (確信度: 87.68%)
#   - ASD_Left_20200127_1703_7-8.mp4: Logit: -0.9901 -> P(class 1)=0.2709 -> 予測クラス: 0 (確信度: 72.91%)
#   - DHS_Right_20200528_1126_6-6.mp4: Logit: -1.6317 -> P(class 1)=0.1636 -> 予測クラス: 0 (確信度: 83.64%)
#
# --- [バッチ 13] 推論中 ---
#
# --- [バッチ 13] のCAMを生成・保存中... ---
#   - DHS_Right_20160927_1100_1-3.mp4: Logit: 1.5120 -> P(class 1)=0.8194 -> 予測クラス: 1 (確信度: 81.94%)
#   - ASD_Right_20200127_1722_4-8.mp4: Logit: 2.3999 -> P(class 1)=0.9168 -> 予測クラス: 1 (確信度: 91.68%)
#   - DHS_Left_20200528_1119_5-8.mp4: Logit: 0.4476 -> P(class 1)=0.6101 -> 予測クラス: 1 (確信度: 61.01%)
#   - ASD_Right_20180625_1_1422_4-4.mp4: Logit: 0.4453 -> P(class 1)=0.6095 -> 予測クラス: 1 (確信度: 60.95%)
#
# --- [バッチ 14] 推論中 ---
#   - ASD_Left_20190917_2021_3-3.mp4: Logit: -2.7683 -> P(class 1)=0.0591 -> 予測クラス: 0 (確信度: 94.09%)
#   - ASD_Left_20190917_1993_2-4.mp4: Logit: -2.1198 -> P(class 1)=0.1072 -> 予測クラス: 0 (確信度: 89.28%)
#   - ASD_Left_20200127_1681_4-9.mp4: Logit: -0.5409 -> P(class 1)=0.3680 -> 予測クラス: 0 (確信度: 63.20%)
#   - ASD_Right_20190917_1967_1-3.mp4: Logit: 0.0557 -> P(class 1)=0.5139 -> 予測クラス: 1 (確信度: 51.39%)
#
# --- [バッチ 15] 推論中 ---
#   - ASD_Left_20190917_2001_3-4.mp4: Logit: -2.7053 -> P(class 1)=0.0627 -> 予測クラス: 0 (確信度: 93.73%)
#   - DHS_Left_20160927_1107_3-4.mp4: Logit: -5.5043 -> P(class 1)=0.0041 -> 予測クラス: 0 (確信度: 99.59%)
#   - ASD_Left_20200127_1695_9-10.mp4: Logit: -0.3361 -> P(class 1)=0.4168 -> 予測クラス: 0 (確信度: 58.32%)
#   - ASD_Left_20200127_1723_8-11.mp4: Logit: 1.6412 -> P(class 1)=0.8377 -> 予測クラス: 1 (確信度: 83.77%)
#
# --- [バッチ 16] 推論中 ---
#
# --- [バッチ 16] のCAMを生成・保存中... ---
#   - DHS_Left_20160927_1063_5-5.mp4: Logit: 0.1243 -> P(class 1)=0.5310 -> 予測クラス: 1 (確信度: 53.10%)
#   - LCS_Right_20211012_769_2-3.mp4: Logit: 0.1442 -> P(class 1)=0.5360 -> 予測クラス: 1 (確信度: 53.60%)
#   - ASD_Right_20210323_2040_1-7.mp4: Logit: -1.1750 -> P(class 1)=0.2360 -> 予測クラス: 0 (確信度: 76.40%)
#   - ASD_Left_20180625_1_1423_4-6.mp4: Logit: -3.6432 -> P(class 1)=0.0255 -> 予測クラス: 0 (確信度: 97.45%)
#
# --- [バッチ 17] 推論中 ---
#   - ASD_Right_20200127_1710_2-7.mp4: Logit: -2.2823 -> P(class 1)=0.0926 -> 予測クラス: 0 (確信度: 90.74%)
#   - ASD_Right_20190819_1440_2-4.mp4: Logit: -2.8171 -> P(class 1)=0.0564 -> 予測クラス: 0 (確信度: 94.36%)
#   - DHS_Right_20160927_1084_2-3.mp4: Logit: -3.3409 -> P(class 1)=0.0342 -> 予測クラス: 0 (確信度: 96.58%)
#   - ASD_Right_20190917_1944_2-3.mp4: Logit: -2.4781 -> P(class 1)=0.0774 -> 予測クラス: 0 (確信度: 92.26%)
#
# --- [バッチ 18] 推論中 ---
#
# --- [バッチ 18] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1685_5-10.mp4: Logit: -5.1397 -> P(class 1)=0.0058 -> 予測クラス: 0 (確信度: 99.42%)
#   - ASD_Left_20200127_1713_1-10.mp4: Logit: -4.7448 -> P(class 1)=0.0086 -> 予測クラス: 0 (確信度: 99.14%)
#   - DHS_Right_20160927_1076_2-4.mp4: Logit: -5.7521 -> P(class 1)=0.0032 -> 予測クラス: 0 (確信度: 99.68%)
#   - ASD_Left_20200127_1715_9-11.mp4: Logit: -4.0436 -> P(class 1)=0.0172 -> 予測クラス: 0 (確信度: 98.28%)
#
# --- [バッチ 19] 推論中 ---
#   - DHS_Left_20160927_1083_2-4.mp4: Logit: 3.2631 -> P(class 1)=0.9631 -> 予測クラス: 1 (確信度: 96.31%)
#   - ASD_Left_20210323_2043_3-10.mp4: Logit: 2.6826 -> P(class 1)=0.9360 -> 予測クラス: 1 (確信度: 93.60%)
#   - ASD_Left_20190917_1953_1-4.mp4: Logit: 3.6370 -> P(class 1)=0.9743 -> 予測クラス: 1 (確信度: 97.43%)
#   - HipOA_Left_20180806_2_872_2-6.mp4: Logit: 3.2019 -> P(class 1)=0.9609 -> 予測クラス: 1 (確信度: 96.09%)
#
# --- [バッチ 20] 推論中 ---
#   - DHS_Left_20160927_1069_3-4.mp4: Logit: 2.0165 -> P(class 1)=0.8825 -> 予測クラス: 1 (確信度: 88.25%)
#   - DHS_Left_20160927_1097_3-4.mp4: Logit: 1.1037 -> P(class 1)=0.7509 -> 予測クラス: 1 (確信度: 75.09%)
#   - ASD_Left_20190917_1968_1-4.mp4: Logit: 3.0474 -> P(class 1)=0.9547 -> 予測クラス: 1 (確信度: 95.47%)
#   - DHS_Left_20160927_1095_3-4.mp4: Logit: 1.0117 -> P(class 1)=0.7334 -> 予測クラス: 1 (確信度: 73.34%)
#
# --- [バッチ 21] 推論中 ---
#
# --- [バッチ 21] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1691_8-10.mp4: Logit: -3.6858 -> P(class 1)=0.0245 -> 予測クラス: 0 (確信度: 97.55%)
#   - ASD_Left_20200127_1705_3-10.mp4: Logit: -3.3026 -> P(class 1)=0.0355 -> 予測クラス: 0 (確信度: 96.45%)
#   - ASD_Right_20190917_1984_1-3.mp4: Logit: -3.2658 -> P(class 1)=0.0368 -> 予測クラス: 0 (確信度: 96.32%)
#   - ASD_Right_20190917_1948_2-2.mp4: Logit: -1.8086 -> P(class 1)=0.1408 -> 予測クラス: 0 (確信度: 85.92%)
#
# --- [バッチ 22] 推論中 ---
#   - ASD_Left_20190917_2015_3-4.mp4: Logit: -5.0088 -> P(class 1)=0.0066 -> 予測クラス: 0 (確信度: 99.34%)
#   - ASD_Right_20190819_1432_3-4.mp4: Logit: -0.1581 -> P(class 1)=0.4606 -> 予測クラス: 0 (確信度: 53.94%)
#   - HipOA_Left_20180806_2_862_4-5.mp4: Logit: 0.5958 -> P(class 1)=0.6447 -> 予測クラス: 1 (確信度: 64.47%)
#   - ASD_Left_20180625_1_1423_2-6.mp4: Logit: 0.5454 -> P(class 1)=0.6331 -> 予測クラス: 1 (確信度: 63.31%)
#
# --- [バッチ 23] 推論中 ---
#
# --- [バッチ 23] のCAMを生成・保存中... ---
#   - LCS_Right_20210706_843_3-5.mp4: Logit: -5.6961 -> P(class 1)=0.0033 -> 予測クラス: 0 (確信度: 99.67%)
#   - ASD_Left_20190917_2019_4-4.mp4: Logit: -8.3501 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - LCS_Right_20210706_837_6-6.mp4: Logit: -7.0147 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#   - ASD_Left_20200127_1711_6-10.mp4: Logit: -4.8458 -> P(class 1)=0.0078 -> 予測クラス: 0 (確信度: 99.22%)
#
# --- [バッチ 24] 推論中 ---
#   - ASD_Right_20200127_1726_3-7.mp4: Logit: 1.8199 -> P(class 1)=0.8606 -> 予測クラス: 1 (確信度: 86.06%)
#   - ASD_Left_20200127_1695_10-10.mp4: Logit: -3.4332 -> P(class 1)=0.0313 -> 予測クラス: 0 (確信度: 96.87%)
#   - ASD_Right_20200127_1726_1-7.mp4: Logit: -3.7258 -> P(class 1)=0.0235 -> 予測クラス: 0 (確信度: 97.65%)
#   - DHS_Left_20160927_1067_1-4.mp4: Logit: -3.5374 -> P(class 1)=0.0283 -> 予測クラス: 0 (確信度: 97.17%)
#
# --- [バッチ 25] 推論中 ---
#   - DHS_Left_20160927_1083_4-4.mp4: Logit: 0.7696 -> P(class 1)=0.6834 -> 予測クラス: 1 (確信度: 68.34%)
#   - ASD_Left_20200127_1711_7-10.mp4: Logit: -0.4845 -> P(class 1)=0.3812 -> 予測クラス: 0 (確信度: 61.88%)
#   - DHS_Right_20160927_1088_2-3.mp4: Logit: 0.2104 -> P(class 1)=0.5524 -> 予測クラス: 1 (確信度: 55.24%)
#   - DHS_Right_20200528_1134_2-6.mp4: Logit: 0.2000 -> P(class 1)=0.5498 -> 予測クラス: 1 (確信度: 54.98%)
#
# --- [バッチ 26] 推論中 ---
#
# --- [バッチ 26] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1136_4-6.mp4: Logit: -4.4368 -> P(class 1)=0.0117 -> 予測クラス: 0 (確信度: 98.83%)
#   - ASD_Right_20200127_1702_6-7.mp4: Logit: -4.2578 -> P(class 1)=0.0140 -> 予測クラス: 0 (確信度: 98.60%)
#   - DHS_Left_20160927_1077_2-5.mp4: Logit: -4.1030 -> P(class 1)=0.0163 -> 予測クラス: 0 (確信度: 98.37%)
#   - HipOA_Left_20180806_2_856_3-5.mp4: Logit: -2.9432 -> P(class 1)=0.0501 -> 予測クラス: 0 (確信度: 94.99%)
#
# --- [バッチ 27] 推論中 ---
#   - ASD_Left_20190917_1985_4-4.mp4: Logit: -3.4185 -> P(class 1)=0.0317 -> 予測クラス: 0 (確信度: 96.83%)
#   - ASD_Left_20200127_1719_10-10.mp4: Logit: -4.3475 -> P(class 1)=0.0128 -> 予測クラス: 0 (確信度: 98.72%)
#   - ASD_Left_20210323_2041_8-9.mp4: Logit: 3.0209 -> P(class 1)=0.9535 -> 予測クラス: 1 (確信度: 95.35%)
#   - ASD_Left_20190819_1451_5-5.mp4: Logit: 1.6891 -> P(class 1)=0.8441 -> 予測クラス: 1 (確信度: 84.41%)
#
# --- [バッチ 28] 推論中 ---
#
# --- [バッチ 28] のCAMを生成・保存中... ---
#   - HipOA_Left_20180806_2_890_4-6.mp4: Logit: -7.6281 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - HipOA_Left_20180806_2_890_3-6.mp4: Logit: -8.6300 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20200127_1681_9-9.mp4: Logit: -8.7172 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - DHS_Left_20200528_1128_8-8.mp4: Logit: -7.0775 -> P(class 1)=0.0008 -> 予測クラス: 0 (確信度: 99.92%)
#
# --- [バッチ 29] 推論中 ---
#   - DHS_Left_20160927_1097_4-4.mp4: Logit: 0.7872 -> P(class 1)=0.6872 -> 予測クラス: 1 (確信度: 68.72%)
#   - ASD_Left_20190917_2013_2-4.mp4: Logit: 0.1373 -> P(class 1)=0.5343 -> 予測クラス: 1 (確信度: 53.43%)
#   - ASD_Left_20200127_1727_7-10.mp4: Logit: -0.1961 -> P(class 1)=0.4511 -> 予測クラス: 0 (確信度: 54.89%)
#   - ASD_Left_20200127_1701_1-9.mp4: Logit: 0.9247 -> P(class 1)=0.7160 -> 予測クラス: 1 (確信度: 71.60%)
#
# --- [バッチ 30] 推論中 ---
#   - ASD_Left_20200127_1681_2-9.mp4: Logit: -2.9735 -> P(class 1)=0.0486 -> 予測クラス: 0 (確信度: 95.14%)
#   - LCS_Left_20211012_742_5-5.mp4: Logit: -5.5817 -> P(class 1)=0.0038 -> 予測クラス: 0 (確信度: 99.62%)
#   - ASD_Left_20200127_1723_4-11.mp4: Logit: -2.8108 -> P(class 1)=0.0567 -> 予測クラス: 0 (確信度: 94.33%)
#   - HipOA_Right_20180806_2_871_4-4.mp4: Logit: -3.7924 -> P(class 1)=0.0220 -> 予測クラス: 0 (確信度: 97.80%)
#
# --- [バッチ 31] 推論中 ---
#
# --- [バッチ 31] のCAMを生成・保存中... ---
#   - DHS_Right_20160927_1076_3-4.mp4: Logit: 2.0134 -> P(class 1)=0.8822 -> 予測クラス: 1 (確信度: 88.22%)
#   - ASD_Left_20200127_1687_4-9.mp4: Logit: 1.3718 -> P(class 1)=0.7977 -> 予測クラス: 1 (確信度: 79.77%)
#   - HipOA_Left_20180806_2_890_1-6.mp4: Logit: 2.8529 -> P(class 1)=0.9455 -> 予測クラス: 1 (確信度: 94.55%)
#   - ASD_Right_20190917_1963_2-3.mp4: Logit: 1.1049 -> P(class 1)=0.7512 -> 予測クラス: 1 (確信度: 75.12%)
#
# --- [バッチ 32] 推論中 ---
#   - DHS_Right_20200528_1125_5-6.mp4: Logit: -2.3124 -> P(class 1)=0.0901 -> 予測クラス: 0 (確信度: 90.99%)
#   - ASD_Left_20200127_1685_1-10.mp4: Logit: -2.3544 -> P(class 1)=0.0867 -> 予測クラス: 0 (確信度: 91.33%)
#   - HipOA_Right_20180806_2_891_4-4.mp4: Logit: -1.9470 -> P(class 1)=0.1249 -> 予測クラス: 0 (確信度: 87.51%)
#   - DHS_Left_20160927_1071_2-4.mp4: Logit: -0.9111 -> P(class 1)=0.2868 -> 予測クラス: 0 (確信度: 71.32%)
#
# --- [バッチ 33] 推論中 ---
#
# --- [バッチ 33] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1987_1-4.mp4: Logit: -1.9839 -> P(class 1)=0.1209 -> 予測クラス: 0 (確信度: 87.91%)
#   - ASD_Left_20190917_2009_1-4.mp4: Logit: -3.6817 -> P(class 1)=0.0246 -> 予測クラス: 0 (確信度: 97.54%)
#   - HipOA_Left_20180806_2_882_5-6.mp4: Logit: -3.2178 -> P(class 1)=0.0385 -> 予測クラス: 0 (確信度: 96.15%)
#   - DHS_Left_20160927_1103_4-4.mp4: Logit: -2.9801 -> P(class 1)=0.0483 -> 予測クラス: 0 (確信度: 95.17%)
#
# --- [バッチ 34] 推論中 ---
#   - LCS_Right_20211012_763_2-3.mp4: Logit: -2.1483 -> P(class 1)=0.1045 -> 予測クラス: 0 (確信度: 89.55%)
#   - HipOA_Right_20180806_2_871_1-4.mp4: Logit: -3.4251 -> P(class 1)=0.0315 -> 予測クラス: 0 (確信度: 96.85%)
#   - DHS_Left_20200528_1119_3-8.mp4: Logit: -2.9232 -> P(class 1)=0.0510 -> 予測クラス: 0 (確信度: 94.90%)
#   - HipOA_Right_20180806_2_885_4-4.mp4: Logit: -6.0195 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#
# --- [バッチ 35] 推論中 ---
#   - ASD_Left_20190917_1982_2-4.mp4: Logit: -3.3877 -> P(class 1)=0.0327 -> 予測クラス: 0 (確信度: 96.73%)
#   - ASD_Right_20200127_1694_6-6.mp4: Logit: -4.5254 -> P(class 1)=0.0107 -> 予測クラス: 0 (確信度: 98.93%)
#   - ASD_Left_20190917_1943_3-4.mp4: Logit: -4.2236 -> P(class 1)=0.0144 -> 予測クラス: 0 (確信度: 98.56%)
#   - LCS_Left_20211012_770_3-5.mp4: Logit: -4.9170 -> P(class 1)=0.0073 -> 予測クラス: 0 (確信度: 99.27%)
#
# --- [バッチ 36] 推論中 ---
#
# --- [バッチ 36] のCAMを生成・保存中... ---
#   - ASD_Right_20200127_1682_1-6.mp4: Logit: -2.5140 -> P(class 1)=0.0749 -> 予測クラス: 0 (確信度: 92.51%)
#   - LCS_Right_20210706_839_3-5.mp4: Logit: -0.2440 -> P(class 1)=0.4393 -> 予測クラス: 0 (確信度: 56.07%)
#   - ASD_Left_20200127_1701_5-9.mp4: Logit: 0.3626 -> P(class 1)=0.5897 -> 予測クラス: 1 (確信度: 58.97%)
#   - HipOA_Left_20180806_2_858_1-5.mp4: Logit: -0.4280 -> P(class 1)=0.3946 -> 予測クラス: 0 (確信度: 60.54%)
#
# --- [バッチ 37] 推論中 ---
#   - ASD_Left_20200127_1717_1-10.mp4: Logit: -4.0046 -> P(class 1)=0.0179 -> 予測クラス: 0 (確信度: 98.21%)
#   - LCS_Left_20211012_744_1-5.mp4: Logit: -2.3440 -> P(class 1)=0.0875 -> 予測クラス: 0 (確信度: 91.25%)
#   - ASD_Left_20190819_1455_5-5.mp4: Logit: -3.0116 -> P(class 1)=0.0469 -> 予測クラス: 0 (確信度: 95.31%)
#   - DHS_Right_20200528_1120_1-6.mp4: Logit: -4.1275 -> P(class 1)=0.0159 -> 予測クラス: 0 (確信度: 98.41%)
#
# --- [バッチ 38] 推論中 ---
#
# --- [バッチ 38] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1721_9-10.mp4: Logit: -4.8466 -> P(class 1)=0.0078 -> 予測クラス: 0 (確信度: 99.22%)
#   - ASD_Left_20190819_1435_3-6.mp4: Logit: -4.6707 -> P(class 1)=0.0093 -> 予測クラス: 0 (確信度: 99.07%)
#   - DHS_Left_20200528_1121_7-8.mp4: Logit: -3.6884 -> P(class 1)=0.0244 -> 予測クラス: 0 (確信度: 97.56%)
#   - ASD_Left_20200127_1705_9-10.mp4: Logit: -4.2546 -> P(class 1)=0.0140 -> 予測クラス: 0 (確信度: 98.60%)
#
# --- [バッチ 39] 推論中 ---
#   - ASD_Left_20190917_1947_3-4.mp4: Logit: -3.6851 -> P(class 1)=0.0245 -> 予測クラス: 0 (確信度: 97.55%)
#   - ASD_Right_20200127_1682_5-6.mp4: Logit: -3.7765 -> P(class 1)=0.0224 -> 予測クラス: 0 (確信度: 97.76%)
#   - ASD_Right_20200127_1690_6-7.mp4: Logit: -3.5639 -> P(class 1)=0.0275 -> 予測クラス: 0 (確信度: 97.25%)
#   - ASD_Left_20200127_1681_7-9.mp4: Logit: 1.5148 -> P(class 1)=0.8198 -> 予測クラス: 1 (確信度: 81.98%)
#
# --- [バッチ 40] 推論中 ---
#   - ASD_Right_20190917_1975_3-3.mp4: Logit: -4.1074 -> P(class 1)=0.0162 -> 予測クラス: 0 (確信度: 98.38%)
#   - ASD_Left_20200127_1705_4-10.mp4: Logit: -2.9523 -> P(class 1)=0.0496 -> 予測クラス: 0 (確信度: 95.04%)
#   - ASD_Left_20200127_1709_5-10.mp4: Logit: -1.6040 -> P(class 1)=0.1674 -> 予測クラス: 0 (確信度: 83.26%)
#   - ASD_Left_20190917_2003_2-4.mp4: Logit: -3.0531 -> P(class 1)=0.0451 -> 予測クラス: 0 (確信度: 95.49%)
#
# --- [バッチ 41] 推論中 ---
#
# --- [バッチ 41] のCAMを生成・保存中... ---
#   - ASD_Left_20190819_1433_5-5.mp4: Logit: -5.4136 -> P(class 1)=0.0044 -> 予測クラス: 0 (確信度: 99.56%)
#   - ASD_Right_20200127_1684_3-6.mp4: Logit: -5.8105 -> P(class 1)=0.0030 -> 予測クラス: 0 (確信度: 99.70%)
#   - DHS_Right_20200528_1133_2-5.mp4: Logit: -5.5610 -> P(class 1)=0.0038 -> 予測クラス: 0 (確信度: 99.62%)
#   - DHS_Right_20160927_1092_1-3.mp4: Logit: -6.4475 -> P(class 1)=0.0016 -> 予測クラス: 0 (確信度: 99.84%)
#
# --- [バッチ 42] 推論中 ---
#   - LCS_Left_20211012_778_5-5.mp4: Logit: -7.3609 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - LCS_Left_20211012_740_5-5.mp4: Logit: -8.6007 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Right_20200127_1684_2-6.mp4: Logit: -9.9090 -> P(class 1)=0.0000 -> 予測クラス: 0 (確信度: 100.00%)
#   - DHS_Right_20160927_1070_1-3.mp4: Logit: -9.6084 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#
# --- [バッチ 43] 推論中 ---
#
# --- [バッチ 43] のCAMを生成・保存中... ---
#   - LCS_Left_20211012_742_4-5.mp4: Logit: -7.6407 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Left_20190917_1985_3-4.mp4: Logit: -9.1803 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - LCS_Left_20211012_756_2-5.mp4: Logit: -9.3370 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - DHS_Left_20160927_1091_2-4.mp4: Logit: -6.2210 -> P(class 1)=0.0020 -> 予測クラス: 0 (確信度: 99.80%)
#
# --- [バッチ 44] 推論中 ---
#   - LCS_Left_20211012_780_4-5.mp4: Logit: -7.6804 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Left_20180625_1_1429_6-6.mp4: Logit: -9.5565 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20180625_1_1427_6-6.mp4: Logit: -8.8729 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20190819_1435_1-6.mp4: Logit: -7.2774 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#
# --- [バッチ 45] 推論中 ---
#   - ASD_Right_20200127_1694_3-6.mp4: Logit: -2.6834 -> P(class 1)=0.0640 -> 予測クラス: 0 (確信度: 93.60%)
#   - ASD_Right_20200127_1728_4-7.mp4: Logit: -3.3895 -> P(class 1)=0.0326 -> 予測クラス: 0 (確信度: 96.74%)
#   - ASD_Right_20200127_1724_1-7.mp4: Logit: -2.3575 -> P(class 1)=0.0865 -> 予測クラス: 0 (確信度: 91.35%)
#   - DHS_Right_20200528_1130_1-6.mp4: Logit: -1.8111 -> P(class 1)=0.1405 -> 予測クラス: 0 (確信度: 85.95%)
#
# --- [バッチ 46] 推論中 ---
#
# --- [バッチ 46] のCAMを生成・保存中... ---
#   - ASD_Left_20190819_1445_5-6.mp4: Logit: -3.0541 -> P(class 1)=0.0450 -> 予測クラス: 0 (確信度: 95.50%)
#   - DHS_Left_20160927_1085_4-4.mp4: Logit: -3.9531 -> P(class 1)=0.0188 -> 予測クラス: 0 (確信度: 98.12%)
#   - ASD_Left_20190917_2021_2-3.mp4: Logit: -5.0589 -> P(class 1)=0.0063 -> 予測クラス: 0 (確信度: 99.37%)
#   - HipOA_Right_20180806_2_871_2-4.mp4: Logit: -7.1395 -> P(class 1)=0.0008 -> 予測クラス: 0 (確信度: 99.92%)
#
# --- [バッチ 47] 推論中 ---
#   - ASD_Right_20190819_1444_1-3.mp4: Logit: -5.0703 -> P(class 1)=0.0062 -> 予測クラス: 0 (確信度: 99.38%)
#   - ASD_Right_20200127_1686_3-6.mp4: Logit: -7.7228 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#   - HipOA_Left_20180806_2_890_2-6.mp4: Logit: -5.0750 -> P(class 1)=0.0062 -> 予測クラス: 0 (確信度: 99.38%)
#   - DHS_Left_20160927_1077_5-5.mp4: Logit: -3.8243 -> P(class 1)=0.0214 -> 予測クラス: 0 (確信度: 97.86%)
#
# --- [バッチ 48] 推論中 ---
#
# --- [バッチ 48] のCAMを生成・保存中... ---
#   - HipOA_Right_20180806_2_863_2-4.mp4: Logit: -3.6435 -> P(class 1)=0.0255 -> 予測クラス: 0 (確信度: 97.45%)
#   - DHS_Left_20160927_1075_5-5.mp4: Logit: -4.0911 -> P(class 1)=0.0164 -> 予測クラス: 0 (確信度: 98.36%)
#   - ASD_Left_20190819_1439_1-6.mp4: Logit: -4.9879 -> P(class 1)=0.0068 -> 予測クラス: 0 (確信度: 99.32%)
#   - LCS_Left_20210706_838_3-7.mp4: Logit: -4.7731 -> P(class 1)=0.0084 -> 予測クラス: 0 (確信度: 99.16%)
#
# --- [バッチ 49] 推論中 ---
#   - ASD_Left_20200127_1731_4-10.mp4: Logit: -4.2472 -> P(class 1)=0.0141 -> 予測クラス: 0 (確信度: 98.59%)
#   - ASD_Right_20200127_1698_3-6.mp4: Logit: -3.9091 -> P(class 1)=0.0197 -> 予測クラス: 0 (確信度: 98.03%)
#   - DHS_Left_20160927_1073_4-5.mp4: Logit: -3.7353 -> P(class 1)=0.0233 -> 予測クラス: 0 (確信度: 97.67%)
#   - ASD_Left_20190917_1966_1-4.mp4: Logit: -2.7461 -> P(class 1)=0.0603 -> 予測クラス: 0 (確信度: 93.97%)
#
# --- [バッチ 50] 推論中 ---
#   - ASD_Left_20200127_1705_2-10.mp4: Logit: -3.4582 -> P(class 1)=0.0305 -> 予測クラス: 0 (確信度: 96.95%)
#   - HipOA_Left_20180806_2_874_4-5.mp4: Logit: -5.3446 -> P(class 1)=0.0048 -> 予測クラス: 0 (確信度: 99.52%)
#   - DHS_Right_20160927_1108_2-3.mp4: Logit: -2.9792 -> P(class 1)=0.0484 -> 予測クラス: 0 (確信度: 95.16%)
#   - DHS_Right_20160927_1074_1-3.mp4: Logit: -3.1162 -> P(class 1)=0.0424 -> 予測クラス: 0 (確信度: 95.76%)
#
# --- [バッチ 51] 推論中 ---
#
# --- [バッチ 51] のCAMを生成・保存中... ---
#   - LCS_Left_20211012_754_5-5.mp4: Logit: -8.9618 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - HipOA_Right_20180806_2_887_4-4.mp4: Logit: -7.6413 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Right_20190819_1450_2-3.mp4: Logit: -10.2937 -> P(class 1)=0.0000 -> 予測クラス: 0 (確信度: 100.00%)
#   - ASD_Right_20200127_1718_2-8.mp4: Logit: -8.2733 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#
# --- [バッチ 52] 推論中 ---
#   - DHS_Right_20200528_1137_6-7.mp4: Logit: -0.2693 -> P(class 1)=0.4331 -> 予測クラス: 0 (確信度: 56.69%)
#   - ASD_Right_20200127_1692_4-6.mp4: Logit: -2.5082 -> P(class 1)=0.0753 -> 予測クラス: 0 (確信度: 92.47%)
#   - ASD_Left_20210323_2043_4-10.mp4: Logit: -2.2910 -> P(class 1)=0.0919 -> 予測クラス: 0 (確信度: 90.81%)
#   - DHS_Right_20160927_1084_3-3.mp4: Logit: -2.5494 -> P(class 1)=0.0725 -> 予測クラス: 0 (確信度: 92.75%)
#
# --- [バッチ 53] 推論中 ---
#
# --- [バッチ 53] のCAMを生成・保存中... ---
#   - HipOA_Left_20180806_2_872_3-6.mp4: Logit: -7.5490 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - DHS_Left_20160927_1069_1-4.mp4: Logit: -7.9888 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - DHS_Right_20200528_1118_2-6.mp4: Logit: -6.8930 -> P(class 1)=0.0010 -> 予測クラス: 0 (確信度: 99.90%)
#   - DHS_Left_20160927_1117_4-4.mp4: Logit: -7.0870 -> P(class 1)=0.0008 -> 予測クラス: 0 (確信度: 99.92%)
#
# --- [バッチ 54] 推論中 ---
#   - ASD_Left_20190819_1455_3-5.mp4: Logit: -6.2995 -> P(class 1)=0.0018 -> 予測クラス: 0 (確信度: 99.82%)
#   - ASD_Left_20200127_1695_1-10.mp4: Logit: -7.1066 -> P(class 1)=0.0008 -> 予測クラス: 0 (確信度: 99.92%)
#   - LCS_Right_20211012_771_2-3.mp4: Logit: -6.6461 -> P(class 1)=0.0013 -> 予測クラス: 0 (確信度: 99.87%)
#   - DHS_Right_20160927_1112_3-3.mp4: Logit: -5.1546 -> P(class 1)=0.0057 -> 予測クラス: 0 (確信度: 99.43%)
#
# --- [バッチ 55] 推論中 ---
#   - DHS_Right_20160927_1086_1-3.mp4: Logit: 2.2506 -> P(class 1)=0.9047 -> 予測クラス: 1 (確信度: 90.47%)
#   - LCS_Left_20211012_758_1-5.mp4: Logit: 2.0910 -> P(class 1)=0.8900 -> 予測クラス: 1 (確信度: 89.00%)
#   - DHS_Left_20160927_1089_3-5.mp4: Logit: 3.1778 -> P(class 1)=0.9600 -> 予測クラス: 1 (確信度: 96.00%)
#   - LCS_Left_20211012_778_4-5.mp4: Logit: 1.0416 -> P(class 1)=0.7392 -> 予測クラス: 1 (確信度: 73.92%)
#
# --- [バッチ 56] 推論中 ---
#
# --- [バッチ 56] のCAMを生成・保存中... ---
#   - ASD_Right_20210803_1410_1-7.mp4: Logit: -7.0343 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#   - HipOA_Right_20180806_2_879_1-3.mp4: Logit: -6.9760 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#   - ASD_Right_20190819_1446_2-4.mp4: Logit: -6.6713 -> P(class 1)=0.0013 -> 予測クラス: 0 (確信度: 99.87%)
#   - ASD_Right_20200127_1730_2-7.mp4: Logit: -7.4053 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#
# --- [バッチ 57] 推論中 ---
#   - LCS_Left_20211012_754_2-5.mp4: Logit: -8.7401 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20190819_1431_4-5.mp4: Logit: -8.3129 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Right_20190819_1434_3-4.mp4: Logit: -9.7254 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - LCS_Left_20211012_772_1-5.mp4: Logit: -7.8305 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#
# --- [バッチ 58] 推論中 ---
#
# --- [バッチ 58] のCAMを生成・保存中... ---
#   - ASD_Left_20210803_1409_7-10.mp4: Logit: -9.6390 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20210323_2041_4-9.mp4: Logit: -9.0319 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Right_20200127_1688_3-7.mp4: Logit: -9.3856 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - LCS_Left_20211012_742_1-5.mp4: Logit: -8.9170 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#
# --- [バッチ 59] 推論中 ---
#   - DHS_Right_20200528_1129_2-4.mp4: Logit: -2.8436 -> P(class 1)=0.0550 -> 予測クラス: 0 (確信度: 94.50%)
#   - ASD_Left_20200127_1693_5-9.mp4: Logit: -3.8487 -> P(class 1)=0.0209 -> 予測クラス: 0 (確信度: 97.91%)
#   - ASD_Left_20200127_1687_2-9.mp4: Logit: -3.5954 -> P(class 1)=0.0267 -> 予測クラス: 0 (確信度: 97.33%)
#   - DHS_Left_20160927_1085_1-4.mp4: Logit: -3.7242 -> P(class 1)=0.0236 -> 予測クラス: 0 (確信度: 97.64%)
#
# --- [バッチ 60] 推論中 ---
#   - ASD_Left_20190917_1951_1-4.mp4: Logit: -3.4073 -> P(class 1)=0.0321 -> 予測クラス: 0 (確信度: 96.79%)
#   - HipOA_Left_20180806_2_850_5-5.mp4: Logit: -1.5093 -> P(class 1)=0.1810 -> 予測クラス: 0 (確信度: 81.90%)
#   - LCS_Right_20211012_763_1-3.mp4: Logit: -3.6633 -> P(class 1)=0.0250 -> 予測クラス: 0 (確信度: 97.50%)
#   - ASD_Right_20190917_1969_1-3.mp4: Logit: -3.4028 -> P(class 1)=0.0322 -> 予測クラス: 0 (確信度: 96.78%)
#
# --- [バッチ 61] 推論中 ---
#
# --- [バッチ 61] のCAMを生成・保存中... ---
#   - ASD_Left_20180625_1_1425_1-6.mp4: Logit: -6.0110 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#   - ASD_Left_20200127_1705_10-10.mp4: Logit: -6.4550 -> P(class 1)=0.0016 -> 予測クラス: 0 (確信度: 99.84%)
#   - ASD_Right_20190917_2000_1-2.mp4: Logit: -4.4820 -> P(class 1)=0.0112 -> 予測クラス: 0 (確信度: 98.88%)
#   - HipOA_Left_20180806_2_850_4-5.mp4: Logit: -4.1616 -> P(class 1)=0.0153 -> 予測クラス: 0 (確信度: 98.47%)
#
# --- [バッチ 62] 推論中 ---
#   - DHS_Left_20160927_1065_2-4.mp4: Logit: 2.5531 -> P(class 1)=0.9278 -> 予測クラス: 1 (確信度: 92.78%)
#   - ASD_Right_20200127_1732_5-7.mp4: Logit: 2.1208 -> P(class 1)=0.8929 -> 予測クラス: 1 (確信度: 89.29%)
#   - DHS_Right_20160927_1106_1-3.mp4: Logit: 2.8058 -> P(class 1)=0.9430 -> 予測クラス: 1 (確信度: 94.30%)
#   - ASD_Left_20180625_1_1427_4-6.mp4: Logit: 1.5488 -> P(class 1)=0.8247 -> 予測クラス: 1 (確信度: 82.47%)
#
# --- [バッチ 63] 推論中 ---
#
# --- [バッチ 63] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1126_4-6.mp4: Logit: -2.0962 -> P(class 1)=0.1095 -> 予測クラス: 0 (確信度: 89.05%)
#   - ASD_Left_20190819_1449_2-6.mp4: Logit: -2.0798 -> P(class 1)=0.1111 -> 予測クラス: 0 (確信度: 88.89%)
#   - ASD_Right_20200127_1706_6-7.mp4: Logit: -1.4542 -> P(class 1)=0.1894 -> 予測クラス: 0 (確信度: 81.06%)
#   - ASD_Right_20200127_1702_4-7.mp4: Logit: -3.5055 -> P(class 1)=0.0292 -> 予測クラス: 0 (確信度: 97.08%)
#
# --- [バッチ 64] 推論中 ---
#   - ASD_Left_20190917_1945_3-4.mp4: Logit: -0.8961 -> P(class 1)=0.2898 -> 予測クラス: 0 (確信度: 71.02%)
#   - ASD_Right_20200127_1690_7-7.mp4: Logit: -1.8040 -> P(class 1)=0.1414 -> 予測クラス: 0 (確信度: 85.86%)
#   - ASD_Right_20190819_1442_1-3.mp4: Logit: -2.6302 -> P(class 1)=0.0672 -> 予測クラス: 0 (確信度: 93.28%)
#   - ASD_Left_20200127_1701_7-9.mp4: Logit: 0.1602 -> P(class 1)=0.5400 -> 予測クラス: 1 (確信度: 54.00%)
#
# --- [バッチ 65] 推論中 ---
#   - ASD_Left_20200127_1715_8-11.mp4: Logit: -2.5152 -> P(class 1)=0.0748 -> 予測クラス: 0 (確信度: 92.52%)
#   - HipOA_Right_20180806_2_885_2-4.mp4: Logit: -2.8846 -> P(class 1)=0.0529 -> 予測クラス: 0 (確信度: 94.71%)
#   - HipOA_Left_20180806_2_868_5-6.mp4: Logit: -1.5087 -> P(class 1)=0.1811 -> 予測クラス: 0 (確信度: 81.89%)
#   - HipOA_Left_20180806_2_852_3-5.mp4: Logit: -2.6166 -> P(class 1)=0.0681 -> 予測クラス: 0 (確信度: 93.19%)
#
# --- [バッチ 66] 推論中 ---
#
# --- [バッチ 66] のCAMを生成・保存中... ---
#   - ASD_Right_20200127_1722_8-8.mp4: Logit: -2.0878 -> P(class 1)=0.1103 -> 予測クラス: 0 (確信度: 88.97%)
#   - ASD_Right_20200127_1718_8-8.mp4: Logit: -2.6990 -> P(class 1)=0.0630 -> 予測クラス: 0 (確信度: 93.70%)
#   - ASD_Left_20190819_1453_3-5.mp4: Logit: -0.8626 -> P(class 1)=0.2968 -> 予測クラス: 0 (確信度: 70.32%)
#   - HipOA_Right_20180806_2_867_4-4.mp4: Logit: -2.3351 -> P(class 1)=0.0883 -> 予測クラス: 0 (確信度: 91.17%)
#
# --- [バッチ 67] 推論中 ---
#   - ASD_Right_20200127_1708_2-7.mp4: Logit: -2.6182 -> P(class 1)=0.0680 -> 予測クラス: 0 (確信度: 93.20%)
#   - HipOA_Left_20180806_2_888_3-5.mp4: Logit: -2.8760 -> P(class 1)=0.0534 -> 予測クラス: 0 (確信度: 94.66%)
#   - HipOA_Left_20180806_2_858_2-5.mp4: Logit: -2.6254 -> P(class 1)=0.0675 -> 予測クラス: 0 (確信度: 93.25%)
#   - ASD_Left_20200127_1703_4-8.mp4: Logit: -3.5326 -> P(class 1)=0.0284 -> 予測クラス: 0 (確信度: 97.16%)
#
# --- [バッチ 68] 推論中 ---
#
# --- [バッチ 68] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1729_7-11.mp4: Logit: -4.5005 -> P(class 1)=0.0110 -> 予測クラス: 0 (確信度: 98.90%)
#   - ASD_Right_20190917_2014_2-3.mp4: Logit: -5.2432 -> P(class 1)=0.0053 -> 予測クラス: 0 (確信度: 99.47%)
#   - DHS_Left_20160927_1091_4-4.mp4: Logit: -4.0422 -> P(class 1)=0.0173 -> 予測クラス: 0 (確信度: 98.27%)
#   - LCS_Right_20211012_749_2-3.mp4: Logit: -4.2422 -> P(class 1)=0.0142 -> 予測クラス: 0 (確信度: 98.58%)
#
# --- [バッチ 69] 推論中 ---
#   - ASD_Right_20190917_2020_1-2.mp4: Logit: -4.2920 -> P(class 1)=0.0135 -> 予測クラス: 0 (確信度: 98.65%)
#   - ASD_Left_20200127_1733_10-10.mp4: Logit: -2.4501 -> P(class 1)=0.0794 -> 予測クラス: 0 (確信度: 92.06%)
#   - DHS_Left_20200528_1119_7-8.mp4: Logit: -3.6550 -> P(class 1)=0.0252 -> 予測クラス: 0 (確信度: 97.48%)
#   - ASD_Right_20210803_1410_2-7.mp4: Logit: -2.9398 -> P(class 1)=0.0502 -> 予測クラス: 0 (確信度: 94.98%)
#
# --- [バッチ 70] 推論中 ---
#   - LCS_Right_20211012_749_3-3.mp4: Logit: -5.1140 -> P(class 1)=0.0060 -> 予測クラス: 0 (確信度: 99.40%)
#   - ASD_Right_20190819_1448_1-4.mp4: Logit: -4.8140 -> P(class 1)=0.0081 -> 予測クラス: 0 (確信度: 99.19%)
#   - DHS_Right_20200528_1130_2-6.mp4: Logit: -4.6102 -> P(class 1)=0.0099 -> 予測クラス: 0 (確信度: 99.01%)
#   - ASD_Left_20180625_1_1421_6-6.mp4: Logit: -6.7890 -> P(class 1)=0.0011 -> 予測クラス: 0 (確信度: 99.89%)
#
# --- [バッチ 71] 推論中 ---
#
# --- [バッチ 71] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1693_2-9.mp4: Logit: -4.8802 -> P(class 1)=0.0075 -> 予測クラス: 0 (確信度: 99.25%)
#   - ASD_Right_20190917_1977_2-2.mp4: Logit: -5.4018 -> P(class 1)=0.0045 -> 予測クラス: 0 (確信度: 99.55%)
#   - DHS_Right_20160927_1092_3-3.mp4: Logit: -3.9555 -> P(class 1)=0.0188 -> 予測クラス: 0 (確信度: 98.12%)
#   - ASD_Left_20200127_1719_5-10.mp4: Logit: -4.0845 -> P(class 1)=0.0166 -> 予測クラス: 0 (確信度: 98.34%)
#
# --- [バッチ 72] 推論中 ---
#   - ASD_Left_20200127_1709_2-10.mp4: Logit: -5.5058 -> P(class 1)=0.0040 -> 予測クラス: 0 (確信度: 99.60%)
#   - DHS_Right_20160927_1082_1-4.mp4: Logit: -4.9259 -> P(class 1)=0.0072 -> 予測クラス: 0 (確信度: 99.28%)
#   - LCS_Right_20210706_841_3-4.mp4: Logit: -6.2627 -> P(class 1)=0.0019 -> 予測クラス: 0 (確信度: 99.81%)
#   - DHS_Left_20160927_1101_3-4.mp4: Logit: -5.8596 -> P(class 1)=0.0028 -> 予測クラス: 0 (確信度: 99.72%)
#
# --- [バッチ 73] 推論中 ---
#
# --- [バッチ 73] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1709_4-10.mp4: Logit: -3.8585 -> P(class 1)=0.0207 -> 予測クラス: 0 (確信度: 97.93%)
#   - DHS_Left_20160927_1063_4-5.mp4: Logit: -3.5764 -> P(class 1)=0.0272 -> 予測クラス: 0 (確信度: 97.28%)
#   - HipOA_Left_20180806_2_884_3-6.mp4: Logit: -4.9439 -> P(class 1)=0.0071 -> 予測クラス: 0 (確信度: 99.29%)
#   - ASD_Left_20200127_1709_10-10.mp4: Logit: -2.7026 -> P(class 1)=0.0628 -> 予測クラス: 0 (確信度: 93.72%)
#
# --- [バッチ 74] 推論中 ---
#   - ASD_Right_20200127_1720_3-7.mp4: Logit: -3.0400 -> P(class 1)=0.0457 -> 予測クラス: 0 (確信度: 95.43%)
#   - ASD_Right_20190917_1961_2-3.mp4: Logit: -2.4787 -> P(class 1)=0.0774 -> 予測クラス: 0 (確信度: 92.26%)
#   - ASD_Left_20190917_1995_2-4.mp4: Logit: -3.7732 -> P(class 1)=0.0225 -> 予測クラス: 0 (確信度: 97.75%)
#   - LCS_Right_20211012_755_2-3.mp4: Logit: -1.8582 -> P(class 1)=0.1349 -> 予測クラス: 0 (確信度: 86.51%)
#
# --- [バッチ 75] 推論中 ---
#   - DHS_Left_20200528_1128_7-8.mp4: Logit: -0.7356 -> P(class 1)=0.3240 -> 予測クラス: 0 (確信度: 67.60%)
#   - DHS_Right_20200528_1120_4-6.mp4: Logit: -3.2283 -> P(class 1)=0.0381 -> 予測クラス: 0 (確信度: 96.19%)
#   - ASD_Left_20210803_1411_5-14.mp4: Logit: -2.4742 -> P(class 1)=0.0777 -> 予測クラス: 0 (確信度: 92.23%)
#   - ASD_Left_20200127_1733_2-10.mp4: Logit: -3.2798 -> P(class 1)=0.0363 -> 予測クラス: 0 (確信度: 96.37%)
#
# --- [バッチ 76] 推論中 ---
#
# --- [バッチ 76] のCAMを生成・保存中... ---
#   - LCS_Right_20211012_765_2-3.mp4: Logit: -5.5601 -> P(class 1)=0.0038 -> 予測クラス: 0 (確信度: 99.62%)
#   - ASD_Right_20190819_1448_3-4.mp4: Logit: -3.6796 -> P(class 1)=0.0246 -> 予測クラス: 0 (確信度: 97.54%)
#   - ASD_Right_20180625_1_1426_2-4.mp4: Logit: -4.7122 -> P(class 1)=0.0089 -> 予測クラス: 0 (確信度: 99.11%)
#   - LCS_Right_20211012_763_3-3.mp4: Logit: -2.3647 -> P(class 1)=0.0859 -> 予測クラス: 0 (確信度: 91.41%)
#
# --- [バッチ 77] 推論中 ---
#   - HipOA_Left_20180806_2_852_1-5.mp4: Logit: -4.3736 -> P(class 1)=0.0124 -> 予測クラス: 0 (確信度: 98.76%)
#   - ASD_Right_20200127_1716_1-8.mp4: Logit: -7.4487 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - DHS_Right_20160927_1100_3-3.mp4: Logit: -4.3754 -> P(class 1)=0.0124 -> 予測クラス: 0 (確信度: 98.76%)
#   - ASD_Left_20210803_1411_13-14.mp4: Logit: -4.3553 -> P(class 1)=0.0127 -> 予測クラス: 0 (確信度: 98.73%)
#
# --- [バッチ 78] 推論中 ---
#
# --- [バッチ 78] のCAMを生成・保存中... ---
#   - HipOA_Right_20180806_2_881_3-3.mp4: Logit: -5.7828 -> P(class 1)=0.0031 -> 予測クラス: 0 (確信度: 99.69%)
#   - ASD_Right_20200127_1702_5-7.mp4: Logit: -6.4276 -> P(class 1)=0.0016 -> 予測クラス: 0 (確信度: 99.84%)
#   - ASD_Left_20210803_1411_9-14.mp4: Logit: -4.1707 -> P(class 1)=0.0152 -> 予測クラス: 0 (確信度: 98.48%)
#   - LCS_Left_20210706_842_3-6.mp4: Logit: -3.9484 -> P(class 1)=0.0189 -> 予測クラス: 0 (確信度: 98.11%)
#
# --- [バッチ 79] 推論中 ---
#   - ASD_Right_20200127_1694_2-6.mp4: Logit: -2.7479 -> P(class 1)=0.0602 -> 予測クラス: 0 (確信度: 93.98%)
#   - ASD_Left_20190917_2005_4-4.mp4: Logit: -5.1379 -> P(class 1)=0.0058 -> 予測クラス: 0 (確信度: 99.42%)
#   - ASD_Left_20180625_1_1423_6-6.mp4: Logit: 1.1747 -> P(class 1)=0.7640 -> 予測クラス: 1 (確信度: 76.40%)
#   - DHS_Left_20160927_1065_4-4.mp4: Logit: -1.6310 -> P(class 1)=0.1637 -> 予測クラス: 0 (確信度: 83.63%)
#
# --- [バッチ 80] 推論中 ---
#   - ASD_Right_20190917_1969_3-3.mp4: Logit: -3.6505 -> P(class 1)=0.0253 -> 予測クラス: 0 (確信度: 97.47%)
#   - ASD_Right_20200127_1696_4-7.mp4: Logit: -1.0198 -> P(class 1)=0.2651 -> 予測クラス: 0 (確信度: 73.49%)
#   - ASD_Left_20190819_1447_6-6.mp4: Logit: -2.6323 -> P(class 1)=0.0671 -> 予測クラス: 0 (確信度: 93.29%)
#   - ASD_Right_20190917_1988_2-2.mp4: Logit: -3.3211 -> P(class 1)=0.0349 -> 予測クラス: 0 (確信度: 96.51%)
#
# --- [バッチ 81] 推論中 ---
#
# --- [バッチ 81] のCAMを生成・保存中... ---
#   - ASD_Right_20210803_1410_3-7.mp4: Logit: -8.7034 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20190819_1447_4-6.mp4: Logit: -8.2551 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - DHS_Right_20160927_1068_2-3.mp4: Logit: -9.8021 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20190819_1443_5-6.mp4: Logit: -9.3119 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#
# --- [バッチ 82] 推論中 ---
#   - ASD_Left_20200127_1733_7-10.mp4: Logit: -5.3500 -> P(class 1)=0.0047 -> 予測クラス: 0 (確信度: 99.53%)
#   - ASD_Right_20190819_1446_4-4.mp4: Logit: -3.1359 -> P(class 1)=0.0416 -> 予測クラス: 0 (確信度: 95.84%)
#   - ASD_Right_20200127_1708_5-7.mp4: Logit: -4.2900 -> P(class 1)=0.0135 -> 予測クラス: 0 (確信度: 98.65%)
#   - ASD_Right_20190819_1452_3-3.mp4: Logit: -3.1612 -> P(class 1)=0.0407 -> 予測クラス: 0 (確信度: 95.93%)
#
# --- [バッチ 83] 推論中 ---
#
# --- [バッチ 83] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1962_3-4.mp4: Logit: -1.0144 -> P(class 1)=0.2661 -> 予測クラス: 0 (確信度: 73.39%)
#   - ASD_Right_20200127_1680_2-6.mp4: Logit: -3.6621 -> P(class 1)=0.0250 -> 予測クラス: 0 (確信度: 97.50%)
#   - ASD_Left_20190917_1982_3-4.mp4: Logit: -4.2680 -> P(class 1)=0.0138 -> 予測クラス: 0 (確信度: 98.62%)
#   - HipOA_Left_20180806_2_894_2-6.mp4: Logit: -0.8942 -> P(class 1)=0.2902 -> 予測クラス: 0 (確信度: 70.98%)
#
# --- [バッチ 84] 推論中 ---
#   - LCS_Left_20211012_764_3-5.mp4: Logit: -7.7219 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#   - ASD_Left_20200127_1731_7-10.mp4: Logit: -6.9717 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#   - ASD_Left_20190917_1983_2-4.mp4: Logit: -7.6592 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - DHS_Right_20160927_1094_3-3.mp4: Logit: -5.9627 -> P(class 1)=0.0026 -> 予測クラス: 0 (確信度: 99.74%)
#
# --- [バッチ 85] 推論中 ---
#   - LCS_Left_20211012_772_5-5.mp4: Logit: -6.4721 -> P(class 1)=0.0015 -> 予測クラス: 0 (確信度: 99.85%)
#   - ASD_Right_20190819_1454_1-3.mp4: Logit: -7.2035 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - ASD_Right_20190819_1436_1-3.mp4: Logit: -9.7147 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - DHS_Left_20160927_1093_3-4.mp4: Logit: -8.9563 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#
# --- [バッチ 86] 推論中 ---
#
# --- [バッチ 86] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1960_3-4.mp4: Logit: -3.3757 -> P(class 1)=0.0331 -> 予測クラス: 0 (確信度: 96.69%)
#   - DHS_Right_20200528_1122_2-5.mp4: Logit: -5.0846 -> P(class 1)=0.0062 -> 予測クラス: 0 (確信度: 99.38%)
#   - HipOA_Left_20180806_2_896_4-6.mp4: Logit: -2.9073 -> P(class 1)=0.0518 -> 予測クラス: 0 (確信度: 94.82%)
#   - LCS_Left_20211012_742_2-5.mp4: Logit: -1.6993 -> P(class 1)=0.1546 -> 予測クラス: 0 (確信度: 84.54%)
#
# --- [バッチ 87] 推論中 ---
#   - ASD_Right_20200127_1718_4-8.mp4: Logit: -4.2352 -> P(class 1)=0.0143 -> 予測クラス: 0 (確信度: 98.57%)
#   - ASD_Right_20190917_1971_1-3.mp4: Logit: -6.0600 -> P(class 1)=0.0023 -> 予測クラス: 0 (確信度: 99.77%)
#   - HipOA_Right_20180806_2_895_1-4.mp4: Logit: -3.3683 -> P(class 1)=0.0333 -> 予測クラス: 0 (確信度: 96.67%)
#   - ASD_Left_20190917_1974_4-4.mp4: Logit: -3.5014 -> P(class 1)=0.0293 -> 予測クラス: 0 (確信度: 97.07%)
#
# --- [バッチ 88] 推論中 ---
#
# --- [バッチ 88] のCAMを生成・保存中... ---
#   - ASD_Right_20190819_1434_2-4.mp4: Logit: -4.4191 -> P(class 1)=0.0119 -> 予測クラス: 0 (確信度: 98.81%)
#   - DHS_Left_20200528_1128_6-8.mp4: Logit: -5.2318 -> P(class 1)=0.0053 -> 予測クラス: 0 (確信度: 99.47%)
#   - ASD_Left_20190917_2015_1-4.mp4: Logit: -4.4472 -> P(class 1)=0.0116 -> 予測クラス: 0 (確信度: 98.84%)
#   - ASD_Left_20200127_1731_8-10.mp4: Logit: -5.1610 -> P(class 1)=0.0057 -> 予測クラス: 0 (確信度: 99.43%)
#
# --- [バッチ 89] 推論中 ---
#   - ASD_Right_20190917_2014_1-3.mp4: Logit: -2.5408 -> P(class 1)=0.0730 -> 予測クラス: 0 (確信度: 92.70%)
#   - ASD_Right_20200127_1686_4-6.mp4: Logit: -3.0007 -> P(class 1)=0.0474 -> 予測クラス: 0 (確信度: 95.26%)
#   - HipOA_Right_20180806_2_895_4-4.mp4: Logit: -4.1125 -> P(class 1)=0.0161 -> 予測クラス: 0 (確信度: 98.39%)
#   - LCS_Right_20211012_781_2-3.mp4: Logit: -1.1922 -> P(class 1)=0.2329 -> 予測クラス: 0 (確信度: 76.71%)
#
# --- [バッチ 90] 推論中 ---
#   - LCS_Right_20211012_755_3-3.mp4: Logit: -4.6816 -> P(class 1)=0.0092 -> 予測クラス: 0 (確信度: 99.08%)
#   - HipOA_Left_20180806_2_874_3-5.mp4: Logit: -3.0254 -> P(class 1)=0.0463 -> 予測クラス: 0 (確信度: 95.37%)
#   - LCS_Left_20211012_740_4-5.mp4: Logit: -4.4757 -> P(class 1)=0.0113 -> 予測クラス: 0 (確信度: 98.87%)
#   - HipOA_Left_20180806_2_880_4-5.mp4: Logit: -5.8944 -> P(class 1)=0.0027 -> 予測クラス: 0 (確信度: 99.73%)
#
# --- [バッチ 91] 推論中 ---
#
# --- [バッチ 91] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1130_6-6.mp4: Logit: -2.0458 -> P(class 1)=0.1145 -> 予測クラス: 0 (確信度: 88.55%)
#   - ASD_Left_20200127_1697_7-10.mp4: Logit: -2.4959 -> P(class 1)=0.0761 -> 予測クラス: 0 (確信度: 92.39%)
#   - ASD_Right_20200127_1702_2-7.mp4: Logit: -2.2850 -> P(class 1)=0.0924 -> 予測クラス: 0 (確信度: 90.76%)
#   - ASD_Right_20200127_1686_6-6.mp4: Logit: -1.9335 -> P(class 1)=0.1264 -> 予測クラス: 0 (確信度: 87.36%)
#
# --- [バッチ 92] 推論中 ---
#   - ASD_Right_20200127_1720_1-7.mp4: Logit: -0.4467 -> P(class 1)=0.3902 -> 予測クラス: 0 (確信度: 60.98%)
#   - HipOA_Left_20180806_2_856_5-5.mp4: Logit: -2.4271 -> P(class 1)=0.0811 -> 予測クラス: 0 (確信度: 91.89%)
#   - ASD_Right_20200127_1690_2-7.mp4: Logit: -1.8343 -> P(class 1)=0.1377 -> 予測クラス: 0 (確信度: 86.23%)
#   - ASD_Right_20200127_1686_2-6.mp4: Logit: -3.2947 -> P(class 1)=0.0358 -> 予測クラス: 0 (確信度: 96.42%)
#
# --- [バッチ 93] 推論中 ---
#
# --- [バッチ 93] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1681_8-9.mp4: Logit: -4.4570 -> P(class 1)=0.0115 -> 予測クラス: 0 (確信度: 98.85%)
#   - ASD_Right_20200127_1710_5-7.mp4: Logit: -4.6662 -> P(class 1)=0.0093 -> 予測クラス: 0 (確信度: 99.07%)
#   - ASD_Right_20200127_1684_5-6.mp4: Logit: -4.8086 -> P(class 1)=0.0081 -> 予測クラス: 0 (確信度: 99.19%)
#   - ASD_Right_20190819_1430_1-4.mp4: Logit: -3.1219 -> P(class 1)=0.0422 -> 予測クラス: 0 (確信度: 95.78%)
#
# --- [バッチ 94] 推論中 ---
#   - ASD_Left_20210323_2041_3-9.mp4: Logit: -5.5291 -> P(class 1)=0.0040 -> 予測クラス: 0 (確信度: 99.60%)
#   - DHS_Right_20200528_1136_5-6.mp4: Logit: -4.8211 -> P(class 1)=0.0080 -> 予測クラス: 0 (確信度: 99.20%)
#   - HipOA_Right_20180806_2_891_3-4.mp4: Logit: -5.0831 -> P(class 1)=0.0062 -> 予測クラス: 0 (確信度: 99.38%)
#   - DHS_Left_20160927_1077_1-5.mp4: Logit: -4.3098 -> P(class 1)=0.0133 -> 予測クラス: 0 (確信度: 98.67%)
#
# --- [バッチ 95] 推論中 ---
#   - HipOA_Left_20180806_2_886_4-6.mp4: Logit: -8.0087 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - LCS_Left_20211012_774_3-5.mp4: Logit: -8.0198 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - ASD_Left_20200127_1713_6-10.mp4: Logit: -8.0085 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - HipOA_Right_20180806_2_853_4-4.mp4: Logit: -6.5127 -> P(class 1)=0.0015 -> 予測クラス: 0 (確信度: 99.85%)
#
# --- [バッチ 96] 推論中 ---
#
# --- [バッチ 96] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1719_4-10.mp4: Logit: -2.8998 -> P(class 1)=0.0522 -> 予測クラス: 0 (確信度: 94.78%)
#   - DHS_Right_20200528_1131_2-6.mp4: Logit: -4.2795 -> P(class 1)=0.0137 -> 予測クラス: 0 (確信度: 98.63%)
#   - ASD_Left_20190917_1995_4-4.mp4: Logit: -2.8874 -> P(class 1)=0.0528 -> 予測クラス: 0 (確信度: 94.72%)
#   - HipOA_Left_20180806_2_896_6-6.mp4: Logit: -4.2889 -> P(class 1)=0.0135 -> 予測クラス: 0 (確信度: 98.65%)
#
# --- [バッチ 97] 推論中 ---
#   - LCS_Right_20211012_741_2-3.mp4: Logit: -4.3130 -> P(class 1)=0.0132 -> 予測クラス: 0 (確信度: 98.68%)
#   - ASD_Right_20190917_1975_1-3.mp4: Logit: -5.9564 -> P(class 1)=0.0026 -> 予測クラス: 0 (確信度: 99.74%)
#   - ASD_Left_20200127_1725_4-10.mp4: Logit: -3.6055 -> P(class 1)=0.0265 -> 予測クラス: 0 (確信度: 97.35%)
#   - DHS_Right_20200528_1135_1-6.mp4: Logit: -4.4171 -> P(class 1)=0.0119 -> 予測クラス: 0 (確信度: 98.81%)
#
# --- [バッチ 98] 推論中 ---
#
# --- [バッチ 98] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1974_2-4.mp4: Logit: -4.0022 -> P(class 1)=0.0179 -> 予測クラス: 0 (確信度: 98.21%)
#   - DHS_Left_20200528_1121_5-8.mp4: Logit: -4.2709 -> P(class 1)=0.0138 -> 予測クラス: 0 (確信度: 98.62%)
#   - HipOA_Right_20180806_2_893_4-4.mp4: Logit: -1.9000 -> P(class 1)=0.1301 -> 予測クラス: 0 (確信度: 86.99%)
#   - HipOA_Right_20180806_2_849_1-3.mp4: Logit: -2.9501 -> P(class 1)=0.0497 -> 予測クラス: 0 (確信度: 95.03%)
#
# --- [バッチ 99] 推論中 ---
#   - ASD_Right_20190917_1977_1-2.mp4: Logit: -2.8847 -> P(class 1)=0.0529 -> 予測クラス: 0 (確信度: 94.71%)
#   - ASD_Left_20200127_1717_10-10.mp4: Logit: -3.5453 -> P(class 1)=0.0281 -> 予測クラス: 0 (確信度: 97.19%)
#   - DHS_Right_20160927_1064_2-3.mp4: Logit: -1.1356 -> P(class 1)=0.2431 -> 予測クラス: 0 (確信度: 75.69%)
#   - DHS_Right_20160927_1112_2-3.mp4: Logit: -2.1478 -> P(class 1)=0.1045 -> 予測クラス: 0 (確信度: 89.55%)
#
# --- [バッチ 100] 推論中 ---
#   - ASD_Right_20200127_1702_7-7.mp4: Logit: 0.2091 -> P(class 1)=0.5521 -> 予測クラス: 1 (確信度: 55.21%)
#   - ASD_Right_20200127_1718_1-8.mp4: Logit: -0.7821 -> P(class 1)=0.3139 -> 予測クラス: 0 (確信度: 68.61%)
#   - HipOA_Left_20180806_2_872_5-6.mp4: Logit: 2.8102 -> P(class 1)=0.9432 -> 予測クラス: 1 (確信度: 94.32%)
#   - ASD_Right_20190917_1992_2-2.mp4: Logit: 1.7396 -> P(class 1)=0.8506 -> 予測クラス: 1 (確信度: 85.06%)
#
# --- [バッチ 101] 推論中 ---
#
# --- [バッチ 101] のCAMを生成・保存中... ---
#   - DHS_Left_20160927_1085_2-4.mp4: Logit: 3.4867 -> P(class 1)=0.9703 -> 予測クラス: 1 (確信度: 97.03%)
#   - LCS_Left_20211012_770_4-5.mp4: Logit: 3.0663 -> P(class 1)=0.9555 -> 予測クラス: 1 (確信度: 95.55%)
#   - ASD_Right_20200127_1724_4-7.mp4: Logit: 2.3175 -> P(class 1)=0.9103 -> 予測クラス: 1 (確信度: 91.03%)
#   - DHS_Right_20200528_1122_1-5.mp4: Logit: 3.4234 -> P(class 1)=0.9684 -> 予測クラス: 1 (確信度: 96.84%)
#
# --- [バッチ 102] 推論中 ---
#   - ASD_Left_20180625_1_1429_2-6.mp4: Logit: -7.5544 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Left_20210803_1411_7-14.mp4: Logit: -9.5457 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - ASD_Left_20200127_1695_8-10.mp4: Logit: -8.5247 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20190819_1437_4-5.mp4: Logit: -7.8027 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#
# --- [バッチ 103] 推論中 ---
#
# --- [バッチ 103] のCAMを生成・保存中... ---
#   - ASD_Right_20190819_1436_2-3.mp4: Logit: -5.2410 -> P(class 1)=0.0053 -> 予測クラス: 0 (確信度: 99.47%)
#   - ASD_Left_20200127_1697_10-10.mp4: Logit: -5.4683 -> P(class 1)=0.0042 -> 予測クラス: 0 (確信度: 99.58%)
#   - ASD_Right_20200127_1696_6-7.mp4: Logit: -4.7107 -> P(class 1)=0.0089 -> 予測クラス: 0 (確信度: 99.11%)
#   - DHS_Right_20160927_1090_2-3.mp4: Logit: -6.2531 -> P(class 1)=0.0019 -> 予測クラス: 0 (確信度: 99.81%)
#
# --- [バッチ 104] 推論中 ---
#   - ASD_Right_20200127_1690_4-7.mp4: Logit: -2.9579 -> P(class 1)=0.0494 -> 予測クラス: 0 (確信度: 95.06%)
#   - DHS_Left_20160927_1095_1-4.mp4: Logit: -0.7869 -> P(class 1)=0.3128 -> 予測クラス: 0 (確信度: 68.72%)
#   - DHS_Left_20160927_1089_4-5.mp4: Logit: -2.2463 -> P(class 1)=0.0957 -> 予測クラス: 0 (確信度: 90.43%)
#   - ASD_Right_20190819_1434_1-4.mp4: Logit: -0.4614 -> P(class 1)=0.3866 -> 予測クラス: 0 (確信度: 61.34%)
#
# --- [バッチ 105] 推論中 ---
#   - HipOA_Left_20180806_2_862_1-5.mp4: Logit: -7.3179 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - ASD_Left_20190917_1989_3-3.mp4: Logit: -5.9361 -> P(class 1)=0.0026 -> 予測クラス: 0 (確信度: 99.74%)
#   - ASD_Left_20190819_1455_2-5.mp4: Logit: -5.6417 -> P(class 1)=0.0035 -> 予測クラス: 0 (確信度: 99.65%)
#   - ASD_Left_20190819_1431_2-5.mp4: Logit: -6.0200 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#
# --- [バッチ 106] 推論中 ---
#
# --- [バッチ 106] のCAMを生成・保存中... ---
#   - LCS_Left_20211012_744_2-5.mp4: Logit: -9.1089 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#   - HipOA_Right_20180806_2_857_2-3.mp4: Logit: -8.6559 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20200127_1719_8-10.mp4: Logit: -8.0174 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - DHS_Left_20200528_1128_3-8.mp4: Logit: -6.6705 -> P(class 1)=0.0013 -> 予測クラス: 0 (確信度: 99.87%)
#
# --- [バッチ 107] 推論中 ---
#   - DHS_Left_20160927_1081_3-4.mp4: Logit: 1.4508 -> P(class 1)=0.8101 -> 予測クラス: 1 (確信度: 81.01%)
#   - LCS_Right_20211012_773_2-3.mp4: Logit: 0.7164 -> P(class 1)=0.6718 -> 予測クラス: 1 (確信度: 67.18%)
#   - ASD_Left_20200127_1683_1-8.mp4: Logit: 1.1898 -> P(class 1)=0.7667 -> 予測クラス: 1 (確信度: 76.67%)
#   - DHS_Right_20200528_1122_5-5.mp4: Logit: 1.4895 -> P(class 1)=0.8160 -> 予測クラス: 1 (確信度: 81.60%)
#
# --- [バッチ 108] 推論中 ---
#
# --- [バッチ 108] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1124_1-6.mp4: Logit: -7.4698 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - LCS_Left_20211012_780_5-5.mp4: Logit: -8.3834 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#   - ASD_Left_20190819_1441_2-5.mp4: Logit: -8.0995 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - HipOA_Left_20180806_2_888_5-5.mp4: Logit: -4.7784 -> P(class 1)=0.0083 -> 予測クラス: 0 (確信度: 99.17%)
#
# --- [バッチ 109] 推論中 ---
#   - HipOA_Left_20180806_2_888_4-5.mp4: Logit: -5.8463 -> P(class 1)=0.0029 -> 予測クラス: 0 (確信度: 99.71%)
#   - HipOA_Left_20180806_2_894_5-6.mp4: Logit: -7.8770 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#   - ASD_Left_20200127_1717_5-10.mp4: Logit: -6.0292 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#   - ASD_Right_20200127_1706_3-7.mp4: Logit: -7.7831 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#
# --- [バッチ 110] 推論中 ---
#   - LCS_Right_20211012_747_2-3.mp4: Logit: -5.2517 -> P(class 1)=0.0052 -> 予測クラス: 0 (確信度: 99.48%)
#   - ASD_Left_20200127_1711_3-10.mp4: Logit: -4.4504 -> P(class 1)=0.0115 -> 予測クラス: 0 (確信度: 98.85%)
#   - ASD_Left_20200127_1719_7-10.mp4: Logit: -3.8857 -> P(class 1)=0.0201 -> 予測クラス: 0 (確信度: 97.99%)
#   - ASD_Left_20210803_1411_8-14.mp4: Logit: -5.5064 -> P(class 1)=0.0040 -> 予測クラス: 0 (確信度: 99.60%)
#
# --- [バッチ 111] 推論中 ---
#
# --- [バッチ 111] のCAMを生成・保存中... ---
#   - ASD_Left_20180625_1_1427_3-6.mp4: Logit: -5.2090 -> P(class 1)=0.0054 -> 予測クラス: 0 (確信度: 99.46%)
#   - ASD_Right_20190917_1996_2-3.mp4: Logit: -4.6667 -> P(class 1)=0.0093 -> 予測クラス: 0 (確信度: 99.07%)
#   - ASD_Right_20200127_1698_1-6.mp4: Logit: -6.9246 -> P(class 1)=0.0010 -> 予測クラス: 0 (確信度: 99.90%)
#   - DHS_Right_20200528_1132_3-6.mp4: Logit: -6.2258 -> P(class 1)=0.0020 -> 予測クラス: 0 (確信度: 99.80%)
#
# --- [バッチ 112] 推論中 ---
# ...
#   - ASD_Left_20200127_1689_1-9.mp4: Logit: -8.2418 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - HipOA_Right_20180806_2_855_3-3.mp4: Logit: -8.7690 -> P(class 1)=0.0002 -> 予測クラス: 0 (確信度: 99.98%)
#
# --- [バッチ 397] 推論中 ---
#   - HipOA_Right_20180806_2_853_2-4.mp4: Logit: -5.3838 -> P(class 1)=0.0046 -> 予測クラス: 0 (確信度: 99.54%)
#   - ASD_Left_20200127_1713_5-10.mp4: Logit: -4.2062 -> P(class 1)=0.0147 -> 予測クラス: 0 (確信度: 98.53%)
#   - ASD_Right_20200127_1680_3-6.mp4: Logit: -3.9546 -> P(class 1)=0.0188 -> 予測クラス: 0 (確信度: 98.12%)
#   - HipOA_Right_20180806_2_865_4-4.mp4: Logit: -5.9193 -> P(class 1)=0.0027 -> 予測クラス: 0 (確信度: 99.73%)
#
# --- [バッチ 398] 推論中 ---
#
# --- [バッチ 398] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1723_6-11.mp4: Logit: -3.7637 -> P(class 1)=0.0227 -> 予測クラス: 0 (確信度: 97.73%)
#   - LCS_Left_20211012_768_2-4.mp4: Logit: -4.1294 -> P(class 1)=0.0158 -> 予測クラス: 0 (確信度: 98.42%)
#   - DHS_Right_20160927_1068_1-3.mp4: Logit: -4.5485 -> P(class 1)=0.0105 -> 予測クラス: 0 (確信度: 98.95%)
#   - ASD_Left_20190819_1441_3-5.mp4: Logit: -4.8476 -> P(class 1)=0.0078 -> 予測クラス: 0 (確信度: 99.22%)
#
# --- [バッチ 399] 推論中 ---
#   - LCS_Left_20211012_748_4-5.mp4: Logit: -7.6481 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Left_20190917_1995_3-4.mp4: Logit: -8.1481 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - DHS_Right_20200528_1124_5-6.mp4: Logit: -8.1942 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - ASD_Left_20190917_1960_4-4.mp4: Logit: -9.2063 -> P(class 1)=0.0001 -> 予測クラス: 0 (確信度: 99.99%)
#
# --- [バッチ 400] 推論中 ---
#   - DHS_Right_20160927_1080_1-3.mp4: Logit: 2.5656 -> P(class 1)=0.9286 -> 予測クラス: 1 (確信度: 92.86%)
#   - LCS_Left_20211012_772_3-5.mp4: Logit: 1.9017 -> P(class 1)=0.8701 -> 予測クラス: 1 (確信度: 87.01%)
#   - ASD_Right_20190819_1440_3-4.mp4: Logit: 0.3561 -> P(class 1)=0.5881 -> 予測クラス: 1 (確信度: 58.81%)
#   - HipOA_Left_20180806_2_886_1-6.mp4: Logit: 0.8537 -> P(class 1)=0.7013 -> 予測クラス: 1 (確信度: 70.13%)
#
# --- [バッチ 401] 推論中 ---
#
# --- [バッチ 401] のCAMを生成・保存中... ---
#   - ASD_Right_20190917_1961_1-3.mp4: Logit: -3.7861 -> P(class 1)=0.0222 -> 予測クラス: 0 (確信度: 97.78%)
#   - ASD_Left_20190917_1980_4-4.mp4: Logit: -3.0192 -> P(class 1)=0.0466 -> 予測クラス: 0 (確信度: 95.34%)
#   - ASD_Right_20210803_1410_5-7.mp4: Logit: -4.0920 -> P(class 1)=0.0164 -> 予測クラス: 0 (確信度: 98.36%)
#   - ASD_Left_20180625_1_1421_4-6.mp4: Logit: -3.1956 -> P(class 1)=0.0393 -> 予測クラス: 0 (確信度: 96.07%)
#
# --- [バッチ 402] 推論中 ---
#   - ASD_Left_20200127_1727_2-10.mp4: Logit: -2.3560 -> P(class 1)=0.0866 -> 予測クラス: 0 (確信度: 91.34%)
#   - ASD_Left_20200127_1723_9-11.mp4: Logit: -5.2494 -> P(class 1)=0.0052 -> 予測クラス: 0 (確信度: 99.48%)
#   - DHS_Left_20160927_1073_2-5.mp4: Logit: -3.1208 -> P(class 1)=0.0423 -> 予測クラス: 0 (確信度: 95.77%)
#   - DHS_Left_20160927_1073_1-5.mp4: Logit: -2.8095 -> P(class 1)=0.0568 -> 予測クラス: 0 (確信度: 94.32%)
#
# --- [バッチ 403] 推論中 ---
#
# --- [バッチ 403] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1711_5-10.mp4: Logit: -4.5967 -> P(class 1)=0.0100 -> 予測クラス: 0 (確信度: 99.00%)
#   - DHS_Right_20200528_1136_2-6.mp4: Logit: -4.9494 -> P(class 1)=0.0070 -> 予測クラス: 0 (確信度: 99.30%)
#   - DHS_Right_20200528_1120_2-6.mp4: Logit: -5.1180 -> P(class 1)=0.0060 -> 予測クラス: 0 (確信度: 99.40%)
#   - DHS_Left_20200528_1128_1-8.mp4: Logit: -4.7341 -> P(class 1)=0.0087 -> 予測クラス: 0 (確信度: 99.13%)
#
# --- [バッチ 404] 推論中 ---
#   - ASD_Right_20190819_1442_2-3.mp4: Logit: -4.7372 -> P(class 1)=0.0087 -> 予測クラス: 0 (確信度: 99.13%)
#   - DHS_Right_20200528_1137_7-7.mp4: Logit: -5.9941 -> P(class 1)=0.0025 -> 予測クラス: 0 (確信度: 99.75%)
#   - DHS_Left_20160927_1083_1-4.mp4: Logit: -5.2455 -> P(class 1)=0.0052 -> 予測クラス: 0 (確信度: 99.48%)
#   - ASD_Left_20200127_1729_10-11.mp4: Logit: -6.2684 -> P(class 1)=0.0019 -> 予測クラス: 0 (確信度: 99.81%)
#
# --- [バッチ 405] 推論中 ---
#   - HipOA_Left_20180806_2_868_3-6.mp4: Logit: -5.9185 -> P(class 1)=0.0027 -> 予測クラス: 0 (確信度: 99.73%)
#   - LCS_Left_20211012_762_4-5.mp4: Logit: -7.2702 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - ASD_Left_20200127_1681_1-9.mp4: Logit: -8.2468 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - HipOA_Right_20180806_2_851_1-3.mp4: Logit: -7.5842 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#
# --- [バッチ 406] 推論中 ---
#
# --- [バッチ 406] のCAMを生成・保存中... ---
#   - ASD_Right_20200127_1710_1-7.mp4: Logit: -0.3335 -> P(class 1)=0.4174 -> 予測クラス: 0 (確信度: 58.26%)
#   - HipOA_Left_20180806_2_872_1-6.mp4: Logit: -0.7402 -> P(class 1)=0.3230 -> 予測クラス: 0 (確信度: 67.70%)
#   - DHS_Left_20160927_1101_4-4.mp4: Logit: -2.2487 -> P(class 1)=0.0955 -> 予測クラス: 0 (確信度: 90.45%)
#   - HipOA_Right_20180806_2_883_1-4.mp4: Logit: -0.9594 -> P(class 1)=0.2770 -> 予測クラス: 0 (確信度: 72.30%)
#
# --- [バッチ 407] 推論中 ---
#   - LCS_Right_20211012_757_3-3.mp4: Logit: -4.9974 -> P(class 1)=0.0067 -> 予測クラス: 0 (確信度: 99.33%)
#   - DHS_Left_20160927_1081_4-4.mp4: Logit: -6.0430 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#   - ASD_Left_20190819_1439_3-6.mp4: Logit: -4.3368 -> P(class 1)=0.0129 -> 予測クラス: 0 (確信度: 98.71%)
#   - ASD_Left_20210803_1409_2-10.mp4: Logit: -5.0318 -> P(class 1)=0.0065 -> 予測クラス: 0 (確信度: 99.35%)
#
# --- [バッチ 408] 推論中 ---
#
# --- [バッチ 408] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1691_9-10.mp4: Logit: -1.5411 -> P(class 1)=0.1764 -> 予測クラス: 0 (確信度: 82.36%)
#   - LCS_Left_20211012_766_4-5.mp4: Logit: -0.0584 -> P(class 1)=0.4854 -> 予測クラス: 0 (確信度: 51.46%)
#   - ASD_Right_20190819_1438_4-4.mp4: Logit: -1.8666 -> P(class 1)=0.1339 -> 予測クラス: 0 (確信度: 86.61%)
#   - DHS_Left_20160927_1081_1-4.mp4: Logit: -1.7224 -> P(class 1)=0.1516 -> 予測クラス: 0 (確信度: 84.84%)
#
# --- [バッチ 409] 推論中 ---
#   - ASD_Left_20190917_1972_1-4.mp4: Logit: -3.7038 -> P(class 1)=0.0240 -> 予測クラス: 0 (確信度: 97.60%)
#   - LCS_Left_20211012_768_1-4.mp4: Logit: -4.1445 -> P(class 1)=0.0156 -> 予測クラス: 0 (確信度: 98.44%)
#   - ASD_Right_20190917_2010_1-3.mp4: Logit: -2.2636 -> P(class 1)=0.0942 -> 予測クラス: 0 (確信度: 90.58%)
#   - HipOA_Right_20180806_2_869_1-4.mp4: Logit: -1.8981 -> P(class 1)=0.1303 -> 予測クラス: 0 (確信度: 86.97%)
#
# --- [バッチ 410] 推論中 ---
#   - HipOA_Left_20180806_2_884_4-6.mp4: Logit: -7.5304 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - ASD_Right_20200127_1684_6-6.mp4: Logit: -8.0653 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - LCS_Left_20211012_772_4-5.mp4: Logit: -7.2845 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - ASD_Right_20200127_1722_3-8.mp4: Logit: -7.0134 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#
# --- [バッチ 411] 推論中 ---
#
# --- [バッチ 411] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1697_3-10.mp4: Logit: -6.0237 -> P(class 1)=0.0024 -> 予測クラス: 0 (確信度: 99.76%)
#   - ASD_Left_20200127_1703_3-8.mp4: Logit: -4.9836 -> P(class 1)=0.0068 -> 予測クラス: 0 (確信度: 99.32%)
#   - HipOA_Left_20180806_2_860_3-5.mp4: Logit: -4.4162 -> P(class 1)=0.0119 -> 予測クラス: 0 (確信度: 98.81%)
#   - DHS_Right_20160927_1066_1-4.mp4: Logit: -4.0002 -> P(class 1)=0.0180 -> 予測クラス: 0 (確信度: 98.20%)
#
# --- [バッチ 412] 推論中 ---
#   - ASD_Left_20210323_2041_7-9.mp4: Logit: -8.2503 -> P(class 1)=0.0003 -> 予測クラス: 0 (確信度: 99.97%)
#   - ASD_Left_20200127_1697_8-10.mp4: Logit: -6.5441 -> P(class 1)=0.0014 -> 予測クラス: 0 (確信度: 99.86%)
#   - ASD_Left_20190819_1441_1-5.mp4: Logit: -6.8288 -> P(class 1)=0.0011 -> 予測クラス: 0 (確信度: 99.89%)
#   - DHS_Right_20200528_1130_5-6.mp4: Logit: -5.7820 -> P(class 1)=0.0031 -> 予測クラス: 0 (確信度: 99.69%)
#
# --- [バッチ 413] 推論中 ---
#
# --- [バッチ 413] のCAMを生成・保存中... ---
#   - ASD_Right_20180625_1_1424_3-4.mp4: Logit: -5.7518 -> P(class 1)=0.0032 -> 予測クラス: 0 (確信度: 99.68%)
#   - ASD_Left_20210323_2043_9-10.mp4: Logit: -6.3527 -> P(class 1)=0.0017 -> 予測クラス: 0 (確信度: 99.83%)
#   - ASD_Left_20190917_2007_3-4.mp4: Logit: -7.4958 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - HipOA_Right_20180806_2_869_4-4.mp4: Logit: -7.3510 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#
# --- [バッチ 414] 推論中 ---
#   - ASD_Right_20200127_1708_4-7.mp4: Logit: -4.8808 -> P(class 1)=0.0075 -> 予測クラス: 0 (確信度: 99.25%)
#   - ASD_Right_20200127_1708_3-7.mp4: Logit: -3.2249 -> P(class 1)=0.0382 -> 予測クラス: 0 (確信度: 96.18%)
#   - ASD_Left_20210803_1411_10-14.mp4: Logit: -3.4916 -> P(class 1)=0.0296 -> 予測クラス: 0 (確信度: 97.04%)
#   - DHS_Right_20160927_1064_3-3.mp4: Logit: -1.4771 -> P(class 1)=0.1859 -> 予測クラス: 0 (確信度: 81.41%)
#
# --- [バッチ 415] 推論中 ---
#   - ASD_Left_20190819_1453_5-5.mp4: Logit: -4.5888 -> P(class 1)=0.0101 -> 予測クラス: 0 (確信度: 98.99%)
#   - ASD_Left_20210803_1409_9-10.mp4: Logit: -5.0258 -> P(class 1)=0.0065 -> 予測クラス: 0 (確信度: 99.35%)
#   - ASD_Right_20200127_1716_8-8.mp4: Logit: -5.7663 -> P(class 1)=0.0031 -> 予測クラス: 0 (確信度: 99.69%)
#   - ASD_Left_20190917_1991_2-4.mp4: Logit: -5.3445 -> P(class 1)=0.0048 -> 予測クラス: 0 (確信度: 99.52%)
#
# --- [バッチ 416] 推論中 ---
#
# --- [バッチ 416] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1960_2-4.mp4: Logit: -4.0210 -> P(class 1)=0.0176 -> 予測クラス: 0 (確信度: 98.24%)
#   - DHS_Left_20160927_1095_4-4.mp4: Logit: -3.2407 -> P(class 1)=0.0377 -> 予測クラス: 0 (確信度: 96.23%)
#   - LCS_Right_20211012_751_1-4.mp4: Logit: -2.7150 -> P(class 1)=0.0621 -> 予測クラス: 0 (確信度: 93.79%)
#   - ASD_Left_20200127_1723_2-11.mp4: Logit: -3.1808 -> P(class 1)=0.0399 -> 予測クラス: 0 (確信度: 96.01%)
#
# --- [バッチ 417] 推論中 ---
#   - ASD_Right_20200127_1728_7-7.mp4: Logit: -3.6448 -> P(class 1)=0.0255 -> 予測クラス: 0 (確信度: 97.45%)
#   - ASD_Right_20200127_1694_5-6.mp4: Logit: -0.9412 -> P(class 1)=0.2807 -> 予測クラス: 0 (確信度: 71.93%)
#   - HipOA_Left_20180806_2_890_5-6.mp4: Logit: -0.4962 -> P(class 1)=0.3784 -> 予測クラス: 0 (確信度: 62.16%)
#   - ASD_Right_20190917_1954_3-3.mp4: Logit: -2.6499 -> P(class 1)=0.0660 -> 予測クラス: 0 (確信度: 93.40%)
#
# --- [バッチ 418] 推論中 ---
#
# --- [バッチ 418] のCAMを生成・保存中... ---
#   - LCS_Left_20211012_762_3-5.mp4: Logit: -7.6677 -> P(class 1)=0.0005 -> 予測クラス: 0 (確信度: 99.95%)
#   - HipOA_Left_20180806_2_850_1-5.mp4: Logit: -7.4954 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - ASD_Right_20200127_1688_7-7.mp4: Logit: -7.1265 -> P(class 1)=0.0008 -> 予測クラス: 0 (確信度: 99.92%)
#   - LCS_Right_20210706_839_2-5.mp4: Logit: -7.0282 -> P(class 1)=0.0009 -> 予測クラス: 0 (確信度: 99.91%)
#
# --- [バッチ 419] 推論中 ---
#   - ASD_Left_20200127_1707_9-10.mp4: Logit: -5.0458 -> P(class 1)=0.0064 -> 予測クラス: 0 (確信度: 99.36%)
#   - ASD_Right_20190819_1446_1-4.mp4: Logit: -3.0814 -> P(class 1)=0.0439 -> 予測クラス: 0 (確信度: 95.61%)
#   - ASD_Right_20210323_2040_5-7.mp4: Logit: -2.7509 -> P(class 1)=0.0600 -> 予測クラス: 0 (確信度: 94.00%)
#   - ASD_Left_20200127_1689_8-9.mp4: Logit: -1.1368 -> P(class 1)=0.2429 -> 予測クラス: 0 (確信度: 75.71%)
#
# --- [バッチ 420] 推論中 ---
#   - ASD_Left_20200127_1725_1-10.mp4: Logit: -1.9192 -> P(class 1)=0.1279 -> 予測クラス: 0 (確信度: 87.21%)
#   - HipOA_Left_20180806_2_884_5-6.mp4: Logit: -5.1407 -> P(class 1)=0.0058 -> 予測クラス: 0 (確信度: 99.42%)
#   - ASD_Left_20200127_1695_3-10.mp4: Logit: -2.4542 -> P(class 1)=0.0791 -> 予測クラス: 0 (確信度: 92.09%)
#   - ASD_Left_20190819_1433_4-5.mp4: Logit: -4.4983 -> P(class 1)=0.0110 -> 予測クラス: 0 (確信度: 98.90%)
#
# --- [バッチ 421] 推論中 ---
#
# --- [バッチ 421] のCAMを生成・保存中... ---
#   - DHS_Right_20200528_1139_4-6.mp4: Logit: -3.0637 -> P(class 1)=0.0446 -> 予測クラス: 0 (確信度: 95.54%)
#   - LCS_Left_20211012_752_5-5.mp4: Logit: -3.5004 -> P(class 1)=0.0293 -> 予測クラス: 0 (確信度: 97.07%)
#   - ASD_Right_20190917_1986_3-3.mp4: Logit: -2.6573 -> P(class 1)=0.0655 -> 予測クラス: 0 (確信度: 93.45%)
#   - ASD_Left_20200127_1705_7-10.mp4: Logit: -4.4154 -> P(class 1)=0.0119 -> 予測クラス: 0 (確信度: 98.81%)
#
# --- [バッチ 422] 推論中 ---
#   - LCS_Left_20211012_748_3-5.mp4: Logit: -7.4016 -> P(class 1)=0.0006 -> 予測クラス: 0 (確信度: 99.94%)
#   - LCS_Left_20211012_742_3-5.mp4: Logit: -7.2065 -> P(class 1)=0.0007 -> 予測クラス: 0 (確信度: 99.93%)
#   - LCS_Left_20211012_752_2-5.mp4: Logit: -7.9156 -> P(class 1)=0.0004 -> 予測クラス: 0 (確信度: 99.96%)
#   - HipOA_Right_20180806_2_871_3-4.mp4: Logit: -6.5508 -> P(class 1)=0.0014 -> 予測クラス: 0 (確信度: 99.86%)
#
# --- [バッチ 423] 推論中 ---
#
# --- [バッチ 423] のCAMを生成・保存中... ---
#   - ASD_Left_20190917_1976_1-4.mp4: Logit: -0.2823 -> P(class 1)=0.4299 -> 予測クラス: 0 (確信度: 57.01%)
#   - HipOA_Right_20180806_2_889_3-4.mp4: Logit: -4.1248 -> P(class 1)=0.0159 -> 予測クラス: 0 (確信度: 98.41%)
#   - ASD_Right_20190917_2018_2-2.mp4: Logit: -2.9588 -> P(class 1)=0.0493 -> 予測クラス: 0 (確信度: 95.07%)
#   - ASD_Left_20200127_1695_5-10.mp4: Logit: -2.1275 -> P(class 1)=0.1064 -> 予測クラス: 0 (確信度: 89.36%)
#
# --- [バッチ 424] 推論中 ---
#   - ASD_Right_20200127_1712_6-6.mp4: Logit: -0.5893 -> P(class 1)=0.3568 -> 予測クラス: 0 (確信度: 64.32%)
#   - LCS_Right_20211012_779_3-3.mp4: Logit: -1.7115 -> P(class 1)=0.1530 -> 予測クラス: 0 (確信度: 84.70%)
#   - ASD_Left_20190819_1453_2-5.mp4: Logit: -0.7153 -> P(class 1)=0.3284 -> 予測クラス: 0 (確信度: 67.16%)
#   - ASD_Left_20190917_1980_1-4.mp4: Logit: 0.0830 -> P(class 1)=0.5207 -> 予測クラス: 1 (確信度: 52.07%)
#
# --- [バッチ 425] 推論中 ---
#   - ASD_Left_20200127_1689_2-9.mp4: Logit: -4.1368 -> P(class 1)=0.0157 -> 予測クラス: 0 (確信度: 98.43%)
#   - HipOA_Left_20180806_2_872_4-6.mp4: Logit: -5.0096 -> P(class 1)=0.0066 -> 予測クラス: 0 (確信度: 99.34%)
#   - DHS_Right_20200528_1137_1-7.mp4: Logit: -4.5807 -> P(class 1)=0.0101 -> 予測クラス: 0 (確信度: 98.99%)
#   - ASD_Left_20180625_1_1429_1-6.mp4: Logit: -5.9559 -> P(class 1)=0.0026 -> 予測クラス: 0 (確信度: 99.74%)
#
# --- [バッチ 426] 推論中 ---
#
# --- [バッチ 426] のCAMを生成・保存中... ---
#   - DHS_Left_20160927_1073_3-5.mp4: Logit: 3.7024 -> P(class 1)=0.9759 -> 予測クラス: 1 (確信度: 97.59%)
#   - ASD_Left_20200127_1707_8-10.mp4: Logit: 2.2420 -> P(class 1)=0.9040 -> 予測クラス: 1 (確信度: 90.40%)
#   - ASD_Right_20190819_1432_1-4.mp4: Logit: 1.7195 -> P(class 1)=0.8481 -> 予測クラス: 1 (確信度: 84.81%)
#   - HipOA_Right_20180806_2_893_3-4.mp4: Logit: 2.3203 -> P(class 1)=0.9105 -> 予測クラス: 1 (確信度: 91.05%)
#
# --- [バッチ 427] 推論中 ---
#   - ASD_Left_20200127_1699_2-9.mp4: Logit: 0.4737 -> P(class 1)=0.6163 -> 予測クラス: 1 (確信度: 61.63%)
#   - LCS_Right_20210706_841_4-4.mp4: Logit: -4.0621 -> P(class 1)=0.0169 -> 予測クラス: 0 (確信度: 98.31%)
#   - LCS_Left_20211012_748_1-5.mp4: Logit: -3.3109 -> P(class 1)=0.0352 -> 予測クラス: 0 (確信度: 96.48%)
#   - ASD_Left_20190917_1970_2-4.mp4: Logit: -5.2075 -> P(class 1)=0.0054 -> 予測クラス: 0 (確信度: 99.46%)
#
# --- [バッチ 428] 推論中 ---
#
# --- [バッチ 428] のCAMを生成・保存中... ---
#   - ASD_Left_20200127_1693_6-9.mp4: Logit: -4.6703 -> P(class 1)=0.0093 -> 予測クラス: 0 (確信度: 99.07%)
#   - ASD_Left_20200127_1719_2-10.mp4: Logit: -3.8577 -> P(class 1)=0.0207 -> 予測クラス: 0 (確信度: 97.93%)
#   - DHS_Right_20200528_1127_6-6.mp4: Logit: -3.2556 -> P(class 1)=0.0371 -> 予測クラス: 0 (確信度: 96.29%)
#   - ASD_Left_20200127_1731_9-10.mp4: Logit: -1.1685 -> P(class 1)=0.2371 -> 予測クラス: 0 (確信度: 76.29%)
#
# --- [バッチ 429] 推論中 ---
#   - ASD_Right_20200127_1682_3-6.mp4: Logit: -2.0761 -> P(class 1)=0.1114 -> 予測クラス: 0 (確信度: 88.86%)
#   - ASD_Left_20190819_1447_3-6.mp4: Logit: -2.6919 -> P(class 1)=0.0635 -> 予測クラス: 0 (確信度: 93.65%)
#   - HipOA_Right_20180806_2_865_2-4.mp4: Logit: 0.3698 -> P(class 1)=0.5914 -> 予測クラス: 1 (確信度: 59.14%)
#   - DHS_Right_20160927_1114_3-3.mp4: Logit: -2.4699 -> P(class 1)=0.0780 -> 予測クラス: 0 (確信度: 92.20%)
#
# --- [バッチ 430] 推論中 ---
#   - ASD_Left_20190917_2001_2-4.mp4: Logit: -2.2365 -> P(class 1)=0.0965 -> 予測クラス: 0 (確信度: 90.35%)
#   - ASD_Right_20180625_1_1420_4-4.mp4: Logit: -3.9529 -> P(class 1)=0.0188 -> 予測クラス: 0 (確信度: 98.12%)
#   - ASD_Left_20190819_1433_1-5.mp4: Logit: -3.3163 -> P(class 1)=0.0350 -> 予測クラス: 0 (確信度: 96.50%)
#
# --- 処理完了 ---
# 条件に一致した 1719 個の平均CAMを保存しました。
#
#
# ==================== 全ての推論結果 ====================
#                           Video Filename  prediction confidence  \
# 0        ASD_Right_20200127_1728_5-7.mp4           0     0.5945
# 1        ASD_Left_20200127_1685_4-10.mp4           1     0.6172
# 2         ASD_Left_20190917_1995_1-4.mp4           0     0.8213
# 3       ASD_Left_20180625_1_1427_2-6.mp4           1     0.7921
# 4     HipOA_Right_20180806_2_883_3-4.mp4           0     0.9917
# ...                                  ...         ...        ...
# 1714  HipOA_Right_20180806_2_865_2-4.mp4           1     0.5914
# 1715     DHS_Right_20160927_1114_3-3.mp4           0     0.9220
# 1716      ASD_Left_20190917_2001_2-4.mp4           0     0.9035
# 1717   ASD_Right_20180625_1_1420_4-4.mp4           0     0.9812
# 1718      ASD_Left_20190819_1433_1-5.mp4           0     0.9650
#
#      prob_for_class_1
# 0              0.4055
# 1              0.6172
# 2              0.1787
# 3              0.7921
# 4              0.0083
# ...               ...
# 1714           0.5914
# 1715           0.0780
# 1716           0.0965
# 1717           0.0188
# 1718           0.0350
#
# [1719 rows x 4 columns]

# %%
# 【分析用コード：修正版】
import numpy as np
import pandas as pd
import os
import glob

# --- 【設定】分析したいFoldを指定してください ---
TARGET_FOLD_TO_ANALYZE = TARGET_FOLD
CAM_OUTPUT_DIR = "/workspace/data/analysis_logs/fails_points/20251023/single_side/CAM"

# --- 1. 分析対象の.npyファイルをすべて取得 ---
fold_path = os.path.join(CAM_OUTPUT_DIR, TARGET_FOLD_TO_ANALYZE)
npy_files = glob.glob(os.path.join(fold_path, 'cam_average_*.npy')) # ファイル名を 'cam_average_' でフィルタリング

if not npy_files:
    print(f"エラー: '{fold_path}' に 'cam_average_*.npy' ファイルが見つかりませんでした。")
else:
    print(f"'{fold_path}' から {len(npy_files)} 個の平均CAMファイルを検出しました。分析を開始します...\n")
    
    all_results = []

    # --- 2. 各.npyファイルをループして分析 ---
    for file_path in npy_files:
        video_filename = os.path.basename(file_path).replace('cam_average_', '').replace('.npy', '')
        
        # 平均化されたCAMデータ(2D配列)を読み込み
        averaged_cam_data = np.load(file_path)
        
        # ヒートマップを3つの領域に分割
        height = averaged_cam_data.shape[0]
        one_third, two_thirds = height // 3, 2 * (height // 3)
        top_region = averaged_cam_data[0:one_third, :]
        middle_region = averaged_cam_data[one_third:two_thirds, :]
        bottom_region = averaged_cam_data[two_thirds:, :]
        
        # 各領域の注目度スコアを計算
        top_score, middle_score, bottom_score = top_region.sum(), middle_region.sum(), bottom_region.sum()
        total_score = top_score + middle_score + bottom_score
        
        scores = {"上部": top_score, "中部": middle_score, "下部": bottom_score}
        dominant_region = max(scores, key=scores.get) if total_score > 0 else "N/A"
        
        # 割合を計算
        if total_score > 0:
            top_percent = (top_score / total_score) * 100
            middle_percent = (middle_score / total_score) * 100
            bottom_percent = (bottom_score / total_score) * 100
        else:
            top_percent, middle_percent, bottom_percent = 0, 0, 0
        
        # 結果を辞書として保存
        result_dict = {
            'video_name': video_filename,
            'top_percent': round(top_percent, 2),
            'middle_percent': round(middle_percent, 2),
            'bottom_percent': round(bottom_percent, 2),
            'dominant_region': dominant_region
        }
        all_results.append(result_dict)

    # --- 3. 結果をPandas DataFrameに変換して表示 ---
    results_df = pd.DataFrame(all_results)
    print("--- 平均CAMの注目領域 分析結果 ---")
    display(results_df)
    
    # --- 4. Fold全体のサマリーを計算して表示 ---
    print(f"\n--- Fold '{TARGET_FOLD_TO_ANALYZE}' 全体のサマリー ---")
    dominant_summary = results_df['dominant_region'].value_counts()
    print("\n[主な注目領域の出現回数]")
    print(dominant_summary)
    average_attention = results_df[['top_percent', 'middle_percent', 'bottom_percent']].mean()
    print("\n[各領域の平均注目率 (%)]")
    print(average_attention)
# Out:
# '/workspace/data/analysis_logs/fails_points/20251023/single_side/CAM/fold3' から 1719 個の平均CAMファイルを検出しました。分析を開始します...
#
# --- 平均CAMの注目領域 分析結果 ---
#                                  video_name  top_percent  middle_percent  \
# 0        DHS_Right_20200528_1135_6-6_pred_0    98.529999        1.470000
# 1         ASD_Left_20190917_1960_3-4_pred_0    47.779999       52.220001
# 2        ASD_Right_20190819_1452_2-3_pred_0    33.009998       66.989998
# 3      HipOA_Left_20180806_2_856_1-5_pred_0    31.120001       68.879997
# 4        ASD_Right_20200127_1690_5-7_pred_0    51.810001       48.189999
# ...                                     ...          ...             ...
# 1714  HipOA_Right_20180806_2_887_2-4_pred_0    77.339996       22.660000
# 1715   HipOA_Left_20180806_2_884_6-6_pred_0    30.420000       69.580002
# 1716      ASD_Left_20190917_1972_1-4_pred_0    32.950001       66.980003
# 1717     DHS_Right_20160927_1070_2-3_pred_0    87.779999       12.220000
# 1718     ASD_Right_20200127_1732_2-7_pred_0    33.240002       66.760002
#
#       bottom_percent dominant_region
# 0               0.00              上部
# 1               0.00              中部
# 2               0.00              中部
# 3               0.00              中部
# 4               0.00              上部
# ...              ...             ...
# 1714            0.00              上部
# 1715            0.00              中部
# 1716            0.07              中部
# 1717            0.00              上部
# 1718            0.00              中部
#
# [1719 rows x 5 columns]
# --- Fold 'fold3' 全体のサマリー ---
#
# [主な注目領域の出現回数]
# dominant_region
# 中部     930
# 上部     606
# N/A    143
# 下部      40
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       46.465625
# middle_percent    42.347399
# bottom_percent     2.868185
# dtype: float64

# %%
import numpy as np
import pandas as pd
import os
import glob

# --- 【設定】---
# CAMデータが保存されている親ディレクトリ

# --- 1. すべてのFoldディレクトリを自動的に検出 ---
# CAM_OUTPUT_DIR内のサブディレクトリをFold名として取得
CAM_OUTPUT_DIR = '/workspace/data/analysis_logs/fails_points/20251023/single_front/CAM'
# is_dir()でディレクトリのみを対象とする
try:
    fold_dirs = [d.name for d in os.scandir(CAM_OUTPUT_DIR) if d.is_dir()]
    if not fold_dirs:
        print(f"エラー: '{CAM_OUTPUT_DIR}'内にFoldのサブディレクトリが見つかりませんでした。")
        # Exit the script if no folds are found
        # In a notebook, you might just print the error and stop.
    else:
        print(f"分析対象のFoldを検出しました: {sorted(fold_dirs)}\n")
except FileNotFoundError:
    print(f"エラー: 親ディレクトリ'{CAM_OUTPUT_DIR}'が見つかりません。")
    fold_dirs = []


# --- 2. 各ファイルの分析結果を保存するリストを準備 ---
all_results = []

# --- 3. 検出した各Foldをループして分析 ---
if fold_dirs:
    for fold_name in sorted(fold_dirs):
        fold_path = os.path.join(CAM_OUTPUT_DIR, fold_name)
        npy_files = glob.glob(os.path.join(fold_path, 'cam_average_*.npy'))
        
        if not npy_files:
            print(f"--- Fold '{fold_name}' には分析対象の.npyファイルがありませんでした。スキップします。 ---")
            continue
            
        print(f"--- Fold '{fold_name}' の分析中 ({len(npy_files)}個のファイル)... ---")

        for file_path in npy_files:
            video_filename = os.path.basename(file_path).replace('cam_average_', '').replace('.npy', '')
            averaged_cam_data = np.load(file_path)
            
            # --- 注目領域の計算 (変更なし) ---
            height = averaged_cam_data.shape[0]
            one_third, two_thirds = height // 3, 2 * (height // 3)
            top_region = averaged_cam_data[0:one_third, :]
            middle_region = averaged_cam_data[one_third:two_thirds, :]
            bottom_region = averaged_cam_data[two_thirds:, :]
            
            top_score, middle_score, bottom_score = top_region.sum(), middle_region.sum(), bottom_region.sum()
            total_score = top_score + middle_score + bottom_score
            
            scores = {"上部": top_score, "中部": middle_score, "下部": bottom_score}
            dominant_region = max(scores, key=scores.get) if total_score > 0 else "N/A"
            
            if total_score > 0:
                top_percent = (top_score / total_score) * 100
                middle_percent = (middle_score / total_score) * 100
                bottom_percent = (bottom_score / total_score) * 100
            else:
                top_percent, middle_percent, bottom_percent = 0, 0, 0
            
            # 結果を辞書として保存 (Fold名も追加)
            result_dict = {
                'fold': fold_name,
                'video_name': video_filename,
                'top_percent': round(top_percent, 2),
                'middle_percent': round(middle_percent, 2),
                'bottom_percent': round(bottom_percent, 2),
                'dominant_region': dominant_region
            }
            all_results.append(result_dict)

    # --- 4. 全Foldの結果を一つのDataFrameにまとめて表示 ---
    if all_results:
        results_df = pd.DataFrame(all_results)
        
        print("\n\n=============================================")
        print("=== 全Foldの詳細な分析結果（最初の15件を表示） ===")
        print("=============================================")
        display(results_df.head(3000))

        # --- 5. Foldごとのサマリーを計算して表示 ---
        print("\n\n============================")
        print("=== Foldごとのサマリー ===")
        print("============================")
        for fold_name in sorted(fold_dirs):
            fold_df = results_df[results_df['fold'] == fold_name]
            if not fold_df.empty:
                print(f"\n--- Fold '{fold_name}' ---")
                dominant_summary = fold_df['dominant_region'].value_counts()
                print("[主な注目領域の出現回数]")
                print(dominant_summary)
                average_attention = fold_df[['top_percent', 'middle_percent', 'bottom_percent']].mean()
                print("\n[各領域の平均注目率 (%)]")
                print(average_attention)
        
        # --- 6. 全Foldを統合した総合サマリーを表示 ---
        print("\n\n======================================")
        print("=== 全Fold統合 総合サマリー ===")
        print("======================================")
        
        # (1) 全体の主な注目領域の出現回数
        total_dominant_summary = results_df['dominant_region'].value_counts()
        print("\n[全体の主な注目領域の出現回数]")
        print(total_dominant_summary)
        
        # (2) 全体の各領域の平均注目度
        total_average_attention = results_df[['top_percent', 'middle_percent', 'bottom_percent']].mean()
        print("\n[全体の各領域の平均注目率 (%)]")
        print(total_average_attention)
        
        # (オプション) 全結果をCSVファイルとして保存
        # results_df.to_csv("cam_analysis_all_folds.csv", index=False)
        # print("\n全分析結果を 'cam_analysis_all_folds.csv' に保存しました。")
# Out:
# 分析対象のFoldを検出しました: ['fold0', 'fold1', 'fold2', 'fold3', 'fold4']
#
# --- Fold 'fold0' の分析中 (2364個のファイル)... ---
# --- Fold 'fold1' の分析中 (2896個のファイル)... ---
# --- Fold 'fold2' の分析中 (2473個のファイル)... ---
# --- Fold 'fold3' の分析中 (1719個のファイル)... ---
# --- Fold 'fold4' の分析中 (1762個のファイル)... ---
#
#
# =============================================
# === 全Foldの詳細な分析結果（最初の15件を表示） ===
# =============================================
#        fold                            video_name  top_percent  \
# 0     fold0   ASD_Left_20180521_2_1835_5-5_pred_0     0.340000
# 1     fold0    ASD_Right_20190917_1942_2-3_pred_1    61.849998
# 2     fold0      DHS_Left_20171127_994_3-6_pred_0    60.759998
# 3     fold0   ASD_Left_20190507_2_1610_3-6_pred_1     0.100000
# 4     fold0  ASD_Right_20190507_2_1645_1-4_pred_1     9.750000
# ...     ...                                   ...          ...
# 2995  fold1    DHS_Right_20200528_1137_5-7_pred_1    98.959999
# 2996  fold1   ASD_Left_20190507_2_1644_3-7_pred_0   100.000000
# 2997  fold1    ASD_Right_20171211_1456_6-7_pred_0    90.080002
# 2998  fold1    DHS_Right_20200528_1124_1-6_pred_0    99.959999
# 2999  fold1     ASD_Left_20210309_1905_2-8_pred_0    94.629997
#
#       middle_percent  bottom_percent dominant_region
# 0               0.98       98.680000              下部
# 1              18.15       20.010000              上部
# 2               8.87       30.370001              上部
# 3               0.74       99.169998              下部
# 4               0.84       89.410004              下部
# ...              ...             ...             ...
# 2995            1.04        0.000000              上部
# 2996            0.00        0.000000              上部
# 2997            9.92        0.000000              上部
# 2998            0.04        0.000000              上部
# 2999            5.37        0.000000              上部
#
# [3000 rows x 6 columns]
# ============================
# === Foldごとのサマリー ===
# ============================
#
# --- Fold 'fold0' ---
# [主な注目領域の出現回数]
# dominant_region
# 下部    1505
# 上部     844
# 中部      15
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       28.796760
# middle_percent     6.397673
# bottom_percent    64.805508
# dtype: float64
#
# --- Fold 'fold1' ---
# [主な注目領域の出現回数]
# dominant_region
# 上部     2479
# N/A     219
# 下部      166
# 中部       32
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       80.171153
# middle_percent     4.377624
# bottom_percent     7.889068
# dtype: float64
#
# --- Fold 'fold2' ---
# [主な注目領域の出現回数]
# dominant_region
# N/A    1081
# 上部      671
# 下部      498
# 中部      223
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       23.805063
# middle_percent    15.195520
# bottom_percent    17.287279
# dtype: float64
#
# --- Fold 'fold3' ---
# [主な注目領域の出現回数]
# dominant_region
# 中部     930
# 上部     606
# N/A    143
# 下部      40
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       46.465625
# middle_percent    42.347399
# bottom_percent     2.868185
# dtype: float64
#
# --- Fold 'fold4' ---
# [主な注目領域の出現回数]
# dominant_region
# 上部     922
# 下部     435
# 中部     306
# N/A     99
# Name: count, dtype: int64
#
# [各領域の平均注目率 (%)]
# top_percent       47.046839
# middle_percent    26.409387
# bottom_percent    20.925289
# dtype: float64
#
#
# ======================================
# === 全Fold統合 総合サマリー ===
# ======================================
#
# [全体の主な注目領域の出現回数]
# dominant_region
# 上部     5522
# 下部     2644
# N/A    1542
# 中部     1506
# Name: count, dtype: int64
#
# [全体の各領域の平均注目率 (%)]
# top_percent       46.539331
# middle_percent    16.471263
# bottom_percent    23.238735
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 # 動画ファイルを読み込むために必要

# show_cam_on_image 関数を再定義
# (以前の定義が別のセルにある場合は、そちらのインポートを使うこともできます)
def show_cam_on_image(img: np.ndarray,
                      mask: np.ndarray,
                      use_rgb: bool = False,
                      colormap: int = cv2.COLORMAP_JET) -> np.ndarray:
    """ This function overlays the CAM on the original image.
    Args:
        img (np.ndarray): The original image.
        mask (np.ndarray): The CAM mask.
        use_rgb (bool): Whether to convert the image to RGB.
        colormap (int): The colormap to use for the CAM mask.
    Returns:
        np.ndarray: The image with the CAM overlay.
    """
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), colormap)
    if use_rgb:
        heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)
    
    heatmap = np.float32(heatmap) / 255
    img = np.float32(img) / 255

    cam = heatmap + img
    cam = cam / np.max(cam)
    return np.uint8(255 * cam)


# --- 【設定】可視化したいファイルとフレームを指定してください ---
# 1. 可視化したい平均CAMの.npyファイルのパス
#    例: 'cam_outputs/fold0/cam_average_test_video_001.mp4_batch_1_vid_0.npy'
NPY_FILE_PATH = '/workspace/data/analysis_logs/fails_points/single_ap/CAM/fold0/cam_average_ASD_Left_20190507_1_1604_2-6.npy' # ★★★変更してください★★★

# 2. そのCAMデータに対応する元の動画ファイルへのパス
#    このパスは、CAM_OUTPUT_DIRではなく、元のデータセットのパスになります。
#    例: '/path/to/your/dataset/test_video_001.mp4'
ORIGINAL_VIDEO_PATH = '/workspace/data/out_dir_ver2_classified_front/fold0/val/ASD/ASD_Left_20190507_1_1604_2-6.mp4' # ★★★変更してください★★★

# 3. 元の動画の何フレーム目を背景画像として使うか (1から8)
#    (平均CAMなのでどのフレームを選んでも意味は同じですが、代表として)
BACKGROUND_FRAME_INDEX = 4 # 1から8の範囲で指定


# --- 1. ファイルの存在確認 ---
if not os.path.exists(NPY_FILE_PATH):
    print(f"エラー: CAMファイルが見つかりません。パスを確認してください: {NPY_FILE_PATH}")
elif not os.path.exists(ORIGINAL_VIDEO_PATH):
    print(f"エラー: 元の動画ファイルが見つかりません。パスを確認してください: {ORIGINAL_VIDEO_PATH}")
else:
    try:
        # --- 2. CAMデータを読み込み ---
        heatmap_data = np.load(NPY_FILE_PATH)
        print(f"CAMファイルを読み込みました。形状: {heatmap_data.shape}")

        # --- 3. 元の動画ファイルを読み込み、指定フレームを抽出 ---
        cap = cv2.VideoCapture(ORIGINAL_VIDEO_PATH)
        if not cap.isOpened():
            raise IOError(f"動画ファイルを開けませんでした: {ORIGINAL_VIDEO_PATH}")

        total_frames_in_video = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        if total_frames_in_video < BACKGROUND_FRAME_INDEX:
            raise ValueError(f"指定されたフレーム {BACKGROUND_FRAME_INDEX} は動画の総フレーム数 {total_frames_in_video} を超えています。")

        # 指定フレームまで読み飛ばし
        cap.set(cv2.CAP_PROP_POS_FRAMES, BACKGROUND_FRAME_INDEX - 1) 
        ret, frame = cap.read() # フレームを読み込み
        cap.release()

        if not ret:
            raise IOError(f"フレーム {BACKGROUND_FRAME_INDEX} を読み込めませんでした。")
        
        # OpenCVはBGRで読み込むのでRGBに変換
        original_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        print(f"元の画像フレームを読み込みました。形状: {original_image.shape}")

        # --- 4. 元の画像とCAMのサイズを合わせる ---
        # Grad-CAMの出力サイズは通常、モデルの最終層の特徴マップのサイズ（例: 7x7）です。
        # これを元の画像サイズにリサイズする必要があります。
        cam_resized = cv2.resize(heatmap_data, 
                                 (original_image.shape[1], original_image.shape[0]), 
                                 interpolation=cv2.INTER_LINEAR)
        
        # cam_resizedの値が0-1の範囲であることを確認
        cam_resized = (cam_resized - cam_resized.min()) / (cam_resized.max() - cam_resized.min() + 1e-8) # ゼロ除算回避

        # --- 5. show_cam_on_image 関数を使って重ね合わせ ---
        overlayed_image = show_cam_on_image(original_image, cam_resized, use_rgb=True, colormap=cv2.COLORMAP_JET)

        # --- 6. 結果を表示 ---
        plt.figure(figsize=(10, 8))
        plt.imshow(overlayed_image)
        
        # タイトルを設定
        file_name = os.path.basename(NPY_FILE_PATH).replace('.npy', '')
        plt.title(f'Overlayed CAM: {file_name} on Frame {BACKGROUND_FRAME_INDEX}')
        
        # 軸の目盛りを非表示にする
        plt.axis('off')
        
        plt.show()

    except Exception as e:
        print(f"エラーが発生しました。詳細: {e}")

# %% [markdown]
# # Grad CAM pytorch
# use pytorch_grad_cam api to make visilization.

# %%
#   {
#      'video': <video_tensor>,     # Shape: (C, T, H, W)
#      'audio': <audio_tensor>,     # Shape: (S)
#      'label': <action_label>,     # Integer defining class annotation
#      'video_name': <video_path>,  # Video file path stem
#      'video_index': <video_id>,   # index of video used by sampler
#      'clip_index': <clip_id>      # index of clip sampled within video
#   }
batch = next(iter(test_data))
video = batch['video'].detach() # b, c, t, h, w
label = batch['label'].detach() # b, class num
print("video_path:", batch['video_name'][3])
print("label:", batch['label'])


i=3
input_tensor = video[i].unsqueeze(dim=0).cuda()
inp_label = label[i]

video.shape, label.shape, input_tensor.shape, inp_label

# %%
from pytorch_grad_cam import GradCAM, HiResCAM, FullGrad, GradCAMPlusPlus, AblationCAM, ScoreCAM, LayerCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# guided grad cam method
target_layer = [model.model.blocks[-2].res_blocks[-1]]
# target_layer = [ model.model.blocks[-2]]

cam = LayerCAM(model, target_layer)
y_hat = model.model(video)
y_hat_sigmoid = torch.sigmoid(y_hat)
pred_labels = torch.where(y_hat_sigmoid >= 0.5, torch.tensor(1), torch.tensor(0))
print(pred_labels)
out_label = pred_labels[0]
print(out_label)

targets = [ClassifierOutputTarget(-1)]

grayscale_cam = cam(input_tensor, aug_smooth=True, eigen_smooth=True)

type(grayscale_cam), grayscale_cam.shape

# %%
inp_tensor = input_tensor.squeeze().permute(1,2,3,0)[2].cpu().detach().numpy()
inp_tensor.shape, type(inp_tensor), grayscale_cam.shape

# %%
cam_map = grayscale_cam.mean(axis=1).squeeze()
# cam_map = grayscale_cam[:,:,:,0].squeeze()
cam_map = np.expand_dims(cam_map, 2)

cam_map.shape, type(cam_map), cam_map

# %%
import matplotlib.pyplot as plt 

plt.imshow(cam_map)

# %%
# use captum visual method
figure, axis = viz.visualize_image_attr_multiple(
        cam_map,
        inp_tensor,
        methods=['original_image', 'blended_heat_map'],
        signs=['all', 'positive'],
        show_colorbar=True,
        outlier_perc=1, 
        cmap='jet',
        titles = ['original image', 'GradCAM++, true label %s, pred label %s' % (int(inp_label), int(out_label))]
    )

# %%
input_tensor.shape

# %%
from torchvision.io import write_video

write_video('1s.mp4', video_array=input_tensor.squeeze().permute(1,2,3,0).detach().cpu(), fps=10)

# %%
batch['video_name'][0]
